# %%
# Importing necessary libraries from the NLTK toolkit
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize  # For tokenizing text into words and sentences

# Importing stopwords from NLTK to remove common words that add little value
from nltk.corpus import stopwords

# Downloading required NLTK datasets
nltk.download('punkt')  # Tokenizer models for sentence and word tokenization
nltk.download('punkt_tab')  # Optional: Extra support for tokenization
nltk.download('stopwords')  # Predefined stopword lists for various languages

! pip install pandas
# Importing pandas for working with data in tabular format 
import pandas as pd
# Loading the CSV dataset into a DataFrame
df = pd.read_csv("data.csv")  # CSV contains columns like 'Message' and labels indicating spam or not

# Step to clean the text data:
# - Removing punctuation, special characters, and multiple spaces
# - Preparing data for tokenization and further text processing
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Requirement already satisfied: pandas in c:\users\varun\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\varun\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varun\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\varun\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\varun\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
df
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5842 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')

import re  # Regular expressions for text cleaning

cleaned = []  # List to store cleaned text
for text in df['Sentence']:  # Looping through each message in the 'Message' column
    cleaned_text = re.sub(r'[^\w\s]', '', text)  # Removing all characters except words and spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replacing multiple spaces with a single space
    cleaned_data = cleaned_text.strip()  # Stripping leading and trailing whitespace
    cleaned.append(cleaned_data)  # Adding the cleaned text to the list

# Tokenizing the cleaned text into words
# This step splits each cleaned text into a list of words
tokens = [word_tokenize(x) for x in cleaned]

# Removing stopwords from tokenized words
# Stopwords are commonly used words like "is", "the", "and", etc., which are removed to reduce noise
stop = set(stopwords.words('english'))  # Fetching the list of English stopwords
stop_token = []  # List to store stopword-removed tokens
for k in range(len(df['Sentence'])):  # Loop through the tokenized text
    p = [i for i in tokens[k] if i not in stop]  # Filter out tokens that are in the stopword list
    stop_token.append(p)  # Append the filtered tokens to the list

# Summary of steps:
# 1. Dataset is downloaded and loaded into a pandas DataFrame.
# 2. Text messages are cleaned by removing punctuation, special characters, and extra spaces.
# 3. The cleaned text is tokenized into words.
# 4. Stopwords are removed to focus on meaningful words.
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\VIGNESH
# [nltk_data]     VARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokens
# Out:
# [['The',
#   'GeoSolutions',
#   'technology',
#   'will',
#   'leverage',
#   'Benefon',
#   's',
#   'GPS',
#   'solutions',
#   'by',
#   'providing',
#   'Location',
#   'Based',
#   'Search',
#   'Technology',
#   'a',
#   'Communities',
#   'Platform',
#   'location',
#   'relevant',
#   'multimedia',
#   'content',
#   'and',
#   'a',
#   'new',
#   'and',
#   'powerful',
#   'commercial',
#   'model'],
#  ['ESI',
#   'on',
#   'lows',
#   'down',
#   '150',
#   'to',
#   '250',
#   'BK',
#   'a',
#   'real',
#   'possibility'],
#  ['For',
#   'the',
#   'last',
#   'quarter',
#   'of',
#   '2010',
#   'Componenta',
#   's',
#   'net',
#   'sales',
#   'doubled',
#   'to',
#   'EUR131m',
#   'from',
#   'EUR76m',
#   'for',
#   'the',
#   'same',
#   'period',
#   'a',
#   'year',
#   'earlier',
#   'while',
#   'it',
#   'moved',
#   'to',
#   'a',
#   'zero',
#   'pretax',
#   'profit',
#   'from',
#   'a',
#   'pretax',
#   'loss',
#   'of',
#   'EUR7m'],
#  ['According',
#   'to',
#   'the',
#   'FinnishRussian',
#   'Chamber',
#   'of',
#   'Commerce',
#   'all',
#   'the',
#   'major',
#   'construction',
#   'companies',
#   'of',
#   'Finland',
#   'are',
#   'operating',
#   'in',
#   'Russia'],
#  ['The',
#   'Swedish',
#   'buyout',
#   'firm',
#   'has',
#   'sold',
#   'its',
#   'remaining',
#   '224',
#   'percent',
#   'stake',
#   'almost',
#   'eighteen',
#   'months',
#   'after',
#   'taking',
#   'the',
#   'company',
#   'public',
#   'in',
#   'Finland'],
#  ['SPY', 'wouldnt', 'be', 'surprised', 'to', 'see', 'a', 'green', 'close'],
#  ['Shells',
#   '70',
#   'Billion',
#   'BG',
#   'Deal',
#   'Meets',
#   'Shareholder',
#   'Skepticism'],
#  ['SSH',
#   'COMMUNICATIONS',
#   'SECURITY',
#   'CORP',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   'OCTOBER',
#   '14',
#   '2008',
#   'AT',
#   '245',
#   'PM',
#   'The',
#   'Company',
#   'updates',
#   'its',
#   'full',
#   'year',
#   'outlook',
#   'and',
#   'estimates',
#   'its',
#   'results',
#   'to',
#   'remain',
#   'at',
#   'loss',
#   'for',
#   'the',
#   'full',
#   'year'],
#  ['Kone',
#   's',
#   'net',
#   'sales',
#   'rose',
#   'by',
#   'some',
#   '14',
#   'yearonyear',
#   'in',
#   'the',
#   'first',
#   'nine',
#   'months',
#   'of',
#   '2008'],
#  ['The',
#   'Stockmann',
#   'department',
#   'store',
#   'will',
#   'have',
#   'a',
#   'total',
#   'floor',
#   'space',
#   'of',
#   'over',
#   '8000',
#   'square',
#   'metres',
#   'and',
#   'Stockmann',
#   's',
#   'investment',
#   'in',
#   'the',
#   'project',
#   'will',
#   'have',
#   'a',
#   'price',
#   'tag',
#   'of',
#   'about',
#   'EUR',
#   '12',
#   'million'],
#  ['Circulation',
#   'revenue',
#   'has',
#   'increased',
#   'by',
#   '5',
#   'in',
#   'Finland',
#   'and',
#   '4',
#   'in',
#   'Sweden',
#   'in',
#   '2008'],
#  ['SAP',
#   'Q1',
#   'disappoints',
#   'as',
#   'software',
#   'licenses',
#   'down',
#   'Real',
#   'problem',
#   'Cloud',
#   'growth',
#   'trails',
#   'MSFT',
#   'ORCL',
#   'GOOG',
#   'CRM',
#   'ADBE',
#   'httpstcojNDphllzq5'],
#  ['The',
#   'subdivision',
#   'made',
#   'sales',
#   'revenues',
#   'last',
#   'year',
#   'of',
#   'EUR',
#   '4807',
#   'million',
#   'EUR',
#   '4149',
#   'million',
#   'in',
#   '2008',
#   'and',
#   'operating',
#   'profits',
#   'of',
#   'EUR',
#   '445',
#   'million',
#   'EUR',
#   '74',
#   'million'],
#  ['Viking', 'Line', 'has', 'canceled', 'some', 'services'],
#  ['Ahlstrom',
#   'Corporation',
#   'STOCK',
#   'EXCHANGE',
#   'ANNOUNCEMENT',
#   '722007',
#   'at',
#   '1030',
#   'A',
#   'total',
#   'of',
#   '56955',
#   'new',
#   'shares',
#   'of',
#   'Ahlstrom',
#   'Corporation',
#   'have',
#   'been',
#   'subscribed',
#   'with',
#   'option',
#   'rights',
#   'under',
#   'the',
#   'company',
#   's',
#   'stock',
#   'option',
#   'programs',
#   'I',
#   '2001',
#   'and',
#   'II',
#   '2001'],
#  ['FB', 'gone', 'green', 'on', 'day'],
#  ['MSFT',
#   'SQL',
#   'Server',
#   'revenue',
#   'grew',
#   'doubledigit',
#   'with',
#   'SQL',
#   'Server',
#   'Premium',
#   'revenue',
#   'growing',
#   'over',
#   '30',
#   'httpstkscoir2F'],
#  ['According',
#   'to',
#   'Lñnnen',
#   'Tehtaat',
#   's',
#   'CEO',
#   'Matti',
#   'Karppinen',
#   'the',
#   'company',
#   'aims',
#   'to',
#   'deliver',
#   'fish',
#   'products',
#   'to',
#   'its',
#   'customers',
#   'a',
#   'day',
#   'earlier',
#   'than',
#   'it',
#   'currently',
#   'does'],
#  ['The',
#   'company',
#   's',
#   'share',
#   'is',
#   'quoted',
#   'on',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'Rautaruukki',
#   'Oyj',
#   'RTRKS'],
#  ['Elcoteq',
#   'SE',
#   'is',
#   'listed',
#   'on',
#   'the',
#   'Nasdaq',
#   'OMX',
#   'Helsinki',
#   'Ltd'],
#  ['Two',
#   'of',
#   'these',
#   'contracts',
#   'are',
#   'for',
#   'turntable',
#   'anode',
#   'vibrocompactors',
#   'that',
#   'will',
#   'be',
#   'delivered',
#   'to',
#   'Gansu',
#   'Hualu',
#   'Aluminum',
#   'Co',
#   'Ltd',
#   'and',
#   'another',
#   'unnamed',
#   'costumer'],
#  ['Aviva',
#   'Friends',
#   'Life',
#   'top',
#   'forecasts',
#   'ahead',
#   'of',
#   '56',
#   'billion',
#   'pound',
#   'merger'],
#  ['In',
#   'stead',
#   'of',
#   'being',
#   'based',
#   'on',
#   'a',
#   'soft',
#   'drink',
#   'as',
#   'is',
#   'usual',
#   'the',
#   'Teho',
#   'energy',
#   'drink',
#   'is',
#   'made',
#   'with',
#   'fresh',
#   'water'],
#  ['The',
#   'company',
#   'plans',
#   'to',
#   'increase',
#   'the',
#   'unit',
#   's',
#   'specialist',
#   'staff',
#   'to',
#   'several',
#   'dozen',
#   'depending',
#   'on',
#   'the',
#   'market',
#   'situation',
#   'during',
#   '2010'],
#  ['The',
#   'company',
#   'closed',
#   'last',
#   'year',
#   'with',
#   'a',
#   'turnover',
#   'of',
#   'about',
#   'four',
#   'million',
#   'euros'],
#  ['Shire',
#   'CEO',
#   'steps',
#   'up',
#   'drive',
#   'to',
#   'get',
#   'Baxalta',
#   'board',
#   'talking'],
#  ['Costco',
#   'A',
#   'Premier',
#   'Retail',
#   'Dividend',
#   'Play',
#   'httpstcoFa5cnh2t0t',
#   'COST'],
#  ['The',
#   'fivestorey',
#   'ecoefficient',
#   'building',
#   'will',
#   'have',
#   'a',
#   'gross',
#   'floor',
#   'area',
#   'of',
#   'about',
#   '15000',
#   'sq',
#   'm',
#   'It',
#   'will',
#   'also',
#   'include',
#   'apartments'],
#  ['The',
#   'first',
#   'installment',
#   'of',
#   'the',
#   'Cinema',
#   'Series',
#   'concludes',
#   'with',
#   'a',
#   'profile',
#   'of',
#   'Finnish',
#   'inventor',
#   'Olavi',
#   'Linden',
#   'whose',
#   'personal',
#   'artistic',
#   'journey',
#   'and',
#   'work',
#   'at',
#   'Fiskars',
#   'has',
#   'led',
#   'to',
#   'dozens',
#   'of',
#   'design',
#   'awards'],
#  ['All', 'are', 'welcome'],
#  ['Stockmann',
#   'and',
#   'Swedish',
#   'sector',
#   'company',
#   'AB',
#   'Lindex',
#   'entered',
#   'into',
#   'an',
#   'agreement',
#   'on',
#   'September',
#   '30',
#   '2007',
#   'whereby',
#   'Stockmann',
#   'or',
#   'a',
#   'whollyowned',
#   'subsidiary',
#   'of',
#   'it',
#   'will',
#   'make',
#   'a',
#   'public',
#   'tender',
#   'offer',
#   'for',
#   'all',
#   'of',
#   'Lindex',
#   's',
#   'issued',
#   'shares'],
#  ['HUHTAMAKI',
#   'OYJ',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   '1692008',
#   'AT',
#   '1332',
#   'Huhtamaki',
#   's',
#   'Capital',
#   'Markets',
#   'Day',
#   'for',
#   'institutional',
#   'investors',
#   'and',
#   'analysts',
#   'is',
#   'held',
#   'in',
#   'Espoo',
#   'September',
#   '16',
#   '2008',
#   'starting',
#   'at',
#   '1330',
#   'pm',
#   'Finnish',
#   'time'],
#  ['We',
#   'are',
#   'pleased',
#   'to',
#   'welcome',
#   'Tapeks',
#   'Noma',
#   'into',
#   'Cramo',
#   'group'],
#  ['Profit', 'before', 'taxes', 'was', 'EUR', '1059', '827', 'million'],
#  ['Royal',
#   'Dutch',
#   'Shell',
#   'to',
#   'Buy',
#   'BG',
#   'Group',
#   'for',
#   'Nearly',
#   '70',
#   'Billion'],
#  ['FinancialWire',
#   'tm',
#   'is',
#   'not',
#   'a',
#   'press',
#   'release',
#   'service',
#   'and',
#   'receives',
#   'no',
#   'compensation',
#   'for',
#   'its',
#   'news',
#   'opinions',
#   'or',
#   'distributions'],
#  ['ASSA',
#   'ABLOY',
#   'Kaupthing',
#   'Bank',
#   'gave',
#   'a',
#   'neutral',
#   'recommendation',
#   'and',
#   'a',
#   'share',
#   'price',
#   'target',
#   'of',
#   '174',
#   'crowns',
#   '247',
#   '19',
#   'euro',
#   'on',
#   'Swedish',
#   'lock',
#   'maker',
#   'Assa',
#   'Abloy',
#   'AB'],
#  ['The',
#   'item',
#   'included',
#   'restructuring',
#   'costs',
#   'of',
#   'EUR1',
#   '6',
#   'm',
#   'while',
#   'a',
#   'year',
#   'earlier',
#   'they',
#   'were',
#   'EUR13',
#   '1',
#   'm',
#   'Diluted',
#   'EPS',
#   'stood',
#   'at',
#   'EUR0',
#   '3',
#   'versus',
#   'a',
#   'loss',
#   'per',
#   'share',
#   'of',
#   'EUR',
#   '01'],
#  ['In',
#   '2005',
#   'the',
#   'bank',
#   'posted',
#   'a',
#   'net',
#   'profit',
#   'of',
#   'Lt',
#   '82',
#   'mn'],
#  ['AAPL',
#   'afternoon',
#   'selloff',
#   'as',
#   'usual',
#   'will',
#   'be',
#   'brutal',
#   'get',
#   'ready',
#   'to',
#   'lose',
#   'a',
#   'ton',
#   'of',
#   'money'],
#  ['TSLA',
#   'recalling',
#   'pretty',
#   'much',
#   'every',
#   'single',
#   'model',
#   'X',
#   'cnnbrk',
#   'got',
#   'to',
#   'short',
#   'that',
#   'even',
#   'at',
#   'work',
#   'you',
#   'jump',
#   'in',
#   'money',
#   'trade'],
#  ['Dolce',
#   'Gabbana',
#   'has',
#   'asked',
#   'the',
#   'European',
#   'Union',
#   'to',
#   'declare',
#   'Marimekko',
#   'Corporation',
#   's',
#   'Unikko',
#   'floral',
#   'pattern',
#   'trademark',
#   'invalid',
#   'in',
#   'a',
#   'continuing',
#   'dispute',
#   'between',
#   'the',
#   'two',
#   'companies'],
#  ['InterContinental',
#   'Hotels',
#   'firstquarter',
#   'global',
#   'room',
#   'revenue',
#   'lags',
#   'estimates'],
#  ['According',
#   'to',
#   'Finnish',
#   'pension',
#   'insurance',
#   'company',
#   'Varma',
#   'Varma',
#   'was',
#   'the',
#   'recipient',
#   'of',
#   'over',
#   'two',
#   'thirds',
#   'of',
#   'the',
#   'revenue',
#   'of',
#   'the',
#   'earningsrelated',
#   'pension',
#   'cover',
#   'that',
#   'was',
#   'under',
#   'competitive',
#   'tendering',
#   'in',
#   'Finland'],
#  ['A',
#   'portion',
#   '125',
#   'million',
#   'will',
#   'be',
#   'recorded',
#   'as',
#   'part',
#   'of',
#   'its',
#   'winnings',
#   'in',
#   'a',
#   'prior',
#   'patent',
#   'dispute',
#   'with',
#   'Finnish',
#   'phone',
#   'maker',
#   'Nokia',
#   'Oyj'],
#  ['LG',
#   'still',
#   'paying',
#   'price',
#   'for',
#   'dividend',
#   'cut',
#   'during',
#   'crisis',
#   'chief',
#   'says'],
#  ['The',
#   'volume',
#   'of',
#   'investments',
#   'in',
#   'the',
#   'two',
#   'phases',
#   'of',
#   'the',
#   'project',
#   'is',
#   'estimated',
#   'at',
#   'USD',
#   '300mn',
#   'EUR',
#   '21503',
#   'mn'],
#  ['Russia',
#   'accounted',
#   'for',
#   '9',
#   'of',
#   'the',
#   'Lagardere',
#   'magazine',
#   'division',
#   's',
#   'revenue',
#   'or',
#   'EUR',
#   '11440',
#   'mn',
#   'USD',
#   '14811',
#   'mn',
#   'in',
#   '2009',
#   'the',
#   'USA',
#   'for',
#   '18'],
#  ['The',
#   'company',
#   'also',
#   'estimates',
#   'the',
#   'already',
#   'carried',
#   'out',
#   'investments',
#   'to',
#   'lead',
#   'to',
#   'an',
#   'increase',
#   'in',
#   'its',
#   'net',
#   'sales',
#   'for',
#   '2010',
#   'from',
#   '2009',
#   'when',
#   'they',
#   'reached',
#   'EUR',
#   '1417',
#   'million'],
#  ['Profit', 'of', 'the', 'accounting', 'period', 'was', 'EUR', '03', 'mn'],
#  ['The',
#   'six',
#   'breweries',
#   'recorded',
#   'a',
#   '52',
#   'percent',
#   'growth',
#   'in',
#   'domestic',
#   'beer',
#   'sales',
#   'last',
#   'year',
#   'to',
#   '27021',
#   'million',
#   'liters',
#   'from',
#   '25688',
#   'million',
#   'liters',
#   'sold',
#   'in',
#   '2005'],
#  ['In',
#   'AugustOctober',
#   '2010',
#   'the',
#   'company',
#   's',
#   'result',
#   'before',
#   'taxes',
#   'totalled',
#   'EUR',
#   '96',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '05',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2009'],
#  ['Systeemitiimi',
#   's',
#   'sales',
#   'and',
#   'project',
#   'resources',
#   'will',
#   'also',
#   'be',
#   'strengthened',
#   'director',
#   'Paul',
#   'Skogberg',
#   'said'],
#  ['Tesco', 'share', 'price', 'jumps', 'as', 'Q3', 'sales', 'top', 'estimates'],
#  ['The', 'fine', 'print', 'is', 'here'],
#  ['The',
#   'price',
#   'for',
#   'logs',
#   'has',
#   'clearly',
#   'improved',
#   'from',
#   '2009',
#   'and',
#   'also',
#   'the',
#   'price',
#   'of',
#   'pulpwood',
#   'has',
#   'gone',
#   'up'],
#  ['Thus',
#   'SysOpen',
#   'Digia',
#   'has',
#   'in',
#   'accordance',
#   'with',
#   'Chapter',
#   '14',
#   'Section',
#   '21',
#   'of',
#   'the',
#   'Finnish',
#   'Companies',
#   'Act',
#   '2991978',
#   '734',
#   'obtained',
#   'title',
#   'to',
#   'all',
#   'the',
#   'shares',
#   'of',
#   'Sentera',
#   'that',
#   'are',
#   'to',
#   'be',
#   'redeemed'],
#  ['Diluted',
#   'earnings',
#   'per',
#   'share',
#   'EPS',
#   'fell',
#   'to',
#   'EUR',
#   '063',
#   'from',
#   'EUR',
#   '171'],
#  ['At',
#   '337',
#   'pm',
#   'Eastern',
#   'time',
#   'a',
#   'block',
#   'of',
#   '2400',
#   'contracts',
#   'changed',
#   'hands',
#   'at',
#   'a',
#   'bid',
#   'price',
#   'of',
#   '045'],
#  ['Some',
#   'of',
#   'the',
#   'most',
#   'recent',
#   'technology',
#   'deliveries',
#   'include',
#   'refinery',
#   'technology',
#   'to',
#   'Anrak',
#   'Aluminium',
#   'an',
#   'iron',
#   'ore',
#   'pelletizing',
#   'plant',
#   'to',
#   'Tata',
#   'Steel',
#   'and',
#   'iron',
#   'ore',
#   'sintering',
#   'plants',
#   'to',
#   'Bhushan',
#   'Steel'],
#  ['VIPS',
#   'similar',
#   'pattern',
#   'like',
#   'beginning',
#   'of',
#   'May',
#   'Did',
#   'u',
#   'sell',
#   'Same',
#   'nowwill',
#   'go',
#   'up',
#   'much',
#   'higher',
#   'after',
#   'this',
#   'drop'],
#  ['The',
#   'firm',
#   'generated',
#   'sales',
#   'of',
#   '187',
#   'mln',
#   'eur',
#   'in',
#   '2005'],
#  ['Stora',
#   'Enso',
#   'has',
#   'also',
#   'had',
#   'meetings',
#   'with',
#   'the',
#   'labor',
#   'authorities',
#   'Employment',
#   'and',
#   'Economic',
#   'Development',
#   'Centres',
#   'and',
#   'representatives',
#   'of',
#   'the',
#   'government',
#   'in',
#   'order',
#   'to',
#   'find',
#   'solutions'],
#  ['AstraZeneca', 'profit', 'down', 'as', 'sales', 'of', 'stalwarts', 'fade'],
#  ['RT',
#   'andrewnyquist',
#   'Chartology',
#   'Yahoo',
#   'httpstksco1itr',
#   'YHOO',
#   'Crazy',
#   'looking',
#   'chart',
#   'but',
#   'nearing',
#   'breakout',
#   'resistance',
#   'line'],
#  ['Most',
#   'bullish',
#   'stocks',
#   'on',
#   'Twitter',
#   'during',
#   'this',
#   'dip',
#   'YHOO',
#   'GDX',
#   'GOOGL',
#   'STZ',
#   'GOLD',
#   'EW',
#   'VZ',
#   'CELG',
#   'SBUX',
#   'SCTY',
#   'more',
#   'httpstcoiuZJelfwt3'],
#  ['Finnish',
#   'GeoSentric',
#   's',
#   'net',
#   'sales',
#   'decreased',
#   'to',
#   'EUR',
#   '939000',
#   'in',
#   'JanuaryMarch',
#   '2009'],
#  ['Cohen',
#   'Steers',
#   'Inc',
#   '5',
#   '534',
#   '626',
#   'shares',
#   'representing',
#   '4985',
#   'of',
#   'the',
#   'share',
#   'capital',
#   'and',
#   'voting',
#   'rights'],
#  ['More',
#   'staff',
#   'has',
#   'been',
#   'recruited',
#   'in',
#   'Japan',
#   'to',
#   'further',
#   'complement',
#   'its',
#   'network',
#   'of',
#   'close',
#   'to',
#   '50',
#   'service',
#   'locations',
#   'in',
#   'more',
#   'than',
#   '20',
#   'countries',
#   'worldwide'],
#  ['Paper',
#   'companies',
#   'were',
#   'in',
#   'negative',
#   'territories',
#   'with',
#   'Stora',
#   'Enso',
#   'R',
#   'shedding',
#   '162',
#   'pct',
#   'to',
#   '1273',
#   'eur',
#   'UPMKymmene',
#   'down',
#   '080',
#   'pct',
#   'at',
#   '1864',
#   'eur',
#   'and',
#   'Mreal',
#   'B',
#   '018',
#   'pct',
#   'lower',
#   'at',
#   '557',
#   'eur'],
#  ['KaukoTelko',
#   's',
#   'centralized',
#   'administration',
#   'will',
#   'be',
#   'dissolved',
#   'and',
#   'appropriate',
#   'parts',
#   'of',
#   'it',
#   'will',
#   'be',
#   'transferred',
#   'to',
#   'operating',
#   'activities',
#   'and',
#   'Group',
#   'administration',
#   'by',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year'],
#  ['Operating',
#   'profit',
#   'for',
#   'the',
#   'quarter',
#   'AprilJune',
#   '2006',
#   'amounted',
#   'to',
#   'EUR182',
#   '2',
#   'm',
#   'on',
#   'sales',
#   'of',
#   'EUR3',
#   '62',
#   'bn'],
#  ['Atria',
#   'chose',
#   'the',
#   'DeLight',
#   'to',
#   'attract',
#   'consumers',
#   'in',
#   'the',
#   '2545',
#   'age',
#   'group',
#   'to',
#   'its',
#   'Atria',
#   'Fresh',
#   'range',
#   'of',
#   'microwaveable',
#   'meals'],
#  ['Finnish',
#   'IT',
#   'solutions',
#   'provider',
#   'Affecto',
#   'Oyj',
#   'HEL',
#   'AFE1V',
#   'said',
#   'today',
#   'its',
#   'slipped',
#   'to',
#   'a',
#   'net',
#   'loss',
#   'of',
#   'EUR',
#   '115000',
#   'USD',
#   '152000',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010',
#   'from',
#   'a',
#   'profit',
#   'of',
#   'EUR',
#   '845000',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'a',
#   'year',
#   'earlier'],
#  ['US',
#   'sanctions',
#   'put',
#   'GazpromShell',
#   'alliance',
#   'plans',
#   'in',
#   'jeopardy'],
#  ['Profit',
#   'for',
#   'the',
#   'period',
#   'was',
#   'EUR',
#   '109',
#   'mn',
#   'down',
#   'from',
#   'EUR',
#   '143',
#   'mn',
#   'in',
#   '2009'],
#  ['Profit',
#   'for',
#   'the',
#   'period',
#   'was',
#   'EUR',
#   '59',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '13',
#   'mn'],
#  ['Operating',
#   'profit',
#   'fell',
#   'to',
#   'EUR',
#   '203',
#   'mn',
#   'from',
#   'EUR',
#   '742',
#   'mn',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2008'],
#  ['However',
#   'sales',
#   'returned',
#   'to',
#   'growth',
#   'in',
#   'AprilJune',
#   '2010',
#   'CEO',
#   'Pekka',
#   'Eloholma',
#   'said'],
#  ['Operating',
#   'profit',
#   'totaled',
#   'EUR',
#   '186',
#   'mn',
#   'or',
#   '83',
#   'of',
#   'net',
#   'sales'],
#  ['Changes',
#   'in',
#   'the',
#   'market',
#   'situation',
#   'and',
#   'tougher',
#   'price',
#   'competition',
#   'have',
#   'substantially',
#   'reduced',
#   'demand',
#   'for',
#   'bread',
#   'packaging',
#   'manufactured',
#   'at',
#   'the',
#   'Kauhava',
#   'plant',
#   'according',
#   'to',
#   'the',
#   'company'],
#  ['In',
#   'connection',
#   'with',
#   'the',
#   'deal',
#   'Digia',
#   'will',
#   'employ',
#   '19',
#   'persons',
#   'from',
#   'Nokia',
#   'in',
#   'Oslo',
#   'and',
#   'in',
#   'Silicon',
#   'Valley',
#   'in',
#   'the',
#   'USA'],
#  ['The',
#   'Brazilian',
#   'unit',
#   'of',
#   'Finnish',
#   'security',
#   'solutions',
#   'provider',
#   'FSecure',
#   'signed',
#   'up',
#   '1500',
#   'new',
#   'clients',
#   'last',
#   'year',
#   'online',
#   'news',
#   'source',
#   'Reseller',
#   'Web',
#   'quoted',
#   'the',
#   'division',
#   's',
#   'commercial',
#   'director',
#   'Vladimir',
#   'Brandúo',
#   'as',
#   'saying'],
#  ['The',
#   'fair',
#   'value',
#   'of',
#   'the',
#   'company',
#   's',
#   'investment',
#   'properties',
#   'went',
#   'down',
#   'to',
#   'EUR',
#   '2768',
#   'billion',
#   'at',
#   'the',
#   'end',
#   'of',
#   '2009',
#   'from',
#   'EUR',
#   '2916',
#   'billion',
#   'a',
#   'year',
#   'earlier'],
#  ['Dealers',
#   'said',
#   'the',
#   'share',
#   'was',
#   'largely',
#   'hit',
#   'by',
#   'investor',
#   'disappointment',
#   'about',
#   'a',
#   'refining',
#   'margin',
#   'of',
#   'just',
#   '948',
#   'usd',
#   'per',
#   'barrel',
#   'for',
#   'the',
#   'quarter',
#   'and',
#   'the',
#   'performance',
#   'of',
#   'its',
#   'shipping',
#   'unit',
#   'which',
#   'saw',
#   'EBIT',
#   'drop',
#   'to',
#   '5',
#   'mln',
#   'eur',
#   'from',
#   '20',
#   'mln',
#   'eur',
#   'a',
#   'year',
#   'amid',
#   'a',
#   'fall',
#   'in',
#   'volumes',
#   'and',
#   'tanker',
#   'rates'],
#  ['It',
#   'is',
#   'a',
#   'testament',
#   'to',
#   'the',
#   'quality',
#   'of',
#   'our',
#   'LTE',
#   'solution',
#   'and',
#   'our',
#   'commitment',
#   'to',
#   'the',
#   'Japanese',
#   'market',
#   'he',
#   'added'],
#  ['The',
#   'companies',
#   'aim',
#   'is',
#   'to',
#   'finalize',
#   'the',
#   'negotiations',
#   'and',
#   'sign',
#   'the',
#   'contracts',
#   'at',
#   'the',
#   'start',
#   'of',
#   'October',
#   '2008'],
#  ['Metso',
#   'Foundries',
#   'Jyvaskyla',
#   'Oy',
#   'will',
#   'discontinue',
#   'production',
#   'on',
#   'this',
#   'line',
#   'by',
#   '30',
#   'September',
#   '2008',
#   'the',
#   'company',
#   'said'],
#  ['A',
#   'total',
#   'six',
#   'of',
#   'the',
#   'polled',
#   'analysts',
#   'rated',
#   'Mreal',
#   'two',
#   'gave',
#   'buy',
#   'accumulate',
#   'three',
#   'gave',
#   'hold',
#   'and',
#   'only',
#   'one',
#   'gave',
#   'sell'],
#  ['In',
#   'September',
#   '2010',
#   'the',
#   'Finnish',
#   'group',
#   'agreed',
#   'to',
#   'buy',
#   'Danish',
#   'company',
#   'Rose',
#   'Poultry',
#   'AS',
#   'for',
#   'up',
#   'to',
#   'EUR23',
#   '9',
#   'm',
#   'in',
#   'a',
#   'combination',
#   'of',
#   'cash',
#   'and',
#   'stock'],
#  ['YANG', 'Double', 'bottom', '52'],
#  ['Tesco',
#   'share',
#   'price',
#   'down',
#   'as',
#   'grocer',
#   'faces',
#   'SFO',
#   'investigation',
#   'outcome'],
#  ['aapl',
#   'news',
#   'is',
#   'becoming',
#   'very',
#   'bullish',
#   'again',
#   'httpstkscotMU'],
#  ['GS',
#   'Engineering',
#   'will',
#   'install',
#   'the',
#   'valves',
#   'at',
#   'a',
#   'liquefied',
#   'natural',
#   'gas',
#   'LNG',
#   'plant',
#   'it',
#   'has',
#   'built',
#   'for',
#   'UAE',
#   'LNG',
#   'extraction',
#   'and',
#   'gas',
#   'plants',
#   'operator',
#   'GASCO',
#   'in',
#   'Ruwais',
#   'UAE'],
#  ['The',
#   'percentages',
#   'of',
#   'shares',
#   'and',
#   'voting',
#   'rights',
#   'have',
#   'been',
#   'calculated',
#   'in',
#   'proportion',
#   'to',
#   'the',
#   'total',
#   'number',
#   'of',
#   'shares',
#   'registered',
#   'with',
#   'the',
#   'Trade',
#   'Register',
#   'and',
#   'the',
#   'total',
#   'number',
#   'of',
#   'voting',
#   'rights',
#   'related',
#   'to',
#   'them'],
#  ['MReal',
#   'said',
#   'there',
#   'are',
#   'no',
#   'grounds',
#   'for',
#   'the',
#   'rumors',
#   'which',
#   'have',
#   'been',
#   'circulating',
#   'in',
#   'the',
#   'market',
#   'for',
#   'some',
#   'months'],
#  ['Lember',
#   'said',
#   'the',
#   'matter',
#   'was',
#   'topical',
#   'also',
#   'in',
#   'Estonia',
#   'where',
#   'a',
#   'bill',
#   'has',
#   'been',
#   'drafted',
#   'at',
#   'the',
#   'Social',
#   'Affairs',
#   'Ministry',
#   'that',
#   'would',
#   'scrap',
#   'oldage',
#   'pensions',
#   'on',
#   'favorable',
#   'conditions'],
#  ['Moody',
#   's',
#   'said',
#   'it',
#   'gave',
#   'P',
#   'A1',
#   'longterm',
#   'senior',
#   'unsecured',
#   'and',
#   'P',
#   'P1',
#   'shortterm',
#   'debt',
#   'ratings',
#   'to',
#   'Finnish',
#   'lender',
#   'Aktia',
#   'Bank',
#   's',
#   'EUR1bn',
#   'USD1',
#   '4',
#   'bn',
#   'euro',
#   'mediumterm',
#   'note',
#   'EMTN',
#   'program',
#   'of',
#   '25',
#   'March',
#   '2011'],
#  ['TSLA', 'recall'],
#  ['The',
#   'liquidity',
#   'providing',
#   'was',
#   'interrupted',
#   'on',
#   'May',
#   '11',
#   '2007',
#   'when',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   's',
#   'shares',
#   'traded',
#   'below',
#   '050',
#   'cent',
#   'Aspocomp',
#   's',
#   'stock',
#   'exchange',
#   'release',
#   '1152007'],
#  ['Hargreaves',
#   'Lansdown',
#   'bucks',
#   'weak',
#   'markets',
#   'to',
#   'see',
#   'assets',
#   'rise',
#   '26',
#   'percent'],
#  ['At',
#   '1259',
#   'pm',
#   'the',
#   'OMX',
#   'Helsinki',
#   '25',
#   'index',
#   'was',
#   '032',
#   'pct',
#   'lower',
#   'at',
#   '269481'],
#  ['The',
#   'decision',
#   'means',
#   'temporary',
#   'layoffs',
#   'of',
#   'fixed',
#   'duration',
#   'at',
#   'the',
#   'company',
#   's',
#   'Nastola',
#   'and',
#   'Jyvaskyla',
#   'units',
#   'in',
#   'southern',
#   'and',
#   'central',
#   'Finland',
#   'respectively'],
#  ['The', 'value', 'of', 'the', 'orders', 'is', 'over', 'EUR', '10mn'],
#  ['Ms',
#   'Laakso',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'HKScan',
#   's',
#   'HR',
#   'functions',
#   'and',
#   'for',
#   'their',
#   'development',
#   'in',
#   'all',
#   'of',
#   'the',
#   'Group',
#   'smarket',
#   'areas'],
#  ['Fiskars',
#   'is',
#   'also',
#   'engaged',
#   'in',
#   'the',
#   'global',
#   'supply',
#   'of',
#   'marine',
#   'and',
#   'energy',
#   'equipment',
#   'solutions',
#   'and',
#   'services',
#   'through',
#   'its',
#   'associated',
#   'company',
#   'Wartsila',
#   'Corporation'],
#  ['Aberdeen', 'Asset', 'Management', 'Gains', 'Foothold', 'In', 'China'],
#  ['Finland',
#   's',
#   'dominating',
#   'rail',
#   'company',
#   'VR',
#   'is',
#   'planning',
#   'to',
#   'set',
#   'the',
#   'infected',
#   'passengers',
#   'for',
#   'longdistance',
#   'trip',
#   'in',
#   'a',
#   'separate',
#   'carriage'],
#  ['In',
#   'November',
#   'the',
#   'Finnish',
#   'government',
#   'decreased',
#   'its',
#   'ownership',
#   'in',
#   'the',
#   'company',
#   'further',
#   'to',
#   '311',
#   'percent',
#   'from',
#   '38',
#   'percent'],
#  ['Finnish',
#   'Exel',
#   'Composites',
#   'a',
#   'technology',
#   'company',
#   'that',
#   'designs',
#   'manufactures',
#   'and',
#   'markets',
#   'composite',
#   'profiles',
#   'and',
#   'tubes',
#   'for',
#   'various',
#   'industrial',
#   'applications',
#   'reports',
#   'its',
#   'net',
#   'sales',
#   'decreased',
#   'by',
#   '06',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010',
#   'to',
#   'EUR',
#   '192',
#   'mn',
#   'from',
#   'EUR',
#   '193',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2009'],
#  ['Of',
#   'Bavelloni',
#   's',
#   'and',
#   'NST',
#   's',
#   'joint',
#   'ventures',
#   'Bavelloni',
#   'Tools',
#   'completes',
#   'semiproducts',
#   'that',
#   'are',
#   'produced',
#   'in',
#   'Italy',
#   'into',
#   'highquality',
#   'tools',
#   'that',
#   'will',
#   'be',
#   'sold',
#   'under',
#   'the',
#   'DiaPol',
#   'brand'],
#  ['The',
#   'tool',
#   'is',
#   'a',
#   'patent',
#   'pending',
#   'design',
#   'that',
#   'allows',
#   'consumers',
#   'to',
#   'lay',
#   'out',
#   'their',
#   'entire',
#   'project',
#   'on',
#   'a',
#   'removable',
#   'plate',
#   'using',
#   'multiple',
#   'clear',
#   'stamps',
#   'of',
#   'any',
#   'kind'],
#  ['GOOGL',
#   'is',
#   'a',
#   'short',
#   'below',
#   '740',
#   'into',
#   'the',
#   'upper',
#   'BB',
#   'and',
#   'is',
#   'overbought'],
#  ['LIGHTS',
#   'OUT',
#   'Before',
#   'curfew',
#   'curl',
#   'up',
#   'with',
#   'the',
#   'latest',
#   'bestseller',
#   'and',
#   'treat',
#   'your',
#   'eyes',
#   'to',
#   'the',
#   'perfect',
#   'reading',
#   'light',
#   'from',
#   'Luceplan'],
#  ['UPMKymmene',
#   'Corp',
#   'the',
#   'world',
#   's',
#   'largest',
#   'maker',
#   'of',
#   'magazine',
#   'paper',
#   'on',
#   'Tuesday',
#   'reported',
#   'a',
#   '19percent',
#   'profit',
#   'drop',
#   'as',
#   'lower',
#   'paper',
#   'prices',
#   'higher',
#   'costs',
#   'and',
#   'a',
#   'strong',
#   'euro',
#   'hurt',
#   'revenue'],
#  ['The',
#   'total',
#   'value',
#   'of',
#   'the',
#   'contract',
#   'is',
#   'some',
#   'EUR',
#   '8',
#   'million'],
#  ['The',
#   'prerequisite',
#   'for',
#   'inclusion',
#   'in',
#   'the',
#   'program',
#   'and',
#   'for',
#   'receipt',
#   'of',
#   'any',
#   'gains',
#   'is',
#   'that',
#   'key',
#   'employees',
#   'acquire',
#   'Aspo',
#   'shares',
#   'to',
#   'the',
#   'amount',
#   'determined',
#   'by',
#   'the',
#   'Board',
#   'in',
#   'advance',
#   'in',
#   'the',
#   'maximum'],
#  ['Mr',
#   'Doring',
#   'has',
#   'been',
#   'with',
#   'Eaton',
#   'since',
#   '1989',
#   'and',
#   'acted',
#   'as',
#   'the',
#   'Business',
#   'Unit',
#   'Manager',
#   'for',
#   'Eaton',
#   's',
#   'Power',
#   'Controls',
#   'Business',
#   'Unit',
#   'since',
#   'January',
#   '2007'],
#  ['The',
#   '250',
#   'sq',
#   'm',
#   '2691',
#   'sq',
#   'ft',
#   'store',
#   'in',
#   'Copenhagen',
#   's',
#   'premier',
#   'shopping',
#   'district',
#   'was',
#   'inaugurated',
#   'today',
#   'further',
#   'strengthening',
#   'the',
#   'company',
#   's',
#   'presence',
#   'in',
#   'Nordic',
#   'capitals'],
#  ['In',
#   'the',
#   'financial',
#   'statement',
#   'for',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2010',
#   'Tikkurila',
#   'is',
#   'reported',
#   'under',
#   'discontinued',
#   'operations'],
#  ['The',
#   'world',
#   's',
#   'second',
#   'largest',
#   'stainless',
#   'steel',
#   'maker',
#   'said',
#   'net',
#   'profit',
#   'in',
#   'the',
#   'threemonth',
#   'period',
#   'until',
#   'Dec',
#   '31',
#   'surged',
#   'to',
#   'euro603',
#   'million',
#   'US',
#   '781',
#   'million',
#   'or',
#   'euro3',
#   '33',
#   'US',
#   '431',
#   'per',
#   'share',
#   'from',
#   'euro172',
#   'million',
#   'or',
#   'euro0',
#   '94',
#   'per',
#   'share',
#   'the',
#   'previous',
#   'year'],
#  ['Name',
#   'of',
#   'Applicant',
#   'Jot',
#   'Automation',
#   'OYName',
#   'of',
#   'Inventor',
#   'Mammila',
#   'Tuomo',
#   'Piirainen',
#   'Mika',
#   'and',
#   'Kellokoski',
#   'MikaApplication',
#   'No',
#   '2424KOLNP2008',
#   'ADate',
#   'of',
#   'filing',
#   'of',
#   'Application',
#   '16062008Publication',
#   'Date',
#   '30012009'],
#  ['Netflix',
#   'Grows',
#   'Efforts',
#   'To',
#   'Create',
#   'Loyal',
#   'Customers',
#   'NFLX',
#   'httpstco5QXBkoBphe'],
#  ['The',
#   'OMX',
#   'Nordic',
#   '40',
#   'OMXN40',
#   'index',
#   'comprising',
#   'the',
#   '40',
#   'most',
#   'traded',
#   'Nordic',
#   'stocks',
#   'on',
#   'the',
#   'Nasdaq',
#   'OMX',
#   'exchange',
#   'closed',
#   'down',
#   '087',
#   'at',
#   '106414',
#   'points',
#   'on',
#   'Thursday'],
#  ['AAPL',
#   'nibbling',
#   'on',
#   'a',
#   'small',
#   'long',
#   'via',
#   '525',
#   'buying',
#   'off',
#   '13min',
#   'charts'],
#  ['The',
#   'operating',
#   'margin',
#   'of',
#   'Aker',
#   'Yards',
#   'Cruise',
#   'Ferries',
#   'division',
#   'went',
#   'down',
#   'from',
#   '83',
#   'to',
#   '64',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2007'],
#  ['TYC',
#   'just',
#   'about',
#   'to',
#   'break',
#   'out',
#   'to',
#   'new',
#   'highs',
#   'lots',
#   'of',
#   'technicals',
#   'looking',
#   'great',
#   'right',
#   'now'],
#  ['Eero',
#   'Katajavuori',
#   'currently',
#   'Group',
#   'Vice',
#   'President',
#   'Human',
#   'Resources',
#   'will',
#   'take',
#   'a',
#   'yearlong',
#   'sabbatical',
#   'starting',
#   'from',
#   'October',
#   '1',
#   '2010'],
#  ['Whats',
#   'up',
#   'with',
#   'LULU',
#   'Numbers',
#   'looked',
#   'good',
#   'not',
#   'great',
#   'but',
#   'good',
#   'I',
#   'think',
#   'conference',
#   'call',
#   'will',
#   'instill',
#   'confidence'],
#  ['The',
#   'adjustment',
#   'measures',
#   'will',
#   'be',
#   'carried',
#   'out',
#   'in',
#   'phases',
#   'to',
#   'secure',
#   'the',
#   'delivery',
#   'capability'],
#  ['Alma',
#   'Media',
#   'Corporation',
#   'Press',
#   'Release',
#   '15',
#   'March',
#   '2010',
#   'TYRVAAN',
#   'SANOMAT',
#   'AND',
#   'PAIKALLISSANOMAT',
#   'BEING',
#   'BOUGHT',
#   'BY',
#   'SUOMEN',
#   'PAIKALLISSANOMAT',
#   'Two',
#   'local',
#   'papers',
#   'Tyrvaan',
#   'Sanomat',
#   'and',
#   'Paikallissanomat',
#   'appearing',
#   'in',
#   'Sastamala',
#   'and',
#   'its',
#   'neighbouring',
#   'municipalities',
#   'are',
#   'to',
#   'be',
#   'bought',
#   'by',
#   'Suomen',
#   'Paikallissanomat',
#   'Oy'],
#  ['Temporary',
#   'layoffs',
#   'affecting',
#   'the',
#   'entire',
#   'workforce',
#   'will',
#   'also',
#   'be',
#   'implemented'],
#  ['A',
#   'meeting',
#   'for',
#   'the',
#   'media',
#   'and',
#   'analysts',
#   'will',
#   'be',
#   'held',
#   'on',
#   'the',
#   'same',
#   'day',
#   'at',
#   '1030',
#   'am',
#   'at',
#   'Stonesoft',
#   'Headquarters',
#   'in',
#   'Helsinki',
#   'Italahdenkatu',
#   '22',
#   'A',
#   'The',
#   'Interim',
#   'report',
#   'will',
#   'be',
#   'presented',
#   'by',
#   'Stonesoft',
#   's',
#   'CEO',
#   'Ilkka',
#   'Hiidenheimo'],
#  ['Finnish',
#   'SampoRosenlew',
#   'manufactures',
#   'approximately',
#   'seven',
#   'forest',
#   'machines',
#   'monthly',
#   'and',
#   'about',
#   'half',
#   'of',
#   'machines',
#   'are',
#   'exported'],
#  ['Facebook',
#   'near',
#   'a',
#   'buy',
#   'point',
#   'last',
#   'week',
#   'faces',
#   'a',
#   'different',
#   'technical',
#   'test',
#   'today',
#   'httpstcoc72LLMpiNM',
#   'FB',
#   'AAPL',
#   'NFLX',
#   'httpstcofPFbYTYPuY'],
#  ['4',
#   'February',
#   '2011',
#   'Finnish',
#   'broadband',
#   'data',
#   'communication',
#   'systems',
#   'provider',
#   'Teleste',
#   'Oyj',
#   'HEL',
#   'TLT1V',
#   'said',
#   'Wednesday',
#   'its',
#   'net',
#   'profit',
#   'rocketed',
#   'to',
#   'EUR4',
#   '8',
#   'm',
#   'in',
#   '2010',
#   'from',
#   'EUR416',
#   '000',
#   'in',
#   '2009',
#   'and',
#   'it',
#   'lifted',
#   'its',
#   'dividend',
#   'proposal'],
#  ['FREE',
#   'Ha',
#   'Heeeeeere',
#   'comes',
#   'the',
#   'pump',
#   'So',
#   'glad',
#   'I',
#   'picked',
#   'up',
#   '9K',
#   'end',
#   'of',
#   'day',
#   'Get',
#   'ready',
#   'for',
#   'the',
#   'bull',
#   'ride'],
#  ['Finnish',
#   'technology',
#   'group',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   'OMX',
#   'Helsinki',
#   'ACG1V',
#   'issued',
#   'its',
#   'third',
#   'quarter',
#   'report',
#   'on',
#   'Thursday',
#   '13',
#   'November',
#   'posting',
#   'an',
#   'operating',
#   'profit',
#   'of',
#   'EUR0',
#   '4',
#   'm',
#   'as',
#   'compared',
#   'to',
#   'a',
#   'loss',
#   'of',
#   'EUR0',
#   '5',
#   'm',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2007'],
#  ['The',
#   'building',
#   'complex',
#   'consists',
#   'of',
#   'highquality',
#   'office',
#   'and',
#   'retail',
#   'space',
#   'totalling',
#   '49200',
#   'square',
#   'metres',
#   'the',
#   'company',
#   'said'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'and',
#   'Kesko',
#   'Group',
#   'are',
#   'ending',
#   'their',
#   'loyal',
#   'customer',
#   'cooperation'],
#  ['The',
#   'unit',
#   'is',
#   'planned',
#   'to',
#   'be',
#   'operational',
#   'during',
#   'the',
#   'second',
#   'half',
#   'of',
#   '2007',
#   'and',
#   'in',
#   'full',
#   'stream',
#   'in',
#   '2008'],
#  ['ITG',
#   's',
#   'share',
#   'in',
#   'the',
#   'deal',
#   'is',
#   'estimated',
#   'at',
#   'some',
#   '500000',
#   'euro',
#   '627000'],
#  ['The',
#   'plant',
#   'is',
#   'expected',
#   'to',
#   'enter',
#   'commercial',
#   'operation',
#   'by',
#   'mid2009'],
#  ['Aspo',
#   'has',
#   'also',
#   'investigated',
#   'the',
#   'sales',
#   'opportunities',
#   'of',
#   'Kaukomarkkinat',
#   's',
#   'electronics',
#   'business'],
#  ['BG', 'Group', 'appoints', 'new', 'CEO', 'one', 'month', 'early'],
#  ['The',
#   'acquisition',
#   'will',
#   'have',
#   'an',
#   'immediate',
#   'positive',
#   'impact',
#   'on',
#   'Aspocomp',
#   's',
#   'financial',
#   'result'],
#  ['Finnair',
#   's',
#   'passenger',
#   'load',
#   'factor',
#   'which',
#   'measures',
#   'the',
#   'number',
#   'of',
#   'sold',
#   'seats',
#   'as',
#   'a',
#   'share',
#   'of',
#   'all',
#   'available',
#   'seats',
#   'dropped',
#   'by',
#   '13',
#   'percentage',
#   'points',
#   'to',
#   '767',
#   'in',
#   'September'],
#  ['RT',
#   'bman1',
#   'LNG',
#   'looks',
#   'primed',
#   'also',
#   'EGHT',
#   'poised',
#   'to',
#   'run',
#   'too'],
#  ['It',
#   'is',
#   'also',
#   '77',
#   'pct',
#   'above',
#   'the',
#   '12month',
#   'volume',
#   'weighted',
#   'average',
#   'price',
#   'of',
#   'the',
#   'stock'],
#  ['Coke',
#   'dividend',
#   '3',
#   'Google',
#   'dividend',
#   '0',
#   'For',
#   'passive',
#   'income',
#   'Coke',
#   'takes',
#   'it',
#   'GOOG',
#   'KO',
#   'httpstcoQBsoWjxOST'],
#  ['Profit',
#   'before',
#   'taxes',
#   'was',
#   'EUR',
#   '54',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '36',
#   'mn',
#   'a',
#   'year',
#   'earlier'],
#  ['The',
#   'subsidiary',
#   'is',
#   'setting',
#   'up',
#   'a',
#   'facility',
#   'for',
#   'manufacturing',
#   'highdensity',
#   'interconnection',
#   'printed',
#   'circuit',
#   'boards',
#   'or',
#   'PCBs',
#   'at',
#   'Nokia',
#   's',
#   'special',
#   'economic',
#   'zone',
#   'at',
#   'Sriperumbudur',
#   'near',
#   'Chennai'],
#  ['CRM',
#   'Sep',
#   '40',
#   'calls',
#   'are',
#   '35',
#   'since',
#   'entry',
#   'BANG',
#   'httpstkscodeDm'],
#  ['In',
#   'JanuaryJune',
#   '2010',
#   'diluted',
#   'loss',
#   'per',
#   'share',
#   'stood',
#   'at',
#   'EUR0',
#   '3',
#   'versus',
#   'EUR0',
#   '1',
#   'in',
#   'the',
#   'first',
#   'half',
#   'of',
#   '2009'],
#  ['Rapala',
#   'said',
#   'it',
#   'estimates',
#   'it',
#   'will',
#   'make',
#   'savings',
#   'of',
#   '12',
#   'mln',
#   'eur',
#   'a',
#   'year',
#   'by',
#   'centralising',
#   'its',
#   'French',
#   'operations',
#   'at',
#   'one',
#   'site'],
#  ['VMW',
#   'Got',
#   'a',
#   'nice',
#   'push',
#   'today',
#   'following',
#   'small',
#   'sweepers',
#   'of',
#   'May',
#   'C',
#   'this',
#   'morning'],
#  ['That',
#   'topped',
#   'consensus',
#   'forecasts',
#   'for',
#   'earnings',
#   'of',
#   '021',
#   'euros',
#   'a',
#   'share'],
#  ['RD', 'Loan'],
#  ['In',
#   'future',
#   'the',
#   'company',
#   'intends',
#   'to',
#   'look',
#   'for',
#   'knowhow',
#   'from',
#   'outside',
#   'the',
#   'company',
#   'and',
#   'to',
#   'cooperate',
#   'with',
#   'other',
#   'actors',
#   'in',
#   'the',
#   'sector'],
#  ['You',
#   'need',
#   'to',
#   'be',
#   'ready',
#   'when',
#   'the',
#   'window',
#   'opens',
#   'up',
#   'Rosberg',
#   'said'],
#  ['More',
#   'than',
#   '50000',
#   'tonnes',
#   'of',
#   'asphalt',
#   'mix',
#   'will',
#   'be',
#   'used',
#   'in',
#   'the',
#   'contract'],
#  ['PA',
#   'JPMorgan',
#   'Chase',
#   'and',
#   'Co',
#   'NYSE',
#   'JPM',
#   'and',
#   'Pohjoa',
#   'Bank',
#   'are',
#   'joint',
#   'leadmanagers',
#   'on',
#   'the',
#   'senior',
#   'unsecured',
#   'deal'],
#  ['CTRP',
#   'breaking',
#   'out',
#   'here',
#   'on',
#   'good',
#   'vol',
#   'and',
#   'a',
#   'parser',
#   'buy',
#   'signal',
#   'noticed',
#   'this',
#   'on',
#   'bob',
#   'langs',
#   'comments',
#   'looking',
#   'for',
#   '48',
#   'fast'],
#  ['Sales',
#   'in',
#   'Finland',
#   'decreased',
#   'by',
#   '105',
#   'in',
#   'January',
#   'while',
#   'sales',
#   'outside',
#   'Finland',
#   'dropped',
#   'by',
#   '17'],
#  ['The',
#   'pulp',
#   'production',
#   'in',
#   'Finnish',
#   'Kemijñrvi',
#   'will',
#   'also',
#   'be',
#   'liquidated',
#   'and',
#   'about',
#   '1100',
#   'employees',
#   'loose',
#   'their',
#   'jobs'],
#  ['Nordea',
#   'was',
#   'the',
#   'cheapest',
#   'also',
#   'for',
#   'a',
#   'couple',
#   'in',
#   'their',
#   '30s',
#   'with',
#   'debt'],
#  ['Jussi',
#   'Pesonen',
#   'member',
#   'of',
#   'the',
#   'Sampo',
#   'Board',
#   'since',
#   '2006',
#   'will',
#   'renounce',
#   'his',
#   'seat',
#   'in',
#   'Sampo',
#   'Board'],
#  ['Tesla',
#   'is',
#   'recalling',
#   '2700',
#   'Model',
#   'X',
#   'cars',
#   'httpstco8Z7BkVsTl9',
#   'TSLA'],
#  ['Adjusted',
#   'for',
#   'changes',
#   'in',
#   'the',
#   'Group',
#   'structure',
#   'the',
#   'Division',
#   's',
#   'net',
#   'sales',
#   'increased',
#   'by',
#   '17'],
#  ['Making',
#   'matters',
#   'more',
#   'difficult',
#   'the',
#   'company',
#   'said',
#   'it',
#   'has',
#   'been',
#   'grappling',
#   'with',
#   'higher',
#   'oil',
#   'and',
#   'gas',
#   'prices',
#   'which',
#   'have',
#   'pushed',
#   'up',
#   'the',
#   'cost',
#   'of',
#   'energy',
#   'raw',
#   'materials',
#   'and',
#   'transportation'],
#  ['The',
#   'amending',
#   'of',
#   'the',
#   'proposal',
#   'simplifies',
#   'the',
#   'proposed',
#   'plan',
#   'and',
#   'increases',
#   'the',
#   'incentive',
#   'for',
#   'key',
#   'employees',
#   'to',
#   'stay',
#   'in',
#   'the',
#   'Company'],
#  ['The',
#   'solution',
#   'will',
#   'now',
#   'be',
#   'expanded',
#   'to',
#   'include',
#   'all',
#   'ground',
#   'staff',
#   'tasks'],
#  ['Operating',
#   'loss',
#   'totalled',
#   'EUR',
#   '32',
#   'mn',
#   'compared',
#   'to',
#   'a',
#   'profit',
#   'of',
#   'EUR',
#   '72',
#   'mn',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008'],
#  ['On',
#   'FEDDAY',
#   'looking',
#   'for',
#   'a',
#   'sharp',
#   'move',
#   'up',
#   'in',
#   'equities',
#   'AAPL',
#   'HD',
#   'LOW',
#   'FB',
#   'seeing',
#   'UVXY',
#   'TVIX',
#   'getting',
#   'hammered',
#   'even',
#   'though',
#   'market',
#   'is',
#   'down'],
#  ['Net',
#   'sales',
#   'totaled',
#   'EUR',
#   '936',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '932',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2005'],
#  ['As',
#   'a',
#   'consequence',
#   'the',
#   'Works',
#   'Council',
#   'had',
#   'withdrawn',
#   'its',
#   'petition',
#   'to',
#   'suspend',
#   'the',
#   'reorganisation'],
#  ['CEO',
#   'Erkki',
#   'Jñrvinen',
#   'is',
#   'happy',
#   'with',
#   'the',
#   'company',
#   's',
#   'performance',
#   'in',
#   '2010'],
#  ['Comparable',
#   'net',
#   'sales',
#   'are',
#   'expected',
#   'to',
#   'increase',
#   'more',
#   'than',
#   '10',
#   'in',
#   '2008',
#   'in',
#   'line',
#   'with',
#   'group',
#   'target'],
#  ['Following',
#   'the',
#   'transaction',
#   'Lundbeck',
#   'has',
#   'worldwide',
#   'rights',
#   'for',
#   'nalmefene',
#   'excluding',
#   'North',
#   'America',
#   'Mexico',
#   'Turkey',
#   'and',
#   'SouthKorea'],
#  ['The',
#   'government',
#   'started',
#   'the',
#   'selloff',
#   'last',
#   'month',
#   'putting',
#   'an',
#   '8',
#   'percent',
#   'stake',
#   'in',
#   'TeliaSonera',
#   'on',
#   'the',
#   'auction',
#   'bloc'],
#  ['The',
#   'report',
#   'goes',
#   'on',
#   'to',
#   'provide',
#   'detailed',
#   'profiles',
#   'of',
#   'ten',
#   'leading',
#   'European',
#   'specialty',
#   'chemicals',
#   'companies',
#   'and',
#   'brief',
#   'profiles',
#   'of',
#   'other',
#   'major',
#   'players'],
#  ['Both',
#   'operating',
#   'profit',
#   'and',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'threemonth',
#   'period',
#   'increased',
#   'respectively',
#   'from',
#   'EUR16',
#   '0',
#   'm',
#   'and',
#   'EUR139m',
#   'as',
#   'compared',
#   'to',
#   'the',
#   'corresponding',
#   'quarter',
#   'in',
#   '2006'],
#  ['The',
#   'company',
#   'expects',
#   'its',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'whole',
#   '2009',
#   'to',
#   'be',
#   'at',
#   'previous',
#   'year',
#   'levels'],
#  ['The',
#   'company',
#   'is',
#   'headquartered',
#   'in',
#   'Sievi',
#   'Finland',
#   'and',
#   'is',
#   'listed',
#   'on',
#   'the',
#   'Nordic',
#   'Exchange',
#   'in',
#   'Helsinki'],
#  ['Commission',
#   'income',
#   'increased',
#   'by',
#   '22',
#   'to',
#   'EUR',
#   '44',
#   'mn',
#   'and',
#   'lending',
#   'volume',
#   'rose',
#   'by',
#   '135'],
#  ['The',
#   'Finnish',
#   'company',
#   'sold',
#   'its',
#   'UK',
#   'operation',
#   'consisting',
#   'of',
#   '50',
#   'staff',
#   'in',
#   'offices',
#   'in',
#   'London',
#   'Birmingham',
#   'and',
#   'Manchester',
#   'as',
#   'part',
#   'of',
#   'a',
#   'deal',
#   'with',
#   'Hampden',
#   'in',
#   'July',
#   '2001',
#   'for',
#   'its',
#   'Europeanwide',
#   'property',
#   'and',
#   'casualty',
#   'arm',
#   'Sampo',
#   'Industrial'],
#  ['In',
#   'the',
#   'building',
#   'and',
#   'home',
#   'improvement',
#   'trade',
#   'sales',
#   'decreased',
#   'by',
#   '225',
#   'to',
#   'EUR',
#   '2014',
#   'mn'],
#  ['The',
#   'Innova',
#   '2',
#   'building',
#   'will',
#   'be',
#   'located',
#   'close',
#   'to',
#   'downtown',
#   'in',
#   'the',
#   'immediate',
#   'vicinity',
#   'of',
#   'Paviljonki',
#   'and',
#   'the',
#   'travel',
#   'center',
#   'and',
#   'within',
#   'walking',
#   'distance',
#   'from',
#   'the',
#   'heart',
#   'of',
#   'the',
#   'city',
#   'thanks',
#   'to',
#   'the',
#   'trade',
#   'fair',
#   'bridge'],
#  ['Finnish',
#   'textiles',
#   'and',
#   'clothing',
#   'group',
#   'Marimekko',
#   'Oyj',
#   'posted',
#   'a',
#   'net',
#   'profit',
#   'of',
#   '799',
#   'mln',
#   'euro',
#   '104',
#   'mln',
#   'for',
#   '2006',
#   'compared',
#   'to',
#   '84',
#   'mln',
#   'euro',
#   '109',
#   'mln',
#   'for',
#   '2005'],
#  ['The',
#   'main',
#   'strength',
#   'of',
#   'the',
#   'cooperation',
#   'project',
#   'lies',
#   'in',
#   'merging',
#   'the',
#   'knowhow',
#   'of',
#   'two',
#   'large',
#   'companies'],
#  ['Shareholders',
#   'have',
#   'a',
#   'right',
#   'to',
#   'put',
#   'on',
#   'the',
#   'agenda',
#   'of',
#   'the',
#   'AGM',
#   'items',
#   'that',
#   'are',
#   'within',
#   'the',
#   'competence',
#   'of',
#   'the',
#   'general',
#   'meeting'],
#  ['Kazgiprotsvetmet',
#   'and',
#   'Outotec',
#   'Finland',
#   'have',
#   'signed',
#   'an',
#   'agreement',
#   'on',
#   'strategic',
#   'cooperation',
#   'in',
#   'the',
#   'marketing',
#   'and',
#   'providing',
#   'of',
#   'minerals',
#   'processing',
#   'and',
#   'metallurgical',
#   'plants',
#   'and',
#   'related',
#   'services',
#   'in',
#   'Kazakhstan',
#   'and',
#   'the',
#   'surrounding',
#   'countries'],
#  ['Due',
#   'to',
#   'the',
#   'rapid',
#   'decrease',
#   'in',
#   'net',
#   'sales',
#   'personnel',
#   'reductions',
#   'have',
#   'been',
#   'carried',
#   'out',
#   'on',
#   'a',
#   'wider',
#   'scale',
#   'than',
#   'initially',
#   'expected'],
#  ['The',
#   'government',
#   'has',
#   'instead',
#   'proposed',
#   'an',
#   'exchange',
#   'of',
#   'the',
#   'state',
#   's',
#   'stake',
#   'in',
#   'LMT',
#   'to',
#   'TeliaSonera',
#   's',
#   'stake',
#   'in',
#   'Lattelecom'],
#  ['Stora',
#   'is',
#   'due',
#   'to',
#   'release',
#   'its',
#   'fourthquarter',
#   'and',
#   '2009',
#   'fullyear',
#   'earnings',
#   'on',
#   'Feb',
#   '4'],
#  ['Fullyear',
#   'operating',
#   'result',
#   'for',
#   '2008',
#   'was',
#   '36',
#   'million',
#   'negative'],
#  ['NQ',
#   'got',
#   'hit',
#   'hard',
#   'lower',
#   'this',
#   'AM',
#   'looks',
#   'like',
#   'it',
#   'has',
#   'found',
#   'support',
#   'a',
#   '1889',
#   'httpstkscos052z'],
#  ['In',
#   '2008',
#   'AVC',
#   'Systemhaus',
#   'had',
#   'net',
#   'sales',
#   'of',
#   'EUR',
#   '10',
#   'million',
#   'USD',
#   '71',
#   'm'],
#  ['The',
#   'company',
#   'has',
#   'established',
#   'a',
#   '3G',
#   'base',
#   'station',
#   'at',
#   'about',
#   '17000',
#   'feet',
#   'at',
#   'the',
#   'foot',
#   'of',
#   'Mount',
#   'Everest',
#   'that',
#   'will',
#   'enable',
#   'mountain',
#   'climbers',
#   'at',
#   'the',
#   '29035foot',
#   'summit',
#   'to',
#   'surf',
#   'the',
#   'Internet',
#   'and',
#   'even',
#   'send',
#   'videos',
#   'of',
#   'their',
#   'exploits'],
#  ['We',
#   'offer',
#   'our',
#   'customers',
#   'solutions',
#   'based',
#   'on',
#   'renewable',
#   'raw',
#   'materials'],
#  ['A',
#   'survey',
#   'conducted',
#   'by',
#   'Taloustutkimus',
#   'for',
#   'Sampo',
#   'Life',
#   'shows',
#   'that',
#   'companies',
#   'are',
#   'badly',
#   'prepared',
#   'to',
#   'losing',
#   'key',
#   'staff',
#   'members'],
#  ['Antti',
#   'Orkola',
#   'president',
#   'of',
#   'Kemira',
#   'GrowHow',
#   's',
#   'Industrial',
#   'Solutions',
#   'unit',
#   'told',
#   'Thomson',
#   'Financial',
#   'News',
#   'the',
#   'company',
#   'has',
#   'put',
#   'off',
#   'opening',
#   'the',
#   'mine',
#   'as',
#   'prices',
#   'of',
#   'phosphate',
#   'have',
#   'been',
#   'quite',
#   'depressed',
#   'for',
#   'a',
#   'long',
#   'time'],
#  ['The',
#   'pretax',
#   'profit',
#   'of',
#   'the',
#   'group',
#   's',
#   'life',
#   'insurance',
#   'business',
#   'increased',
#   'to',
#   'EUR36m',
#   'from',
#   'EUR27m'],
#  ['We',
#   'make',
#   'available',
#   'the',
#   'following',
#   'brandnew',
#   'market',
#   'analyses',
#   'Cement',
#   'Pakistan',
#   'Cement',
#   'Malaysia',
#   'Cement',
#   'Taiwan',
#   'Cement',
#   'Philippines',
#   'These',
#   'analyses',
#   'give',
#   'a',
#   'clear',
#   'overview',
#   'of',
#   'the',
#   'actual',
#   'situation',
#   'and',
#   'future',
#   'outlook',
#   'of',
#   'the',
#   'cement',
#   'industry',
#   'in',
#   'some',
#   'Asian',
#   'countries'],
#  ['The',
#   'Company',
#   'serves',
#   'approximately',
#   '3000',
#   'customers',
#   'in',
#   'over',
#   '100',
#   'countries'],
#  ['RT',
#   'alphatrends',
#   'VMarkets',
#   'Are',
#   'Still',
#   'Acting',
#   'Weak',
#   'httpstksco1agn',
#   'SPY',
#   'QQQ',
#   'XLF',
#   'SMH',
#   'IWM'],
#  ['Operating',
#   'profit',
#   'totalled',
#   'EUR',
#   '302',
#   'mn',
#   'down',
#   'from',
#   'EUR',
#   '438',
#   'mn',
#   'a',
#   'year',
#   'earlier'],
#  ['One',
#   'of',
#   'the',
#   'installed',
#   'elevators',
#   'will',
#   'be',
#   'a',
#   'doubledeck',
#   'elevator',
#   'which',
#   'enables',
#   'more',
#   'efficient',
#   'use',
#   'of',
#   'the',
#   'building',
#   's',
#   'core',
#   'space'],
#  ['HELSINKI',
#   'AFX',
#   'Outokumpu',
#   'said',
#   'it',
#   'has',
#   'agreed',
#   'to',
#   'sell',
#   'the',
#   'Hitura',
#   'nickel',
#   'mine',
#   'in',
#   'Finland',
#   'to',
#   'Canadian',
#   'group',
#   'Belvedere',
#   'Resources',
#   'Ltd',
#   'for',
#   '10',
#   'mln',
#   'eur',
#   'worth',
#   'of',
#   'Belvedere',
#   'shares'],
#  ['Just', 'went', 'long', 'ILMN'],
#  ['Social',
#   'networking',
#   'and',
#   'locationbased',
#   'service',
#   'trends',
#   'comprise',
#   'a',
#   'significant',
#   'share',
#   'of',
#   'the',
#   'Internet',
#   'traffic',
#   'today',
#   'and',
#   'are',
#   'appealing',
#   'to',
#   'MID',
#   'users'],
#  ['A',
#   'total',
#   '30',
#   'of',
#   'the',
#   'order',
#   'value',
#   'was',
#   'booked',
#   'in',
#   'the',
#   'fourth',
#   'quarter',
#   'of',
#   '2009',
#   'and',
#   'the',
#   'remainder',
#   'will',
#   'be',
#   'booked',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010'],
#  ['Johnson',
#   'Matthey',
#   'share',
#   'price',
#   'slumps',
#   'as',
#   'company',
#   'posts',
#   'fullyear',
#   'results'],
#  ['There',
#   'have',
#   'not',
#   'been',
#   'previous',
#   'share',
#   'subscriptions',
#   'with',
#   '2004',
#   'stock',
#   'options'],
#  ['AffectoGenimap',
#   'builds',
#   'highly',
#   'customised',
#   'IT',
#   'solutions',
#   'for',
#   'its',
#   'customers',
#   'in',
#   'Finland',
#   'and',
#   'the',
#   'Baltic',
#   'countries'],
#  ['The',
#   'closing',
#   'of',
#   'the',
#   'transaction',
#   'is',
#   'scheduled',
#   'to',
#   'take',
#   'place',
#   'on',
#   'January',
#   '10',
#   '2008'],
#  ['However',
#   'the',
#   'offering',
#   'will',
#   'probably',
#   'not',
#   'be',
#   'made',
#   'at',
#   'the',
#   'current',
#   'valuation',
#   'which',
#   'partly',
#   'derives',
#   'from',
#   'the',
#   'deal',
#   'in',
#   'which',
#   'the',
#   'company',
#   'was',
#   'merged',
#   'into',
#   'a',
#   'stock',
#   'market',
#   'shell'],
#  ['Operating',
#   'result',
#   'for',
#   'the',
#   '12month',
#   'period',
#   'decreased',
#   'from',
#   'the',
#   'profit',
#   'of',
#   'EUR0',
#   '4',
#   'm',
#   'while',
#   'turnover',
#   'decreased',
#   'from',
#   'EUR5',
#   '6',
#   'm',
#   'as',
#   'compared',
#   'to',
#   '2004'],
#  ['The',
#   'administrators',
#   'have',
#   'indicated',
#   'a',
#   'need',
#   'for',
#   '900',
#   'job',
#   'cuts',
#   'at',
#   'the',
#   'Irish',
#   'insurer',
#   'over',
#   'the',
#   'next',
#   '15',
#   'months'],
#  ['Net',
#   'sales',
#   'in',
#   '2008',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'on',
#   'the',
#   'same',
#   'level',
#   'as',
#   'in',
#   '2007'],
#  ['Technical',
#   'indicators',
#   'for',
#   'the',
#   'stock',
#   'are',
#   'bullish',
#   'and',
#   'SP',
#   'gives',
#   'NOK',
#   'a',
#   'positive',
#   '4',
#   'STARS',
#   'out',
#   'of',
#   '5',
#   'buy',
#   'ranking'],
#  ['Revenue',
#   'for',
#   'the',
#   'quarter',
#   'totaled',
#   '274',
#   'billion',
#   'down',
#   '2',
#   'percent',
#   'from',
#   '281',
#   'billion',
#   'in',
#   'the',
#   'fourth',
#   'quarter',
#   'in',
#   '2008'],
#  ['NViro',
#   'operates',
#   'processing',
#   'facilities',
#   'independently',
#   'as',
#   'well',
#   'as',
#   'in',
#   'partnership',
#   'with',
#   'municipalities'],
#  ['The',
#   'number',
#   'of',
#   'bodily',
#   'injury',
#   'cases',
#   'quadrupled',
#   'in',
#   '20002006'],
#  ['According',
#   'to',
#   'Ringman',
#   'Finnish',
#   'paper',
#   'companies',
#   'have',
#   'acquired',
#   'knowhow',
#   'and',
#   'capacity',
#   'in',
#   'paper',
#   'recycling',
#   'which',
#   'has',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'successful',
#   'strategy'],
#  ['The',
#   'company',
#   'also',
#   'said',
#   'that',
#   'in',
#   'Poland',
#   'a',
#   'profitability',
#   'program',
#   'has',
#   'been',
#   'launched',
#   'at',
#   'the',
#   'Oborniki',
#   'steel',
#   'frame',
#   'and',
#   'sandwich',
#   'panel',
#   'plant'],
#  ['And',
#   'US',
#   'energy',
#   'executives',
#   'say',
#   'high',
#   'steel',
#   'prices',
#   'are',
#   'threatening',
#   'energy',
#   'exploration'],
#  ['Tesco', 'sales', 'rise', 'shows', 'tentative', 'recovery', 'continues'],
#  ['In',
#   'Finland',
#   'the',
#   'launch',
#   'of',
#   'tiein',
#   'sales',
#   'of',
#   '3G',
#   'mobile',
#   'phones',
#   'did',
#   'not',
#   'cause',
#   'a',
#   'dramatic',
#   'rush',
#   'in',
#   'mobile',
#   'retail',
#   'outlets',
#   'during',
#   'the',
#   'first',
#   'few',
#   'days'],
#  ['NUAN',
#   'held',
#   'up',
#   'well',
#   'after',
#   'the',
#   'big',
#   'gains',
#   'Maybe',
#   'were',
#   'finally',
#   'on',
#   'the',
#   'move',
#   'on',
#   'thisits',
#   'still',
#   'very',
#   'undervalued',
#   'and',
#   'has',
#   'major',
#   'upside'],
#  ['The',
#   'company',
#   'can',
#   'be',
#   'split',
#   'into',
#   'two',
#   'parts',
#   'over',
#   'the',
#   'coming',
#   'months',
#   'with',
# ...
#   'in',
#   'Europe',
#   'America',
#   'Africa',
#   'Asia',
#   'and',
#   'Australia',
#   'to',
#   'develop',
#   'and',
#   'introduce',
#   'new',
#   'raw',
#   'materials'],
#  ['The',
#   'new',
#   'agreement',
#   'which',
#   'expands',
#   'a',
#   'longestablished',
#   'cooperation',
#   'between',
#   'the',
#   'companies',
#   'involves',
#   'the',
#   'transfer',
#   'of',
#   'certain',
#   'engineering',
#   'and',
#   'documentation',
#   'functions',
#   'from',
#   'Larox',
#   'to',
#   'Etteplan'],
#  ['It', 's', 'not'],
#  ['took',
#   'some',
#   'ENDP',
#   'long',
#   'this',
#   'am',
#   'using',
#   'VWAP',
#   'as',
#   'guide'],
#  ['Despite',
#   'sales',
#   'growth',
#   'UKs',
#   'Tesco',
#   'cautions',
#   'recovery',
#   'to',
#   'be',
#   'bumpy'],
#  ['In',
#   'Finland',
#   'metal',
#   'sector',
#   'company',
#   'Componenta',
#   'is',
#   'laying',
#   'off',
#   'temporarily',
#   'the',
#   'staff',
#   'of',
#   'its',
#   'Pori',
#   'mill',
#   'from',
#   'Christmas',
#   '2008',
#   'till',
#   '6',
#   'January',
#   '2009'],
#  ['In',
#   'Middle',
#   'East',
#   'North',
#   'Africa',
#   'Tecnotree',
#   'has',
#   'grown',
#   'considerably',
#   'in',
#   'the',
#   'recent',
#   'years'],
#  ['Both',
#   'operating',
#   'profit',
#   'and',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'sixmonth',
#   'period',
#   'increased',
#   'respectively',
#   'from',
#   'EUR18',
#   '1',
#   'm',
#   'and',
#   'EUR127',
#   '6',
#   'm',
#   'as',
#   'compared',
#   'to',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2006'],
#  ['Insurer',
#   'Axa',
#   'PAR',
#   'CS',
#   'slid',
#   'by',
#   '535',
#   'to',
#   'EUR',
#   '1415',
#   'after',
#   'Citigroup',
#   'and',
#   'ING',
#   'slashed',
#   'their',
#   'targets',
#   'on',
#   'the',
#   'stock'],
#  ['The',
#   'order',
#   'values',
#   'at',
#   'EUR',
#   '69',
#   'mn',
#   'and',
#   'it',
#   'consists',
#   'of',
#   'design',
#   'services',
#   'and',
#   'hardware',
#   'and',
#   'software',
#   'licences'],
#  ['Scanfil', 'has', 'also', 'issued', 'a', 'profit', 'warning'],
#  ['A',
#   'spokesman',
#   'said',
#   'The',
#   'food',
#   'store',
#   'center',
#   'subject',
#   'to',
#   'council',
#   'and',
#   'local',
#   'support',
#   'could',
#   'comprise',
#   'a',
#   'supermarket',
#   'or',
#   'smaller',
#   'store',
#   'and',
#   'other',
#   'niche',
#   'outlets',
#   'and',
#   'this',
#   'will',
#   'be',
#   'firmed',
#   'up',
#   'following',
#   'consultation',
#   'with',
#   'the',
#   'council',
#   'and',
#   'local',
#   'community',
#   'regarding',
#   'appropriate',
#   'uses',
#   'and',
#   'occupiers'],
#  ['The',
#   'bond',
#   'has',
#   'a',
#   'value',
#   'of',
#   'EUR150m',
#   'and',
#   'a',
#   'maturity',
#   'of',
#   '4',
#   'years'],
#  ['MillerCoors', 'Board', 'Names', 'Gavin', 'Hattersley', 'Interim', 'CEO'],
#  ['Airbus',
#   'will',
#   'attempt',
#   'to',
#   'evacuate',
#   'up',
#   'to',
#   '873',
#   'people',
#   'within',
#   '90',
#   'seconds'],
#  ['First',
#   'quarter',
#   'underlying',
#   'operating',
#   'profit',
#   'rose',
#   'to',
#   '41',
#   'mln',
#   'eur',
#   'from',
#   '33',
#   'mln',
#   'a',
#   'year',
#   'earlier'],
#  ['EPS',
#   'for',
#   'the',
#   'quarter',
#   'was',
#   'EUR0',
#   '00',
#   'as',
#   'compared',
#   'with',
#   'EUR0',
#   '01',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008',
#   'representing',
#   'a',
#   'Group',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'third',
#   'quarter',
#   'were',
#   'EUR15',
#   '3',
#   'm',
#   'up',
#   'by',
#   '28',
#   'as',
#   'compared',
#   'with',
#   'EUR14',
#   '9',
#   'm',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008'],
#  ['Royal', 'Dutch', 'Shell', 'profit', 'rises', 'dividend', 'up', '4'],
#  ['Meanwhile',
#   'ElectrowattEkono',
#   'Philippines',
#   'Inc',
#   'was',
#   'also',
#   'awarded',
#   'a',
#   'threeyear',
#   'operation',
#   'and',
#   'maintenance',
#   'OM',
#   'contract',
#   'by',
#   'FR',
#   'Cement',
#   'Corporation'],
#  ['The',
#   'agreement',
#   'includes',
#   'application',
#   'maintenance',
#   'and',
#   'support',
#   'services'],
#  ['Nokia',
#   'is',
#   'just',
#   'interested',
#   'in',
#   'bring',
#   'Nokia',
#   'to',
#   'the',
#   'market'],
#  ['Affecto',
#   'expects',
#   'its',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'whole',
#   '2010',
#   'to',
#   'increase',
#   'from',
#   'the',
#   '2009',
#   'level',
#   'when',
#   'they',
#   'reached',
#   'EUR',
#   '103',
#   'million'],
#  ['The',
#   'report',
#   'profiles',
#   '158',
#   'companies',
#   'including',
#   'many',
#   'key',
#   'and',
#   'niche',
#   'players',
#   'including',
#   'major',
#   'Nonwovens',
#   'manufacturers',
#   'such',
#   'as',
#   'Ahlstrom',
#   'Corporation',
#   'Asahi',
#   'Kasei',
#   'Corporation',
#   'Buckeye',
#   'Technologies',
#   'Inc',
#   'EI'],
#  ['The',
#   'layoffs',
#   'will',
#   'affect',
#   '240',
#   'people',
#   'out',
#   'of',
#   'the',
#   'total',
#   '320',
#   'Okmetic',
#   'employees',
#   'in',
#   'Finland'],
#  ['The',
#   'acquisition',
#   'of',
#   'Elektros',
#   'Pavara',
#   'completes',
#   'KONE',
#   's',
#   'market',
#   'expansion',
#   'strategy',
#   'in',
#   'the',
#   'Baltic',
#   'Countries'],
#  ['18',
#   'May',
#   '2010',
#   'Finnish',
#   'electronics',
#   'producer',
#   'Elcoteq',
#   'SE',
#   'HEL',
#   'ELQAV',
#   'said',
#   'today',
#   'that',
#   'it',
#   'has',
#   'signed',
#   'an',
#   'extensive',
#   'cooperation',
#   'agreement',
#   'on',
#   'industrialisation',
#   'manufacturing',
#   'distribution',
#   'and',
#   'aftermarket',
#   'services',
#   'for',
#   'mobile',
#   'phones',
#   'with',
#   'Japan',
#   's',
#   'Sharp',
#   'TYO',
#   '6753'],
#  ['Morrisons',
#   'book',
#   'second',
#   'consecutive',
#   'quarter',
#   'of',
#   'sales',
#   'growth'],
#  ['Marimekko',
#   'has',
#   'today',
#   '20',
#   'November',
#   'signed',
#   'a',
#   'license',
#   'agreement',
#   'with',
#   'the',
#   'Swedish',
#   'chain',
#   'whereby',
#   'Marimekko',
#   'will',
#   'license',
#   'some',
#   'of',
#   'its',
#   'popular',
#   'patterns',
#   'from',
#   'the',
#   '1950s',
#   '1960s',
#   'and',
#   '1970s',
#   'to',
#   'HM'],
#  ['that',
#   'was',
#   'quick',
#   'out',
#   'FIO',
#   '2135',
#   'market',
#   'tanking',
#   'scaling',
#   'down',
#   'longs',
#   'now'],
#  ['The',
#   'announcement',
#   'pushed',
#   'Freenet',
#   'shares',
#   'down',
#   '63',
#   'or',
#   'EUR0',
#   '71',
#   'in',
#   'Frankfurt',
#   'trade',
#   'to',
#   'EUR10',
#   '65',
#   'as',
#   'investors',
#   'gave',
#   'up',
#   'hope',
#   'United',
#   'Internet',
#   'AG',
#   'and',
#   'Drillisch',
#   'would',
#   'pursue',
#   'their',
#   'own',
#   'takeover',
#   'and',
#   'breakup',
#   'of',
#   'Freenet'],
#  ['Finnish',
#   'telecoms',
#   'software',
#   'developer',
#   'Tecnomen',
#   'Oyj',
#   'said',
#   'on',
#   'December',
#   '5',
#   '2006',
#   'it',
#   'won',
#   'a',
#   '33',
#   'mln',
#   '25',
#   'mln',
#   'euro',
#   'order',
#   'to',
#   'supply',
#   'an',
#   'expansion',
#   'of',
#   'the',
#   'charging',
#   'and',
#   'messaging',
#   'systems',
#   'for',
#   'the',
#   'mobile',
#   'and',
#   'fixed',
#   'networks',
#   'of',
#   'Brasil',
#   'Telecom'],
#  ['CompaniesUnilever',
#   'sales',
#   'lifted',
#   'by',
#   'ice',
#   'cream',
#   'in',
#   'soft',
#   'economy'],
#  ['EPS', 'dropped', 'to', 'EUR0', '2', 'from', 'EUR0', '3'],
#  ['saltwaternurse',
#   'INO',
#   'can',
#   'test',
#   '10',
#   'again',
#   'in',
#   'next',
#   'few',
#   'days',
#   'time',
#   'to',
#   'take',
#   'some',
#   'profits',
#   'here',
#   'or',
#   'hedge',
#   'with',
#   'puts'],
#  ['No', 'financial', 'information', 'was', 'provided'],
#  ['EasyJet',
#   'attracts',
#   'more',
#   'passengers',
#   'in',
#   'June',
#   'but',
#   'still',
#   'lags',
#   'Ryanair'],
#  ['Morning', 'Agenda', 'Shires', 'Deal', 'for', 'NPS'],
#  ['Metso',
#   'will',
#   'supply',
#   'the',
#   'equipment',
#   'for',
#   'two',
#   'process',
#   'lines',
#   'at',
#   'Northland',
#   'Resources',
#   'new',
#   'Kaunisvaara',
#   'iron',
#   'ore',
#   'project',
#   'in',
#   'Sweden',
#   'which',
#   'exploits',
#   'Tapuli',
#   'and',
#   'Sahavaara',
#   'iron',
#   'ore',
#   'deposits'],
#  ['Under',
#   'this',
#   'agreement',
#   'Biohit',
#   'becomes',
#   'a',
#   'focus',
#   'supplier',
#   'of',
#   'pipettors',
#   'and',
#   'disposable',
#   'pipettor',
#   'tips',
#   'to',
#   'VWR',
#   'customers',
#   'throughout',
#   'Europe'],
#  ['The',
#   'company',
#   's',
#   'previous',
#   'estimate',
#   'was',
#   'for',
#   'a',
#   'lower',
#   'revenue',
#   'than',
#   'the',
#   'yearago',
#   'EUR',
#   '939',
#   'million'],
#  ['Earnings',
#   'per',
#   'share',
#   'EPS',
#   'dropped',
#   'to',
#   'EUR',
#   '021',
#   'from',
#   'EUR',
#   '031'],
#  ['Bids',
#   'or',
#   'offers',
#   'include',
#   'at',
#   'least',
#   '1000',
#   'shares',
#   'and',
#   'the',
#   'value',
#   'of',
#   'the',
#   'shares',
#   'must',
#   'correspond',
#   'to',
#   'at',
#   'least',
#   'EUR4',
#   '000'],
#  ['Earnings',
#   'per',
#   'share',
#   'EPS',
#   'amounted',
#   'to',
#   'a',
#   'loss',
#   'of',
#   'to',
#   'EUR0',
#   '06'],
#  ['NetApp',
#   'downgraded',
#   'by',
#   'Macquarie',
#   'to',
#   'underperform',
#   '2200',
#   'PT',
#   'httpstcoXCNgws0t4q',
#   'NTAP',
#   'NTAP',
#   'via',
#   'RatingsNetwork'],
#  ['Russia',
#   'is',
#   'ready',
#   'to',
#   'participate',
#   'in',
#   'an',
#   'open',
#   'tender',
#   'for',
#   'Lattelecom',
#   's',
#   'privatization'],
#  ['Technopolis',
#   'and',
#   'the',
#   'St',
#   'Petersburg',
#   'government',
#   'signed',
#   'a',
#   'cooperation',
#   'memorandum',
#   'in',
#   'October',
#   '2005',
#   'to',
#   'set',
#   'up',
#   'a',
#   'technopark',
#   'in',
#   'the',
#   'Neudorf',
#   'production',
#   'zone',
#   'in',
#   'the',
#   'village',
#   'of',
#   'Strelny',
#   'in',
#   'the',
#   'St',
#   'Petersburg',
#   'suburbs'],
#  ['The',
#   'owners',
#   'who',
#   'have',
#   'participated',
#   'in',
#   'the',
#   'business',
#   'operations',
#   'of',
#   'the',
#   'company',
#   'will',
#   'continue',
#   'in',
#   'Poyry',
#   's',
#   'employment',
#   'after',
#   'the',
#   'transaction'],
#  ['The',
#   'goal',
#   'is',
#   'to',
#   'secure',
#   'the',
#   'company',
#   's',
#   'profitability',
#   'and',
#   'competitiveness'],
#  ['However',
#   'the',
#   'company',
#   'saw',
#   'its',
#   'net',
#   'profit',
#   'for',
#   'the',
#   'third',
#   'quarter',
#   'down',
#   'to',
#   'EUR',
#   '14',
#   'million',
#   'from',
#   'EUR',
#   '15',
#   'million',
#   'for',
#   'the',
#   'corresponding',
#   'period',
#   'of',
#   '2009'],
#  ['Neste',
#   'oil',
#   's',
#   'board',
#   'proposed',
#   '100',
#   'eur',
#   'dividend',
#   'for',
#   'the',
#   'fullyear',
#   '2007',
#   'compared',
#   'with',
#   '090',
#   'eur',
#   'a',
#   'year',
#   'ago'],
#  ['Basware',
#   'Einvoices',
#   'Oy',
#   'will',
#   'be',
#   'merged',
#   'into',
#   'the',
#   'parent',
#   'company',
#   'during',
#   'the',
#   'present',
#   'fiscal',
#   'period'],
#  ['Fintech',
#   'provider',
#   'CAFN',
#   'Cachet',
#   'Financial',
#   'Solutions',
#   'Surging',
#   'Forward',
#   'today',
#   'post',
#   'earnings',
#   'Up',
#   '1326',
#   'httpstco9BJ3csk2i9',
#   'JKHY',
#   'FISV',
#   'Momo'],
#  ['Before',
#   'Kemira',
#   's',
#   'installation',
#   'NordAlu',
#   'was',
#   'producing',
#   '3500',
#   'tons',
#   'of',
#   'liquid',
#   'and',
#   'solid',
#   'aluminum',
#   'waste',
#   'per',
#   'year'],
#  ['He',
#   'is',
#   'a',
#   'Chartered',
#   'Accountant',
#   'in',
#   'British',
#   'Columbia',
#   'and',
#   'Alberta',
#   'as',
#   'well',
#   'as',
#   'a',
#   'Certified',
#   'Public',
#   'Accountant',
#   'in',
#   'Washington',
#   'State'],
#  ['Very',
#   'recommendable',
#   'is',
#   'the',
#   'Nokian',
#   'Z',
#   'G2',
#   'according',
#   'to',
#   'the',
#   'ADAC',
#   'judgement',
#   'in',
#   'the',
#   'latest',
#   'summer',
#   'tyre',
#   'test',
#   'of',
#   'the',
#   'German',
#   'automobile',
#   'association',
#   'ADAC'],
#  ['The',
#   'Group',
#   's',
#   'result',
#   'before',
#   'taxes',
#   'was',
#   'a',
#   'loss',
#   'of',
#   'EUR',
#   '06',
#   '06',
#   'million'],
#  ['Cash',
#   'flow',
#   'from',
#   'operating',
#   'activities',
#   'before',
#   'investments',
#   'was',
#   'EUR',
#   '08',
#   '12',
#   'million'],
#  ['Viking', 'Line', 'has', 'canceled', 'some', 'services'],
#  ['Exel', 'is', 'headquartered', 'in', 'Mantyharju', 'in', 'Finland'],
#  ['Stora',
#   'Chief',
#   'Executive',
#   'Jouko',
#   'Karvinen',
#   'has',
#   'described',
#   'the',
#   'Russian',
#   'tariff',
#   'hikes',
#   'as',
#   'a',
#   'threat',
#   'to',
#   'the',
#   'future',
#   'of',
#   'the',
#   'forest',
#   'products',
#   'industry',
#   'in',
#   'Finland'],
#  ['After',
#   'Barclays',
#   'and',
#   'Bank',
#   'of',
#   'America',
#   'Citigroup',
#   'has',
#   'blockchain',
#   'in',
#   'sight'],
#  ['Google',
#   'Inc',
#   'completes',
#   'acquisition',
#   'of',
#   'ICOA',
#   'Inc',
#   'httpstksconFEI',
#   'ICOA',
#   'GOOG'],
#  ['TSLA',
#   'looking',
#   'goodid',
#   'love',
#   'to',
#   'see',
#   'a',
#   'basing',
#   'action',
#   'here',
#   'letting',
#   'the',
#   'RSI',
#   'take',
#   'a',
#   'breather',
#   'httpstkscog1T7c'],
#  ['Finnish',
#   'plumbing',
#   'and',
#   'heating',
#   'systems',
#   'supplier',
#   'Uponor',
#   's',
#   'net',
#   'sales',
#   'from',
#   'continuing',
#   'operations',
#   'decreased',
#   'by',
#   '94',
#   'in',
#   '2008',
#   'to',
#   'EUR',
#   '9492',
#   'mn',
#   'from',
#   'EUR',
#   '10474',
#   'mn',
#   'in',
#   '2007'],
#  ['This',
#   'location',
#   'makes',
#   'the',
#   'mall',
#   'a',
#   'convenient',
#   'place',
#   'to',
#   'shop',
#   'for',
#   'consumers',
#   'from',
#   'three',
#   'large',
#   'residential',
#   'areas',
#   'nearby',
#   'Jaroszowka',
#   'Wysockiego',
#   'and',
#   'Zgody'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'and',
#   'Kesko',
#   'Group',
#   'are',
#   'ending',
#   'their',
#   'loyal',
#   'customer',
#   'cooperation'],
#  ['The',
#   'casing',
#   'comprises',
#   'a',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'with',
#   'the',
#   'first',
#   'side',
#   'vat',
#   'segment',
#   'and',
#   'a',
#   'second',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'with',
#   'the',
#   'second',
#   'side',
#   'vat',
#   'segment',
#   'at',
#   'least',
#   'the',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'being',
#   'pivotable',
#   'about',
#   'a',
#   'rotation',
#   'axis'],
#  ['Finlandbased',
#   'Elcoteq',
#   'SE',
#   'a',
#   'privately',
#   'held',
#   'provider',
#   'of',
#   'electronics',
#   'manufacturing',
#   'services',
#   'to',
#   'communications',
#   'companies',
#   'said',
#   'Thursday',
#   'it',
#   'signed',
#   'a',
#   'longterm',
#   'manufacturing',
#   'supply',
#   'deal',
#   'with',
#   'communications',
#   'equipment',
#   'company',
#   'Andrew',
#   'Corp'],
#  ['In',
#   'Q1',
#   'of',
#   '2009',
#   'Bank',
#   'of',
#   'àland',
#   's',
#   'net',
#   'interest',
#   'income',
#   'weakened',
#   'by',
#   '10',
#   'to',
#   'EUR',
#   '91',
#   'mn'],
#  ['RBS',
#   'Pays',
#   '17',
#   'Billion',
#   'to',
#   'Scrap',
#   'UK',
#   'Treasurys',
#   'Dividend',
#   'Rights'],
#  ['Increased',
#   'trust',
#   'of',
#   'our',
#   'clients',
#   'in',
#   'YIT',
#   'can',
#   'be',
#   'seen',
#   'as',
#   'apartment',
#   'sales',
#   'accelerated'],
#  ['Talvivaara',
#   'Mining',
#   'Company',
#   'Plc',
#   'Talvivaara',
#   'Mining',
#   'Company',
#   'is',
#   'an',
#   'internationally',
#   'significant',
#   'base',
#   'metals',
#   'producer',
#   'with',
#   'its',
#   'primary',
#   'focus',
#   'on',
#   'nickel',
#   'and',
#   'zinc',
#   'using',
#   'a',
#   'technology',
#   'known',
#   'as',
#   'bioheapleaching',
#   'to',
#   'extract',
#   'metals',
#   'out',
#   'of',
#   'ore'],
#  ['Operating',
#   'profit',
#   'for',
#   '2009',
#   'lower',
#   'than',
#   'outlook',
#   'published',
#   'earlier'],
#  ['Less', 'than', 'ten', 'people', 'will', 'face', 'pension', 'agreements'],
#  ['The',
#   'company',
#   's',
#   'consolidated',
#   'operating',
#   'profit',
#   'amounted',
#   'to',
#   'EUR',
#   '1586',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '414',
#   'mn',
#   'yearonyear'],
#  ['AstraZeneca', 'to', 'Buy', 'ZS', 'Pharma', 'for', '27', 'Billion'],
#  ['Finnish',
#   'waste',
#   'management',
#   'and',
#   'cleaning',
#   'group',
#   'Lassila',
#   'Tikanoja',
#   'Oyj',
#   'LT',
#   'net',
#   'profit',
#   'went',
#   'down',
#   'to',
#   '322',
#   'mln',
#   'euro',
#   '477',
#   'mln',
#   'for',
#   '2007',
#   'from',
#   '353',
#   'mln',
#   'euro',
#   '523',
#   'mln',
#   'for',
#   '2006'],
#  ['The',
#   'operating',
#   'margin',
#   'of',
#   'Aker',
#   'Yards',
#   'Cruise',
#   'Ferries',
#   'division',
#   'went',
#   'down',
#   'from',
#   '83',
#   'to',
#   '64',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2007'],
#  ['HELSINKI',
#   'Thomson',
#   'Financial',
#   'Shares',
#   'in',
#   'Cargotec',
#   'fell',
#   'sharply',
#   'in',
#   'early',
#   'afternoon',
#   'trade',
#   'after',
#   'the',
#   'cargo',
#   'handling',
#   'group',
#   'posted',
#   'a',
#   'surprise',
#   'drop',
#   'in',
#   'AprilJune',
#   'profits',
#   'which',
#   'overshadowed',
#   'the',
#   'large',
#   'number',
#   'of',
#   'new',
#   'orders',
#   'received',
#   'during',
#   'the',
#   'three',
#   'months'],
#  ['The',
#   'program',
#   's',
#   'target',
#   'is',
#   'structural',
#   'cost',
#   'reductions',
#   'of',
#   'about',
#   'EUR',
#   '30mn',
#   'in',
#   '2009'],
#  ['Our',
#   'tools',
#   'are',
#   'specifically',
#   'designed',
#   'with',
#   'the',
#   'needs',
#   'of',
#   'both',
#   'the',
#   'business',
#   'users',
#   'and',
#   'ICT',
#   'experts',
#   'in',
#   'mind'],
#  ...]

# %%
tokens
# Out:
# [['The',
#   'GeoSolutions',
#   'technology',
#   'will',
#   'leverage',
#   'Benefon',
#   's',
#   'GPS',
#   'solutions',
#   'by',
#   'providing',
#   'Location',
#   'Based',
#   'Search',
#   'Technology',
#   'a',
#   'Communities',
#   'Platform',
#   'location',
#   'relevant',
#   'multimedia',
#   'content',
#   'and',
#   'a',
#   'new',
#   'and',
#   'powerful',
#   'commercial',
#   'model'],
#  ['ESI',
#   'on',
#   'lows',
#   'down',
#   '150',
#   'to',
#   '250',
#   'BK',
#   'a',
#   'real',
#   'possibility'],
#  ['For',
#   'the',
#   'last',
#   'quarter',
#   'of',
#   '2010',
#   'Componenta',
#   's',
#   'net',
#   'sales',
#   'doubled',
#   'to',
#   'EUR131m',
#   'from',
#   'EUR76m',
#   'for',
#   'the',
#   'same',
#   'period',
#   'a',
#   'year',
#   'earlier',
#   'while',
#   'it',
#   'moved',
#   'to',
#   'a',
#   'zero',
#   'pretax',
#   'profit',
#   'from',
#   'a',
#   'pretax',
#   'loss',
#   'of',
#   'EUR7m'],
#  ['According',
#   'to',
#   'the',
#   'FinnishRussian',
#   'Chamber',
#   'of',
#   'Commerce',
#   'all',
#   'the',
#   'major',
#   'construction',
#   'companies',
#   'of',
#   'Finland',
#   'are',
#   'operating',
#   'in',
#   'Russia'],
#  ['The',
#   'Swedish',
#   'buyout',
#   'firm',
#   'has',
#   'sold',
#   'its',
#   'remaining',
#   '224',
#   'percent',
#   'stake',
#   'almost',
#   'eighteen',
#   'months',
#   'after',
#   'taking',
#   'the',
#   'company',
#   'public',
#   'in',
#   'Finland'],
#  ['SPY', 'wouldnt', 'be', 'surprised', 'to', 'see', 'a', 'green', 'close'],
#  ['Shells',
#   '70',
#   'Billion',
#   'BG',
#   'Deal',
#   'Meets',
#   'Shareholder',
#   'Skepticism'],
#  ['SSH',
#   'COMMUNICATIONS',
#   'SECURITY',
#   'CORP',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   'OCTOBER',
#   '14',
#   '2008',
#   'AT',
#   '245',
#   'PM',
#   'The',
#   'Company',
#   'updates',
#   'its',
#   'full',
#   'year',
#   'outlook',
#   'and',
#   'estimates',
#   'its',
#   'results',
#   'to',
#   'remain',
#   'at',
#   'loss',
#   'for',
#   'the',
#   'full',
#   'year'],
#  ['Kone',
#   's',
#   'net',
#   'sales',
#   'rose',
#   'by',
#   'some',
#   '14',
#   'yearonyear',
#   'in',
#   'the',
#   'first',
#   'nine',
#   'months',
#   'of',
#   '2008'],
#  ['The',
#   'Stockmann',
#   'department',
#   'store',
#   'will',
#   'have',
#   'a',
#   'total',
#   'floor',
#   'space',
#   'of',
#   'over',
#   '8000',
#   'square',
#   'metres',
#   'and',
#   'Stockmann',
#   's',
#   'investment',
#   'in',
#   'the',
#   'project',
#   'will',
#   'have',
#   'a',
#   'price',
#   'tag',
#   'of',
#   'about',
#   'EUR',
#   '12',
#   'million'],
#  ['Circulation',
#   'revenue',
#   'has',
#   'increased',
#   'by',
#   '5',
#   'in',
#   'Finland',
#   'and',
#   '4',
#   'in',
#   'Sweden',
#   'in',
#   '2008'],
#  ['SAP',
#   'Q1',
#   'disappoints',
#   'as',
#   'software',
#   'licenses',
#   'down',
#   'Real',
#   'problem',
#   'Cloud',
#   'growth',
#   'trails',
#   'MSFT',
#   'ORCL',
#   'GOOG',
#   'CRM',
#   'ADBE',
#   'httpstcojNDphllzq5'],
#  ['The',
#   'subdivision',
#   'made',
#   'sales',
#   'revenues',
#   'last',
#   'year',
#   'of',
#   'EUR',
#   '4807',
#   'million',
#   'EUR',
#   '4149',
#   'million',
#   'in',
#   '2008',
#   'and',
#   'operating',
#   'profits',
#   'of',
#   'EUR',
#   '445',
#   'million',
#   'EUR',
#   '74',
#   'million'],
#  ['Viking', 'Line', 'has', 'canceled', 'some', 'services'],
#  ['Ahlstrom',
#   'Corporation',
#   'STOCK',
#   'EXCHANGE',
#   'ANNOUNCEMENT',
#   '722007',
#   'at',
#   '1030',
#   'A',
#   'total',
#   'of',
#   '56955',
#   'new',
#   'shares',
#   'of',
#   'Ahlstrom',
#   'Corporation',
#   'have',
#   'been',
#   'subscribed',
#   'with',
#   'option',
#   'rights',
#   'under',
#   'the',
#   'company',
#   's',
#   'stock',
#   'option',
#   'programs',
#   'I',
#   '2001',
#   'and',
#   'II',
#   '2001'],
#  ['FB', 'gone', 'green', 'on', 'day'],
#  ['MSFT',
#   'SQL',
#   'Server',
#   'revenue',
#   'grew',
#   'doubledigit',
#   'with',
#   'SQL',
#   'Server',
#   'Premium',
#   'revenue',
#   'growing',
#   'over',
#   '30',
#   'httpstkscoir2F'],
#  ['According',
#   'to',
#   'Lñnnen',
#   'Tehtaat',
#   's',
#   'CEO',
#   'Matti',
#   'Karppinen',
#   'the',
#   'company',
#   'aims',
#   'to',
#   'deliver',
#   'fish',
#   'products',
#   'to',
#   'its',
#   'customers',
#   'a',
#   'day',
#   'earlier',
#   'than',
#   'it',
#   'currently',
#   'does'],
#  ['The',
#   'company',
#   's',
#   'share',
#   'is',
#   'quoted',
#   'on',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'Rautaruukki',
#   'Oyj',
#   'RTRKS'],
#  ['Elcoteq',
#   'SE',
#   'is',
#   'listed',
#   'on',
#   'the',
#   'Nasdaq',
#   'OMX',
#   'Helsinki',
#   'Ltd'],
#  ['Two',
#   'of',
#   'these',
#   'contracts',
#   'are',
#   'for',
#   'turntable',
#   'anode',
#   'vibrocompactors',
#   'that',
#   'will',
#   'be',
#   'delivered',
#   'to',
#   'Gansu',
#   'Hualu',
#   'Aluminum',
#   'Co',
#   'Ltd',
#   'and',
#   'another',
#   'unnamed',
#   'costumer'],
#  ['Aviva',
#   'Friends',
#   'Life',
#   'top',
#   'forecasts',
#   'ahead',
#   'of',
#   '56',
#   'billion',
#   'pound',
#   'merger'],
#  ['In',
#   'stead',
#   'of',
#   'being',
#   'based',
#   'on',
#   'a',
#   'soft',
#   'drink',
#   'as',
#   'is',
#   'usual',
#   'the',
#   'Teho',
#   'energy',
#   'drink',
#   'is',
#   'made',
#   'with',
#   'fresh',
#   'water'],
#  ['The',
#   'company',
#   'plans',
#   'to',
#   'increase',
#   'the',
#   'unit',
#   's',
#   'specialist',
#   'staff',
#   'to',
#   'several',
#   'dozen',
#   'depending',
#   'on',
#   'the',
#   'market',
#   'situation',
#   'during',
#   '2010'],
#  ['The',
#   'company',
#   'closed',
#   'last',
#   'year',
#   'with',
#   'a',
#   'turnover',
#   'of',
#   'about',
#   'four',
#   'million',
#   'euros'],
#  ['Shire',
#   'CEO',
#   'steps',
#   'up',
#   'drive',
#   'to',
#   'get',
#   'Baxalta',
#   'board',
#   'talking'],
#  ['Costco',
#   'A',
#   'Premier',
#   'Retail',
#   'Dividend',
#   'Play',
#   'httpstcoFa5cnh2t0t',
#   'COST'],
#  ['The',
#   'fivestorey',
#   'ecoefficient',
#   'building',
#   'will',
#   'have',
#   'a',
#   'gross',
#   'floor',
#   'area',
#   'of',
#   'about',
#   '15000',
#   'sq',
#   'm',
#   'It',
#   'will',
#   'also',
#   'include',
#   'apartments'],
#  ['The',
#   'first',
#   'installment',
#   'of',
#   'the',
#   'Cinema',
#   'Series',
#   'concludes',
#   'with',
#   'a',
#   'profile',
#   'of',
#   'Finnish',
#   'inventor',
#   'Olavi',
#   'Linden',
#   'whose',
#   'personal',
#   'artistic',
#   'journey',
#   'and',
#   'work',
#   'at',
#   'Fiskars',
#   'has',
#   'led',
#   'to',
#   'dozens',
#   'of',
#   'design',
#   'awards'],
#  ['All', 'are', 'welcome'],
#  ['Stockmann',
#   'and',
#   'Swedish',
#   'sector',
#   'company',
#   'AB',
#   'Lindex',
#   'entered',
#   'into',
#   'an',
#   'agreement',
#   'on',
#   'September',
#   '30',
#   '2007',
#   'whereby',
#   'Stockmann',
#   'or',
#   'a',
#   'whollyowned',
#   'subsidiary',
#   'of',
#   'it',
#   'will',
#   'make',
#   'a',
#   'public',
#   'tender',
#   'offer',
#   'for',
#   'all',
#   'of',
#   'Lindex',
#   's',
#   'issued',
#   'shares'],
#  ['HUHTAMAKI',
#   'OYJ',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   '1692008',
#   'AT',
#   '1332',
#   'Huhtamaki',
#   's',
#   'Capital',
#   'Markets',
#   'Day',
#   'for',
#   'institutional',
#   'investors',
#   'and',
#   'analysts',
#   'is',
#   'held',
#   'in',
#   'Espoo',
#   'September',
#   '16',
#   '2008',
#   'starting',
#   'at',
#   '1330',
#   'pm',
#   'Finnish',
#   'time'],
#  ['We',
#   'are',
#   'pleased',
#   'to',
#   'welcome',
#   'Tapeks',
#   'Noma',
#   'into',
#   'Cramo',
#   'group'],
#  ['Profit', 'before', 'taxes', 'was', 'EUR', '1059', '827', 'million'],
#  ['Royal',
#   'Dutch',
#   'Shell',
#   'to',
#   'Buy',
#   'BG',
#   'Group',
#   'for',
#   'Nearly',
#   '70',
#   'Billion'],
#  ['FinancialWire',
#   'tm',
#   'is',
#   'not',
#   'a',
#   'press',
#   'release',
#   'service',
#   'and',
#   'receives',
#   'no',
#   'compensation',
#   'for',
#   'its',
#   'news',
#   'opinions',
#   'or',
#   'distributions'],
#  ['ASSA',
#   'ABLOY',
#   'Kaupthing',
#   'Bank',
#   'gave',
#   'a',
#   'neutral',
#   'recommendation',
#   'and',
#   'a',
#   'share',
#   'price',
#   'target',
#   'of',
#   '174',
#   'crowns',
#   '247',
#   '19',
#   'euro',
#   'on',
#   'Swedish',
#   'lock',
#   'maker',
#   'Assa',
#   'Abloy',
#   'AB'],
#  ['The',
#   'item',
#   'included',
#   'restructuring',
#   'costs',
#   'of',
#   'EUR1',
#   '6',
#   'm',
#   'while',
#   'a',
#   'year',
#   'earlier',
#   'they',
#   'were',
#   'EUR13',
#   '1',
#   'm',
#   'Diluted',
#   'EPS',
#   'stood',
#   'at',
#   'EUR0',
#   '3',
#   'versus',
#   'a',
#   'loss',
#   'per',
#   'share',
#   'of',
#   'EUR',
#   '01'],
#  ['In',
#   '2005',
#   'the',
#   'bank',
#   'posted',
#   'a',
#   'net',
#   'profit',
#   'of',
#   'Lt',
#   '82',
#   'mn'],
#  ['AAPL',
#   'afternoon',
#   'selloff',
#   'as',
#   'usual',
#   'will',
#   'be',
#   'brutal',
#   'get',
#   'ready',
#   'to',
#   'lose',
#   'a',
#   'ton',
#   'of',
#   'money'],
#  ['TSLA',
#   'recalling',
#   'pretty',
#   'much',
#   'every',
#   'single',
#   'model',
#   'X',
#   'cnnbrk',
#   'got',
#   'to',
#   'short',
#   'that',
#   'even',
#   'at',
#   'work',
#   'you',
#   'jump',
#   'in',
#   'money',
#   'trade'],
#  ['Dolce',
#   'Gabbana',
#   'has',
#   'asked',
#   'the',
#   'European',
#   'Union',
#   'to',
#   'declare',
#   'Marimekko',
#   'Corporation',
#   's',
#   'Unikko',
#   'floral',
#   'pattern',
#   'trademark',
#   'invalid',
#   'in',
#   'a',
#   'continuing',
#   'dispute',
#   'between',
#   'the',
#   'two',
#   'companies'],
#  ['InterContinental',
#   'Hotels',
#   'firstquarter',
#   'global',
#   'room',
#   'revenue',
#   'lags',
#   'estimates'],
#  ['According',
#   'to',
#   'Finnish',
#   'pension',
#   'insurance',
#   'company',
#   'Varma',
#   'Varma',
#   'was',
#   'the',
#   'recipient',
#   'of',
#   'over',
#   'two',
#   'thirds',
#   'of',
#   'the',
#   'revenue',
#   'of',
#   'the',
#   'earningsrelated',
#   'pension',
#   'cover',
#   'that',
#   'was',
#   'under',
#   'competitive',
#   'tendering',
#   'in',
#   'Finland'],
#  ['A',
#   'portion',
#   '125',
#   'million',
#   'will',
#   'be',
#   'recorded',
#   'as',
#   'part',
#   'of',
#   'its',
#   'winnings',
#   'in',
#   'a',
#   'prior',
#   'patent',
#   'dispute',
#   'with',
#   'Finnish',
#   'phone',
#   'maker',
#   'Nokia',
#   'Oyj'],
#  ['LG',
#   'still',
#   'paying',
#   'price',
#   'for',
#   'dividend',
#   'cut',
#   'during',
#   'crisis',
#   'chief',
#   'says'],
#  ['The',
#   'volume',
#   'of',
#   'investments',
#   'in',
#   'the',
#   'two',
#   'phases',
#   'of',
#   'the',
#   'project',
#   'is',
#   'estimated',
#   'at',
#   'USD',
#   '300mn',
#   'EUR',
#   '21503',
#   'mn'],
#  ['Russia',
#   'accounted',
#   'for',
#   '9',
#   'of',
#   'the',
#   'Lagardere',
#   'magazine',
#   'division',
#   's',
#   'revenue',
#   'or',
#   'EUR',
#   '11440',
#   'mn',
#   'USD',
#   '14811',
#   'mn',
#   'in',
#   '2009',
#   'the',
#   'USA',
#   'for',
#   '18'],
#  ['The',
#   'company',
#   'also',
#   'estimates',
#   'the',
#   'already',
#   'carried',
#   'out',
#   'investments',
#   'to',
#   'lead',
#   'to',
#   'an',
#   'increase',
#   'in',
#   'its',
#   'net',
#   'sales',
#   'for',
#   '2010',
#   'from',
#   '2009',
#   'when',
#   'they',
#   'reached',
#   'EUR',
#   '1417',
#   'million'],
#  ['Profit', 'of', 'the', 'accounting', 'period', 'was', 'EUR', '03', 'mn'],
#  ['The',
#   'six',
#   'breweries',
#   'recorded',
#   'a',
#   '52',
#   'percent',
#   'growth',
#   'in',
#   'domestic',
#   'beer',
#   'sales',
#   'last',
#   'year',
#   'to',
#   '27021',
#   'million',
#   'liters',
#   'from',
#   '25688',
#   'million',
#   'liters',
#   'sold',
#   'in',
#   '2005'],
#  ['In',
#   'AugustOctober',
#   '2010',
#   'the',
#   'company',
#   's',
#   'result',
#   'before',
#   'taxes',
#   'totalled',
#   'EUR',
#   '96',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '05',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2009'],
#  ['Systeemitiimi',
#   's',
#   'sales',
#   'and',
#   'project',
#   'resources',
#   'will',
#   'also',
#   'be',
#   'strengthened',
#   'director',
#   'Paul',
#   'Skogberg',
#   'said'],
#  ['Tesco', 'share', 'price', 'jumps', 'as', 'Q3', 'sales', 'top', 'estimates'],
#  ['The', 'fine', 'print', 'is', 'here'],
#  ['The',
#   'price',
#   'for',
#   'logs',
#   'has',
#   'clearly',
#   'improved',
#   'from',
#   '2009',
#   'and',
#   'also',
#   'the',
#   'price',
#   'of',
#   'pulpwood',
#   'has',
#   'gone',
#   'up'],
#  ['Thus',
#   'SysOpen',
#   'Digia',
#   'has',
#   'in',
#   'accordance',
#   'with',
#   'Chapter',
#   '14',
#   'Section',
#   '21',
#   'of',
#   'the',
#   'Finnish',
#   'Companies',
#   'Act',
#   '2991978',
#   '734',
#   'obtained',
#   'title',
#   'to',
#   'all',
#   'the',
#   'shares',
#   'of',
#   'Sentera',
#   'that',
#   'are',
#   'to',
#   'be',
#   'redeemed'],
#  ['Diluted',
#   'earnings',
#   'per',
#   'share',
#   'EPS',
#   'fell',
#   'to',
#   'EUR',
#   '063',
#   'from',
#   'EUR',
#   '171'],
#  ['At',
#   '337',
#   'pm',
#   'Eastern',
#   'time',
#   'a',
#   'block',
#   'of',
#   '2400',
#   'contracts',
#   'changed',
#   'hands',
#   'at',
#   'a',
#   'bid',
#   'price',
#   'of',
#   '045'],
#  ['Some',
#   'of',
#   'the',
#   'most',
#   'recent',
#   'technology',
#   'deliveries',
#   'include',
#   'refinery',
#   'technology',
#   'to',
#   'Anrak',
#   'Aluminium',
#   'an',
#   'iron',
#   'ore',
#   'pelletizing',
#   'plant',
#   'to',
#   'Tata',
#   'Steel',
#   'and',
#   'iron',
#   'ore',
#   'sintering',
#   'plants',
#   'to',
#   'Bhushan',
#   'Steel'],
#  ['VIPS',
#   'similar',
#   'pattern',
#   'like',
#   'beginning',
#   'of',
#   'May',
#   'Did',
#   'u',
#   'sell',
#   'Same',
#   'nowwill',
#   'go',
#   'up',
#   'much',
#   'higher',
#   'after',
#   'this',
#   'drop'],
#  ['The',
#   'firm',
#   'generated',
#   'sales',
#   'of',
#   '187',
#   'mln',
#   'eur',
#   'in',
#   '2005'],
#  ['Stora',
#   'Enso',
#   'has',
#   'also',
#   'had',
#   'meetings',
#   'with',
#   'the',
#   'labor',
#   'authorities',
#   'Employment',
#   'and',
#   'Economic',
#   'Development',
#   'Centres',
#   'and',
#   'representatives',
#   'of',
#   'the',
#   'government',
#   'in',
#   'order',
#   'to',
#   'find',
#   'solutions'],
#  ['AstraZeneca', 'profit', 'down', 'as', 'sales', 'of', 'stalwarts', 'fade'],
#  ['RT',
#   'andrewnyquist',
#   'Chartology',
#   'Yahoo',
#   'httpstksco1itr',
#   'YHOO',
#   'Crazy',
#   'looking',
#   'chart',
#   'but',
#   'nearing',
#   'breakout',
#   'resistance',
#   'line'],
#  ['Most',
#   'bullish',
#   'stocks',
#   'on',
#   'Twitter',
#   'during',
#   'this',
#   'dip',
#   'YHOO',
#   'GDX',
#   'GOOGL',
#   'STZ',
#   'GOLD',
#   'EW',
#   'VZ',
#   'CELG',
#   'SBUX',
#   'SCTY',
#   'more',
#   'httpstcoiuZJelfwt3'],
#  ['Finnish',
#   'GeoSentric',
#   's',
#   'net',
#   'sales',
#   'decreased',
#   'to',
#   'EUR',
#   '939000',
#   'in',
#   'JanuaryMarch',
#   '2009'],
#  ['Cohen',
#   'Steers',
#   'Inc',
#   '5',
#   '534',
#   '626',
#   'shares',
#   'representing',
#   '4985',
#   'of',
#   'the',
#   'share',
#   'capital',
#   'and',
#   'voting',
#   'rights'],
#  ['More',
#   'staff',
#   'has',
#   'been',
#   'recruited',
#   'in',
#   'Japan',
#   'to',
#   'further',
#   'complement',
#   'its',
#   'network',
#   'of',
#   'close',
#   'to',
#   '50',
#   'service',
#   'locations',
#   'in',
#   'more',
#   'than',
#   '20',
#   'countries',
#   'worldwide'],
#  ['Paper',
#   'companies',
#   'were',
#   'in',
#   'negative',
#   'territories',
#   'with',
#   'Stora',
#   'Enso',
#   'R',
#   'shedding',
#   '162',
#   'pct',
#   'to',
#   '1273',
#   'eur',
#   'UPMKymmene',
#   'down',
#   '080',
#   'pct',
#   'at',
#   '1864',
#   'eur',
#   'and',
#   'Mreal',
#   'B',
#   '018',
#   'pct',
#   'lower',
#   'at',
#   '557',
#   'eur'],
#  ['KaukoTelko',
#   's',
#   'centralized',
#   'administration',
#   'will',
#   'be',
#   'dissolved',
#   'and',
#   'appropriate',
#   'parts',
#   'of',
#   'it',
#   'will',
#   'be',
#   'transferred',
#   'to',
#   'operating',
#   'activities',
#   'and',
#   'Group',
#   'administration',
#   'by',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year'],
#  ['Operating',
#   'profit',
#   'for',
#   'the',
#   'quarter',
#   'AprilJune',
#   '2006',
#   'amounted',
#   'to',
#   'EUR182',
#   '2',
#   'm',
#   'on',
#   'sales',
#   'of',
#   'EUR3',
#   '62',
#   'bn'],
#  ['Atria',
#   'chose',
#   'the',
#   'DeLight',
#   'to',
#   'attract',
#   'consumers',
#   'in',
#   'the',
#   '2545',
#   'age',
#   'group',
#   'to',
#   'its',
#   'Atria',
#   'Fresh',
#   'range',
#   'of',
#   'microwaveable',
#   'meals'],
#  ['Finnish',
#   'IT',
#   'solutions',
#   'provider',
#   'Affecto',
#   'Oyj',
#   'HEL',
#   'AFE1V',
#   'said',
#   'today',
#   'its',
#   'slipped',
#   'to',
#   'a',
#   'net',
#   'loss',
#   'of',
#   'EUR',
#   '115000',
#   'USD',
#   '152000',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010',
#   'from',
#   'a',
#   'profit',
#   'of',
#   'EUR',
#   '845000',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'a',
#   'year',
#   'earlier'],
#  ['US',
#   'sanctions',
#   'put',
#   'GazpromShell',
#   'alliance',
#   'plans',
#   'in',
#   'jeopardy'],
#  ['Profit',
#   'for',
#   'the',
#   'period',
#   'was',
#   'EUR',
#   '109',
#   'mn',
#   'down',
#   'from',
#   'EUR',
#   '143',
#   'mn',
#   'in',
#   '2009'],
#  ['Profit',
#   'for',
#   'the',
#   'period',
#   'was',
#   'EUR',
#   '59',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '13',
#   'mn'],
#  ['Operating',
#   'profit',
#   'fell',
#   'to',
#   'EUR',
#   '203',
#   'mn',
#   'from',
#   'EUR',
#   '742',
#   'mn',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2008'],
#  ['However',
#   'sales',
#   'returned',
#   'to',
#   'growth',
#   'in',
#   'AprilJune',
#   '2010',
#   'CEO',
#   'Pekka',
#   'Eloholma',
#   'said'],
#  ['Operating',
#   'profit',
#   'totaled',
#   'EUR',
#   '186',
#   'mn',
#   'or',
#   '83',
#   'of',
#   'net',
#   'sales'],
#  ['Changes',
#   'in',
#   'the',
#   'market',
#   'situation',
#   'and',
#   'tougher',
#   'price',
#   'competition',
#   'have',
#   'substantially',
#   'reduced',
#   'demand',
#   'for',
#   'bread',
#   'packaging',
#   'manufactured',
#   'at',
#   'the',
#   'Kauhava',
#   'plant',
#   'according',
#   'to',
#   'the',
#   'company'],
#  ['In',
#   'connection',
#   'with',
#   'the',
#   'deal',
#   'Digia',
#   'will',
#   'employ',
#   '19',
#   'persons',
#   'from',
#   'Nokia',
#   'in',
#   'Oslo',
#   'and',
#   'in',
#   'Silicon',
#   'Valley',
#   'in',
#   'the',
#   'USA'],
#  ['The',
#   'Brazilian',
#   'unit',
#   'of',
#   'Finnish',
#   'security',
#   'solutions',
#   'provider',
#   'FSecure',
#   'signed',
#   'up',
#   '1500',
#   'new',
#   'clients',
#   'last',
#   'year',
#   'online',
#   'news',
#   'source',
#   'Reseller',
#   'Web',
#   'quoted',
#   'the',
#   'division',
#   's',
#   'commercial',
#   'director',
#   'Vladimir',
#   'Brandúo',
#   'as',
#   'saying'],
#  ['The',
#   'fair',
#   'value',
#   'of',
#   'the',
#   'company',
#   's',
#   'investment',
#   'properties',
#   'went',
#   'down',
#   'to',
#   'EUR',
#   '2768',
#   'billion',
#   'at',
#   'the',
#   'end',
#   'of',
#   '2009',
#   'from',
#   'EUR',
#   '2916',
#   'billion',
#   'a',
#   'year',
#   'earlier'],
#  ['Dealers',
#   'said',
#   'the',
#   'share',
#   'was',
#   'largely',
#   'hit',
#   'by',
#   'investor',
#   'disappointment',
#   'about',
#   'a',
#   'refining',
#   'margin',
#   'of',
#   'just',
#   '948',
#   'usd',
#   'per',
#   'barrel',
#   'for',
#   'the',
#   'quarter',
#   'and',
#   'the',
#   'performance',
#   'of',
#   'its',
#   'shipping',
#   'unit',
#   'which',
#   'saw',
#   'EBIT',
#   'drop',
#   'to',
#   '5',
#   'mln',
#   'eur',
#   'from',
#   '20',
#   'mln',
#   'eur',
#   'a',
#   'year',
#   'amid',
#   'a',
#   'fall',
#   'in',
#   'volumes',
#   'and',
#   'tanker',
#   'rates'],
#  ['It',
#   'is',
#   'a',
#   'testament',
#   'to',
#   'the',
#   'quality',
#   'of',
#   'our',
#   'LTE',
#   'solution',
#   'and',
#   'our',
#   'commitment',
#   'to',
#   'the',
#   'Japanese',
#   'market',
#   'he',
#   'added'],
#  ['The',
#   'companies',
#   'aim',
#   'is',
#   'to',
#   'finalize',
#   'the',
#   'negotiations',
#   'and',
#   'sign',
#   'the',
#   'contracts',
#   'at',
#   'the',
#   'start',
#   'of',
#   'October',
#   '2008'],
#  ['Metso',
#   'Foundries',
#   'Jyvaskyla',
#   'Oy',
#   'will',
#   'discontinue',
#   'production',
#   'on',
#   'this',
#   'line',
#   'by',
#   '30',
#   'September',
#   '2008',
#   'the',
#   'company',
#   'said'],
#  ['A',
#   'total',
#   'six',
#   'of',
#   'the',
#   'polled',
#   'analysts',
#   'rated',
#   'Mreal',
#   'two',
#   'gave',
#   'buy',
#   'accumulate',
#   'three',
#   'gave',
#   'hold',
#   'and',
#   'only',
#   'one',
#   'gave',
#   'sell'],
#  ['In',
#   'September',
#   '2010',
#   'the',
#   'Finnish',
#   'group',
#   'agreed',
#   'to',
#   'buy',
#   'Danish',
#   'company',
#   'Rose',
#   'Poultry',
#   'AS',
#   'for',
#   'up',
#   'to',
#   'EUR23',
#   '9',
#   'm',
#   'in',
#   'a',
#   'combination',
#   'of',
#   'cash',
#   'and',
#   'stock'],
#  ['YANG', 'Double', 'bottom', '52'],
#  ['Tesco',
#   'share',
#   'price',
#   'down',
#   'as',
#   'grocer',
#   'faces',
#   'SFO',
#   'investigation',
#   'outcome'],
#  ['aapl',
#   'news',
#   'is',
#   'becoming',
#   'very',
#   'bullish',
#   'again',
#   'httpstkscotMU'],
#  ['GS',
#   'Engineering',
#   'will',
#   'install',
#   'the',
#   'valves',
#   'at',
#   'a',
#   'liquefied',
#   'natural',
#   'gas',
#   'LNG',
#   'plant',
#   'it',
#   'has',
#   'built',
#   'for',
#   'UAE',
#   'LNG',
#   'extraction',
#   'and',
#   'gas',
#   'plants',
#   'operator',
#   'GASCO',
#   'in',
#   'Ruwais',
#   'UAE'],
#  ['The',
#   'percentages',
#   'of',
#   'shares',
#   'and',
#   'voting',
#   'rights',
#   'have',
#   'been',
#   'calculated',
#   'in',
#   'proportion',
#   'to',
#   'the',
#   'total',
#   'number',
#   'of',
#   'shares',
#   'registered',
#   'with',
#   'the',
#   'Trade',
#   'Register',
#   'and',
#   'the',
#   'total',
#   'number',
#   'of',
#   'voting',
#   'rights',
#   'related',
#   'to',
#   'them'],
#  ['MReal',
#   'said',
#   'there',
#   'are',
#   'no',
#   'grounds',
#   'for',
#   'the',
#   'rumors',
#   'which',
#   'have',
#   'been',
#   'circulating',
#   'in',
#   'the',
#   'market',
#   'for',
#   'some',
#   'months'],
#  ['Lember',
#   'said',
#   'the',
#   'matter',
#   'was',
#   'topical',
#   'also',
#   'in',
#   'Estonia',
#   'where',
#   'a',
#   'bill',
#   'has',
#   'been',
#   'drafted',
#   'at',
#   'the',
#   'Social',
#   'Affairs',
#   'Ministry',
#   'that',
#   'would',
#   'scrap',
#   'oldage',
#   'pensions',
#   'on',
#   'favorable',
#   'conditions'],
#  ['Moody',
#   's',
#   'said',
#   'it',
#   'gave',
#   'P',
#   'A1',
#   'longterm',
#   'senior',
#   'unsecured',
#   'and',
#   'P',
#   'P1',
#   'shortterm',
#   'debt',
#   'ratings',
#   'to',
#   'Finnish',
#   'lender',
#   'Aktia',
#   'Bank',
#   's',
#   'EUR1bn',
#   'USD1',
#   '4',
#   'bn',
#   'euro',
#   'mediumterm',
#   'note',
#   'EMTN',
#   'program',
#   'of',
#   '25',
#   'March',
#   '2011'],
#  ['TSLA', 'recall'],
#  ['The',
#   'liquidity',
#   'providing',
#   'was',
#   'interrupted',
#   'on',
#   'May',
#   '11',
#   '2007',
#   'when',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   's',
#   'shares',
#   'traded',
#   'below',
#   '050',
#   'cent',
#   'Aspocomp',
#   's',
#   'stock',
#   'exchange',
#   'release',
#   '1152007'],
#  ['Hargreaves',
#   'Lansdown',
#   'bucks',
#   'weak',
#   'markets',
#   'to',
#   'see',
#   'assets',
#   'rise',
#   '26',
#   'percent'],
#  ['At',
#   '1259',
#   'pm',
#   'the',
#   'OMX',
#   'Helsinki',
#   '25',
#   'index',
#   'was',
#   '032',
#   'pct',
#   'lower',
#   'at',
#   '269481'],
#  ['The',
#   'decision',
#   'means',
#   'temporary',
#   'layoffs',
#   'of',
#   'fixed',
#   'duration',
#   'at',
#   'the',
#   'company',
#   's',
#   'Nastola',
#   'and',
#   'Jyvaskyla',
#   'units',
#   'in',
#   'southern',
#   'and',
#   'central',
#   'Finland',
#   'respectively'],
#  ['The', 'value', 'of', 'the', 'orders', 'is', 'over', 'EUR', '10mn'],
#  ['Ms',
#   'Laakso',
#   'will',
#   'be',
#   'responsible',
#   'for',
#   'HKScan',
#   's',
#   'HR',
#   'functions',
#   'and',
#   'for',
#   'their',
#   'development',
#   'in',
#   'all',
#   'of',
#   'the',
#   'Group',
#   'smarket',
#   'areas'],
#  ['Fiskars',
#   'is',
#   'also',
#   'engaged',
#   'in',
#   'the',
#   'global',
#   'supply',
#   'of',
#   'marine',
#   'and',
#   'energy',
#   'equipment',
#   'solutions',
#   'and',
#   'services',
#   'through',
#   'its',
#   'associated',
#   'company',
#   'Wartsila',
#   'Corporation'],
#  ['Aberdeen', 'Asset', 'Management', 'Gains', 'Foothold', 'In', 'China'],
#  ['Finland',
#   's',
#   'dominating',
#   'rail',
#   'company',
#   'VR',
#   'is',
#   'planning',
#   'to',
#   'set',
#   'the',
#   'infected',
#   'passengers',
#   'for',
#   'longdistance',
#   'trip',
#   'in',
#   'a',
#   'separate',
#   'carriage'],
#  ['In',
#   'November',
#   'the',
#   'Finnish',
#   'government',
#   'decreased',
#   'its',
#   'ownership',
#   'in',
#   'the',
#   'company',
#   'further',
#   'to',
#   '311',
#   'percent',
#   'from',
#   '38',
#   'percent'],
#  ['Finnish',
#   'Exel',
#   'Composites',
#   'a',
#   'technology',
#   'company',
#   'that',
#   'designs',
#   'manufactures',
#   'and',
#   'markets',
#   'composite',
#   'profiles',
#   'and',
#   'tubes',
#   'for',
#   'various',
#   'industrial',
#   'applications',
#   'reports',
#   'its',
#   'net',
#   'sales',
#   'decreased',
#   'by',
#   '06',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010',
#   'to',
#   'EUR',
#   '192',
#   'mn',
#   'from',
#   'EUR',
#   '193',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2009'],
#  ['Of',
#   'Bavelloni',
#   's',
#   'and',
#   'NST',
#   's',
#   'joint',
#   'ventures',
#   'Bavelloni',
#   'Tools',
#   'completes',
#   'semiproducts',
#   'that',
#   'are',
#   'produced',
#   'in',
#   'Italy',
#   'into',
#   'highquality',
#   'tools',
#   'that',
#   'will',
#   'be',
#   'sold',
#   'under',
#   'the',
#   'DiaPol',
#   'brand'],
#  ['The',
#   'tool',
#   'is',
#   'a',
#   'patent',
#   'pending',
#   'design',
#   'that',
#   'allows',
#   'consumers',
#   'to',
#   'lay',
#   'out',
#   'their',
#   'entire',
#   'project',
#   'on',
#   'a',
#   'removable',
#   'plate',
#   'using',
#   'multiple',
#   'clear',
#   'stamps',
#   'of',
#   'any',
#   'kind'],
#  ['GOOGL',
#   'is',
#   'a',
#   'short',
#   'below',
#   '740',
#   'into',
#   'the',
#   'upper',
#   'BB',
#   'and',
#   'is',
#   'overbought'],
#  ['LIGHTS',
#   'OUT',
#   'Before',
#   'curfew',
#   'curl',
#   'up',
#   'with',
#   'the',
#   'latest',
#   'bestseller',
#   'and',
#   'treat',
#   'your',
#   'eyes',
#   'to',
#   'the',
#   'perfect',
#   'reading',
#   'light',
#   'from',
#   'Luceplan'],
#  ['UPMKymmene',
#   'Corp',
#   'the',
#   'world',
#   's',
#   'largest',
#   'maker',
#   'of',
#   'magazine',
#   'paper',
#   'on',
#   'Tuesday',
#   'reported',
#   'a',
#   '19percent',
#   'profit',
#   'drop',
#   'as',
#   'lower',
#   'paper',
#   'prices',
#   'higher',
#   'costs',
#   'and',
#   'a',
#   'strong',
#   'euro',
#   'hurt',
#   'revenue'],
#  ['The',
#   'total',
#   'value',
#   'of',
#   'the',
#   'contract',
#   'is',
#   'some',
#   'EUR',
#   '8',
#   'million'],
#  ['The',
#   'prerequisite',
#   'for',
#   'inclusion',
#   'in',
#   'the',
#   'program',
#   'and',
#   'for',
#   'receipt',
#   'of',
#   'any',
#   'gains',
#   'is',
#   'that',
#   'key',
#   'employees',
#   'acquire',
#   'Aspo',
#   'shares',
#   'to',
#   'the',
#   'amount',
#   'determined',
#   'by',
#   'the',
#   'Board',
#   'in',
#   'advance',
#   'in',
#   'the',
#   'maximum'],
#  ['Mr',
#   'Doring',
#   'has',
#   'been',
#   'with',
#   'Eaton',
#   'since',
#   '1989',
#   'and',
#   'acted',
#   'as',
#   'the',
#   'Business',
#   'Unit',
#   'Manager',
#   'for',
#   'Eaton',
#   's',
#   'Power',
#   'Controls',
#   'Business',
#   'Unit',
#   'since',
#   'January',
#   '2007'],
#  ['The',
#   '250',
#   'sq',
#   'm',
#   '2691',
#   'sq',
#   'ft',
#   'store',
#   'in',
#   'Copenhagen',
#   's',
#   'premier',
#   'shopping',
#   'district',
#   'was',
#   'inaugurated',
#   'today',
#   'further',
#   'strengthening',
#   'the',
#   'company',
#   's',
#   'presence',
#   'in',
#   'Nordic',
#   'capitals'],
#  ['In',
#   'the',
#   'financial',
#   'statement',
#   'for',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2010',
#   'Tikkurila',
#   'is',
#   'reported',
#   'under',
#   'discontinued',
#   'operations'],
#  ['The',
#   'world',
#   's',
#   'second',
#   'largest',
#   'stainless',
#   'steel',
#   'maker',
#   'said',
#   'net',
#   'profit',
#   'in',
#   'the',
#   'threemonth',
#   'period',
#   'until',
#   'Dec',
#   '31',
#   'surged',
#   'to',
#   'euro603',
#   'million',
#   'US',
#   '781',
#   'million',
#   'or',
#   'euro3',
#   '33',
#   'US',
#   '431',
#   'per',
#   'share',
#   'from',
#   'euro172',
#   'million',
#   'or',
#   'euro0',
#   '94',
#   'per',
#   'share',
#   'the',
#   'previous',
#   'year'],
#  ['Name',
#   'of',
#   'Applicant',
#   'Jot',
#   'Automation',
#   'OYName',
#   'of',
#   'Inventor',
#   'Mammila',
#   'Tuomo',
#   'Piirainen',
#   'Mika',
#   'and',
#   'Kellokoski',
#   'MikaApplication',
#   'No',
#   '2424KOLNP2008',
#   'ADate',
#   'of',
#   'filing',
#   'of',
#   'Application',
#   '16062008Publication',
#   'Date',
#   '30012009'],
#  ['Netflix',
#   'Grows',
#   'Efforts',
#   'To',
#   'Create',
#   'Loyal',
#   'Customers',
#   'NFLX',
#   'httpstco5QXBkoBphe'],
#  ['The',
#   'OMX',
#   'Nordic',
#   '40',
#   'OMXN40',
#   'index',
#   'comprising',
#   'the',
#   '40',
#   'most',
#   'traded',
#   'Nordic',
#   'stocks',
#   'on',
#   'the',
#   'Nasdaq',
#   'OMX',
#   'exchange',
#   'closed',
#   'down',
#   '087',
#   'at',
#   '106414',
#   'points',
#   'on',
#   'Thursday'],
#  ['AAPL',
#   'nibbling',
#   'on',
#   'a',
#   'small',
#   'long',
#   'via',
#   '525',
#   'buying',
#   'off',
#   '13min',
#   'charts'],
#  ['The',
#   'operating',
#   'margin',
#   'of',
#   'Aker',
#   'Yards',
#   'Cruise',
#   'Ferries',
#   'division',
#   'went',
#   'down',
#   'from',
#   '83',
#   'to',
#   '64',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2007'],
#  ['TYC',
#   'just',
#   'about',
#   'to',
#   'break',
#   'out',
#   'to',
#   'new',
#   'highs',
#   'lots',
#   'of',
#   'technicals',
#   'looking',
#   'great',
#   'right',
#   'now'],
#  ['Eero',
#   'Katajavuori',
#   'currently',
#   'Group',
#   'Vice',
#   'President',
#   'Human',
#   'Resources',
#   'will',
#   'take',
#   'a',
#   'yearlong',
#   'sabbatical',
#   'starting',
#   'from',
#   'October',
#   '1',
#   '2010'],
#  ['Whats',
#   'up',
#   'with',
#   'LULU',
#   'Numbers',
#   'looked',
#   'good',
#   'not',
#   'great',
#   'but',
#   'good',
#   'I',
#   'think',
#   'conference',
#   'call',
#   'will',
#   'instill',
#   'confidence'],
#  ['The',
#   'adjustment',
#   'measures',
#   'will',
#   'be',
#   'carried',
#   'out',
#   'in',
#   'phases',
#   'to',
#   'secure',
#   'the',
#   'delivery',
#   'capability'],
#  ['Alma',
#   'Media',
#   'Corporation',
#   'Press',
#   'Release',
#   '15',
#   'March',
#   '2010',
#   'TYRVAAN',
#   'SANOMAT',
#   'AND',
#   'PAIKALLISSANOMAT',
#   'BEING',
#   'BOUGHT',
#   'BY',
#   'SUOMEN',
#   'PAIKALLISSANOMAT',
#   'Two',
#   'local',
#   'papers',
#   'Tyrvaan',
#   'Sanomat',
#   'and',
#   'Paikallissanomat',
#   'appearing',
#   'in',
#   'Sastamala',
#   'and',
#   'its',
#   'neighbouring',
#   'municipalities',
#   'are',
#   'to',
#   'be',
#   'bought',
#   'by',
#   'Suomen',
#   'Paikallissanomat',
#   'Oy'],
#  ['Temporary',
#   'layoffs',
#   'affecting',
#   'the',
#   'entire',
#   'workforce',
#   'will',
#   'also',
#   'be',
#   'implemented'],
#  ['A',
#   'meeting',
#   'for',
#   'the',
#   'media',
#   'and',
#   'analysts',
#   'will',
#   'be',
#   'held',
#   'on',
#   'the',
#   'same',
#   'day',
#   'at',
#   '1030',
#   'am',
#   'at',
#   'Stonesoft',
#   'Headquarters',
#   'in',
#   'Helsinki',
#   'Italahdenkatu',
#   '22',
#   'A',
#   'The',
#   'Interim',
#   'report',
#   'will',
#   'be',
#   'presented',
#   'by',
#   'Stonesoft',
#   's',
#   'CEO',
#   'Ilkka',
#   'Hiidenheimo'],
#  ['Finnish',
#   'SampoRosenlew',
#   'manufactures',
#   'approximately',
#   'seven',
#   'forest',
#   'machines',
#   'monthly',
#   'and',
#   'about',
#   'half',
#   'of',
#   'machines',
#   'are',
#   'exported'],
#  ['Facebook',
#   'near',
#   'a',
#   'buy',
#   'point',
#   'last',
#   'week',
#   'faces',
#   'a',
#   'different',
#   'technical',
#   'test',
#   'today',
#   'httpstcoc72LLMpiNM',
#   'FB',
#   'AAPL',
#   'NFLX',
#   'httpstcofPFbYTYPuY'],
#  ['4',
#   'February',
#   '2011',
#   'Finnish',
#   'broadband',
#   'data',
#   'communication',
#   'systems',
#   'provider',
#   'Teleste',
#   'Oyj',
#   'HEL',
#   'TLT1V',
#   'said',
#   'Wednesday',
#   'its',
#   'net',
#   'profit',
#   'rocketed',
#   'to',
#   'EUR4',
#   '8',
#   'm',
#   'in',
#   '2010',
#   'from',
#   'EUR416',
#   '000',
#   'in',
#   '2009',
#   'and',
#   'it',
#   'lifted',
#   'its',
#   'dividend',
#   'proposal'],
#  ['FREE',
#   'Ha',
#   'Heeeeeere',
#   'comes',
#   'the',
#   'pump',
#   'So',
#   'glad',
#   'I',
#   'picked',
#   'up',
#   '9K',
#   'end',
#   'of',
#   'day',
#   'Get',
#   'ready',
#   'for',
#   'the',
#   'bull',
#   'ride'],
#  ['Finnish',
#   'technology',
#   'group',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   'OMX',
#   'Helsinki',
#   'ACG1V',
#   'issued',
#   'its',
#   'third',
#   'quarter',
#   'report',
#   'on',
#   'Thursday',
#   '13',
#   'November',
#   'posting',
#   'an',
#   'operating',
#   'profit',
#   'of',
#   'EUR0',
#   '4',
#   'm',
#   'as',
#   'compared',
#   'to',
#   'a',
#   'loss',
#   'of',
#   'EUR0',
#   '5',
#   'm',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2007'],
#  ['The',
#   'building',
#   'complex',
#   'consists',
#   'of',
#   'highquality',
#   'office',
#   'and',
#   'retail',
#   'space',
#   'totalling',
#   '49200',
#   'square',
#   'metres',
#   'the',
#   'company',
#   'said'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'and',
#   'Kesko',
#   'Group',
#   'are',
#   'ending',
#   'their',
#   'loyal',
#   'customer',
#   'cooperation'],
#  ['The',
#   'unit',
#   'is',
#   'planned',
#   'to',
#   'be',
#   'operational',
#   'during',
#   'the',
#   'second',
#   'half',
#   'of',
#   '2007',
#   'and',
#   'in',
#   'full',
#   'stream',
#   'in',
#   '2008'],
#  ['ITG',
#   's',
#   'share',
#   'in',
#   'the',
#   'deal',
#   'is',
#   'estimated',
#   'at',
#   'some',
#   '500000',
#   'euro',
#   '627000'],
#  ['The',
#   'plant',
#   'is',
#   'expected',
#   'to',
#   'enter',
#   'commercial',
#   'operation',
#   'by',
#   'mid2009'],
#  ['Aspo',
#   'has',
#   'also',
#   'investigated',
#   'the',
#   'sales',
#   'opportunities',
#   'of',
#   'Kaukomarkkinat',
#   's',
#   'electronics',
#   'business'],
#  ['BG', 'Group', 'appoints', 'new', 'CEO', 'one', 'month', 'early'],
#  ['The',
#   'acquisition',
#   'will',
#   'have',
#   'an',
#   'immediate',
#   'positive',
#   'impact',
#   'on',
#   'Aspocomp',
#   's',
#   'financial',
#   'result'],
#  ['Finnair',
#   's',
#   'passenger',
#   'load',
#   'factor',
#   'which',
#   'measures',
#   'the',
#   'number',
#   'of',
#   'sold',
#   'seats',
#   'as',
#   'a',
#   'share',
#   'of',
#   'all',
#   'available',
#   'seats',
#   'dropped',
#   'by',
#   '13',
#   'percentage',
#   'points',
#   'to',
#   '767',
#   'in',
#   'September'],
#  ['RT',
#   'bman1',
#   'LNG',
#   'looks',
#   'primed',
#   'also',
#   'EGHT',
#   'poised',
#   'to',
#   'run',
#   'too'],
#  ['It',
#   'is',
#   'also',
#   '77',
#   'pct',
#   'above',
#   'the',
#   '12month',
#   'volume',
#   'weighted',
#   'average',
#   'price',
#   'of',
#   'the',
#   'stock'],
#  ['Coke',
#   'dividend',
#   '3',
#   'Google',
#   'dividend',
#   '0',
#   'For',
#   'passive',
#   'income',
#   'Coke',
#   'takes',
#   'it',
#   'GOOG',
#   'KO',
#   'httpstcoQBsoWjxOST'],
#  ['Profit',
#   'before',
#   'taxes',
#   'was',
#   'EUR',
#   '54',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '36',
#   'mn',
#   'a',
#   'year',
#   'earlier'],
#  ['The',
#   'subsidiary',
#   'is',
#   'setting',
#   'up',
#   'a',
#   'facility',
#   'for',
#   'manufacturing',
#   'highdensity',
#   'interconnection',
#   'printed',
#   'circuit',
#   'boards',
#   'or',
#   'PCBs',
#   'at',
#   'Nokia',
#   's',
#   'special',
#   'economic',
#   'zone',
#   'at',
#   'Sriperumbudur',
#   'near',
#   'Chennai'],
#  ['CRM',
#   'Sep',
#   '40',
#   'calls',
#   'are',
#   '35',
#   'since',
#   'entry',
#   'BANG',
#   'httpstkscodeDm'],
#  ['In',
#   'JanuaryJune',
#   '2010',
#   'diluted',
#   'loss',
#   'per',
#   'share',
#   'stood',
#   'at',
#   'EUR0',
#   '3',
#   'versus',
#   'EUR0',
#   '1',
#   'in',
#   'the',
#   'first',
#   'half',
#   'of',
#   '2009'],
#  ['Rapala',
#   'said',
#   'it',
#   'estimates',
#   'it',
#   'will',
#   'make',
#   'savings',
#   'of',
#   '12',
#   'mln',
#   'eur',
#   'a',
#   'year',
#   'by',
#   'centralising',
#   'its',
#   'French',
#   'operations',
#   'at',
#   'one',
#   'site'],
#  ['VMW',
#   'Got',
#   'a',
#   'nice',
#   'push',
#   'today',
#   'following',
#   'small',
#   'sweepers',
#   'of',
#   'May',
#   'C',
#   'this',
#   'morning'],
#  ['That',
#   'topped',
#   'consensus',
#   'forecasts',
#   'for',
#   'earnings',
#   'of',
#   '021',
#   'euros',
#   'a',
#   'share'],
#  ['RD', 'Loan'],
#  ['In',
#   'future',
#   'the',
#   'company',
#   'intends',
#   'to',
#   'look',
#   'for',
#   'knowhow',
#   'from',
#   'outside',
#   'the',
#   'company',
#   'and',
#   'to',
#   'cooperate',
#   'with',
#   'other',
#   'actors',
#   'in',
#   'the',
#   'sector'],
#  ['You',
#   'need',
#   'to',
#   'be',
#   'ready',
#   'when',
#   'the',
#   'window',
#   'opens',
#   'up',
#   'Rosberg',
#   'said'],
#  ['More',
#   'than',
#   '50000',
#   'tonnes',
#   'of',
#   'asphalt',
#   'mix',
#   'will',
#   'be',
#   'used',
#   'in',
#   'the',
#   'contract'],
#  ['PA',
#   'JPMorgan',
#   'Chase',
#   'and',
#   'Co',
#   'NYSE',
#   'JPM',
#   'and',
#   'Pohjoa',
#   'Bank',
#   'are',
#   'joint',
#   'leadmanagers',
#   'on',
#   'the',
#   'senior',
#   'unsecured',
#   'deal'],
#  ['CTRP',
#   'breaking',
#   'out',
#   'here',
#   'on',
#   'good',
#   'vol',
#   'and',
#   'a',
#   'parser',
#   'buy',
#   'signal',
#   'noticed',
#   'this',
#   'on',
#   'bob',
#   'langs',
#   'comments',
#   'looking',
#   'for',
#   '48',
#   'fast'],
#  ['Sales',
#   'in',
#   'Finland',
#   'decreased',
#   'by',
#   '105',
#   'in',
#   'January',
#   'while',
#   'sales',
#   'outside',
#   'Finland',
#   'dropped',
#   'by',
#   '17'],
#  ['The',
#   'pulp',
#   'production',
#   'in',
#   'Finnish',
#   'Kemijñrvi',
#   'will',
#   'also',
#   'be',
#   'liquidated',
#   'and',
#   'about',
#   '1100',
#   'employees',
#   'loose',
#   'their',
#   'jobs'],
#  ['Nordea',
#   'was',
#   'the',
#   'cheapest',
#   'also',
#   'for',
#   'a',
#   'couple',
#   'in',
#   'their',
#   '30s',
#   'with',
#   'debt'],
#  ['Jussi',
#   'Pesonen',
#   'member',
#   'of',
#   'the',
#   'Sampo',
#   'Board',
#   'since',
#   '2006',
#   'will',
#   'renounce',
#   'his',
#   'seat',
#   'in',
#   'Sampo',
#   'Board'],
#  ['Tesla',
#   'is',
#   'recalling',
#   '2700',
#   'Model',
#   'X',
#   'cars',
#   'httpstco8Z7BkVsTl9',
#   'TSLA'],
#  ['Adjusted',
#   'for',
#   'changes',
#   'in',
#   'the',
#   'Group',
#   'structure',
#   'the',
#   'Division',
#   's',
#   'net',
#   'sales',
#   'increased',
#   'by',
#   '17'],
#  ['Making',
#   'matters',
#   'more',
#   'difficult',
#   'the',
#   'company',
#   'said',
#   'it',
#   'has',
#   'been',
#   'grappling',
#   'with',
#   'higher',
#   'oil',
#   'and',
#   'gas',
#   'prices',
#   'which',
#   'have',
#   'pushed',
#   'up',
#   'the',
#   'cost',
#   'of',
#   'energy',
#   'raw',
#   'materials',
#   'and',
#   'transportation'],
#  ['The',
#   'amending',
#   'of',
#   'the',
#   'proposal',
#   'simplifies',
#   'the',
#   'proposed',
#   'plan',
#   'and',
#   'increases',
#   'the',
#   'incentive',
#   'for',
#   'key',
#   'employees',
#   'to',
#   'stay',
#   'in',
#   'the',
#   'Company'],
#  ['The',
#   'solution',
#   'will',
#   'now',
#   'be',
#   'expanded',
#   'to',
#   'include',
#   'all',
#   'ground',
#   'staff',
#   'tasks'],
#  ['Operating',
#   'loss',
#   'totalled',
#   'EUR',
#   '32',
#   'mn',
#   'compared',
#   'to',
#   'a',
#   'profit',
#   'of',
#   'EUR',
#   '72',
#   'mn',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008'],
#  ['On',
#   'FEDDAY',
#   'looking',
#   'for',
#   'a',
#   'sharp',
#   'move',
#   'up',
#   'in',
#   'equities',
#   'AAPL',
#   'HD',
#   'LOW',
#   'FB',
#   'seeing',
#   'UVXY',
#   'TVIX',
#   'getting',
#   'hammered',
#   'even',
#   'though',
#   'market',
#   'is',
#   'down'],
#  ['Net',
#   'sales',
#   'totaled',
#   'EUR',
#   '936',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '932',
#   'mn',
#   'in',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2005'],
#  ['As',
#   'a',
#   'consequence',
#   'the',
#   'Works',
#   'Council',
#   'had',
#   'withdrawn',
#   'its',
#   'petition',
#   'to',
#   'suspend',
#   'the',
#   'reorganisation'],
#  ['CEO',
#   'Erkki',
#   'Jñrvinen',
#   'is',
#   'happy',
#   'with',
#   'the',
#   'company',
#   's',
#   'performance',
#   'in',
#   '2010'],
#  ['Comparable',
#   'net',
#   'sales',
#   'are',
#   'expected',
#   'to',
#   'increase',
#   'more',
#   'than',
#   '10',
#   'in',
#   '2008',
#   'in',
#   'line',
#   'with',
#   'group',
#   'target'],
#  ['Following',
#   'the',
#   'transaction',
#   'Lundbeck',
#   'has',
#   'worldwide',
#   'rights',
#   'for',
#   'nalmefene',
#   'excluding',
#   'North',
#   'America',
#   'Mexico',
#   'Turkey',
#   'and',
#   'SouthKorea'],
#  ['The',
#   'government',
#   'started',
#   'the',
#   'selloff',
#   'last',
#   'month',
#   'putting',
#   'an',
#   '8',
#   'percent',
#   'stake',
#   'in',
#   'TeliaSonera',
#   'on',
#   'the',
#   'auction',
#   'bloc'],
#  ['The',
#   'report',
#   'goes',
#   'on',
#   'to',
#   'provide',
#   'detailed',
#   'profiles',
#   'of',
#   'ten',
#   'leading',
#   'European',
#   'specialty',
#   'chemicals',
#   'companies',
#   'and',
#   'brief',
#   'profiles',
#   'of',
#   'other',
#   'major',
#   'players'],
#  ['Both',
#   'operating',
#   'profit',
#   'and',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'threemonth',
#   'period',
#   'increased',
#   'respectively',
#   'from',
#   'EUR16',
#   '0',
#   'm',
#   'and',
#   'EUR139m',
#   'as',
#   'compared',
#   'to',
#   'the',
#   'corresponding',
#   'quarter',
#   'in',
#   '2006'],
#  ['The',
#   'company',
#   'expects',
#   'its',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'whole',
#   '2009',
#   'to',
#   'be',
#   'at',
#   'previous',
#   'year',
#   'levels'],
#  ['The',
#   'company',
#   'is',
#   'headquartered',
#   'in',
#   'Sievi',
#   'Finland',
#   'and',
#   'is',
#   'listed',
#   'on',
#   'the',
#   'Nordic',
#   'Exchange',
#   'in',
#   'Helsinki'],
#  ['Commission',
#   'income',
#   'increased',
#   'by',
#   '22',
#   'to',
#   'EUR',
#   '44',
#   'mn',
#   'and',
#   'lending',
#   'volume',
#   'rose',
#   'by',
#   '135'],
#  ['The',
#   'Finnish',
#   'company',
#   'sold',
#   'its',
#   'UK',
#   'operation',
#   'consisting',
#   'of',
#   '50',
#   'staff',
#   'in',
#   'offices',
#   'in',
#   'London',
#   'Birmingham',
#   'and',
#   'Manchester',
#   'as',
#   'part',
#   'of',
#   'a',
#   'deal',
#   'with',
#   'Hampden',
#   'in',
#   'July',
#   '2001',
#   'for',
#   'its',
#   'Europeanwide',
#   'property',
#   'and',
#   'casualty',
#   'arm',
#   'Sampo',
#   'Industrial'],
#  ['In',
#   'the',
#   'building',
#   'and',
#   'home',
#   'improvement',
#   'trade',
#   'sales',
#   'decreased',
#   'by',
#   '225',
#   'to',
#   'EUR',
#   '2014',
#   'mn'],
#  ['The',
#   'Innova',
#   '2',
#   'building',
#   'will',
#   'be',
#   'located',
#   'close',
#   'to',
#   'downtown',
#   'in',
#   'the',
#   'immediate',
#   'vicinity',
#   'of',
#   'Paviljonki',
#   'and',
#   'the',
#   'travel',
#   'center',
#   'and',
#   'within',
#   'walking',
#   'distance',
#   'from',
#   'the',
#   'heart',
#   'of',
#   'the',
#   'city',
#   'thanks',
#   'to',
#   'the',
#   'trade',
#   'fair',
#   'bridge'],
#  ['Finnish',
#   'textiles',
#   'and',
#   'clothing',
#   'group',
#   'Marimekko',
#   'Oyj',
#   'posted',
#   'a',
#   'net',
#   'profit',
#   'of',
#   '799',
#   'mln',
#   'euro',
#   '104',
#   'mln',
#   'for',
#   '2006',
#   'compared',
#   'to',
#   '84',
#   'mln',
#   'euro',
#   '109',
#   'mln',
#   'for',
#   '2005'],
#  ['The',
#   'main',
#   'strength',
#   'of',
#   'the',
#   'cooperation',
#   'project',
#   'lies',
#   'in',
#   'merging',
#   'the',
#   'knowhow',
#   'of',
#   'two',
#   'large',
#   'companies'],
#  ['Shareholders',
#   'have',
#   'a',
#   'right',
#   'to',
#   'put',
#   'on',
#   'the',
#   'agenda',
#   'of',
#   'the',
#   'AGM',
#   'items',
#   'that',
#   'are',
#   'within',
#   'the',
#   'competence',
#   'of',
#   'the',
#   'general',
#   'meeting'],
#  ['Kazgiprotsvetmet',
#   'and',
#   'Outotec',
#   'Finland',
#   'have',
#   'signed',
#   'an',
#   'agreement',
#   'on',
#   'strategic',
#   'cooperation',
#   'in',
#   'the',
#   'marketing',
#   'and',
#   'providing',
#   'of',
#   'minerals',
#   'processing',
#   'and',
#   'metallurgical',
#   'plants',
#   'and',
#   'related',
#   'services',
#   'in',
#   'Kazakhstan',
#   'and',
#   'the',
#   'surrounding',
#   'countries'],
#  ['Due',
#   'to',
#   'the',
#   'rapid',
#   'decrease',
#   'in',
#   'net',
#   'sales',
#   'personnel',
#   'reductions',
#   'have',
#   'been',
#   'carried',
#   'out',
#   'on',
#   'a',
#   'wider',
#   'scale',
#   'than',
#   'initially',
#   'expected'],
#  ['The',
#   'government',
#   'has',
#   'instead',
#   'proposed',
#   'an',
#   'exchange',
#   'of',
#   'the',
#   'state',
#   's',
#   'stake',
#   'in',
#   'LMT',
#   'to',
#   'TeliaSonera',
#   's',
#   'stake',
#   'in',
#   'Lattelecom'],
#  ['Stora',
#   'is',
#   'due',
#   'to',
#   'release',
#   'its',
#   'fourthquarter',
#   'and',
#   '2009',
#   'fullyear',
#   'earnings',
#   'on',
#   'Feb',
#   '4'],
#  ['Fullyear',
#   'operating',
#   'result',
#   'for',
#   '2008',
#   'was',
#   '36',
#   'million',
#   'negative'],
#  ['NQ',
#   'got',
#   'hit',
#   'hard',
#   'lower',
#   'this',
#   'AM',
#   'looks',
#   'like',
#   'it',
#   'has',
#   'found',
#   'support',
#   'a',
#   '1889',
#   'httpstkscos052z'],
#  ['In',
#   '2008',
#   'AVC',
#   'Systemhaus',
#   'had',
#   'net',
#   'sales',
#   'of',
#   'EUR',
#   '10',
#   'million',
#   'USD',
#   '71',
#   'm'],
#  ['The',
#   'company',
#   'has',
#   'established',
#   'a',
#   '3G',
#   'base',
#   'station',
#   'at',
#   'about',
#   '17000',
#   'feet',
#   'at',
#   'the',
#   'foot',
#   'of',
#   'Mount',
#   'Everest',
#   'that',
#   'will',
#   'enable',
#   'mountain',
#   'climbers',
#   'at',
#   'the',
#   '29035foot',
#   'summit',
#   'to',
#   'surf',
#   'the',
#   'Internet',
#   'and',
#   'even',
#   'send',
#   'videos',
#   'of',
#   'their',
#   'exploits'],
#  ['We',
#   'offer',
#   'our',
#   'customers',
#   'solutions',
#   'based',
#   'on',
#   'renewable',
#   'raw',
#   'materials'],
#  ['A',
#   'survey',
#   'conducted',
#   'by',
#   'Taloustutkimus',
#   'for',
#   'Sampo',
#   'Life',
#   'shows',
#   'that',
#   'companies',
#   'are',
#   'badly',
#   'prepared',
#   'to',
#   'losing',
#   'key',
#   'staff',
#   'members'],
#  ['Antti',
#   'Orkola',
#   'president',
#   'of',
#   'Kemira',
#   'GrowHow',
#   's',
#   'Industrial',
#   'Solutions',
#   'unit',
#   'told',
#   'Thomson',
#   'Financial',
#   'News',
#   'the',
#   'company',
#   'has',
#   'put',
#   'off',
#   'opening',
#   'the',
#   'mine',
#   'as',
#   'prices',
#   'of',
#   'phosphate',
#   'have',
#   'been',
#   'quite',
#   'depressed',
#   'for',
#   'a',
#   'long',
#   'time'],
#  ['The',
#   'pretax',
#   'profit',
#   'of',
#   'the',
#   'group',
#   's',
#   'life',
#   'insurance',
#   'business',
#   'increased',
#   'to',
#   'EUR36m',
#   'from',
#   'EUR27m'],
#  ['We',
#   'make',
#   'available',
#   'the',
#   'following',
#   'brandnew',
#   'market',
#   'analyses',
#   'Cement',
#   'Pakistan',
#   'Cement',
#   'Malaysia',
#   'Cement',
#   'Taiwan',
#   'Cement',
#   'Philippines',
#   'These',
#   'analyses',
#   'give',
#   'a',
#   'clear',
#   'overview',
#   'of',
#   'the',
#   'actual',
#   'situation',
#   'and',
#   'future',
#   'outlook',
#   'of',
#   'the',
#   'cement',
#   'industry',
#   'in',
#   'some',
#   'Asian',
#   'countries'],
#  ['The',
#   'Company',
#   'serves',
#   'approximately',
#   '3000',
#   'customers',
#   'in',
#   'over',
#   '100',
#   'countries'],
#  ['RT',
#   'alphatrends',
#   'VMarkets',
#   'Are',
#   'Still',
#   'Acting',
#   'Weak',
#   'httpstksco1agn',
#   'SPY',
#   'QQQ',
#   'XLF',
#   'SMH',
#   'IWM'],
#  ['Operating',
#   'profit',
#   'totalled',
#   'EUR',
#   '302',
#   'mn',
#   'down',
#   'from',
#   'EUR',
#   '438',
#   'mn',
#   'a',
#   'year',
#   'earlier'],
#  ['One',
#   'of',
#   'the',
#   'installed',
#   'elevators',
#   'will',
#   'be',
#   'a',
#   'doubledeck',
#   'elevator',
#   'which',
#   'enables',
#   'more',
#   'efficient',
#   'use',
#   'of',
#   'the',
#   'building',
#   's',
#   'core',
#   'space'],
#  ['HELSINKI',
#   'AFX',
#   'Outokumpu',
#   'said',
#   'it',
#   'has',
#   'agreed',
#   'to',
#   'sell',
#   'the',
#   'Hitura',
#   'nickel',
#   'mine',
#   'in',
#   'Finland',
#   'to',
#   'Canadian',
#   'group',
#   'Belvedere',
#   'Resources',
#   'Ltd',
#   'for',
#   '10',
#   'mln',
#   'eur',
#   'worth',
#   'of',
#   'Belvedere',
#   'shares'],
#  ['Just', 'went', 'long', 'ILMN'],
#  ['Social',
#   'networking',
#   'and',
#   'locationbased',
#   'service',
#   'trends',
#   'comprise',
#   'a',
#   'significant',
#   'share',
#   'of',
#   'the',
#   'Internet',
#   'traffic',
#   'today',
#   'and',
#   'are',
#   'appealing',
#   'to',
#   'MID',
#   'users'],
#  ['A',
#   'total',
#   '30',
#   'of',
#   'the',
#   'order',
#   'value',
#   'was',
#   'booked',
#   'in',
#   'the',
#   'fourth',
#   'quarter',
#   'of',
#   '2009',
#   'and',
#   'the',
#   'remainder',
#   'will',
#   'be',
#   'booked',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   'of',
#   '2010'],
#  ['Johnson',
#   'Matthey',
#   'share',
#   'price',
#   'slumps',
#   'as',
#   'company',
#   'posts',
#   'fullyear',
#   'results'],
#  ['There',
#   'have',
#   'not',
#   'been',
#   'previous',
#   'share',
#   'subscriptions',
#   'with',
#   '2004',
#   'stock',
#   'options'],
#  ['AffectoGenimap',
#   'builds',
#   'highly',
#   'customised',
#   'IT',
#   'solutions',
#   'for',
#   'its',
#   'customers',
#   'in',
#   'Finland',
#   'and',
#   'the',
#   'Baltic',
#   'countries'],
#  ['The',
#   'closing',
#   'of',
#   'the',
#   'transaction',
#   'is',
#   'scheduled',
#   'to',
#   'take',
#   'place',
#   'on',
#   'January',
#   '10',
#   '2008'],
#  ['However',
#   'the',
#   'offering',
#   'will',
#   'probably',
#   'not',
#   'be',
#   'made',
#   'at',
#   'the',
#   'current',
#   'valuation',
#   'which',
#   'partly',
#   'derives',
#   'from',
#   'the',
#   'deal',
#   'in',
#   'which',
#   'the',
#   'company',
#   'was',
#   'merged',
#   'into',
#   'a',
#   'stock',
#   'market',
#   'shell'],
#  ['Operating',
#   'result',
#   'for',
#   'the',
#   '12month',
#   'period',
#   'decreased',
#   'from',
#   'the',
#   'profit',
#   'of',
#   'EUR0',
#   '4',
#   'm',
#   'while',
#   'turnover',
#   'decreased',
#   'from',
#   'EUR5',
#   '6',
#   'm',
#   'as',
#   'compared',
#   'to',
#   '2004'],
#  ['The',
#   'administrators',
#   'have',
#   'indicated',
#   'a',
#   'need',
#   'for',
#   '900',
#   'job',
#   'cuts',
#   'at',
#   'the',
#   'Irish',
#   'insurer',
#   'over',
#   'the',
#   'next',
#   '15',
#   'months'],
#  ['Net',
#   'sales',
#   'in',
#   '2008',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'on',
#   'the',
#   'same',
#   'level',
#   'as',
#   'in',
#   '2007'],
#  ['Technical',
#   'indicators',
#   'for',
#   'the',
#   'stock',
#   'are',
#   'bullish',
#   'and',
#   'SP',
#   'gives',
#   'NOK',
#   'a',
#   'positive',
#   '4',
#   'STARS',
#   'out',
#   'of',
#   '5',
#   'buy',
#   'ranking'],
#  ['Revenue',
#   'for',
#   'the',
#   'quarter',
#   'totaled',
#   '274',
#   'billion',
#   'down',
#   '2',
#   'percent',
#   'from',
#   '281',
#   'billion',
#   'in',
#   'the',
#   'fourth',
#   'quarter',
#   'in',
#   '2008'],
#  ['NViro',
#   'operates',
#   'processing',
#   'facilities',
#   'independently',
#   'as',
#   'well',
#   'as',
#   'in',
#   'partnership',
#   'with',
#   'municipalities'],
#  ['The',
#   'number',
#   'of',
#   'bodily',
#   'injury',
#   'cases',
#   'quadrupled',
#   'in',
#   '20002006'],
#  ['According',
#   'to',
#   'Ringman',
#   'Finnish',
#   'paper',
#   'companies',
#   'have',
#   'acquired',
#   'knowhow',
#   'and',
#   'capacity',
#   'in',
#   'paper',
#   'recycling',
#   'which',
#   'has',
#   'turned',
#   'out',
#   'to',
#   'be',
#   'a',
#   'successful',
#   'strategy'],
#  ['The',
#   'company',
#   'also',
#   'said',
#   'that',
#   'in',
#   'Poland',
#   'a',
#   'profitability',
#   'program',
#   'has',
#   'been',
#   'launched',
#   'at',
#   'the',
#   'Oborniki',
#   'steel',
#   'frame',
#   'and',
#   'sandwich',
#   'panel',
#   'plant'],
#  ['And',
#   'US',
#   'energy',
#   'executives',
#   'say',
#   'high',
#   'steel',
#   'prices',
#   'are',
#   'threatening',
#   'energy',
#   'exploration'],
#  ['Tesco', 'sales', 'rise', 'shows', 'tentative', 'recovery', 'continues'],
#  ['In',
#   'Finland',
#   'the',
#   'launch',
#   'of',
#   'tiein',
#   'sales',
#   'of',
#   '3G',
#   'mobile',
#   'phones',
#   'did',
#   'not',
#   'cause',
#   'a',
#   'dramatic',
#   'rush',
#   'in',
#   'mobile',
#   'retail',
#   'outlets',
#   'during',
#   'the',
#   'first',
#   'few',
#   'days'],
#  ['NUAN',
#   'held',
#   'up',
#   'well',
#   'after',
#   'the',
#   'big',
#   'gains',
#   'Maybe',
#   'were',
#   'finally',
#   'on',
#   'the',
#   'move',
#   'on',
#   'thisits',
#   'still',
#   'very',
#   'undervalued',
#   'and',
#   'has',
#   'major',
#   'upside'],
#  ['The',
#   'company',
#   'can',
#   'be',
#   'split',
#   'into',
#   'two',
#   'parts',
#   'over',
#   'the',
#   'coming',
#   'months',
#   'with',
# ...
#   'in',
#   'Europe',
#   'America',
#   'Africa',
#   'Asia',
#   'and',
#   'Australia',
#   'to',
#   'develop',
#   'and',
#   'introduce',
#   'new',
#   'raw',
#   'materials'],
#  ['The',
#   'new',
#   'agreement',
#   'which',
#   'expands',
#   'a',
#   'longestablished',
#   'cooperation',
#   'between',
#   'the',
#   'companies',
#   'involves',
#   'the',
#   'transfer',
#   'of',
#   'certain',
#   'engineering',
#   'and',
#   'documentation',
#   'functions',
#   'from',
#   'Larox',
#   'to',
#   'Etteplan'],
#  ['It', 's', 'not'],
#  ['took',
#   'some',
#   'ENDP',
#   'long',
#   'this',
#   'am',
#   'using',
#   'VWAP',
#   'as',
#   'guide'],
#  ['Despite',
#   'sales',
#   'growth',
#   'UKs',
#   'Tesco',
#   'cautions',
#   'recovery',
#   'to',
#   'be',
#   'bumpy'],
#  ['In',
#   'Finland',
#   'metal',
#   'sector',
#   'company',
#   'Componenta',
#   'is',
#   'laying',
#   'off',
#   'temporarily',
#   'the',
#   'staff',
#   'of',
#   'its',
#   'Pori',
#   'mill',
#   'from',
#   'Christmas',
#   '2008',
#   'till',
#   '6',
#   'January',
#   '2009'],
#  ['In',
#   'Middle',
#   'East',
#   'North',
#   'Africa',
#   'Tecnotree',
#   'has',
#   'grown',
#   'considerably',
#   'in',
#   'the',
#   'recent',
#   'years'],
#  ['Both',
#   'operating',
#   'profit',
#   'and',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'sixmonth',
#   'period',
#   'increased',
#   'respectively',
#   'from',
#   'EUR18',
#   '1',
#   'm',
#   'and',
#   'EUR127',
#   '6',
#   'm',
#   'as',
#   'compared',
#   'to',
#   'the',
#   'corresponding',
#   'period',
#   'in',
#   '2006'],
#  ['Insurer',
#   'Axa',
#   'PAR',
#   'CS',
#   'slid',
#   'by',
#   '535',
#   'to',
#   'EUR',
#   '1415',
#   'after',
#   'Citigroup',
#   'and',
#   'ING',
#   'slashed',
#   'their',
#   'targets',
#   'on',
#   'the',
#   'stock'],
#  ['The',
#   'order',
#   'values',
#   'at',
#   'EUR',
#   '69',
#   'mn',
#   'and',
#   'it',
#   'consists',
#   'of',
#   'design',
#   'services',
#   'and',
#   'hardware',
#   'and',
#   'software',
#   'licences'],
#  ['Scanfil', 'has', 'also', 'issued', 'a', 'profit', 'warning'],
#  ['A',
#   'spokesman',
#   'said',
#   'The',
#   'food',
#   'store',
#   'center',
#   'subject',
#   'to',
#   'council',
#   'and',
#   'local',
#   'support',
#   'could',
#   'comprise',
#   'a',
#   'supermarket',
#   'or',
#   'smaller',
#   'store',
#   'and',
#   'other',
#   'niche',
#   'outlets',
#   'and',
#   'this',
#   'will',
#   'be',
#   'firmed',
#   'up',
#   'following',
#   'consultation',
#   'with',
#   'the',
#   'council',
#   'and',
#   'local',
#   'community',
#   'regarding',
#   'appropriate',
#   'uses',
#   'and',
#   'occupiers'],
#  ['The',
#   'bond',
#   'has',
#   'a',
#   'value',
#   'of',
#   'EUR150m',
#   'and',
#   'a',
#   'maturity',
#   'of',
#   '4',
#   'years'],
#  ['MillerCoors', 'Board', 'Names', 'Gavin', 'Hattersley', 'Interim', 'CEO'],
#  ['Airbus',
#   'will',
#   'attempt',
#   'to',
#   'evacuate',
#   'up',
#   'to',
#   '873',
#   'people',
#   'within',
#   '90',
#   'seconds'],
#  ['First',
#   'quarter',
#   'underlying',
#   'operating',
#   'profit',
#   'rose',
#   'to',
#   '41',
#   'mln',
#   'eur',
#   'from',
#   '33',
#   'mln',
#   'a',
#   'year',
#   'earlier'],
#  ['EPS',
#   'for',
#   'the',
#   'quarter',
#   'was',
#   'EUR0',
#   '00',
#   'as',
#   'compared',
#   'with',
#   'EUR0',
#   '01',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008',
#   'representing',
#   'a',
#   'Group',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'third',
#   'quarter',
#   'were',
#   'EUR15',
#   '3',
#   'm',
#   'up',
#   'by',
#   '28',
#   'as',
#   'compared',
#   'with',
#   'EUR14',
#   '9',
#   'm',
#   'in',
#   'the',
#   'third',
#   'quarter',
#   'of',
#   '2008'],
#  ['Royal', 'Dutch', 'Shell', 'profit', 'rises', 'dividend', 'up', '4'],
#  ['Meanwhile',
#   'ElectrowattEkono',
#   'Philippines',
#   'Inc',
#   'was',
#   'also',
#   'awarded',
#   'a',
#   'threeyear',
#   'operation',
#   'and',
#   'maintenance',
#   'OM',
#   'contract',
#   'by',
#   'FR',
#   'Cement',
#   'Corporation'],
#  ['The',
#   'agreement',
#   'includes',
#   'application',
#   'maintenance',
#   'and',
#   'support',
#   'services'],
#  ['Nokia',
#   'is',
#   'just',
#   'interested',
#   'in',
#   'bring',
#   'Nokia',
#   'to',
#   'the',
#   'market'],
#  ['Affecto',
#   'expects',
#   'its',
#   'net',
#   'sales',
#   'for',
#   'the',
#   'whole',
#   '2010',
#   'to',
#   'increase',
#   'from',
#   'the',
#   '2009',
#   'level',
#   'when',
#   'they',
#   'reached',
#   'EUR',
#   '103',
#   'million'],
#  ['The',
#   'report',
#   'profiles',
#   '158',
#   'companies',
#   'including',
#   'many',
#   'key',
#   'and',
#   'niche',
#   'players',
#   'including',
#   'major',
#   'Nonwovens',
#   'manufacturers',
#   'such',
#   'as',
#   'Ahlstrom',
#   'Corporation',
#   'Asahi',
#   'Kasei',
#   'Corporation',
#   'Buckeye',
#   'Technologies',
#   'Inc',
#   'EI'],
#  ['The',
#   'layoffs',
#   'will',
#   'affect',
#   '240',
#   'people',
#   'out',
#   'of',
#   'the',
#   'total',
#   '320',
#   'Okmetic',
#   'employees',
#   'in',
#   'Finland'],
#  ['The',
#   'acquisition',
#   'of',
#   'Elektros',
#   'Pavara',
#   'completes',
#   'KONE',
#   's',
#   'market',
#   'expansion',
#   'strategy',
#   'in',
#   'the',
#   'Baltic',
#   'Countries'],
#  ['18',
#   'May',
#   '2010',
#   'Finnish',
#   'electronics',
#   'producer',
#   'Elcoteq',
#   'SE',
#   'HEL',
#   'ELQAV',
#   'said',
#   'today',
#   'that',
#   'it',
#   'has',
#   'signed',
#   'an',
#   'extensive',
#   'cooperation',
#   'agreement',
#   'on',
#   'industrialisation',
#   'manufacturing',
#   'distribution',
#   'and',
#   'aftermarket',
#   'services',
#   'for',
#   'mobile',
#   'phones',
#   'with',
#   'Japan',
#   's',
#   'Sharp',
#   'TYO',
#   '6753'],
#  ['Morrisons',
#   'book',
#   'second',
#   'consecutive',
#   'quarter',
#   'of',
#   'sales',
#   'growth'],
#  ['Marimekko',
#   'has',
#   'today',
#   '20',
#   'November',
#   'signed',
#   'a',
#   'license',
#   'agreement',
#   'with',
#   'the',
#   'Swedish',
#   'chain',
#   'whereby',
#   'Marimekko',
#   'will',
#   'license',
#   'some',
#   'of',
#   'its',
#   'popular',
#   'patterns',
#   'from',
#   'the',
#   '1950s',
#   '1960s',
#   'and',
#   '1970s',
#   'to',
#   'HM'],
#  ['that',
#   'was',
#   'quick',
#   'out',
#   'FIO',
#   '2135',
#   'market',
#   'tanking',
#   'scaling',
#   'down',
#   'longs',
#   'now'],
#  ['The',
#   'announcement',
#   'pushed',
#   'Freenet',
#   'shares',
#   'down',
#   '63',
#   'or',
#   'EUR0',
#   '71',
#   'in',
#   'Frankfurt',
#   'trade',
#   'to',
#   'EUR10',
#   '65',
#   'as',
#   'investors',
#   'gave',
#   'up',
#   'hope',
#   'United',
#   'Internet',
#   'AG',
#   'and',
#   'Drillisch',
#   'would',
#   'pursue',
#   'their',
#   'own',
#   'takeover',
#   'and',
#   'breakup',
#   'of',
#   'Freenet'],
#  ['Finnish',
#   'telecoms',
#   'software',
#   'developer',
#   'Tecnomen',
#   'Oyj',
#   'said',
#   'on',
#   'December',
#   '5',
#   '2006',
#   'it',
#   'won',
#   'a',
#   '33',
#   'mln',
#   '25',
#   'mln',
#   'euro',
#   'order',
#   'to',
#   'supply',
#   'an',
#   'expansion',
#   'of',
#   'the',
#   'charging',
#   'and',
#   'messaging',
#   'systems',
#   'for',
#   'the',
#   'mobile',
#   'and',
#   'fixed',
#   'networks',
#   'of',
#   'Brasil',
#   'Telecom'],
#  ['CompaniesUnilever',
#   'sales',
#   'lifted',
#   'by',
#   'ice',
#   'cream',
#   'in',
#   'soft',
#   'economy'],
#  ['EPS', 'dropped', 'to', 'EUR0', '2', 'from', 'EUR0', '3'],
#  ['saltwaternurse',
#   'INO',
#   'can',
#   'test',
#   '10',
#   'again',
#   'in',
#   'next',
#   'few',
#   'days',
#   'time',
#   'to',
#   'take',
#   'some',
#   'profits',
#   'here',
#   'or',
#   'hedge',
#   'with',
#   'puts'],
#  ['No', 'financial', 'information', 'was', 'provided'],
#  ['EasyJet',
#   'attracts',
#   'more',
#   'passengers',
#   'in',
#   'June',
#   'but',
#   'still',
#   'lags',
#   'Ryanair'],
#  ['Morning', 'Agenda', 'Shires', 'Deal', 'for', 'NPS'],
#  ['Metso',
#   'will',
#   'supply',
#   'the',
#   'equipment',
#   'for',
#   'two',
#   'process',
#   'lines',
#   'at',
#   'Northland',
#   'Resources',
#   'new',
#   'Kaunisvaara',
#   'iron',
#   'ore',
#   'project',
#   'in',
#   'Sweden',
#   'which',
#   'exploits',
#   'Tapuli',
#   'and',
#   'Sahavaara',
#   'iron',
#   'ore',
#   'deposits'],
#  ['Under',
#   'this',
#   'agreement',
#   'Biohit',
#   'becomes',
#   'a',
#   'focus',
#   'supplier',
#   'of',
#   'pipettors',
#   'and',
#   'disposable',
#   'pipettor',
#   'tips',
#   'to',
#   'VWR',
#   'customers',
#   'throughout',
#   'Europe'],
#  ['The',
#   'company',
#   's',
#   'previous',
#   'estimate',
#   'was',
#   'for',
#   'a',
#   'lower',
#   'revenue',
#   'than',
#   'the',
#   'yearago',
#   'EUR',
#   '939',
#   'million'],
#  ['Earnings',
#   'per',
#   'share',
#   'EPS',
#   'dropped',
#   'to',
#   'EUR',
#   '021',
#   'from',
#   'EUR',
#   '031'],
#  ['Bids',
#   'or',
#   'offers',
#   'include',
#   'at',
#   'least',
#   '1000',
#   'shares',
#   'and',
#   'the',
#   'value',
#   'of',
#   'the',
#   'shares',
#   'must',
#   'correspond',
#   'to',
#   'at',
#   'least',
#   'EUR4',
#   '000'],
#  ['Earnings',
#   'per',
#   'share',
#   'EPS',
#   'amounted',
#   'to',
#   'a',
#   'loss',
#   'of',
#   'to',
#   'EUR0',
#   '06'],
#  ['NetApp',
#   'downgraded',
#   'by',
#   'Macquarie',
#   'to',
#   'underperform',
#   '2200',
#   'PT',
#   'httpstcoXCNgws0t4q',
#   'NTAP',
#   'NTAP',
#   'via',
#   'RatingsNetwork'],
#  ['Russia',
#   'is',
#   'ready',
#   'to',
#   'participate',
#   'in',
#   'an',
#   'open',
#   'tender',
#   'for',
#   'Lattelecom',
#   's',
#   'privatization'],
#  ['Technopolis',
#   'and',
#   'the',
#   'St',
#   'Petersburg',
#   'government',
#   'signed',
#   'a',
#   'cooperation',
#   'memorandum',
#   'in',
#   'October',
#   '2005',
#   'to',
#   'set',
#   'up',
#   'a',
#   'technopark',
#   'in',
#   'the',
#   'Neudorf',
#   'production',
#   'zone',
#   'in',
#   'the',
#   'village',
#   'of',
#   'Strelny',
#   'in',
#   'the',
#   'St',
#   'Petersburg',
#   'suburbs'],
#  ['The',
#   'owners',
#   'who',
#   'have',
#   'participated',
#   'in',
#   'the',
#   'business',
#   'operations',
#   'of',
#   'the',
#   'company',
#   'will',
#   'continue',
#   'in',
#   'Poyry',
#   's',
#   'employment',
#   'after',
#   'the',
#   'transaction'],
#  ['The',
#   'goal',
#   'is',
#   'to',
#   'secure',
#   'the',
#   'company',
#   's',
#   'profitability',
#   'and',
#   'competitiveness'],
#  ['However',
#   'the',
#   'company',
#   'saw',
#   'its',
#   'net',
#   'profit',
#   'for',
#   'the',
#   'third',
#   'quarter',
#   'down',
#   'to',
#   'EUR',
#   '14',
#   'million',
#   'from',
#   'EUR',
#   '15',
#   'million',
#   'for',
#   'the',
#   'corresponding',
#   'period',
#   'of',
#   '2009'],
#  ['Neste',
#   'oil',
#   's',
#   'board',
#   'proposed',
#   '100',
#   'eur',
#   'dividend',
#   'for',
#   'the',
#   'fullyear',
#   '2007',
#   'compared',
#   'with',
#   '090',
#   'eur',
#   'a',
#   'year',
#   'ago'],
#  ['Basware',
#   'Einvoices',
#   'Oy',
#   'will',
#   'be',
#   'merged',
#   'into',
#   'the',
#   'parent',
#   'company',
#   'during',
#   'the',
#   'present',
#   'fiscal',
#   'period'],
#  ['Fintech',
#   'provider',
#   'CAFN',
#   'Cachet',
#   'Financial',
#   'Solutions',
#   'Surging',
#   'Forward',
#   'today',
#   'post',
#   'earnings',
#   'Up',
#   '1326',
#   'httpstco9BJ3csk2i9',
#   'JKHY',
#   'FISV',
#   'Momo'],
#  ['Before',
#   'Kemira',
#   's',
#   'installation',
#   'NordAlu',
#   'was',
#   'producing',
#   '3500',
#   'tons',
#   'of',
#   'liquid',
#   'and',
#   'solid',
#   'aluminum',
#   'waste',
#   'per',
#   'year'],
#  ['He',
#   'is',
#   'a',
#   'Chartered',
#   'Accountant',
#   'in',
#   'British',
#   'Columbia',
#   'and',
#   'Alberta',
#   'as',
#   'well',
#   'as',
#   'a',
#   'Certified',
#   'Public',
#   'Accountant',
#   'in',
#   'Washington',
#   'State'],
#  ['Very',
#   'recommendable',
#   'is',
#   'the',
#   'Nokian',
#   'Z',
#   'G2',
#   'according',
#   'to',
#   'the',
#   'ADAC',
#   'judgement',
#   'in',
#   'the',
#   'latest',
#   'summer',
#   'tyre',
#   'test',
#   'of',
#   'the',
#   'German',
#   'automobile',
#   'association',
#   'ADAC'],
#  ['The',
#   'Group',
#   's',
#   'result',
#   'before',
#   'taxes',
#   'was',
#   'a',
#   'loss',
#   'of',
#   'EUR',
#   '06',
#   '06',
#   'million'],
#  ['Cash',
#   'flow',
#   'from',
#   'operating',
#   'activities',
#   'before',
#   'investments',
#   'was',
#   'EUR',
#   '08',
#   '12',
#   'million'],
#  ['Viking', 'Line', 'has', 'canceled', 'some', 'services'],
#  ['Exel', 'is', 'headquartered', 'in', 'Mantyharju', 'in', 'Finland'],
#  ['Stora',
#   'Chief',
#   'Executive',
#   'Jouko',
#   'Karvinen',
#   'has',
#   'described',
#   'the',
#   'Russian',
#   'tariff',
#   'hikes',
#   'as',
#   'a',
#   'threat',
#   'to',
#   'the',
#   'future',
#   'of',
#   'the',
#   'forest',
#   'products',
#   'industry',
#   'in',
#   'Finland'],
#  ['After',
#   'Barclays',
#   'and',
#   'Bank',
#   'of',
#   'America',
#   'Citigroup',
#   'has',
#   'blockchain',
#   'in',
#   'sight'],
#  ['Google',
#   'Inc',
#   'completes',
#   'acquisition',
#   'of',
#   'ICOA',
#   'Inc',
#   'httpstksconFEI',
#   'ICOA',
#   'GOOG'],
#  ['TSLA',
#   'looking',
#   'goodid',
#   'love',
#   'to',
#   'see',
#   'a',
#   'basing',
#   'action',
#   'here',
#   'letting',
#   'the',
#   'RSI',
#   'take',
#   'a',
#   'breather',
#   'httpstkscog1T7c'],
#  ['Finnish',
#   'plumbing',
#   'and',
#   'heating',
#   'systems',
#   'supplier',
#   'Uponor',
#   's',
#   'net',
#   'sales',
#   'from',
#   'continuing',
#   'operations',
#   'decreased',
#   'by',
#   '94',
#   'in',
#   '2008',
#   'to',
#   'EUR',
#   '9492',
#   'mn',
#   'from',
#   'EUR',
#   '10474',
#   'mn',
#   'in',
#   '2007'],
#  ['This',
#   'location',
#   'makes',
#   'the',
#   'mall',
#   'a',
#   'convenient',
#   'place',
#   'to',
#   'shop',
#   'for',
#   'consumers',
#   'from',
#   'three',
#   'large',
#   'residential',
#   'areas',
#   'nearby',
#   'Jaroszowka',
#   'Wysockiego',
#   'and',
#   'Zgody'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'and',
#   'Kesko',
#   'Group',
#   'are',
#   'ending',
#   'their',
#   'loyal',
#   'customer',
#   'cooperation'],
#  ['The',
#   'casing',
#   'comprises',
#   'a',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'with',
#   'the',
#   'first',
#   'side',
#   'vat',
#   'segment',
#   'and',
#   'a',
#   'second',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'with',
#   'the',
#   'second',
#   'side',
#   'vat',
#   'segment',
#   'at',
#   'least',
#   'the',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'being',
#   'pivotable',
#   'about',
#   'a',
#   'rotation',
#   'axis'],
#  ['Finlandbased',
#   'Elcoteq',
#   'SE',
#   'a',
#   'privately',
#   'held',
#   'provider',
#   'of',
#   'electronics',
#   'manufacturing',
#   'services',
#   'to',
#   'communications',
#   'companies',
#   'said',
#   'Thursday',
#   'it',
#   'signed',
#   'a',
#   'longterm',
#   'manufacturing',
#   'supply',
#   'deal',
#   'with',
#   'communications',
#   'equipment',
#   'company',
#   'Andrew',
#   'Corp'],
#  ['In',
#   'Q1',
#   'of',
#   '2009',
#   'Bank',
#   'of',
#   'àland',
#   's',
#   'net',
#   'interest',
#   'income',
#   'weakened',
#   'by',
#   '10',
#   'to',
#   'EUR',
#   '91',
#   'mn'],
#  ['RBS',
#   'Pays',
#   '17',
#   'Billion',
#   'to',
#   'Scrap',
#   'UK',
#   'Treasurys',
#   'Dividend',
#   'Rights'],
#  ['Increased',
#   'trust',
#   'of',
#   'our',
#   'clients',
#   'in',
#   'YIT',
#   'can',
#   'be',
#   'seen',
#   'as',
#   'apartment',
#   'sales',
#   'accelerated'],
#  ['Talvivaara',
#   'Mining',
#   'Company',
#   'Plc',
#   'Talvivaara',
#   'Mining',
#   'Company',
#   'is',
#   'an',
#   'internationally',
#   'significant',
#   'base',
#   'metals',
#   'producer',
#   'with',
#   'its',
#   'primary',
#   'focus',
#   'on',
#   'nickel',
#   'and',
#   'zinc',
#   'using',
#   'a',
#   'technology',
#   'known',
#   'as',
#   'bioheapleaching',
#   'to',
#   'extract',
#   'metals',
#   'out',
#   'of',
#   'ore'],
#  ['Operating',
#   'profit',
#   'for',
#   '2009',
#   'lower',
#   'than',
#   'outlook',
#   'published',
#   'earlier'],
#  ['Less', 'than', 'ten', 'people', 'will', 'face', 'pension', 'agreements'],
#  ['The',
#   'company',
#   's',
#   'consolidated',
#   'operating',
#   'profit',
#   'amounted',
#   'to',
#   'EUR',
#   '1586',
#   'mn',
#   'up',
#   'from',
#   'EUR',
#   '414',
#   'mn',
#   'yearonyear'],
#  ['AstraZeneca', 'to', 'Buy', 'ZS', 'Pharma', 'for', '27', 'Billion'],
#  ['Finnish',
#   'waste',
#   'management',
#   'and',
#   'cleaning',
#   'group',
#   'Lassila',
#   'Tikanoja',
#   'Oyj',
#   'LT',
#   'net',
#   'profit',
#   'went',
#   'down',
#   'to',
#   '322',
#   'mln',
#   'euro',
#   '477',
#   'mln',
#   'for',
#   '2007',
#   'from',
#   '353',
#   'mln',
#   'euro',
#   '523',
#   'mln',
#   'for',
#   '2006'],
#  ['The',
#   'operating',
#   'margin',
#   'of',
#   'Aker',
#   'Yards',
#   'Cruise',
#   'Ferries',
#   'division',
#   'went',
#   'down',
#   'from',
#   '83',
#   'to',
#   '64',
#   'in',
#   'the',
#   'first',
#   'quarter',
#   'of',
#   '2007'],
#  ['HELSINKI',
#   'Thomson',
#   'Financial',
#   'Shares',
#   'in',
#   'Cargotec',
#   'fell',
#   'sharply',
#   'in',
#   'early',
#   'afternoon',
#   'trade',
#   'after',
#   'the',
#   'cargo',
#   'handling',
#   'group',
#   'posted',
#   'a',
#   'surprise',
#   'drop',
#   'in',
#   'AprilJune',
#   'profits',
#   'which',
#   'overshadowed',
#   'the',
#   'large',
#   'number',
#   'of',
#   'new',
#   'orders',
#   'received',
#   'during',
#   'the',
#   'three',
#   'months'],
#  ['The',
#   'program',
#   's',
#   'target',
#   'is',
#   'structural',
#   'cost',
#   'reductions',
#   'of',
#   'about',
#   'EUR',
#   '30mn',
#   'in',
#   '2009'],
#  ['Our',
#   'tools',
#   'are',
#   'specifically',
#   'designed',
#   'with',
#   'the',
#   'needs',
#   'of',
#   'both',
#   'the',
#   'business',
#   'users',
#   'and',
#   'ICT',
#   'experts',
#   'in',
#   'mind'],
#  ...]

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\VIGNESH
# [nltk_data]     VARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stem_vec = [' '.join(text) for text in stemedata]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stem_vec = [' '.join(text) for text in stemedata]
#
# NameError: name 'stemedata' is not defined

# %%
stem_vec
# Out:
# ['the geosolut technolog leverag benefon gp solut provid locat base search technolog commun platform locat relev multimedia content new power commerci model',
#  'esi low 150 250 bk real possibl',
#  'for last quarter 2010 componenta net sale doubl eur131m eur76m period year earlier move zero pretax profit pretax loss eur7m',
#  'accord finnishrussian chamber commerc major construct compani finland oper russia',
#  'the swedish buyout firm sold remain 224 percent stake almost eighteen month take compani public finland',
#  'spi wouldnt surpris see green close',
#  'shell 70 billion bg deal meet sharehold skeptic',
#  'ssh commun secur corp stock exchang releas octob 14 2008 at 245 pm the compani updat full year outlook estim result remain loss full year',
#  'kone net sale rose 14 yearonyear first nine month 2008',
#  'the stockmann depart store total floor space 8000 squar metr stockmann invest project price tag eur 12 million',
#  'circul revenu increas 5 finland 4 sweden 2008',
#  'sap q1 disappoint softwar licens real problem cloud growth trail msft orcl goog crm adb httpstcojndphllzq5',
#  'the subdivis made sale revenu last year eur 4807 million eur 4149 million 2008 oper profit eur 445 million eur 74 million',
#  'vike line cancel servic',
#  'ahlstrom corpor stock exchang announc 722007 1030 a total 56955 new share ahlstrom corpor subscrib option right compani stock option program i 2001 ii 2001',
#  'fb gone green day',
#  'msft sql server revenu grew doubledigit sql server premium revenu grow 30 httpstkscoir2f',
#  'accord lñnnen tehtaat ceo matti karppinen compani aim deliv fish product custom day earlier current',
#  'the compani share quot nasdaq omx helsinki rautaruukki oyj rtrk',
#  'elcoteq se list nasdaq omx helsinki ltd',
#  'two contract turntabl anod vibrocompactor deliv gansu hualu aluminum co ltd anoth unnam costum',
#  'aviva friend life top forecast ahead 56 billion pound merger',
#  'in stead base soft drink usual teho energi drink made fresh water',
#  'the compani plan increas unit specialist staff sever dozen depend market situat 2010',
#  'the compani close last year turnov four million euro',
#  'shire ceo step drive get baxalta board talk',
#  'costco a premier retail dividend play httpstcofa5cnh2t0t cost',
#  'the fivestorey ecoeffici build gross floor area 15000 sq it also includ apart',
#  'the first instal cinema seri conclud profil finnish inventor olavi linden whose person artist journey work fiskar led dozen design award',
#  'all welcom',
#  'stockmann swedish sector compani ab lindex enter agreement septemb 30 2007 wherebi stockmann whollyown subsidiari make public tender offer lindex issu share',
#  'huhtamaki oyj stock exchang releas 1692008 at 1332 huhtamaki capit market day institut investor analyst held espoo septemb 16 2008 start 1330 pm finnish time',
#  'we pleas welcom tapek noma cramo group',
#  'profit tax eur 1059 827 million',
#  'royal dutch shell buy bg group nearli 70 billion',
#  'financialwir tm press releas servic receiv compens news opinion distribut',
#  'assa abloy kaupth bank gave neutral recommend share price target 174 crown 247 19 euro swedish lock maker assa abloy ab',
#  'the item includ restructur cost eur1 6 year earlier eur13 1 dilut ep stood eur0 3 versu loss per share eur 01',
#  'in 2005 bank post net profit lt 82 mn',
#  'aapl afternoon selloff usual brutal get readi lose ton money',
#  'tsla recal pretti much everi singl model x cnnbrk got short even work jump money trade',
#  'dolc gabbana ask european union declar marimekko corpor unikko floral pattern trademark invalid continu disput two compani',
#  'intercontinent hotel firstquart global room revenu lag estim',
#  'accord finnish pension insur compani varma varma recipi two third revenu earningsrel pension cover competit tender finland',
#  'a portion 125 million record part win prior patent disput finnish phone maker nokia oyj',
#  'lg still pay price dividend cut crisi chief say',
#  'the volum invest two phase project estim usd 300mn eur 21503 mn',
#  'russia account 9 lagarder magazin divis revenu eur 11440 mn usd 14811 mn 2009 usa 18',
#  'the compani also estim alreadi carri invest lead increas net sale 2010 2009 reach eur 1417 million',
#  'profit account period eur 03 mn',
#  'the six breweri record 52 percent growth domest beer sale last year 27021 million liter 25688 million liter sold 2005',
#  'in augustoctob 2010 compani result tax total eur 96 mn eur 05 mn correspond period 2009',
#  'systeemitiimi sale project resourc also strengthen director paul skogberg said',
#  'tesco share price jump q3 sale top estim',
#  'the fine print',
#  'the price log clearli improv 2009 also price pulpwood gone',
#  'thu sysopen digia accord chapter 14 section 21 finnish compani act 2991978 734 obtain titl share sentera redeem',
#  'dilut earn per share ep fell eur 063 eur 171',
#  'at 337 pm eastern time block 2400 contract chang hand bid price 045',
#  'some recent technolog deliveri includ refineri technolog anrak aluminium iron ore pellet plant tata steel iron ore sinter plant bhushan steel',
#  'vip similar pattern like begin may did u sell same nowwil go much higher drop',
#  'the firm gener sale 187 mln eur 2005',
#  'stora enso also meet labor author employ econom develop centr repres govern order find solut',
#  'astrazeneca profit sale stalwart fade',
#  'rt andrewnyquist chartolog yahoo httpstksco1itr yhoo crazi look chart near breakout resist line',
#  'most bullish stock twitter dip yhoo gdx googl stz gold ew vz celg sbux scti httpstcoiuzjelfwt3',
#  'finnish geosentr net sale decreas eur 939000 januarymarch 2009',
#  'cohen steer inc 5 534 626 share repres 4985 share capit vote right',
#  'more staff recruit japan complement network close 50 servic locat 20 countri worldwid',
#  'paper compani neg territori stora enso r shed 162 pct 1273 eur upmkymmen 080 pct 1864 eur mreal b 018 pct lower 557 eur',
#  'kaukotelko central administr dissolv appropri part transfer oper activ group administr end year',
#  'oper profit quarter apriljun 2006 amount eur182 2 sale eur3 62 bn',
#  'atria chose delight attract consum 2545 age group atria fresh rang microwav meal',
#  'finnish it solut provid affecto oyj hel afe1v said today slip net loss eur 115000 usd 152000 second quarter 2010 profit eur 845000 correspond period year earlier',
#  'us sanction put gazpromshel allianc plan jeopardi',
#  'profit period eur 109 mn eur 143 mn 2009',
#  'profit period eur 59 mn eur 13 mn',
#  'oper profit fell eur 203 mn eur 742 mn second quarter 2008',
#  'howev sale return growth apriljun 2010 ceo pekka eloholma said',
#  'oper profit total eur 186 mn 83 net sale',
#  'chang market situat tougher price competit substanti reduc demand bread packag manufactur kauhava plant accord compani',
#  'in connect deal digia employ 19 person nokia oslo silicon valley usa',
#  'the brazilian unit finnish secur solut provid fsecur sign 1500 new client last year onlin news sourc resel web quot divis commerci director vladimir brandúo say',
#  'the fair valu compani invest properti went eur 2768 billion end 2009 eur 2916 billion year earlier',
#  'dealer said share larg hit investor disappoint refin margin 948 usd per barrel quarter perform ship unit saw ebit drop 5 mln eur 20 mln eur year amid fall volum tanker rate',
#  'it testament qualiti lte solut commit japanes market ad',
#  'the compani aim final negoti sign contract start octob 2008',
#  'metso foundri jyvaskyla oy discontinu product line 30 septemb 2008 compani said',
#  'a total six poll analyst rate mreal two gave buy accumul three gave hold one gave sell',
#  'in septemb 2010 finnish group agre buy danish compani rose poultri as eur23 9 combin cash stock',
#  'yang doubl bottom 52',
#  'tesco share price grocer face sfo investig outcom',
#  'aapl news becom bullish httpstkscotmu',
#  'gs engin instal valv liquefi natur ga lng plant built uae lng extract ga plant oper gasco ruwai uae',
#  'the percentag share vote right calcul proport total number share regist trade regist total number vote right relat',
#  'mreal said ground rumor circul market month',
#  'lember said matter topic also estonia bill draft social affair ministri would scrap oldag pension favor condit',
#  'moodi said gave p a1 longterm senior unsecur p p1 shortterm debt rate finnish lender aktia bank eur1bn usd1 4 bn euro mediumterm note emtn program 25 march 2011',
#  'tsla recal',
#  'the liquid provid interrupt may 11 2007 aspocomp group oyj share trade 050 cent aspocomp stock exchang releas 1152007',
#  'hargreav lansdown buck weak market see asset rise 26 percent',
#  'at 1259 pm omx helsinki 25 index 032 pct lower 269481',
#  'the decis mean temporari layoff fix durat compani nastola jyvaskyla unit southern central finland respect',
#  'the valu order eur 10mn',
#  'ms laakso respons hkscan hr function develop group smarket area',
#  'fiskar also engag global suppli marin energi equip solut servic associ compani wartsila corpor',
#  'aberdeen asset manag gain foothold in china',
#  'finland domin rail compani vr plan set infect passeng longdist trip separ carriag',
#  'in novemb finnish govern decreas ownership compani 311 percent 38 percent',
#  'finnish exel composit technolog compani design manufactur market composit profil tube variou industri applic report net sale decreas 06 second quarter 2010 eur 192 mn eur 193 mn correspond period 2009',
#  'of bavelloni nst joint ventur bavelloni tool complet semiproduct produc itali highqual tool sold diapol brand',
#  'the tool patent pend design allow consum lay entir project remov plate use multipl clear stamp kind',
#  'googl short 740 upper bb overbought',
#  'light out befor curfew curl latest bestsel treat eye perfect read light luceplan',
#  'upmkymmen corp world largest maker magazin paper tuesday report 19percent profit drop lower paper price higher cost strong euro hurt revenu',
#  'the total valu contract eur 8 million',
#  'the prerequisit inclus program receipt gain key employe acquir aspo share amount determin board advanc maximum',
#  'mr dore eaton sinc 1989 act busi unit manag eaton power control busi unit sinc januari 2007',
#  'the 250 sq 2691 sq ft store copenhagen premier shop district inaugur today strengthen compani presenc nordic capit',
#  'in financi statement first quarter 2010 tikkurila report discontinu oper',
#  'the world second largest stainless steel maker said net profit threemonth period dec 31 surg euro603 million us 781 million euro3 33 us 431 per share euro172 million euro0 94 per share previou year',
#  'name applic jot autom oynam inventor mammila tuomo piirainen mika kellokoski mikaappl no 2424kolnp2008 adat file applic 16062008public date 30012009',
#  'netflix grow effort to creat loyal custom nflx httpstco5qxbkobph',
#  'the omx nordic 40 omxn40 index compris 40 trade nordic stock nasdaq omx exchang close 087 106414 point thursday',
#  'aapl nibbl small long via 525 buy 13min chart',
#  'the oper margin aker yard cruis ferri divis went 83 64 first quarter 2007',
#  'tyc break new high lot technic look great right',
#  'eero katajavuori current group vice presid human resourc take yearlong sabbat start octob 1 2010',
#  'what lulu number look good great good i think confer call instil confid',
#  'the adjust measur carri phase secur deliveri capabl',
#  'alma media corpor press releas 15 march 2010 tyrvaan sanomat and paikallissanomat be bought by suomen paikallissanomat two local paper tyrvaan sanomat paikallissanomat appear sastamala neighbour municip bought suomen paikallissanomat oy',
#  'temporari layoff affect entir workforc also implement',
#  'a meet media analyst held day 1030 stonesoft headquart helsinki italahdenkatu 22 a the interim report present stonesoft ceo ilkka hiidenheimo',
#  'finnish samporosenlew manufactur approxim seven forest machin monthli half machin export',
#  'facebook near buy point last week face differ technic test today httpstcoc72llmpinm fb aapl nflx httpstcofpfbytypuy',
#  '4 februari 2011 finnish broadband data commun system provid telest oyj hel tlt1v said wednesday net profit rocket eur4 8 2010 eur416 000 2009 lift dividend propos',
#  'free ha heeeeeer come pump so glad i pick 9k end day get readi bull ride',
#  'finnish technolog group aspocomp group oyj omx helsinki acg1v issu third quarter report thursday 13 novemb post oper profit eur0 4 compar loss eur0 5 third quarter 2007',
#  'the build complex consist highqual offic retail space total 49200 squar metr compani said',
#  'finnish insur compani fennia kesko group end loyal custom cooper',
#  'the unit plan oper second half 2007 full stream 2008',
#  'itg share deal estim 500000 euro 627000',
#  'the plant expect enter commerci oper mid2009',
#  'aspo also investig sale opportun kaukomarkkinat electron busi',
#  'bg group appoint new ceo one month earli',
#  'the acquisit immedi posit impact aspocomp financi result',
#  'finnair passeng load factor measur number sold seat share avail seat drop 13 percentag point 767 septemb',
#  'rt bman1 lng look prime also eght pois run',
#  'it also 77 pct 12month volum weight averag price stock',
#  'coke dividend 3 googl dividend 0 for passiv incom coke take goog ko httpstcoqbsowjxost',
#  'profit tax eur 54 mn eur 36 mn year earlier',
#  'the subsidiari set facil manufactur highdens interconnect print circuit board pcb nokia special econom zone sriperumbudur near chennai',
#  'crm sep 40 call 35 sinc entri bang httpstkscodedm',
#  'in januaryjun 2010 dilut loss per share stood eur0 3 versu eur0 1 first half 2009',
#  'rapala said estim make save 12 mln eur year centralis french oper one site',
#  'vmw got nice push today follow small sweeper may c morn',
#  'that top consensu forecast earn 021 euro share',
#  'rd loan',
#  'in futur compani intend look knowhow outsid compani cooper actor sector',
#  'you need readi window open rosberg said',
#  'more 50000 tonn asphalt mix use contract',
#  'pa jpmorgan chase co nyse jpm pohjoa bank joint leadmanag senior unsecur deal',
#  'ctrp break good vol parser buy signal notic bob lang comment look 48 fast',
#  'sale finland decreas 105 januari sale outsid finland drop 17',
#  'the pulp product finnish kemijñrvi also liquid 1100 employe loos job',
#  'nordea cheapest also coupl 30 debt',
#  'jussi pesonen member sampo board sinc 2006 renounc seat sampo board',
#  'tesla recal 2700 model x car httpstco8z7bkvstl9 tsla',
#  'adjust chang group structur divis net sale increas 17',
#  'make matter difficult compani said grappl higher oil ga price push cost energi raw materi transport',
#  'the amend propos simplifi propos plan increas incent key employe stay compani',
#  'the solut expand includ ground staff task',
#  'oper loss total eur 32 mn compar profit eur 72 mn third quarter 2008',
#  'on fedday look sharp move equiti aapl hd low fb see uvxi tvix get hammer even though market',
#  'net sale total eur 936 mn eur 932 mn correspond period 2005',
#  'as consequ work council withdrawn petit suspend reorganis',
#  'ceo erkki jñrvinen happi compani perform 2010',
#  'compar net sale expect increas 10 2008 line group target',
#  'follow transact lundbeck worldwid right nalmefen exclud north america mexico turkey southkorea',
#  'the govern start selloff last month put 8 percent stake teliasonera auction bloc',
#  'the report goe provid detail profil ten lead european specialti chemic compani brief profil major player',
#  'both oper profit net sale threemonth period increas respect eur16 0 eur139m compar correspond quarter 2006',
#  'the compani expect net sale whole 2009 previou year level',
#  'the compani headquart sievi finland list nordic exchang helsinki',
#  'commiss incom increas 22 eur 44 mn lend volum rose 135',
#  'the finnish compani sold uk oper consist 50 staff offic london birmingham manchest part deal hampden juli 2001 europeanwid properti casualti arm sampo industri',
#  'in build home improv trade sale decreas 225 eur 2014 mn',
#  'the innova 2 build locat close downtown immedi vicin paviljonki travel center within walk distanc heart citi thank trade fair bridg',
#  'finnish textil cloth group marimekko oyj post net profit 799 mln euro 104 mln 2006 compar 84 mln euro 109 mln 2005',
#  'the main strength cooper project lie merg knowhow two larg compani',
#  'sharehold right put agenda agm item within compet gener meet',
#  'kazgiprotsvetmet outotec finland sign agreement strateg cooper market provid miner process metallurg plant relat servic kazakhstan surround countri',
#  'due rapid decreas net sale personnel reduct carri wider scale initi expect',
#  'the govern instead propos exchang state stake lmt teliasonera stake lattelecom',
#  'stora due releas fourthquart 2009 fullyear earn feb 4',
#  'fullyear oper result 2008 36 million neg',
#  'nq got hit hard lower am look like found support 1889 httpstkscos052z',
#  'in 2008 avc systemhau net sale eur 10 million usd 71',
#  'the compani establish 3g base station 17000 feet foot mount everest enabl mountain climber 29035foot summit surf internet even send video exploit',
#  'we offer custom solut base renew raw materi',
#  'a survey conduct taloustutkimu sampo life show compani badli prepar lose key staff member',
#  'antti orkola presid kemira growhow industri solut unit told thomson financi new compani put open mine price phosphat quit depress long time',
#  'the pretax profit group life insur busi increas eur36m eur27m',
#  'we make avail follow brandnew market analys cement pakistan cement malaysia cement taiwan cement philippin these analys give clear overview actual situat futur outlook cement industri asian countri',
#  'the compani serv approxim 3000 custom 100 countri',
#  'rt alphatrend vmarket are still act weak httpstksco1agn spi qqq xlf smh iwm',
#  'oper profit total eur 302 mn eur 438 mn year earlier',
#  'one instal elev doubledeck elev enabl effici use build core space',
#  'helsinki afx outokumpu said agre sell hitura nickel mine finland canadian group belveder resourc ltd 10 mln eur worth belveder share',
#  'just went long ilmn',
#  'social network locationbas servic trend compris signific share internet traffic today appeal mid user',
#  'a total 30 order valu book fourth quarter 2009 remaind book second quarter 2010',
#  'johnson matthey share price slump compani post fullyear result',
#  'there previou share subscript 2004 stock option',
#  'affectogenimap build highli customis it solut custom finland baltic countri',
#  'the close transact schedul take place januari 10 2008',
#  'howev offer probabl made current valuat partli deriv deal compani merg stock market shell',
#  'oper result 12month period decreas profit eur0 4 turnov decreas eur5 6 compar 2004',
#  'the administr indic need 900 job cut irish insur next 15 month',
#  'net sale 2008 expect level 2007',
#  'technic indic stock bullish sp give nok posit 4 star 5 buy rank',
#  'revenu quarter total 274 billion 2 percent 281 billion fourth quarter 2008',
#  'nviro oper process facil independ well partnership municip',
#  'the number bodili injuri case quadrupl 20002006',
#  'accord ringman finnish paper compani acquir knowhow capac paper recycl turn success strategi',
#  'the compani also said poland profit program launch oborniki steel frame sandwich panel plant',
#  'and us energi execut say high steel price threaten energi explor',
#  'tesco sale rise show tent recoveri continu',
#  'in finland launch tiein sale 3g mobil phone caus dramat rush mobil retail outlet first day',
#  'nuan held well big gain mayb final move thisit still undervalu major upsid',
#  'the compani split two part come month essent own oper product suppli enexi own oper grid',
#  'offici disclos contract valu',
#  'london lead share today jump almost 100 point 17 market open',
#  'in third quarter fiscal 2008 efor swung net loss eur 400000 versu net profit eur 200000 correspond period fiscal 2007',
#  'the group oper loss eur 08 mn profit eur 25 mn 2004',
#  'the move trigger weak demand forestri equip uncertain market situat',
#  'the combin compani proforma net sale 140 mln euro 1889 mln oper profit 13 mln euro 175 mln 2006',
#  'manag director kari inkinen say sponda leas oper develop highli favour',
#  '17 march 2011 goldman sach estim neg prospect norwegian mobil oper norway telenor asa osl tel sweden teliasonera ab sto tlsn short term',
#  'tsla steam stock relentless moment',
#  'marathon estim valu remain stake protalix 27 million',
#  'whitbread share price climb q4 sale growth',
#  'incap contract manufactur subsidiari incap corpor finland',
#  'oper profit total eur 377 mn slightli eur 372 mn correspond period 2006',
#  'we went market yield guidanc 725 area gave us flexibl go 18th',
#  'rt stockdemon think short close might play spi high beta reversinglook worth shot',
#  'vdw combin lxe devic enhanc product enabl worker use singl devic perform voic scan keyboard function',
#  'thu method cut work cost fasten plan build process',
#  'talentum net sale septemb smaller expect',
#  'copyright afx new afx financi new logo regist trademark afx new limit',
#  'lnkd daili phase 2 retest price experienc earli reject can retest httpstkscot04xx',
#  'rb reportedli appoint howard davi next chairman',
#  'tesco asda sale fall march discount continueskantar',
#  'with new version import us introduc bim process base detail build inform model',
#  'sampo plc jarmo salonen head investor relat group commun tel 358 10 516 0030 distribut nasdaq omx helsinki the princip media financi supervisori author wwwsampocom thi announc distribut thomson reuter behalf thomson reuter client',
#  'barronsonlin see appl 150share year 36 today grow servic busi aapl httpstco3bdnekn7l1',
#  'pharmaceut market poland global research data servic publish recent market analysi pharmaceut market poland',
#  'altogeth finnair cancel 500 flight strike',
#  'the employ togeth health personnel support quit pay part cost nicotin treatment',
#  'pretax loss total eur 117mn compar loss eur 65mn correspond period',
#  'the order includ 48 ship crane deliv 12 contain feeder built wenchong shipyard china',
#  'copper lead nickel also drop hbo hbo plummet 20 703 penc say yearó',
#  'goog test 200 day consolid httpstkscoh0cpj',
#  'he join technopoli kone held variou posit within group recent director servic busi busi develop kone middl eastern oper',
#  'we succeed increas market share sold apart comment mr kari kauniskanga head yit intern construct servic',
#  'profit ebit 139 compar 131 previousyear period',
#  'finnish geosentr net sale decreas eur 939000 januarymarch 2009',
#  'the plant schedul complet late februari 2007 hand area januari two supplier nokia aspocomp group oyj perlo announc plan establish plant within nokia complex togeth invest rs 365 crore',
#  'upmkymmen upgrad inlin underperform goldman sach',
#  'slump weir lead ftse record high',
#  'jan 6 ford struggl face slow truck suv sale surfeit uptod gottahav car',
#  'royal mail breach competit law deliveri servic chang ofcom claim',
#  'the cooper involv arena partner buy 35 share new joint ventur compani oper alma media home sale vehicl consum advertis marketplac busi',
#  'the efor plant saarijarvi central finland one largest employ region',
#  'howev shortterm rental becom popular',
#  'emsa deputi chairman board juri lember told bn wednesday first time heard strike swedish side inform estonian union yet',
#  'tesco close new chairman dixon carphon john allan frame',
#  'the devic offer multimedia perform along host product applic includ live stock price',
#  'sale climb 192 pct 1002 bln eur surpass 953 mln eur consensu figur',
#  'fb turn back earli trade httpstcoreuf5pzhbm',
#  'utah capit want next us headquart amer sport corp skiequip compani',
#  'old mutual firstquart sale up 18 buoy emerg market',
#  'the dividend payabl februari 1 2010 sharehold record januari 19 2010',
#  'sale finland decreas 105 januari sale outsid finland drop 17',
#  'furthermor bung also sign licens agreement sunnuntai carlshamn mejeri brand',
#  'kesko corpor stock exchang releas 28022008 at 0930 1 1 kesko corpor aspo plc today sign agreement aspo acquir share capit kaukotelko ltd subsidiari wholli own kesko',
#  'lulu outlook q1 2013 lost revenu rang 12 million 17 million good',
#  'mobil commun wireless broadband provid nokia inc nyse nok today set new financi target forecast nokia mobil devic industri also nokia siemen network mobil fix infrastructur relat servic market',
#  'poyri plc addit inform heikki malinen presid ceo poyri plc tel 358 10 33 21307 poyri global expert consult engin',
#  'danish compani flsmidth acknowledg violat patent held finnish metso',
#  'amanda capit invest 22 privat equiti fund 200 unquot compani mainli europ',
#  'net interest incom eur 393 mn eur 327 mn',
#  'jeder betatest erhñlt kostenlo sech monat lang updat und hat laut eigen aussag die mâglichkeit die final version zu beeinflussen',
#  'jp morgan expect scala lower nobel biocar growth forecast 2007 current guidanc 2325 pct well oper margin target current 3435 pct',
#  'aviva promis higher dividend boost flag share price',
#  'in addit mid alway onlin enabl full internet brows',
#  'fiskar strong portfolio intern brand includ fiskar iittala gerber silva buster',
#  'tesla model x recal add to reliabl issu tsla httpstcojvxq4doxnp',
#  'the name buyer disclos',
#  'net sale veget oil busi rose eur 106 mn eur 101 mn',
#  'under agreement benefon forthcom rang twig integr gp navig mobil phone devic use jointli develop webbas track locat technolog consum commerci applic',
#  'follow increas huhtamaki regist share capit eur360 62 number share outstand 106063320',
#  'the three year turnaround program expect ensur salomon futur competit compani said',
#  'in autumn plan expand servic st petersburg moscow launch servic yekaterinburg russia fli three time week',
#  'the compani profit total ls 578100 h1 2007 309 yearonyear',
#  'the feder secretari transport commun mexico award poyri mexican partner sintra consult contract connect buenavistacuautitlan suburban railway',
#  'fda approv astrazeneca drug advanc lung cancer',
#  'the order includ metso fourth quarter 2007 order backlog',
#  'lieksaar oy earlier regard control saarelainen oy individu sharehold sharehold agreement',
#  'raguti control finnish breweri report 54percent rise beer sale 1044 million litr held 1109percent market share',
#  'mcp roll new intraday low bottom picker continu get destroy',
#  'the compani annual turnov eur32 8',
#  'it has80 branch finland annual revenu finland',
#  'the portfolio compris 118000 m2 leasabl space vacanc rate roughli 5 let around 140 tenant two largest swedish govern ericsson',
#  'wpp boost sale despit cautiou client',
#  'the mediumterm oper target compani remain unchang',
#  'adp new feb 13 2009 finnish retail kesko oyj hel kesbv said today total sale exclud valu ad tax vat stood eur 6613 million usd 8531 januari 2009 152 yearonyea',
#  'consum well receiv pack fresh meat',
#  'the correct chapter entireti',
#  'the major part deliveri includ differ ac cxe amplifi solut product dinh telecom compani acquir telest last spring',
#  'tietoen use nokia intellisync mobil suit wireless email calendar devic manag capabl compani extend servic custom',
#  'it provid heat form hot water sawmil need',
#  'howev net sale declin eur 8036 million eur 12 billion',
#  'in second quarter 2010 raut net loss narrow eur 123000 eur 15 million period 2009',
#  'dgi technic alert gilligan island buy setup stochast buy signal lizard bullish hammer candlestick wid httpstkscoc29nu',
#  'the record date dividend distribut march 14 2008',
#  'ih move enhanc growth',
#  'the ebrd use fund provid 216 million a loan b portion 10 million euro syndic two finnish commerci bank nordea bank finland plc 77 million euro pohjola bank plc 23 million euro',
#  'stockholm 3 march 2011 about cybercom the cybercom group hightech consult offer global sourc endtoend solut',
#  'he said lose five famili month economi mani make altern arrang save money',
#  'milan afx the italian ship group grimaldi increas stake finnish compani finnlin 354 pct 305 pct held june accord news agenc ansa',
#  'comment deal shane lennon svp market product develop gypsii said',
#  'extern net sale print busi fell 437 partli due termin print contract ilkkayhtyma print hous iprint oy sector player hss media ab decemb 2009 fall print price',
#  'the group intend reloc warehous offic space loudeac saint marcel morvillar east countri alreadi oper hook manufactur distribut unit',
#  'the firm headquart vantaa southern finland 16 employe',
#  'at 133 pm omx helsinki 25 030 pct lower 246367 omx helsinki 037 pct 853742 volum 256 mln eur',
#  'we honor recogn gartner specialist busi process model analysi compani mani largest softwar vendor world',
#  'westpac bank corp is issu benchmark 3 year frn deal euro',
#  'includ compani brand share data categori well distribut channel data',
#  'for new share subscrib stock option sharehold right commenc date enter trade regist',
#  'aapl price momentum weaken go close',
#  'through acquisit solteq expand solut offer microsoft dynam busi softwar product',
#  'the compani profit total ls 134700',
#  'leed intern recogn green build certif system develop us green build council',
#  'howev market share shrank 4759 per cent 48 per cent year earlier',
#  'talktalk hire bae system investig cyber attack',
#  'look like book one way ticket 40 week ma near 50 lose 10 week lulu httpchartly7xb9h9b',
#  'ftse led lower ms glaxosmithklin',
#  'the exercis price option base safran softwar solut licens mainten sale well result compani',
#  'fullyear oper result 2008 36 million neg',
#  'the compani said product volum far indic circuit capabl target output rate 60000 tonn per day 22 million tonn year',
#  'jun 25 2008 boy geniu report deliv newstex the nokia nyse nok n78 huh',
#  'we come decis base preliminari econom oper environment find karvinen said',
#  'the new major owner aspocomp thailand co ltd certain privat person belong immedi circl aspocomp present joint ventur partner saha pathana interhold plc',
#  'some 38 mln euro 52 mln base acquisit price paid cash rest subscript offer total 850000 new ixono share',
#  'establish 1987 srv group privat finnish construct concern oper finland baltic countri russia',
#  'the busi section also includ ahlstrom sustain report',
#  'lemist citi environ knowledgebas economi provid work 3300 peopl total turnov compani amount eek 54 bn said lo pñrnit chairman supervisori board lemist citi mainor',
#  'jacob support storengi invest develop storag site sinc 2006 owner engin',
#  'the compani earlier said consid differ strateg option struggl lowcost mobil oper includ divest hold',
#  'sainsburi asda tesco morrison cut petrol price oil fall',
#  'barclay sell benchmark indic unit bloomberg',
#  'oper profit fourth quarter fell eur33m eur39m year earlier',
#  'finnish forestri compani upmkymmen wast manag compani lassila tikanoja said jan 30 plan produc ethanol energi commerci industri wast',
#  'ism disclos financi result daili said',
#  'the contract cover manufactur surfacetreat instal steel structur',
#  'finnish metal industri solut supplier outotec oyj net profit rose 504 mln euro 725 mln first nine month 2007 201 mln euro 289 mln period 2006',
#  'under deal know it pay sek90m usd12 8 meur8 6 cash stock',
#  'for first nine month 2010 compani net profit rose eur41m eur30m correspond period 2009',
#  'aapl 50dma turn macd crossov halfahair away weekli eod break like',
#  'protalix 42 million cash sale',
#  'that bearish outsid day tuesday signific 200 day resist still intact opinion sd httpchartly2bey48t',
#  'all right reserv',
#  'it oper nokia support nokia netact network servic manag system',
#  'mr priit kasak balti metsamasina owner said rakverebas compani wish increas valmet market share 27 third coupl year',
#  'shire see baxalta deal close expect after new rule',
#  'sainsburi cfo roger replac home retail ceo walden',
#  'marathon 46 percent stake plx said accord bloomberg',
#  'simmon elect dcuc chairman portsmouth nhgordon a simmon ceo servic credit union elect chairman defens credit union council 20072008 term',
#  'sanoma new advertis sale decreas 22 year',
#  'pharmaceut market czech republ global research data servic publish recent market analysi pharmaceut market czech republ',
#  'finnish construct compani yit reduc number startup marketfinanc residenti unit 2007 2300 previous announc 2700',
#  'cash flow oper recent quarter also reach eight year low',
#  'tietoen 113 pct 1838 extend recent low last week secondquart report dealer said',
#  'the maritim administr said ship ignor warn ici condit',
#  'synergi pharma soar 67 today on posit phase 3 result sgyp httpstkscoj2awg',
#  'oper profit rose eur 16 mn eur 11 mn correspond period 2006',
#  'make matter difficult compani said grappl higher oil ga price push cost energi raw materi transport',
#  'vrtx vertex monthli lower hilow lo long term uptrend intract far',
#  'financi detail disclos',
#  'these includ softwar develop internet mobil telephon content commun valuead softwar financi servic secur applic system integr electron ebrd inform',
#  'yit lodg counter claim nest oil total eur25m primarili base work carri contract addit cost incur due prolong project',
#  'should you follow berkshir hathaway into appl stock',
#  'the total amount subscript price record fund invest nonrestrict equiti',
#  'tsla 5th wave 1 hour chart hammer candl develop close 200 sma might good spot call',
#  'strongest growth seen new market russia czech republ slovakia',
#  'the tower engin creat 18 degre westward lean four time inclin lean tower pisa use diagrid structur align geometr use tekla structur bim build inform model softwar',
#  'amer bought salomon adida octob said job cut aim boost competit',
#  'acando ab acanb ss fell 89 percent 1335 kronor lowest close sinc dec 11',
#  'with measur suominen corpor aim ensur competit flexibl packag busi long term',
#  'ifhedieshedi bullhorn334 znga short get nervou',
#  'the financi statement releas avail publish compani internet page wwwcargoteccom',
#  'the world glass come egypt invit visitor around world attend glass world exhibit 2009 regist now wwwglassworldexcom',
#  'compar oper profit total eur 47 mn eur 51 mn correspond period 2005 repres 74 net sale',
#  'most raw materi come europ us paid euro us dollar sale take place rubl',
#  'adpnew may 4 2010 finnish cutleri hand tool maker fiskar oyj abp hel fisa said today net profit declin eur 129 million usd 17m first quarter 2010 eur 17 million correspond',
#  'a maximum 666104 new share subscrib exercis b option 2004 stock option plan',
#  'it inspect compani strateg strength weak',
#  'no plan close date provid',
#  'the lemminkainen group headquart helsinki finland oper sector construct industri civil engin build contract technic build servic build materi industri',
#  'the implement deal subject approv finnish competit author',
#  'microsoft also churn courtship agre use navteq map servic offer compani nokia bought 81 billion year ago',
#  'the geosolut team provid intrigu new technolog combin gp mobilebas technolog togeth internetbas social network',
#  'the 3c expo signatur show dongguan support dongguan municip govern everi year featur comput accessori softwar commun network product',
#  'pharmaceut poland thi brandnew market analysi give clear overview actual situat futur outlook pharmaceut market poland',
#  'trade new share right dividend distribut fund start exchang helsinki tomorrow',
#  'the dualfuel engin vessel oper liquefi natur ga lng low emiss',
#  'among finnish share trade us stora enso close 033 pct lower 1211 eur upmkymmen 028 pct 1810 eur metso 013 pct 3106 eur',
#  'in addit present held presid ceo kai telann cfo tuoma itkonen particip opportun discuss member compani manag',
#  'the chang hold accord chapter 2 section 9 finnish secur market act describ',
#  'with capman partner abl develop busi continu focu provid qualiti restaur servic custom say christoph wynn ceo papa john russia',
#  'the crane would instal onboard two freighter order singaporean ship owner masterbulk',
#  'the busi divest gener consolid net sale eur 60 million annual current 640 employe',
#  'adpnew feb 5 2010 finnish real estat investor sponda oyj hel sda1v said today slip net loss eur 815 million usd 118 2009 profit eur 293 million 2008',
#  'the compani eur2 8 bn asset count among five largest sharehold finnish insur ilmarinen 434 varma 070 well finnish state pension fund ver 061',
#  'in addit 29 employe laid notic whole workforc laid short period need',
#  'chessnwin iwm 30minut chart small cap threaten descend triangl breakdown 11020 httpstkscor0kkm',
#  'corpor it updat c 19952009 m2 commun ltd finnish technolog group telest corpor omx helsinki tlt1v report wednesday 4 februari oper profit eur5 6 net sale eur108 7 year 2008',
#  'stockholmbas nordea bank sto nda said yesterday hire casper von koskul lead corpor merchant bank capit market unit effect 1 septemb',
#  'the total need staff cut correspond 300 manyear',
#  'finnish fiber plastic product maker suominen corpor said net loss narrow 16 mln euro 20 mln first nine month 2006 216 mln euro 27 mln period 2005',
#  'companiesfresnillo share jump 8 silver price break 21',
#  'bluewin secur avail monthli subscript',
#  'oper profit eur 114 mn eur 75 mn',
#  'finnish raisio diagnost launch new dnabas quick test ensur safeti food',
#  'the nonrecur cost caus talentum premedia busi area restructur amount 20 mln euro 27 mln includ compani financi result second quarter 2007',
#  'finnish softwar develop baswar oyj said novemb 30 2006 us subsidiari baswar inc order provid softwar contract lifecycl manag unnam us medic technolog compani',
#  'the chain unit 4550 centr end 2008',
#  'the import thing keep bank exist 15000 custom',
#  'the price stainless steel also rose europ',
#  'in sweden gallerix accumul sek denomin sale 1 eur denomin sale 11',
#  'isrg isrg short httpstkscof1vvu httpstkscoc1qrm',
#  'dara break',
#  'a total 38244 new citycon share nomin valu eur 135 per share subscrib 19 april exercis abc option base compani stock option plan 1999',
#  'aapl im sure short hold breath hope miracl lol',
#  'manag decid end 2005 increas cathod copper capac',
#  'imag data produc browser phone server convert bitmap imag sent handset display',
#  'shire say intern synergi goal baxalta deal higher',
#  'one largest project magazin divis sanomawsoy sanoma magazin intern 2006 becam launch russian magazin gloriya',
#  'finnish airlin finnair start temporari layoff cabin crew februari 2010',
#  'the seller founder compani',
#  'foodservic consum good market serv approxim 13000 peopl 54 manufactur unit sever sale offic 33 countri',
#  'the acquisit frozen food fish sector long synergi lñnnen tehtaat busi',
#  'gnrc find support 10day line far',
#  'under transact agreement metsaliitto purchas 247 metsabotnia share upm 3 mreal',
#  'britain ftse fall back ashtead commod pressur',
#  'sale seppala diminish 6 per cent',
#  'bbri bye bye sammi hello bb sound like well see green tomorrow',
#  'as capac cut 14 passeng load factor 78 percentag point',
#  'rockwel collin provid flight deck cabin inform manag solut busi aircraft oper',
#  'the floor area yliopistonrinn project 7900 sq build gross area total 12800 sq a total 251 facil let',
#  'nflx vision short term consolid movement higher httpstkscoj05uu',
#  'theodosopoulo said tellab could valu nokia siemen nortel given lead suppli statu verizon along highgrowth product',
#  'in current posit manti work sinc 1996',
#  'with new product plant compani would increas capac meet expect increas demand would improv use raw materi therefor increas product profit',
#  'analyst view astrazeneca share seen recent volatil 2015',
#  'earn per share ep drop eur 021 eur 031',
#  'after transact tikkurila powder coatingsrel oper compani said',
#  'are arm hold plc domino pizza group plc aso plc 3 musthav growth stock',
#  'pearl plaza llc joint ventur srv shanghai industri invest hold co ltd conclud invest decis construct first phase shop center saint petersburg russia',
#  'the measur result decreas demand technic design product inform',
#  'finnish financi group aktia report oper profit eur 444 mn januaryseptemb 2009 eur 373 mn correspond period 2008',
#  'key price watch nflx previou doubl top reject 21823 httpstkscosiyn',
#  'finnish glass technolog compani glaston oyj abp net profit decreas 26 mln euro 38 mln first nine month 2007 78 mln euro 114 mln period 2006',
#  'citi spirit sink diageo come short sale slide',
#  'oper loss increas eur 17mn loss eur 108 mn 2005',
#  'alexandria va june 7 michael g william newburi park calif develop network devic',
#  'olvi post strong set figur first six month year',
#  'stanchart rb struggl bank england stress test',
#  'in begin year wartsila secur order deliv four gasfuel main engin propuls machineri vessel',
#  'in januarynovemb 2009 group sale total eur 78017 mn drop 126 period 2008',
#  'glaxosmithklin target growth across unit scrap viiv ipo',
#  'bhp billiton share price brazil sue samarco â35bn',
#  'it come complet lcd touch screen system select chosen function price start around pound 4805 mark',
#  'revenu quarter fell 8 percent euro 24 billion compar year earlier',
#  'after split compani would 26885540 seri a share 9540000 seri k share',
#  'a le coq special develop bicentenari compani trade mark brewer said',
#  'arcelormitt chief execut offic lakshmi mittal alreadi cut output furnac',
#  'oper profit fell eur 151 mn eur 246 mn 2006',
#  'the bridg part highway 14 develop project',
#  'kesko agro lietuva agricultur machineri grain trader anoth member kesko group boost sale 429 percent 134 million euro vat inclus',
#  'adpnew dec 1 2009 finnish cutleri hand tool maker fiskar oyj abp hel fisa said today make redund total 18 offic manag staff member subsidiari iittala group ltd',
#  'metso foundri jyvaskyla oy discontinu product line 30 septemb 2008',
#  'the sale price disclos',
#  'helsinki afx retail wholesal group kesko report net sale 6594 mln eur februari increas 108 pct yearonyear',
#  'in februari 2011 new word ident document act make mobil id stateapprov electron document februari 1st 2011 enter forc',
#  'antti orkola presid kemira growhow industri solut unit told thomson financi new compani put open mine price phosphat quit depress long time',
#  'you alon',
#  '2009 3 februari 2010 finlandbas steel maker rautaruukki oyj hel rtrk ruukki said today slip largerthanexpect pretax loss eur46m fourth quarter 2009 yearearli profit eur45m',
#  'the sale savcor face cencorp result profit loss yet determin owe factor includ valuat consider share receiv prevail exchang rate',
#  'the acquisit àlandsbanken sverig 2009 burden perform eur 30 mn',
#  'it first applic market invoic purchas requisit approv mobil devic',
#  'a helsinki eliiv today report ep eur1 13 2009 increas ep eur1 12 2008',
#  'easyjet dismiss lufthansa lowcost plan contest germani',
#  'order receiv grew 55 yearonyear eur732m',
#  'in januaryaugust 2009 import sea contain lorri trailer unit fell 277 export 286 correspond period 2008',
#  'finnish broadband data commun system provid telest oyj hel tlt1v said yesterday return net profit eur 27 million usd 38 first nine month 2010 versu net loss eur 579000 period 2009',
#  'adpnew dec 23 2009 norwegian financi servic group sparebank 1 gruppen as osl sbgrp said board director appoint today jarl haug manag director claim collect subsidiari sparebank 1 gruppen finan',
#  'finnishown contract manufactur electron elcoteq hungari kft announc plan recruit 650 new staffer fulfil new order pc compani two plant',
#  'at 1259 pm omx helsinki 25 index 032 pct lower 269481',
#  'nyrstar also agre suppli talvivaara 150000 tonn sulphur acid per annum use talvivaara leach process period suppli zinc concentr',
#  '23 april 2010 finnish construct engin compani outotec oyj hel ote1v said today slip net loss eur7 3 first quarter 2010 net profit eur12 5 correspond period last year',
#  'revenu slightli x20ac 495 million 634 million compar x20ac 497 million year earlier',
#  'rt dasan tmtanalyst sinc aapl master suppli chain corner nand appl master everyon suppli chain',
#  'poyri net sale 2007 amount eur 720 million employ 7400 expert',
#  'the adjust concern staff specialti paper fiber composit segment',
#  'accord notif hold ameripric inc group compani total 808973 share repres 3582 tekla share vote right',
#  'appl break major support level watch httpstkscojrmw aapl qqq',
#  'royal mail chairman donald brydon set step',
#  'it also confirm earn guidanc whole 2009 issu report whole 2008',
#  'their offer also cover localis servic relat product transfer finnish compani custom alreadi product asian market made decis transfer product',
#  'db juliu baer emerg potenti bidder barclay asia wealth unit',
#  'the fair valu invest properti eur 2 2510 1 2814 million',
#  'companiestravi perkin lift dividend earn rise 15',
#  'okmet product base hightech expertis gener ad valu custom innov product develop extrem effici product process',
#  'compar oper profit total eur 47 mn eur 51 mn correspond period 2005 repres 74 net sale',
#  'the equip design bollor africa logist termin societ dexploit du termin de vridi setv abidjan ivori coast deliveri schedul start march 2010',
#  'telest hybrid tv solut includ compon whole process deliv video servic consum content acquisit servic creation deliveri rang access solut includ hfc hybrid fibrecoaxi xdsl etth ftth',
#  'in 2006 compani net sale amount approxim eur259m 8000 employe',
#  'new novat product suppos export',
#  'elcoteq global network after market servic site long experi serv consum electron system solut custom',
#  'finnish compon supplier componenta corpor omx helsinki cth1v report tuesday 15 juli oper profit eur46 2 net sale eur386 0 financi period januaryjun 2008',
#  'save break downtrend line increas volum a move 2057 could see upsid httpstkscol8y4',
#  'the offici open offic locat pragu celebr may 20',
#  'appl anoth attempt break appl weak pvt aapl trade invest aapl httpstcodnh7hgv22v',
#  'it also turn earn per share ep eur 008 versu loss per share eur 004',
#  'complet transact subject final agreement due dilig process',
#  'morrison financ chief fill gap ceo leav earli',
#  'earn per share ep amount eur0 98 loss eur0 02',
#  'tiimari oper 194 store six countri includ core finnish market gener turnov 765 mln eur 2005',
#  'chang announc today effect close trade friday june 19 2009',
#  'accord chairman michael hornborg organ mere criticis raisio weak perform',
#  'bae systemss sale boost european typhoon currenc',
#  'honkarakenn also decid yesterday sell 88500 b seri share key staff member eur2 9 per share',
#  'to rais consum awar encourag peopl recycl old mobil devic nokia run regular recycl campaign around world',
#  'in baltic merger busi two expect complet earli 2008',
#  'tieto look energi solut would best support idea sustain develop happi abl provid solut saysjouni haikarainen vice presid fortum',
#  'expens ratio 1026 compar 929 correspond period 2005',
#  'stockmann plc compani announc februari 20 2007 1340 an annual summari stockmann stock exchang financi press releas 2006 avail compani websit address wwwstockmanncom',
#  'hopeturock ye expect deal somewhat price could see nice pop bid come higher expect yhoo',
#  'aapl dip bought real quick higher low fo sho',
#  'oper profit continu oper fell eur 483 mn eur 724 mn first half 2007',
#  'baswar ceo ilkka sihvo comment conjunct interim report as whole baswar succeed well second quarter 2007',
#  'nasdaq omx geo1v gypsii busi unit develop awardwin gypsii mobil social network applic today announc avail free download via samsung mobil applic store',
#  'i tri deal slaveri differ perspect balanc stori say deramu formerli writer detroit free press detroit new',
#  'compar ftse 100 index rose 949 point 16 day rel price chang 04',
#  'whi alphabet inc upgrad buy httpstcodevnlkhqtz googl',
#  'all raisio divis record oper profit',
#  'the announc come two week key licens agreement expir two compani embroil disagr royalti payment texa instrument chip use qualcommpat technolog',
#  'the share capit alma media corpor busi id 19447574i eur 4503151380 divid 75052523 share',
#  'the forecast 2012 33',
#  'the hull vessel built one block time ruukki deliv plate materi block construct progress',
#  'oper profit eur 16 mn 2005 compar eur 59 mn 2004',
#  'the reason st petersburg statu capit one particip meet quot chikunov say',
#  'upon complet sale proha would get usd12 7 stake artemi',
#  'buffett berkshir build deer stake dump exxon',
#  'last year net sale rose eur 683 million eur 622 million',
#  'earn per share quarter also higher yearonyear 033 eur versu 027 market expect 028 eur',
# ...
#  'product situat improv',
#  'ssh commun secur corpor headquart helsinki finland',
#  'for full 2010 compani expect net sale oper result improv previou year say posit oper result amount depend order intak end summer',
#  'oper margin howev slip 144 151 drag poor perform enterpris solut',
#  'finnish metal product compani componenta oyj net profit rose 261 mln euro 359 mln first quarter 2007 53 mln euro 73 mln period 2006',
#  'so today close 81514 im long tsla amtd twtr fb aapl celg longerterm technic swing long basi',
#  'the acquir busi main asset mobil authent sign solut brand tectia mobileid provid authent web email sslvpn ms sharepoint tectia secur solut applic resourc',
#  'the report examin medic equip busi structur oper histori product provid analysi key medic equip revenu line',
#  'adpnew aug 3 2009 finnish media group ilkkayhtyma oyj hel ilk2 said today net profit fell 45 year eur 59 million usd 84 first half 2009',
#  'the new technolog improv glass qualiti consist increas throughput',
#  'london marketwatch nokia nok said fiveyear servic contract run hutchison essar network oper nine locat india',
#  'soullor regular scrappi q swi usual present sale weak margin debt still way',
#  'oper profit margin 83 compar 118 year earlier',
#  'consolid net sale increas 16 reach eur74 8 oper profit amount eur0 9 compar loss eur0 7 prior year period',
#  'finnish forest machineri manufactur ponss issu profit warn',
#  'the enterpris valu fray bento pulp mill forest orient total approxim euro1 6 billion upm said',
#  'rental build equip account 88 percent oper incom',
#  'the measur result weak demand shipbuild industri',
#  'may 29 2010 companiesandmarketscom deliv newstex thi report provid key data inform meat fish poultri market finland',
#  'in addit demand finland export line stone product also increas',
#  'the current refer grade instrument challeng oper due high price complex routin use',
#  'they alreadi alloc money inventori',
#  'a total 131000 talvivaara mine compani plc new share subscrib period may 1 2010 june 30 2010 compani stock option right 2007a',
#  'eurusd find support near 110 level ero uup udn fxe httpstkscob29eu',
#  'the annual valu contract estim usd 2mn next three year',
#  'in addit launch versatil onlin servic complet tradit print newspap mr valkama say',
#  'the compani said oper sold newli establish compani cp gmbh present manag plastic busi coowner',
#  'finnish metal product compani componenta oyj net profit went slightli 251 mln euro 402 mln first half 2008 254 mln euro 407 mln period 2007',
#  'marketsbp promot upstream boss deputi ceo',
#  'britain ftse bounc back mondi barratt lead',
#  'loudey corp 256 433 nokia corp 10 cent 1946 nokia agre buy digit music distributor 60 million',
#  'raguti control finnish breweri olvi achiev 57 percent rise beer sale 226 million liter held 1075 percent market share',
#  'finnair said cancel flight would caus daili loss x20ac 25 million us 3 million',
#  'the energi sector account approxim 33 steel industri 57 transport volum',
#  'the 5000 megawatt wind farm plan raah would built offshor front ruukki raah work',
#  'the australian compani mirabela nickel award outokumpu technolog contract grind technolog nickel sulfid project bahia state brazil',
#  'standard charter rb escap capit rais stress test',
#  'oper profit half 08 09 glisten invest brand manag team',
#  'the expans final autumn 2009',
#  'finnish konecran tri acquir italian fantuzzi manufactur gantri crane reach stacker',
#  '1 pm central offic nordea bank 19 3ya ulitsa yamskogo polya build 1 telephon 495 7773477 ext 3932 3931 03022011 unimilk egm 0304 022011 xvi intern businesssummit food busi russia 2011 take place',
#  'adpnew feb 3 2010 finlandbas steel maker rautaruukki oyj hel rtrk ruukki said today slip largerthanexpect pretax loss eur 46 million usd 645 fourth quarter 2009',
#  'the compani expect net sale 2008 increas 510 2007',
#  'about 72 evraz group share own lanebrook whose beneficiari one hand millhous hold compani asset billionair roman abramovich busi partner 50 evraz execut alexand abramov alexand frolov 50',
#  'the margarin busi put good shape last two year make natur addit bung look leverag posit central northern european market raisio ceo matti rihko said statement',
#  'the loyal custom found bank àland index 80',
#  'tesco break downward slide cut sale declin half',
#  'eriikka sâderstrâm previous held sever posit financ control nokia network includ act busi group control corpor control posit nokia siemen network',
#  'no price detail disclos',
#  'long aapl',
#  'salonen ad data show produc pulp inventori north america declin',
#  'finnish it consult satama interact oyj post net profit 14 mln euro 20 mln first nine month 2007 compar net loss 462000 euro 664000 period 2006',
#  'consist seven interconnect unit mega imag logist center 347 metr length 12 metr height',
#  'tesco plc recoveri continu with a â250m cash infus',
#  'kesko 2000 store engag chain oper nordic baltic countri russia belaru',
#  'is troubl brew at legal gener group plc and aviva plc',
#  'helsinkibas componenta bought turkish list compani dokta octob 2006 89 million euro make largest finnish invest turkey date',
#  'the ecb mainli target inflat',
#  'oper profit total eur 38 mn eur 45 mn correspond period 2005',
#  'the group said intend initi within year process buyout minor sharehold raguti aim becom sole owner compani',
#  'initi compani said maximum 15 peopl would made redund parent compani 15 subsidiari',
#  'the contract incorpor converg charg rate solut voic data includ internet gpr sm mm wap',
#  'astrazeneca lung cancer drug tagrisso get fda approv',
#  'our custom includ compani energi process industri sector particular',
#  'europ howev remain import strong market us',
#  'morrison debenham surpris citi christma bounc back',
#  'the ongo project tekla structur use vashi exhibit centr develop insteel engin pvt ltdiivrcl infrastructur project ltd cidco',
#  'talentum expect net sale core busi increas 2008 compar 2007',
#  'oper profit half 08 09 glisten invest brand manag team',
#  'it total annual revenu come 160 mln zloti 569 mln42 3 mln euro',
#  'the correspond increas share capit eur422 754 enter trade regist today',
#  'group ebit first half eur13 6 us 178 fall short eur22 5 post period 2009',
#  'relat citi damag comment mr ashley criticis citi investor analyst cri babi',
#  'the engin electr output 18321 kw make largest ga power gener set world',
#  'pretax profit total eur 49 mn compar eur 52 mn first quarter 2005',
#  'most recent found virent energi system inc 80 person catalyt biofuel compani presid ceo led compani multipl financ defin compani market strategi secur compani first custom',
#  'addu servic includ person care assist activ daili live skill nurs rehabilit therapi adult day care',
#  'tripadvisor jump ma rumor httpstcoo4lwcdxmbr trip',
#  'finnish civil aviat administr decid temporarili reopen finnish capit helsinki airport sinc 3 pm 11 pm monday local time',
#  'report accord merg busi oper start januari 1 2011',
#  'earn per share ep first quarter 2007 amount eur0 07 eur0 04',
#  'finnlin estim annual gener meet 2008 financi tough year due larg invest',
#  'meanwhil minor sharehold expect teliasonera retain bid sell share',
#  'extern net sale print busi fell 437 partli due termin print contract ilkkayhtyma print hous iprint oy sector player hss media ab decemb 2009 fall print price',
#  'oper profit eur 98 mn compar loss eur 127 mn correspond period 2009',
#  'word street allergen look endo intern fail pfizer merger may20 35 call activ endp',
#  'fbr capit reiter outperform rate brcm price target 4500 friday',
#  'metalszinc surg 12 pct glencor cut output fuell metal ralli',
#  'profit period fell eur 16 mn eur 75 mn januaryseptemb 2008',
#  'is it worth invest in tesco plc and prudenti plc now',
#  'finland finnish pharmaceut compani orion corpor omx helsinki ornav said wednesday 7 januari conclud personnel negoti finland reduc number personnel 205',
#  'finnish retail stockmann approv board swedish rival lindex public tender offer aim expand compani presenc russia cee countri stockmann said monday',
#  'in releas compani said vocollect t2 custom north america take advantag voic direct wareh solut increas warehous effici product gain discount price',
#  'nikla skogster employ abb group variou posit concern develop oper',
#  'oper profit exclud nonrecur item total eur 02 mn eur 08 mn correspond period 2006',
#  'finnish metso paper award contract rebuild sabah forest industri sfi pulp mill sabah malaysia',
#  'ruukki forecast 1520 annual sale growth posit pretax result 2010',
#  'the price gmo soy 5 7 lower nongmo',
#  'finland nokian tyre kazakhstan ordabasi corpor sign agreement build plant astana produc car tire ordabasi chairman dinmukhamet idrisov said press confer',
#  'with sale 127 billion last twelv month end octob 2010 9200 store 35 state dollar gener nation largest small box discount retail',
#  'get midnighttrad in realtim thi report delay',
#  'danish compani flsmidth acknowledg violat patent held finnish metso',
#  'the share issu derog preemptiv right sharehold compris six million new share market price offer subscript sharehold holder capit note profession client',
#  'tielinja gener net sale 75 mln euro 96 mln 2005',
#  'karachi sept 14 ixono world leader develop integr solut handheld devic announc implement touch screen mobil user interfac solut intel atom processor z6xx base smartphon',
#  'nest oil work 20 research commun europ america africa asia australia develop introduc new raw materi',
#  'the new agreement expand longestablish cooper compani involv transfer certain engin document function larox etteplan',
#  'it',
#  'took endp long use vwap guid',
#  'despit sale growth uk tesco caution recoveri bumpi',
#  'in finland metal sector compani componenta lay temporarili staff pori mill christma 2008 till 6 januari 2009',
#  'in middl east north africa tecnotre grown consider recent year',
#  'both oper profit net sale sixmonth period increas respect eur18 1 eur127 6 compar correspond period 2006',
#  'insur axa par cs slid 535 eur 1415 citigroup ing slash target stock',
#  'the order valu eur 69 mn consist design servic hardwar softwar licenc',
#  'scanfil also issu profit warn',
#  'a spokesman said the food store center subject council local support could compris supermarket smaller store nich outlet firm follow consult council local commun regard appropri use occupi',
#  'the bond valu eur150m matur 4 year',
#  'millercoor board name gavin hattersley interim ceo',
#  'airbu attempt evacu 873 peopl within 90 second',
#  'first quarter underli oper profit rose 41 mln eur 33 mln year earlier',
#  'ep quarter eur0 00 compar eur0 01 third quarter 2008 repres group net sale third quarter eur15 3 28 compar eur14 9 third quarter 2008',
#  'royal dutch shell profit rise dividend 4',
#  'meanwhil electrowattekono philippin inc also award threeyear oper mainten om contract fr cement corpor',
#  'the agreement includ applic mainten support servic',
#  'nokia interest bring nokia market',
#  'affecto expect net sale whole 2010 increas 2009 level reach eur 103 million',
#  'the report profil 158 compani includ mani key nich player includ major nonwoven manufactur ahlstrom corpor asahi kasei corpor buckey technolog inc ei',
#  'the layoff affect 240 peopl total 320 okmet employe finland',
#  'the acquisit elektro pavara complet kone market expans strategi baltic countri',
#  '18 may 2010 finnish electron produc elcoteq se hel elqav said today sign extens cooper agreement industrialis manufactur distribut aftermarket servic mobil phone japan sharp tyo 6753',
#  'morrison book second consecut quarter sale growth',
#  'marimekko today 20 novemb sign licens agreement swedish chain wherebi marimekko licens popular pattern 1950 1960 1970 hm',
#  'quick fio 2135 market tank scale long',
#  'the announc push freenet share 63 eur0 71 frankfurt trade eur10 65 investor gave hope unit internet ag drillisch would pursu takeov breakup freenet',
#  'finnish telecom softwar develop tecnomen oyj said decemb 5 2006 33 mln 25 mln euro order suppli expans charg messag system mobil fix network brasil telecom',
#  'companiesunilev sale lift ice cream soft economi',
#  'ep drop eur0 2 eur0 3',
#  'saltwaternurs ino test 10 next day time take profit hedg put',
#  'no financi inform provid',
#  'easyjet attract passeng june still lag ryanair',
#  'morn agenda shire deal np',
#  'metso suppli equip two process line northland resourc new kaunisvaara iron ore project sweden exploit tapuli sahavaara iron ore deposit',
#  'under agreement biohit becom focu supplier pipettor dispos pipettor tip vwr custom throughout europ',
#  'the compani previou estim lower revenu yearago eur 939 million',
#  'earn per share ep drop eur 021 eur 031',
#  'bid offer includ least 1000 share valu share must correspond least eur4 000',
#  'earn per share ep amount loss eur0 06',
#  'netapp downgrad macquari underperform 2200 pt httpstcoxcngws0t4q ntap ntap via ratingsnetwork',
#  'russia readi particip open tender lattelecom privat',
#  'technopoli st petersburg govern sign cooper memorandum octob 2005 set technopark neudorf product zone villag strelni st petersburg suburb',
#  'the owner particip busi oper compani continu poyri employ transact',
#  'the goal secur compani profit competit',
#  'howev compani saw net profit third quarter eur 14 million eur 15 million correspond period 2009',
#  'nest oil board propos 100 eur dividend fullyear 2007 compar 090 eur year ago',
#  'baswar einvoic oy merg parent compani present fiscal period',
#  'fintech provid cafn cachet financi solut surg forward today post earn up 1326 httpstco9bj3csk2i9 jkhi fisv momo',
#  'befor kemira instal nordalu produc 3500 ton liquid solid aluminum wast per year',
#  'he charter account british columbia alberta well certifi public account washington state',
#  'veri recommend nokian z g2 accord adac judgement latest summer tyre test german automobil associ adac',
#  'the group result tax loss eur 06 06 million',
#  'cash flow oper activ invest eur 08 12 million',
#  'vike line cancel servic',
#  'exel headquart mantyharju finland',
#  'stora chief execut jouko karvinen describ russian tariff hike threat futur forest product industri finland',
#  'after barclay bank america citigroup blockchain sight',
#  'googl inc complet acquisit icoa inc httpstksconfei icoa goog',
#  'tsla look goodid love see base action let rsi take breather httpstkscog1t7c',
#  'finnish plumb heat system supplier uponor net sale continu oper decreas 94 2008 eur 9492 mn eur 10474 mn 2007',
#  'thi locat make mall conveni place shop consum three larg residenti area nearbi jaroszowka wysockiego zgodi',
#  'finnish insur compani fennia kesko group end loyal custom cooper',
#  'the case compris first side case member provid first side vat segment second side case member provid second side vat segment least first side case member pivot rotat axi',
#  'finlandbas elcoteq se privat held provid electron manufactur servic commun compani said thursday sign longterm manufactur suppli deal commun equip compani andrew corp',
#  'in q1 2009 bank àland net interest incom weaken 10 eur 91 mn',
#  'rb pay 17 billion scrap uk treasuri dividend right',
#  'increas trust client yit seen apart sale acceler',
#  'talvivaara mine compani plc talvivaara mine compani intern signific base metal produc primari focu nickel zinc use technolog known bioheapleach extract metal ore',
#  'oper profit 2009 lower outlook publish earlier',
#  'less ten peopl face pension agreement',
#  'the compani consolid oper profit amount eur 1586 mn eur 414 mn yearonyear',
#  'astrazeneca buy zs pharma 27 billion',
#  'finnish wast manag clean group lassila tikanoja oyj lt net profit went 322 mln euro 477 mln 2007 353 mln euro 523 mln 2006',
#  'the oper margin aker yard cruis ferri divis went 83 64 first quarter 2007',
#  'helsinki thomson financi share cargotec fell sharpli earli afternoon trade cargo handl group post surpris drop apriljun profit overshadow larg number new order receiv three month',
#  'the program target structur cost reduct eur 30mn 2009',
#  'our tool specif design need busi user ict expert mind',
#  ...]

# %%
x=cv.fit_transform(stem_vec).toarray()

# %%
#importing multinomial
from sklearn.naive_bayes import MultinomialNB

# %%
y=df['Sentiment']

# %%
mb = MultinomialNB()

# %%
mb.fit(x,y)

# %%
x[0]
# Out:
# array([1, 0, 0])

# %%
df['Sentence'][0]
# Out:
# 'positive'

# %%
mb.predict([x[1]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x_vec,y,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = LogisticRegression()

# %%
lgr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
import pickle
with open("vectorizer.pickle","wb") as mdl_file:
    pickle.dump(x,mdl_file)
