# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
df.tail()
# Out:
#                                                Sentence Sentiment
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive

# %%
x=df.iloc[0,1]
x
# Out:
# 'positive'

# %%
import re

# %%
# Dropping null values and converting to string
df['Sentence'] = df['Sentence'].dropna().astype(str)

# %%
mydata=[] #empty list
for i in df['Sentence']:
  text = re.sub(r',','',i)
  cleaned_text = re.sub(r'[^\w\s]', '', text)  # Removes everything except word characters and spaces
  cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replaces multiple spaces with a single space
  cleaned_data = cleaned_text.strip()  # Removes leading/trailing whitespace
  mydata.append(cleaned_data)

# %%
mydata
# Out:
# ['The GeoSolutions technology will leverage Benefon s GPS solutions by providing Location Based Search Technology a Communities Platform location relevant multimedia content and a new and powerful commercial model',
#  'ESI on lows down 150 to 250 BK a real possibility',
#  'For the last quarter of 2010 Componenta s net sales doubled to EUR131m from EUR76m for the same period a year earlier while it moved to a zero pretax profit from a pretax loss of EUR7m',
#  'According to the FinnishRussian Chamber of Commerce all the major construction companies of Finland are operating in Russia',
#  'The Swedish buyout firm has sold its remaining 224 percent stake almost eighteen months after taking the company public in Finland',
#  'SPY wouldnt be surprised to see a green close',
#  'Shells 70 Billion BG Deal Meets Shareholder Skepticism',
#  'SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANGE RELEASE OCTOBER 14 2008 AT 245 PM The Company updates its full year outlook and estimates its results to remain at loss for the full year',
#  'Kone s net sales rose by some 14 yearonyear in the first nine months of 2008',
#  'The Stockmann department store will have a total floor space of over 8000 square metres and Stockmann s investment in the project will have a price tag of about EUR 12 million',
#  'Circulation revenue has increased by 5 in Finland and 4 in Sweden in 2008',
#  'SAP Q1 disappoints as software licenses down Real problem Cloud growth trails MSFT ORCL GOOG CRM ADBE httpstcojNDphllzq5',
#  'The subdivision made sales revenues last year of EUR 4807 million EUR 4149 million in 2008 and operating profits of EUR 445 million EUR 74 million',
#  'Viking Line has canceled some services',
#  'Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEMENT 722007 at 1030 A total of 56955 new shares of Ahlstrom Corporation have been subscribed with option rights under the company s stock option programs I 2001 and II 2001',
#  'FB gone green on day',
#  'MSFT SQL Server revenue grew doubledigit with SQL Server Premium revenue growing over 30 httpstkscoir2F',
#  'According to Lñnnen Tehtaat s CEO Matti Karppinen the company aims to deliver fish products to its customers a day earlier than it currently does',
#  'The company s share is quoted on NASDAQ OMX Helsinki Rautaruukki Oyj RTRKS',
#  'Elcoteq SE is listed on the Nasdaq OMX Helsinki Ltd',
#  'Two of these contracts are for turntable anode vibrocompactors that will be delivered to Gansu Hualu Aluminum Co Ltd and another unnamed costumer',
#  'Aviva Friends Life top forecasts ahead of 56 billion pound merger',
#  'In stead of being based on a soft drink as is usual the Teho energy drink is made with fresh water',
#  'The company plans to increase the unit s specialist staff to several dozen depending on the market situation during 2010',
#  'The company closed last year with a turnover of about four million euros',
#  'Shire CEO steps up drive to get Baxalta board talking',
#  'Costco A Premier Retail Dividend Play httpstcoFa5cnh2t0t COST',
#  'The fivestorey ecoefficient building will have a gross floor area of about 15000 sq m It will also include apartments',
#  'The first installment of the Cinema Series concludes with a profile of Finnish inventor Olavi Linden whose personal artistic journey and work at Fiskars has led to dozens of design awards',
#  'All are welcome',
#  'Stockmann and Swedish sector company AB Lindex entered into an agreement on September 30 2007 whereby Stockmann or a whollyowned subsidiary of it will make a public tender offer for all of Lindex s issued shares',
#  'HUHTAMAKI OYJ STOCK EXCHANGE RELEASE 1692008 AT 1332 Huhtamaki s Capital Markets Day for institutional investors and analysts is held in Espoo September 16 2008 starting at 1330 pm Finnish time',
#  'We are pleased to welcome Tapeks Noma into Cramo group',
#  'Profit before taxes was EUR 1059 827 million',
#  'Royal Dutch Shell to Buy BG Group for Nearly 70 Billion',
#  'FinancialWire tm is not a press release service and receives no compensation for its news opinions or distributions',
#  'ASSA ABLOY Kaupthing Bank gave a neutral recommendation and a share price target of 174 crowns 247 19 euro on Swedish lock maker Assa Abloy AB',
#  'The item included restructuring costs of EUR1 6 m while a year earlier they were EUR13 1 m Diluted EPS stood at EUR0 3 versus a loss per share of EUR 01',
#  'In 2005 the bank posted a net profit of Lt 82 mn',
#  'AAPL afternoon selloff as usual will be brutal get ready to lose a ton of money',
#  'TSLA recalling pretty much every single model X cnnbrk got to short that even at work you jump in money trade',
#  'Dolce Gabbana has asked the European Union to declare Marimekko Corporation s Unikko floral pattern trademark invalid in a continuing dispute between the two companies',
#  'InterContinental Hotels firstquarter global room revenue lags estimates',
#  'According to Finnish pension insurance company Varma Varma was the recipient of over two thirds of the revenue of the earningsrelated pension cover that was under competitive tendering in Finland',
#  'A portion 125 million will be recorded as part of its winnings in a prior patent dispute with Finnish phone maker Nokia Oyj',
#  'LG still paying price for dividend cut during crisis chief says',
#  'The volume of investments in the two phases of the project is estimated at USD 300mn EUR 21503 mn',
#  'Russia accounted for 9 of the Lagardere magazine division s revenue or EUR 11440 mn USD 14811 mn in 2009 the USA for 18',
#  'The company also estimates the already carried out investments to lead to an increase in its net sales for 2010 from 2009 when they reached EUR 1417 million',
#  'Profit of the accounting period was EUR 03 mn',
#  'The six breweries recorded a 52 percent growth in domestic beer sales last year to 27021 million liters from 25688 million liters sold in 2005',
#  'In AugustOctober 2010 the company s result before taxes totalled EUR 96 mn up from EUR 05 mn in the corresponding period in 2009',
#  'Systeemitiimi s sales and project resources will also be strengthened director Paul Skogberg said',
#  'Tesco share price jumps as Q3 sales top estimates',
#  'The fine print is here',
#  'The price for logs has clearly improved from 2009 and also the price of pulpwood has gone up',
#  'Thus SysOpen Digia has in accordance with Chapter 14 Section 21 of the Finnish Companies Act 2991978 734 obtained title to all the shares of Sentera that are to be redeemed',
#  'Diluted earnings per share EPS fell to EUR 063 from EUR 171',
#  'At 337 pm Eastern time a block of 2400 contracts changed hands at a bid price of 045',
#  'Some of the most recent technology deliveries include refinery technology to Anrak Aluminium an iron ore pelletizing plant to Tata Steel and iron ore sintering plants to Bhushan Steel',
#  'VIPS similar pattern like beginning of May Did u sell Same nowwill go up much higher after this drop',
#  'The firm generated sales of 187 mln eur in 2005',
#  'Stora Enso has also had meetings with the labor authorities Employment and Economic Development Centres and representatives of the government in order to find solutions',
#  'AstraZeneca profit down as sales of stalwarts fade',
#  'RT andrewnyquist Chartology Yahoo httpstksco1itr YHOO Crazy looking chart but nearing breakout resistance line',
#  'Most bullish stocks on Twitter during this dip YHOO GDX GOOGL STZ GOLD EW VZ CELG SBUX SCTY more httpstcoiuZJelfwt3',
#  'Finnish GeoSentric s net sales decreased to EUR 939000 in JanuaryMarch 2009',
#  'Cohen Steers Inc 5 534 626 shares representing 4985 of the share capital and voting rights',
#  'More staff has been recruited in Japan to further complement its network of close to 50 service locations in more than 20 countries worldwide',
#  'Paper companies were in negative territories with Stora Enso R shedding 162 pct to 1273 eur UPMKymmene down 080 pct at 1864 eur and Mreal B 018 pct lower at 557 eur',
#  'KaukoTelko s centralized administration will be dissolved and appropriate parts of it will be transferred to operating activities and Group administration by the end of the year',
#  'Operating profit for the quarter AprilJune 2006 amounted to EUR182 2 m on sales of EUR3 62 bn',
#  'Atria chose the DeLight to attract consumers in the 2545 age group to its Atria Fresh range of microwaveable meals',
#  'Finnish IT solutions provider Affecto Oyj HEL AFE1V said today its slipped to a net loss of EUR 115000 USD 152000 in the second quarter of 2010 from a profit of EUR 845000 in the corresponding period a year earlier',
#  'US sanctions put GazpromShell alliance plans in jeopardy',
#  'Profit for the period was EUR 109 mn down from EUR 143 mn in 2009',
#  'Profit for the period was EUR 59 mn up from EUR 13 mn',
#  'Operating profit fell to EUR 203 mn from EUR 742 mn in the second quarter of 2008',
#  'However sales returned to growth in AprilJune 2010 CEO Pekka Eloholma said',
#  'Operating profit totaled EUR 186 mn or 83 of net sales',
#  'Changes in the market situation and tougher price competition have substantially reduced demand for bread packaging manufactured at the Kauhava plant according to the company',
#  'In connection with the deal Digia will employ 19 persons from Nokia in Oslo and in Silicon Valley in the USA',
#  'The Brazilian unit of Finnish security solutions provider FSecure signed up 1500 new clients last year online news source Reseller Web quoted the division s commercial director Vladimir Brandúo as saying',
#  'The fair value of the company s investment properties went down to EUR 2768 billion at the end of 2009 from EUR 2916 billion a year earlier',
#  'Dealers said the share was largely hit by investor disappointment about a refining margin of just 948 usd per barrel for the quarter and the performance of its shipping unit which saw EBIT drop to 5 mln eur from 20 mln eur a year amid a fall in volumes and tanker rates',
#  'It is a testament to the quality of our LTE solution and our commitment to the Japanese market he added',
#  'The companies aim is to finalize the negotiations and sign the contracts at the start of October 2008',
#  'Metso Foundries Jyvaskyla Oy will discontinue production on this line by 30 September 2008 the company said',
#  'A total six of the polled analysts rated Mreal two gave buy accumulate three gave hold and only one gave sell',
#  'In September 2010 the Finnish group agreed to buy Danish company Rose Poultry AS for up to EUR23 9 m in a combination of cash and stock',
#  'YANG Double bottom 52',
#  'Tesco share price down as grocer faces SFO investigation outcome',
#  'aapl news is becoming very bullish again httpstkscotMU',
#  'GS Engineering will install the valves at a liquefied natural gas LNG plant it has built for UAE LNG extraction and gas plants operator GASCO in Ruwais UAE',
#  'The percentages of shares and voting rights have been calculated in proportion to the total number of shares registered with the Trade Register and the total number of voting rights related to them',
#  'MReal said there are no grounds for the rumors which have been circulating in the market for some months',
#  'Lember said the matter was topical also in Estonia where a bill has been drafted at the Social Affairs Ministry that would scrap oldage pensions on favorable conditions',
#  'Moody s said it gave P A1 longterm senior unsecured and P P1 shortterm debt ratings to Finnish lender Aktia Bank s EUR1bn USD1 4 bn euro mediumterm note EMTN program of 25 March 2011',
#  'TSLA recall',
#  'The liquidity providing was interrupted on May 11 2007 when Aspocomp Group Oyj s shares traded below 050 cent Aspocomp s stock exchange release 1152007',
#  'Hargreaves Lansdown bucks weak markets to see assets rise 26 percent',
#  'At 1259 pm the OMX Helsinki 25 index was 032 pct lower at 269481',
#  'The decision means temporary layoffs of fixed duration at the company s Nastola and Jyvaskyla units in southern and central Finland respectively',
#  'The value of the orders is over EUR 10mn',
#  'Ms Laakso will be responsible for HKScan s HR functions and for their development in all of the Group smarket areas',
#  'Fiskars is also engaged in the global supply of marine and energy equipment solutions and services through its associated company Wartsila Corporation',
#  'Aberdeen Asset Management Gains Foothold In China',
#  'Finland s dominating rail company VR is planning to set the infected passengers for longdistance trip in a separate carriage',
#  'In November the Finnish government decreased its ownership in the company further to 311 percent from 38 percent',
#  'Finnish Exel Composites a technology company that designs manufactures and markets composite profiles and tubes for various industrial applications reports its net sales decreased by 06 in the second quarter of 2010 to EUR 192 mn from EUR 193 mn in the corresponding period in 2009',
#  'Of Bavelloni s and NST s joint ventures Bavelloni Tools completes semiproducts that are produced in Italy into highquality tools that will be sold under the DiaPol brand',
#  'The tool is a patent pending design that allows consumers to lay out their entire project on a removable plate using multiple clear stamps of any kind',
#  'GOOGL is a short below 740 into the upper BB and is overbought',
#  'LIGHTS OUT Before curfew curl up with the latest bestseller and treat your eyes to the perfect reading light from Luceplan',
#  'UPMKymmene Corp the world s largest maker of magazine paper on Tuesday reported a 19percent profit drop as lower paper prices higher costs and a strong euro hurt revenue',
#  'The total value of the contract is some EUR 8 million',
#  'The prerequisite for inclusion in the program and for receipt of any gains is that key employees acquire Aspo shares to the amount determined by the Board in advance in the maximum',
#  'Mr Doring has been with Eaton since 1989 and acted as the Business Unit Manager for Eaton s Power Controls Business Unit since January 2007',
#  'The 250 sq m 2691 sq ft store in Copenhagen s premier shopping district was inaugurated today further strengthening the company s presence in Nordic capitals',
#  'In the financial statement for the first quarter of 2010 Tikkurila is reported under discontinued operations',
#  'The world s second largest stainless steel maker said net profit in the threemonth period until Dec 31 surged to euro603 million US 781 million or euro3 33 US 431 per share from euro172 million or euro0 94 per share the previous year',
#  'Name of Applicant Jot Automation OYName of Inventor Mammila Tuomo Piirainen Mika and Kellokoski MikaApplication No 2424KOLNP2008 ADate of filing of Application 16062008Publication Date 30012009',
#  'Netflix Grows Efforts To Create Loyal Customers NFLX httpstco5QXBkoBphe',
#  'The OMX Nordic 40 OMXN40 index comprising the 40 most traded Nordic stocks on the Nasdaq OMX exchange closed down 087 at 106414 points on Thursday',
#  'AAPL nibbling on a small long via 525 buying off 13min charts',
#  'The operating margin of Aker Yards Cruise Ferries division went down from 83 to 64 in the first quarter of 2007',
#  'TYC just about to break out to new highs lots of technicals looking great right now',
#  'Eero Katajavuori currently Group Vice President Human Resources will take a yearlong sabbatical starting from October 1 2010',
#  'Whats up with LULU Numbers looked good not great but good I think conference call will instill confidence',
#  'The adjustment measures will be carried out in phases to secure the delivery capability',
#  'Alma Media Corporation Press Release 15 March 2010 TYRVAAN SANOMAT AND PAIKALLISSANOMAT BEING BOUGHT BY SUOMEN PAIKALLISSANOMAT Two local papers Tyrvaan Sanomat and Paikallissanomat appearing in Sastamala and its neighbouring municipalities are to be bought by Suomen Paikallissanomat Oy',
#  'Temporary layoffs affecting the entire workforce will also be implemented',
#  'A meeting for the media and analysts will be held on the same day at 1030 am at Stonesoft Headquarters in Helsinki Italahdenkatu 22 A The Interim report will be presented by Stonesoft s CEO Ilkka Hiidenheimo',
#  'Finnish SampoRosenlew manufactures approximately seven forest machines monthly and about half of machines are exported',
#  'Facebook near a buy point last week faces a different technical test today httpstcoc72LLMpiNM FB AAPL NFLX httpstcofPFbYTYPuY',
#  '4 February 2011 Finnish broadband data communication systems provider Teleste Oyj HEL TLT1V said Wednesday its net profit rocketed to EUR4 8 m in 2010 from EUR416 000 in 2009 and it lifted its dividend proposal',
#  'FREE Ha Heeeeeere comes the pump So glad I picked up 9K end of day Get ready for the bull ride',
#  'Finnish technology group Aspocomp Group Oyj OMX Helsinki ACG1V issued its third quarter report on Thursday 13 November posting an operating profit of EUR0 4 m as compared to a loss of EUR0 5 m in the third quarter of 2007',
#  'The building complex consists of highquality office and retail space totalling 49200 square metres the company said',
#  'Finnish insurance company Fennia and Kesko Group are ending their loyal customer cooperation',
#  'The unit is planned to be operational during the second half of 2007 and in full stream in 2008',
#  'ITG s share in the deal is estimated at some 500000 euro 627000',
#  'The plant is expected to enter commercial operation by mid2009',
#  'Aspo has also investigated the sales opportunities of Kaukomarkkinat s electronics business',
#  'BG Group appoints new CEO one month early',
#  'The acquisition will have an immediate positive impact on Aspocomp s financial result',
#  'Finnair s passenger load factor which measures the number of sold seats as a share of all available seats dropped by 13 percentage points to 767 in September',
#  'RT bman1 LNG looks primed also EGHT poised to run too',
#  'It is also 77 pct above the 12month volume weighted average price of the stock',
#  'Coke dividend 3 Google dividend 0 For passive income Coke takes it GOOG KO httpstcoQBsoWjxOST',
#  'Profit before taxes was EUR 54 mn up from EUR 36 mn a year earlier',
#  'The subsidiary is setting up a facility for manufacturing highdensity interconnection printed circuit boards or PCBs at Nokia s special economic zone at Sriperumbudur near Chennai',
#  'CRM Sep 40 calls are 35 since entry BANG httpstkscodeDm',
#  'In JanuaryJune 2010 diluted loss per share stood at EUR0 3 versus EUR0 1 in the first half of 2009',
#  'Rapala said it estimates it will make savings of 12 mln eur a year by centralising its French operations at one site',
#  'VMW Got a nice push today following small sweepers of May C this morning',
#  'That topped consensus forecasts for earnings of 021 euros a share',
#  'RD Loan',
#  'In future the company intends to look for knowhow from outside the company and to cooperate with other actors in the sector',
#  'You need to be ready when the window opens up Rosberg said',
#  'More than 50000 tonnes of asphalt mix will be used in the contract',
#  'PA JPMorgan Chase and Co NYSE JPM and Pohjoa Bank are joint leadmanagers on the senior unsecured deal',
#  'CTRP breaking out here on good vol and a parser buy signal noticed this on bob langs comments looking for 48 fast',
#  'Sales in Finland decreased by 105 in January while sales outside Finland dropped by 17',
#  'The pulp production in Finnish Kemijñrvi will also be liquidated and about 1100 employees loose their jobs',
#  'Nordea was the cheapest also for a couple in their 30s with debt',
#  'Jussi Pesonen member of the Sampo Board since 2006 will renounce his seat in Sampo Board',
#  'Tesla is recalling 2700 Model X cars httpstco8Z7BkVsTl9 TSLA',
#  'Adjusted for changes in the Group structure the Division s net sales increased by 17',
#  'Making matters more difficult the company said it has been grappling with higher oil and gas prices which have pushed up the cost of energy raw materials and transportation',
#  'The amending of the proposal simplifies the proposed plan and increases the incentive for key employees to stay in the Company',
#  'The solution will now be expanded to include all ground staff tasks',
#  'Operating loss totalled EUR 32 mn compared to a profit of EUR 72 mn in the third quarter of 2008',
#  'On FEDDAY looking for a sharp move up in equities AAPL HD LOW FB seeing UVXY TVIX getting hammered even though market is down',
#  'Net sales totaled EUR 936 mn up from EUR 932 mn in the corresponding period in 2005',
#  'As a consequence the Works Council had withdrawn its petition to suspend the reorganisation',
#  'CEO Erkki Jñrvinen is happy with the company s performance in 2010',
#  'Comparable net sales are expected to increase more than 10 in 2008 in line with group target',
#  'Following the transaction Lundbeck has worldwide rights for nalmefene excluding North America Mexico Turkey and SouthKorea',
#  'The government started the selloff last month putting an 8 percent stake in TeliaSonera on the auction bloc',
#  'The report goes on to provide detailed profiles of ten leading European specialty chemicals companies and brief profiles of other major players',
#  'Both operating profit and net sales for the threemonth period increased respectively from EUR16 0 m and EUR139m as compared to the corresponding quarter in 2006',
#  'The company expects its net sales for the whole 2009 to be at previous year levels',
#  'The company is headquartered in Sievi Finland and is listed on the Nordic Exchange in Helsinki',
#  'Commission income increased by 22 to EUR 44 mn and lending volume rose by 135',
#  'The Finnish company sold its UK operation consisting of 50 staff in offices in London Birmingham and Manchester as part of a deal with Hampden in July 2001 for its Europeanwide property and casualty arm Sampo Industrial',
#  'In the building and home improvement trade sales decreased by 225 to EUR 2014 mn',
#  'The Innova 2 building will be located close to downtown in the immediate vicinity of Paviljonki and the travel center and within walking distance from the heart of the city thanks to the trade fair bridge',
#  'Finnish textiles and clothing group Marimekko Oyj posted a net profit of 799 mln euro 104 mln for 2006 compared to 84 mln euro 109 mln for 2005',
#  'The main strength of the cooperation project lies in merging the knowhow of two large companies',
#  'Shareholders have a right to put on the agenda of the AGM items that are within the competence of the general meeting',
#  'Kazgiprotsvetmet and Outotec Finland have signed an agreement on strategic cooperation in the marketing and providing of minerals processing and metallurgical plants and related services in Kazakhstan and the surrounding countries',
#  'Due to the rapid decrease in net sales personnel reductions have been carried out on a wider scale than initially expected',
#  'The government has instead proposed an exchange of the state s stake in LMT to TeliaSonera s stake in Lattelecom',
#  'Stora is due to release its fourthquarter and 2009 fullyear earnings on Feb 4',
#  'Fullyear operating result for 2008 was 36 million negative',
#  'NQ got hit hard lower this AM looks like it has found support a 1889 httpstkscos052z',
#  'In 2008 AVC Systemhaus had net sales of EUR 10 million USD 71 m',
#  'The company has established a 3G base station at about 17000 feet at the foot of Mount Everest that will enable mountain climbers at the 29035foot summit to surf the Internet and even send videos of their exploits',
#  'We offer our customers solutions based on renewable raw materials',
#  'A survey conducted by Taloustutkimus for Sampo Life shows that companies are badly prepared to losing key staff members',
#  'Antti Orkola president of Kemira GrowHow s Industrial Solutions unit told Thomson Financial News the company has put off opening the mine as prices of phosphate have been quite depressed for a long time',
#  'The pretax profit of the group s life insurance business increased to EUR36m from EUR27m',
#  'We make available the following brandnew market analyses Cement Pakistan Cement Malaysia Cement Taiwan Cement Philippines These analyses give a clear overview of the actual situation and future outlook of the cement industry in some Asian countries',
#  'The Company serves approximately 3000 customers in over 100 countries',
#  'RT alphatrends VMarkets Are Still Acting Weak httpstksco1agn SPY QQQ XLF SMH IWM',
#  'Operating profit totalled EUR 302 mn down from EUR 438 mn a year earlier',
#  'One of the installed elevators will be a doubledeck elevator which enables more efficient use of the building s core space',
#  'HELSINKI AFX Outokumpu said it has agreed to sell the Hitura nickel mine in Finland to Canadian group Belvedere Resources Ltd for 10 mln eur worth of Belvedere shares',
#  'Just went long ILMN',
#  'Social networking and locationbased service trends comprise a significant share of the Internet traffic today and are appealing to MID users',
#  'A total 30 of the order value was booked in the fourth quarter of 2009 and the remainder will be booked in the second quarter of 2010',
#  'Johnson Matthey share price slumps as company posts fullyear results',
#  'There have not been previous share subscriptions with 2004 stock options',
#  'AffectoGenimap builds highly customised IT solutions for its customers in Finland and the Baltic countries',
#  'The closing of the transaction is scheduled to take place on January 10 2008',
#  'However the offering will probably not be made at the current valuation which partly derives from the deal in which the company was merged into a stock market shell',
#  'Operating result for the 12month period decreased from the profit of EUR0 4 m while turnover decreased from EUR5 6 m as compared to 2004',
#  'The administrators have indicated a need for 900 job cuts at the Irish insurer over the next 15 months',
#  'Net sales in 2008 are expected to be on the same level as in 2007',
#  'Technical indicators for the stock are bullish and SP gives NOK a positive 4 STARS out of 5 buy ranking',
#  'Revenue for the quarter totaled 274 billion down 2 percent from 281 billion in the fourth quarter in 2008',
#  'NViro operates processing facilities independently as well as in partnership with municipalities',
#  'The number of bodily injury cases quadrupled in 20002006',
#  'According to Ringman Finnish paper companies have acquired knowhow and capacity in paper recycling which has turned out to be a successful strategy',
#  'The company also said that in Poland a profitability program has been launched at the Oborniki steel frame and sandwich panel plant',
#  'And US energy executives say high steel prices are threatening energy exploration',
#  'Tesco sales rise shows tentative recovery continues',
#  'In Finland the launch of tiein sales of 3G mobile phones did not cause a dramatic rush in mobile retail outlets during the first few days',
#  'NUAN held up well after the big gains Maybe were finally on the move on thisits still very undervalued and has major upside',
#  'The company can be split into two parts over the coming months with Essent owning and operating production and supply and Enexis owning and operating the grid',
#  'Officials did not disclose the contract value',
#  'London s leading shares today jumped almost 100 points or 17 as the market opened',
#  'In the third quarter of fiscal 2008 Efore swung to a net loss of EUR 400000 versus a net profit of EUR 200000 for the corresponding period of fiscal 2007',
#  'The group s operating loss was EUR 08 mn down from a profit of EUR 25 mn in 2004',
#  'The move was triggered by weak demand for forestry equipment and the uncertain market situation',
#  'The combined company had proforma net sales of 140 mln euro 1889 mln and an operating profit of 13 mln euro 175 mln for 2006',
#  'Managing Director Kari Inkinen says that Sponda s leasing operations developed highly favourably',
#  '17 March 2011 Goldman Sachs estimates that there are negative prospects for the Norwegian mobile operations of Norway s Telenor ASA OSL TEL and Sweden s TeliaSonera AB STO TLSN in the short term',
#  'TSLA steaming up again this stock is relentless at the moment',
#  'Marathon estimates the value of its remaining stake in Protalix at 27 million',
#  'Whitbread share price climbs on Q4 sales growth',
#  'Incap Contract Manufacturing is a subsidiary of Incap Corporation of Finland',
#  'Operating profit totaled EUR 377 mn up slightly from EUR 372 mn in the corresponding period in 2006',
#  'We went to the market with yield guidance of the 725 area which gave us the flexibility to go up or down by 18th',
#  'RT stockdemons think shorting here into close might be play SPY high beta reversinglooks worth a shot',
#  'VDW combined with LXE devices enhances productivity enabling workers to use a single device to perform voice scanning and keyboard functions',
#  'Thus the method will cut working costs and will fasten the planning and building processes',
#  'Talentum s net sales in September were smaller than expected',
#  'COPYRIGHT AFX News and AFX Financial News Logo are registered trademarks of AFX News Limited',
#  'LNKD Daily Phase 2 retest Price experiencing early rejection Can it retest httpstkscot04xX',
#  'RBS will reportedly appoint Howard Davies as its next chairman',
#  'Tesco Asda sales fall as march of the discounters continuesKantar',
#  'With this new version it is very important for us to introduce a BIM process that is based on the detailed building information model',
#  'SAMPO PLC Jarmo Salonen Head of Investor Relations and Group Communications tel 358 10 516 0030 Distribution NASDAQ OMX Helsinki The principal media Financial Supervisory Authority wwwsampocom This announcement is distributed by Thomson Reuters on behalf of Thomson Reuters clients',
#  'barronsonline sees Apple at 150share in a year 36 from today on growing services business AAPL httpstco3BDNEKN7l1',
#  'Pharmaceutical market in Poland Global Research Data Services published recently a market analysis about the pharmaceutical markets in Poland',
#  'Altogether Finnair has canceled over 500 flights because of the strike',
#  'The employer together with health personnel supports quitting and pays part of the cost of nicotine treatments',
#  'Pretax loss totaled EUR 117mn compared to a loss of EUR 65mn in the corresponding period',
#  'The order includes 48 ship cranes that will be delivered for 12 container feeders to be built at Wenchong shipyard in China',
#  'Copper lead and nickel also dropped HBOS HBOS plummeted 20 to 703 pence after saying this yearó',
#  'GOOG Testing the 200 day after some consolidation httpstkscoh0cPJ',
#  'He joins Technopolis from KONE where he has held various positions within the Group most recently as Director of Service Business and Business Development for KONE s Middle Eastern operations',
#  'We succeeded in increasing our market share of sold apartment comments Mr Kari Kauniskangas Head of YIT International Construction Services',
#  'Profitability EBIT was 139 compared to 131 in the previousyear period',
#  'Finnish GeoSentric s net sales decreased to EUR 939000 in JanuaryMarch 2009',
#  'The plant is scheduled for completion in late February 2007 with hand over of some areas in January Two other suppliers of Nokia Aspocomp Group Oyj and Perlos have announced their plans to establish plants within the Nokia complex Together they will invest Rs 365 crore',
#  'UPMKymmene upgraded to inline from underperform by Goldman Sachs',
#  'Slump in Weir leads FTSE down from record high',
#  'Jan 6 Ford is struggling in the face of slowing truck and SUV sales and a surfeit of uptodate gottahave cars',
#  'Royal Mail breached competition law over delivery service changes Ofcom claims',
#  'The cooperation will involve Arena Partners buying a 35 share of the new joint venture company operating in Alma Media s home sales vehicle and consumer advertising marketplace businesses',
#  'The Efore plant at Saarijarvi in central Finland is one of the largest employers in the region',
#  'However shortterm rentals are becoming more popular',
#  'EMSA Deputy Chairman of the Board Juri Lember told BNS on Wednesday that this was the first time he heard about the strike as the Swedish side had not informed the Estonian union yet',
#  'Tesco closes in on new chairman with Dixons Carphones John Allan in the frame',
#  'The device offers multimedia performance along with a host of productivity applications including live stock prices',
#  'Sales climbed 192 pct to 1002 bln eur surpassing the 953 mln eur consensus figure',
#  'FB turns back down in early trading httpstcoreuf5PzhBm',
#  'Utah s capital wanted to be the next US headquarters of Amer Sports Corp a skiequipment company',
#  'Old Mutual FirstQuarter Sales Up 18 Buoyed by Emerging Markets',
#  'The dividend is payable on February 1 2010 to shareholders of record on January 19 2010',
#  'Sales in Finland decreased by 105 in January while sales outside Finland dropped by 17',
#  'Furthermore Bunge will also sign a licensing agreement for the Sunnuntai and Carlshamn Mejeri brands',
#  'KESKO CORPORATION STOCK EXCHANGE RELEASE 28022008 AT 0930 1 1 Kesko Corporation and Aspo plc today signed an agreement by which Aspo acquires the share capital of KaukoTelko Ltd a subsidiary wholly owned by Kesko',
#  'LULU Outlook Q1 2013 lost revenue in the range of 12 million to 17 million not good',
#  'Mobile communication and wireless broadband provider Nokia Inc NYSE NOK today set new financial targets and forecasts for Nokia and the mobile device industry and also for Nokia Siemens Networks and the mobile and fixed infrastructure and related services market',
#  'POYRY PLC Additional information by Heikki Malinen President and CEO Poyry PLC tel 358 10 33 21307 Poyry is a global expert in consulting and engineering',
#  'Danish company FLSmidth has acknowledged that it has violated a patent held by Finnish Metso',
#  'Amanda Capital has investments in 22 private equity funds and in over 200 unquoted companies mainly in Europe',
#  'Net interest income was EUR 393 mn up from EUR 327 mn',
#  'Jeder BetaTester erhñlt kostenlos sechs Monate lang Updates und hat laut eigener Aussage die MÂglichkeit die finale Version zu beeinflussen',
#  'JP Morgan expects that Scala will lower Nobel Biocare s growth forecast for 2007 from the current guidance of 2325 pct as well as the operating margin target from the current 3435 pct',
#  'Aviva promises higher dividends to boost flagging share price',
#  'In addition MIDs are always online and enable full Internet browsing',
#  'Fiskars has a strong portfolio of international brands which include Fiskars Iittala Gerber Silva and Buster',
#  'Tesla Model X Recall Adds To Reliability Issues TSLA httpstcojVXQ4DoXnP',
#  'The name of the buyer was not disclosed',
#  'Net sales of the Vegetable Oil Business rose to EUR 106 mn from EUR 101 mn',
#  'Under the agreement Benefon s forthcoming range of TWIG integrated GPS navigation and mobile phone devices will use the jointly developed webbased tracking and location technology in both consumer and commercial applications',
#  'Following this increase Huhtamaki s registered share capital is EUR360 62 m and the number of shares outstanding is 106063320',
#  'The three year turnaround program is expected to ensure Salomon s future competitiveness the company said',
#  'In the autumn it plans to expand service to St Petersburg and Moscow and launch service to Yekaterinburg Russia flying there three times a week',
#  'The company s profit totaled Ls 578100 in H1 2007 down 309 yearonyear',
#  'The Federal Secretary for Transport and Communication of Mexico has awarded Poyry and its Mexican partner Sintra a consulting contract in connection with the BuenavistaCuautitlan suburban railway',
#  'FDA approves AstraZeneca drug for advanced lung cancer',
#  'The order is included in Metso s fourth quarter 2007 order backlog',
#  'Lieksaare Oy has earlier been regarded under the control of Saarelainen Oy and the individual shareholders under the shareholder agreement',
#  'Ragutis which is controlled by the Finnish brewery reported a 54percent rise in beer sales to 1044 million litres and held an 1109percent market share',
#  'mcp rolling over for a new intraday low Bottom Pickers continue to get destroyed',
#  'The company has an annual turnover of EUR32 8 m',
#  'It has80 branches in Finland with annual revenue in Finland of',
#  'The portfolio comprises of 118000 m2 of leasable space with a vacancy rate of roughly 5 let to around 140 tenants of which two of the largest are the Swedish government and Ericsson',
#  'WPP boosts sales despite cautious clients',
#  'The mediumterm operative targets of the company remain unchanged',
#  'ADP News Feb 13 2009 Finnish retailer Kesko Oyj HEL KESBV said today its total sales excluding value added tax VAT stood at EUR 6613 million USD 8531 m in January 2009 down 152 yearonyea',
#  'Consumers have very well received our packed fresh meat',
#  'The corrected chapter is in its entirety below',
#  'The major part of the deliveries include different AC and CXE amplifier solutions and products by DINH Telecom a company acquired by Teleste last spring',
#  'TietoEnator itself uses Nokia s Intellisync Mobile Suite s wireless email calendar and device management capabilities and the company will now extend these services to its customers',
#  'It will provide heating in the form of hot water for the sawmill s needs',
#  'However the net sales declined to EUR 8036 million from EUR 12 billion',
#  'In the second quarter of 2010 Raute s net loss narrowed to EUR 123000 from EUR 15 million in the same period of 2009',
#  'DGI technical alerts Gilligans Island Buy Setup Stochastic Buy Signal Lizard Bullish Hammer Candlestick Wid httpstkscoc29Nu',
#  'The record date for dividend distribution is March 14 2008',
#  'IH in a move to enhance growth',
#  'The EBRD is using its own funds to provide a 216 million A loan while the B portion of 10 million Euros has been syndicated to two Finnish commercial banks Nordea Bank Finland Plc 77 million Euros and Pohjola Bank Plc 23 million Euros',
#  'Stockholm 3 March 2011 About Cybercom The Cybercom Group is a hightech consultancy that offers global sourcing for endtoend solutions',
#  'He said he has been losing five families a month to the economy as many make alternative arrangements to save money',
#  'MILAN AFX The Italian shipping group Grimaldi has increased its stake in the Finnish company Finnlines to 354 pct from the 305 pct held in June according to news agency ANSA',
#  'Commenting on the deal Shane Lennon SVP of Marketing Product Development at GyPSii said',
#  'External net sales from the printing business fell by 437 partly due to the termination of the printing contract between IlkkaYhtyma s printing house Iprint Oy and sector player HSS Media AB in December 2009 and the fall in printing prices',
#  'The group intends to relocate warehouse and office space in Loudeac and Saint Marcel to Morvillars in the east of the country where it already operates a hook manufacturing and distribution unit',
#  'The firm is headquartered in Vantaa southern Finland and has 16 employees',
#  'At 133 pm the OMX Helsinki 25 was 030 pct lower at 246367 and the OMX Helsinki was down 037 pct at 853742 on volume of 256 mln eur',
#  'We are honored to be recognized by Gartner as a specialist in Business Process Modeling and Analysis in the company of many of the largest software vendors in the world',
#  'Westpac Banking Corp Is to issue a benchmark 3 year FRN deal in Euros',
#  'Includes company and brand share data by category as well as distribution channel data',
#  'For the new shares subscribed with stock options all shareholder rights commence from the date on which they are entered into the Trade Register',
#  'AAPL price momentum weakening going into the close',
#  'Through the acquisition Solteq will expand its solutions offering by Microsoft s Dynamics business software products',
#  'The company s profit totaled Ls 134700',
#  'LEED is an internationally recognized green building certification system developed by the US Green Building Council',
#  'However its market share shrank to 4759 per cent from 48 per cent a year earlier',
#  'TalkTalk hires BAE Systems to investigate cyber attack',
#  'Looks like its booking a one way ticket to its 40 week MA near 50 Losing 10 week here LULU httpchartly7xb9h9b',
#  'FTSE led lower by MS GlaxoSmithKline',
#  'The exercise price of the option will be based on Safran Software Solutions license and maintenance sales as well as the result of the company',
#  'Fullyear operating result for 2008 was 36 million negative',
#  'The company said production volumes so far indicate the circuit is capable of the targeted output rate of 60000 tonnes per day or 22 million tonnes a year',
#  'Jun 25 2008 Boy Genius Report delivered by Newstex The Nokia NYSE NOK N78 huh',
#  'We have come out with a decision which is based on our preliminary economic operational and environmental findings Karvinen said',
#  'The new majority owners of Aspocomp Thailand Co Ltd are certain private persons belonging to immediate circle of Aspocomp s present Joint Venture partner Saha Pathana InterHolding Plc',
#  'Some 38 mln euro 52 mln of the base acquisition price will be paid in cash and the rest through a subscription offering of a total of 850000 new Ixonos shares',
#  'Established in 1987 the SRV Group is a private Finnish construction concern with operations in Finland the Baltic countries and Russia',
#  'The business section also includes Ahlstrom s sustainability report',
#  'lemiste City is the environment for a knowledgebased economy providing work for 3300 people with the total turnover of its companies amounting to EEK 54 bn said lo Pñrnits chairman of the supervisory board of lemiste City and Mainor',
#  'Jacobs has been supporting Storengy s investment of developing storage sites since 2006 as owner s engineer',
#  'The company had earlier said that it was considering different strategic options for the struggling lowcost mobile operator including a divestment of its holding',
#  'Sainsburys Asda Tesco and Morrisons will all cut petrol prices as oil falls',
#  'Barclays sells benchmark indices unit to Bloomberg',
#  'Operating profit in the fourth quarter fell to EUR33m from EUR39m a year earlier',
#  'Finnish forestry company UPMKymmene and waste management company Lassila Tikanoja said on Jan 30 they were planning to produce ethanol and energy from commercial and industrial waste',
#  'ISMS does not disclose its financial results the daily said',
#  'The contract covers the manufacturing surfacetreatment and installation of the steel structures',
#  'Finnish metal industry solutions supplier Outotec Oyj net profit rose to 504 mln euro 725 mln for the first nine months of 2007 from 201 mln euro 289 mln for the same period of 2006',
#  'Under the deal Know IT will pay SEK90m USD12 8 mEUR8 6 m in cash and stock',
#  'For the first nine months of 2010 the company s net profit rose to EUR41m from EUR30m for the corresponding period of 2009',
#  'AAPL 50DMA turned up MACD crossover a halfahair away on the weekly EOD break out likely',
#  'Protalix has 42 million in cash and no sales',
#  'That bearish outside day Tuesday is significant 200 day resistance still intact just my opinion SDS httpchartly2bey48t',
#  'All rights reserved',
#  'It will be operated by Nokia and supported by its Nokia NetAct network and service management system',
#  'Mr Priit Kasak Balti Metsamasina s owner said the Rakverebased company wishes to increase Valmet s market share from 27 to a third in a couple of years',
#  'Shire Sees Baxalta Deal Closing as Expected After New Rules',
#  'Sainsbury CFO Rogers to Replace Home Retail CEO Walden',
#  'Marathon now has a 46 percent stake in PLX it said according to Bloomberg',
#  'Simmons Elected DCUC Chairman PORTSMOUTH NHGordon A Simmons CEO of Service Credit Union has been elected chairman of the Defense Credit Union Council for the 20072008 term',
#  'Sanoma News advertising sales decreased by 22 during the year',
#  'Pharmaceutical market in Czech Republic Global Research Data Services published recently a market analysis about the pharmaceutical markets in Czech Republic',
#  'Finnish construction company YIT is reducing the number of startups of marketfinanced residential units in 2007 to about 2300 from the previously announced 2700',
#  'Cash Flow from Operations for the most recent quarter also reached a eight year low',
#  'TietoEnator was down 113 pct to 1838 extending recent lows after last week s secondquarter report dealers said',
#  'The maritime administration said the ships had ignored warnings about the icy conditions',
#  'Synergy Pharma Soars 67 Today On Positive Phase 3 Results SGYP httpstkscoj2awg',
#  'Operating profit rose to EUR 16 mn from EUR 11 mn in the corresponding period in 2006',
#  'Making matters more difficult the company said it has been grappling with higher oil and gas prices which have pushed up the cost of energy raw materials and transportation',
#  'VRTX Vertex Monthly lower hilower lo Long term uptrend intract so far',
#  'Financial details were not disclosed',
#  'These include software development for internet and mobile telephone content communications valueadded software financial services security applications systems integration and electronics EBRD informed',
#  'YIT lodged counter claims against Neste Oil totaling some EUR25m primarily based on work carried out under the contract and additional costs incurred due to prolongation of the project',
#  'Should You Follow Berkshire Hathaway Into Apple Stock',
#  'The total amount of subscription prices was recorded in the fund for invested nonrestricted equity',
#  'TSLA 5th wave down on the 1 hour chart hammer candle developing close to 200 sma might be a good spot for calls',
#  'Strongest growth was seen in the new markets in Russia the Czech Republic and Slovakia',
#  'The tower s engineers have created an 18 degree westward lean four times the inclination on the Leaning Tower of Pisa using diagrid structures that are aligned geometrically using Tekla Structures BIM Building Information Modeling software',
#  'Amer which bought Salomon from adidas in October said the job cuts are aimed at boosting competitiveness',
#  'Acando AB ACANB SS fell 89 percent to 1335 kronor the lowest close since Dec 11',
#  'With the measures Suominen Corporation aims to ensure the competitiveness of the Flexible Packaging business in the long term',
#  'IfHeDiesHeDies Bullhorn334 ZNGA shorts are getting nervous',
#  'The financial statements release will be available after publishing on the Company s internet pages at wwwcargoteccom',
#  'The world of glass is coming to Egypt and we invite Visitors from all around the world to attend Glass World Exhibition 2009 Register Now at wwwglassworldexcom',
#  'Comparable operating profit totaled EUR 47 mn down from EUR 51 mn in the corresponding period in 2005 representing 74 of net sales',
#  'Most of the raw materials come from Europe and the US and are paid in euros or US dollars while sales take place in rubles',
#  'ADPnews May 4 2010 Finnish cutlery and hand tools maker Fiskars Oyj Abp HEL FISAS said today its net profit declined to EUR 129 million USD 17m in the first quarter of 2010 from EUR 17 million in the correspond',
#  'A maximum of 666104 new shares can further be subscribed for by exercising B options under the 2004 stock option plan',
#  'It inspects the companys strategic strengths and weaknesses',
#  'No planned closing date was provided',
#  'The Lemminkainen Group headquartered in Helsinki Finland operates in all sectors of the construction industry civil engineering building contracting technical building services and the building materials industry',
#  'The implementation of the deal is subject to the approval by the Finnish Competition Authority',
#  'Microsoft also churned up its courtship agreeing to use the Navteq mapping service which is offered by a company Nokia bought for 81 billion a few years ago',
#  'The GeoSolutions team further provides an intriguing new technology combining GPS and Mobilebased technologies together with Internetbased social networking',
#  'The 3C Expo is a signature show in Dongguan which is supported by the Dongguan Municipal Government every year featuring computer accessories software communication and network products',
# ...
#  'No pricing details were disclosed',
#  'long AAPL',
#  'Salonen added that data shows producers pulp inventories in North America are declining',
#  'Finnish IT consultancy Satama Interactive Oyj posted a net profit of 14 mln euro 20 mln for the first nine months of 2007 compared to a net loss of 462000 euro 664000 for the same period of 2006',
#  'Consisting of seven interconnected units Mega Image s logistics center will be 347 metres in length and 12 metres in height',
#  'Tesco PLCs Recovery Continues With A Â250m Cash Infusion',
#  'Kesko has about 2000 stores engaged in chain operations in the Nordic and Baltic countries Russia and Belarus',
#  'Is Trouble Brewing At Legal General Group Plc And Aviva plc',
#  'Helsinkibased Componenta bought Turkish listed company Doktas in October 2006 for 89 million euros making it the largest Finnish investment in Turkey to date',
#  'The ECB can mainly target inflation',
#  'Operating profit totaled EUR 38 mn down from EUR 45 mn in the corresponding period in 2005',
#  'The group said it intends to initiate within this year the process of buyout of minority shareholders of Ragutis with the aim of becoming the sole owner of the company',
#  'Initially the company said a maximum of 15 people would be made redundant in the parent company and about 15 in its subsidiaries',
#  'The contract incorporates a Convergent Charging rating solution for voice and data which includes Internet GPRS SMS MMS and WAP',
#  'AstraZenecas Lung Cancer Drug Tagrisso Gets FDA Approval',
#  'Our customers include companies in the energy and process industry sectors in particular',
#  'Europe however remains an important and strong market for us',
#  'Morrisons and Debenhams surprise City with Christmas bounce back',
#  'The ongoing project where Tekla Structures is being used is the Vashi Exhibition Centre being developed by Insteel Engineers Pvt LtdIIVRCL Infrastructures Projects Ltd CIDCO',
#  'Talentum expects that the net sales of its core business will increase in 2008 compared to 2007',
#  'Operating profits in the half were 08 m down from 09 m as Glisten invested in the brand and the management team',
#  'Its total annual revenue comes up to about 160 mln zloty 569 mln42 3 mln euro',
#  'The corresponding increase in the share capital EUR422 754 has been entered in the Trade Register today',
#  'Group EBIT for the first half was EUR13 6 m US 178 m falling short of the EUR22 5 m it posted for the same period of 2009',
#  'Relations with the City have been further damaged by comments from Mr Ashley criticising City investors and analysts as cry babies',
#  'The engine has an electrical output of 18321 kW making it the largest gas powered generating set in the world',
#  'Pretax profit totaled EUR 49 mn compared to EUR 52 mn in the first quarter of 2005',
#  'Most recently he founded Virent Energy Systems Inc an 80 person catalytic biofuels company where as president and CEO he led the company through multiple financings defined the company s market strategy and secured the company s first customers',
#  'Addus services include personal care and assistance with activities of daily living skilled nursing and rehabilitative therapies and adult day care',
#  'TripAdvisor jumps on MA rumors httpstcoO4lwCDXMbr TRIP',
#  'Finnish Civil Aviation Administration decided to temporarily reopen Finnish capital s Helsinki airport since 3 pm to 11 pm Monday local time',
#  'Reporting in accordance with the merged business operations will start as of January 1 2011',
#  'Earnings per share EPS for the first quarter 2007 amounted to EUR0 07 up from EUR0 04',
#  'Finnlines estimated in its annual general meeting that 2008 will be financially a tough year due to large investments',
#  'Meanwhile minority shareholders expecting TeliaSonera to retain the bid sell shares now',
#  'External net sales from the printing business fell by 437 partly due to the termination of the printing contract between IlkkaYhtyma s printing house Iprint Oy and sector player HSS Media AB in December 2009 and the fall in printing prices',
#  'Operating profit was EUR 98 mn compared to a loss of EUR 127 mn in the corresponding period in 2009',
#  'Word on the street is that Allergen is looking at Endo International after the failed Pfizer merger May20 35 calls active ENDP',
#  'FBR Capital reiterated Outperform rating on BRCM with a price target of 4500 on Friday',
#  'METALSZinc surges 12 pct after Glencore cuts output fuelling metals rally',
#  'Profit for the period fell to EUR 16 mn from EUR 75 mn in JanuarySeptember 2008',
#  'Is It Worth Investing In Tesco PLC And Prudential plc Now',
#  'in Finland Finnish pharmaceutical company Orion Corporation OMX Helsinki ORNAV said on Wednesday 7 January that it has concluded its personnel negotiations in Finland and will reduce the number of personnel by 205',
#  'Finnish retailer Stockmann has won approval from the board of Swedish rival Lindex for a public tender offer with the aim of expanding the companies presence in Russia and other CEE countries Stockmann said Monday',
#  'In a release the Company said that Vocollect T2 customers in North America can now take advantage of its Voice Directed Warehousing solution and increase warehouse efficiency and productivity gains at a discounted price',
#  'Niklas Skogster has been employed by the ABB Group in various positions concerning the development of operations',
#  'Operating profit excluding nonrecurring items totaled EUR 02 mn down from EUR 08 mn in the corresponding period in 2006',
#  'Finnish Metso Paper has been awarded a contract for the rebuild of Sabah Forest Industries SFI pulp mill in Sabah Malaysia',
#  'Ruukki forecast a 1520 annual sales growth and a positive pretax result for 2010',
#  'The price of GMO soy is 5 7 lower than that of nonGMO',
#  'Finland s Nokian Tyres and Kazakhstan s Ordabasy Corporation signed an agreement to build a plant in Astana to produce car tires Ordabasy chairman Dinmukhamet Idrisov said at a press conference',
#  'With sales of 127 billion over the last twelve months ending October 2010 and over 9200 stores in 35 states Dollar General is the nation s largest small box discount retailer',
#  'GET MIDNIGHTTRADER IN REALTIME This report is delayed',
#  'Danish company FLSmidth has acknowledged that it has violated a patent held by Finnish Metso',
#  'The share issue derogating from the preemptive right of the shareholders and comprising some six million new shares at market price will be offered for subscription by shareholders holders of capital notes and by professional clients',
#  'Tielinja generated net sales of 75 mln euro 96 mln in 2005',
#  'Karachi Sept 14 Ixonos a world leader in the development and integration of solutions for handheld devices announced that it is implementing a touch screen mobile user interface solution for the Intel Atom processor Z6xx based smartphones',
#  'Neste Oil is working with over 20 research communities in Europe America Africa Asia and Australia to develop and introduce new raw materials',
#  'The new agreement which expands a longestablished cooperation between the companies involves the transfer of certain engineering and documentation functions from Larox to Etteplan',
#  'It s not',
#  'took some ENDP long this am using VWAP as guide',
#  'Despite sales growth UKs Tesco cautions recovery to be bumpy',
#  'In Finland metal sector company Componenta is laying off temporarily the staff of its Pori mill from Christmas 2008 till 6 January 2009',
#  'In Middle East North Africa Tecnotree has grown considerably in the recent years',
#  'Both operating profit and net sales for the sixmonth period increased respectively from EUR18 1 m and EUR127 6 m as compared to the corresponding period in 2006',
#  'Insurer Axa PAR CS slid by 535 to EUR 1415 after Citigroup and ING slashed their targets on the stock',
#  'The order values at EUR 69 mn and it consists of design services and hardware and software licences',
#  'Scanfil has also issued a profit warning',
#  'A spokesman said The food store center subject to council and local support could comprise a supermarket or smaller store and other niche outlets and this will be firmed up following consultation with the council and local community regarding appropriate uses and occupiers',
#  'The bond has a value of EUR150m and a maturity of 4 years',
#  'MillerCoors Board Names Gavin Hattersley Interim CEO',
#  'Airbus will attempt to evacuate up to 873 people within 90 seconds',
#  'First quarter underlying operating profit rose to 41 mln eur from 33 mln a year earlier',
#  'EPS for the quarter was EUR0 00 as compared with EUR0 01 in the third quarter of 2008 representing a Group net sales for the third quarter were EUR15 3 m up by 28 as compared with EUR14 9 m in the third quarter of 2008',
#  'Royal Dutch Shell profit rises dividend up 4',
#  'Meanwhile ElectrowattEkono Philippines Inc was also awarded a threeyear operation and maintenance OM contract by FR Cement Corporation',
#  'The agreement includes application maintenance and support services',
#  'Nokia is just interested in bring Nokia to the market',
#  'Affecto expects its net sales for the whole 2010 to increase from the 2009 level when they reached EUR 103 million',
#  'The report profiles 158 companies including many key and niche players including major Nonwovens manufacturers such as Ahlstrom Corporation Asahi Kasei Corporation Buckeye Technologies Inc EI',
#  'The layoffs will affect 240 people out of the total 320 Okmetic employees in Finland',
#  'The acquisition of Elektros Pavara completes KONE s market expansion strategy in the Baltic Countries',
#  '18 May 2010 Finnish electronics producer Elcoteq SE HEL ELQAV said today that it has signed an extensive cooperation agreement on industrialisation manufacturing distribution and aftermarket services for mobile phones with Japan s Sharp TYO 6753',
#  'Morrisons book second consecutive quarter of sales growth',
#  'Marimekko has today 20 November signed a license agreement with the Swedish chain whereby Marimekko will license some of its popular patterns from the 1950s 1960s and 1970s to HM',
#  'that was quick out FIO 2135 market tanking scaling down longs now',
#  'The announcement pushed Freenet shares down 63 or EUR0 71 in Frankfurt trade to EUR10 65 as investors gave up hope United Internet AG and Drillisch would pursue their own takeover and breakup of Freenet',
#  'Finnish telecoms software developer Tecnomen Oyj said on December 5 2006 it won a 33 mln 25 mln euro order to supply an expansion of the charging and messaging systems for the mobile and fixed networks of Brasil Telecom',
#  'CompaniesUnilever sales lifted by ice cream in soft economy',
#  'EPS dropped to EUR0 2 from EUR0 3',
#  'saltwaternurse INO can test 10 again in next few days time to take some profits here or hedge with puts',
#  'No financial information was provided',
#  'EasyJet attracts more passengers in June but still lags Ryanair',
#  'Morning Agenda Shires Deal for NPS',
#  'Metso will supply the equipment for two process lines at Northland Resources new Kaunisvaara iron ore project in Sweden which exploits Tapuli and Sahavaara iron ore deposits',
#  'Under this agreement Biohit becomes a focus supplier of pipettors and disposable pipettor tips to VWR customers throughout Europe',
#  'The company s previous estimate was for a lower revenue than the yearago EUR 939 million',
#  'Earnings per share EPS dropped to EUR 021 from EUR 031',
#  'Bids or offers include at least 1000 shares and the value of the shares must correspond to at least EUR4 000',
#  'Earnings per share EPS amounted to a loss of to EUR0 06',
#  'NetApp downgraded by Macquarie to underperform 2200 PT httpstcoXCNgws0t4q NTAP NTAP via RatingsNetwork',
#  'Russia is ready to participate in an open tender for Lattelecom s privatization',
#  'Technopolis and the St Petersburg government signed a cooperation memorandum in October 2005 to set up a technopark in the Neudorf production zone in the village of Strelny in the St Petersburg suburbs',
#  'The owners who have participated in the business operations of the company will continue in Poyry s employment after the transaction',
#  'The goal is to secure the company s profitability and competitiveness',
#  'However the company saw its net profit for the third quarter down to EUR 14 million from EUR 15 million for the corresponding period of 2009',
#  'Neste oil s board proposed 100 eur dividend for the fullyear 2007 compared with 090 eur a year ago',
#  'Basware Einvoices Oy will be merged into the parent company during the present fiscal period',
#  'Fintech provider CAFN Cachet Financial Solutions Surging Forward today post earnings Up 1326 httpstco9BJ3csk2i9 JKHY FISV Momo',
#  'Before Kemira s installation NordAlu was producing 3500 tons of liquid and solid aluminum waste per year',
#  'He is a Chartered Accountant in British Columbia and Alberta as well as a Certified Public Accountant in Washington State',
#  'Very recommendable is the Nokian Z G2 according to the ADAC judgement in the latest summer tyre test of the German automobile association ADAC',
#  'The Group s result before taxes was a loss of EUR 06 06 million',
#  'Cash flow from operating activities before investments was EUR 08 12 million',
#  'Viking Line has canceled some services',
#  'Exel is headquartered in Mantyharju in Finland',
#  'Stora Chief Executive Jouko Karvinen has described the Russian tariff hikes as a threat to the future of the forest products industry in Finland',
#  'After Barclays and Bank of America Citigroup has blockchain in sight',
#  'Google Inc completes acquisition of ICOA Inc httpstksconFEI ICOA GOOG',
#  'TSLA looking goodid love to see a basing action here letting the RSI take a breather httpstkscog1T7c',
#  'Finnish plumbing and heating systems supplier Uponor s net sales from continuing operations decreased by 94 in 2008 to EUR 9492 mn from EUR 10474 mn in 2007',
#  'This location makes the mall a convenient place to shop for consumers from three large residential areas nearby Jaroszowka Wysockiego and Zgody',
#  'Finnish insurance company Fennia and Kesko Group are ending their loyal customer cooperation',
#  'The casing comprises a first side casing member provided with the first side vat segment and a second side casing member provided with the second side vat segment at least the first side casing member being pivotable about a rotation axis',
#  'Finlandbased Elcoteq SE a privately held provider of electronics manufacturing services to communications companies said Thursday it signed a longterm manufacturing supply deal with communications equipment company Andrew Corp',
#  'In Q1 of 2009 Bank of àland s net interest income weakened by 10 to EUR 91 mn',
#  'RBS Pays 17 Billion to Scrap UK Treasurys Dividend Rights',
#  'Increased trust of our clients in YIT can be seen as apartment sales accelerated',
#  'Talvivaara Mining Company Plc Talvivaara Mining Company is an internationally significant base metals producer with its primary focus on nickel and zinc using a technology known as bioheapleaching to extract metals out of ore',
#  'Operating profit for 2009 lower than outlook published earlier',
#  'Less than ten people will face pension agreements',
#  'The company s consolidated operating profit amounted to EUR 1586 mn up from EUR 414 mn yearonyear',
#  'AstraZeneca to Buy ZS Pharma for 27 Billion',
#  'Finnish waste management and cleaning group Lassila Tikanoja Oyj LT net profit went down to 322 mln euro 477 mln for 2007 from 353 mln euro 523 mln for 2006',
#  'The operating margin of Aker Yards Cruise Ferries division went down from 83 to 64 in the first quarter of 2007',
#  'HELSINKI Thomson Financial Shares in Cargotec fell sharply in early afternoon trade after the cargo handling group posted a surprise drop in AprilJune profits which overshadowed the large number of new orders received during the three months',
#  'The program s target is structural cost reductions of about EUR 30mn in 2009',
#  'Our tools are specifically designed with the needs of both the business users and ICT experts in mind',
#  ...]

# %%
tokens=[word_tokenize(x) for x in df['Sentence']]

# %%
tokens[5]
# Out:
# ['$',
#  'SPY',
#  'would',
#  "n't",
#  'be',
#  'surprised',
#  'to',
#  'see',
#  'a',
#  'green',
#  'close']

# %%
#to remove stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
stop=stopwords.words('english')

# %%
stop_token=[]
for x in tokens:
  cl = [i for i in x if i not in stop]
  stop_token.append(cl)

# %%
stop_token
# Out:
# [['The',
#   'GeoSolutions',
#   'technology',
#   'leverage',
#   'Benefon',
#   "'s",
#   'GPS',
#   'solutions',
#   'providing',
#   'Location',
#   'Based',
#   'Search',
#   'Technology',
#   ',',
#   'Communities',
#   'Platform',
#   ',',
#   'location',
#   'relevant',
#   'multimedia',
#   'content',
#   'new',
#   'powerful',
#   'commercial',
#   'model',
#   '.'],
#  ['$',
#   'ESI',
#   'lows',
#   ',',
#   '$',
#   '1.50',
#   '$',
#   '2.50',
#   'BK',
#   'real',
#   'possibility'],
#  ['For',
#   'last',
#   'quarter',
#   '2010',
#   ',',
#   'Componenta',
#   "'s",
#   'net',
#   'sales',
#   'doubled',
#   'EUR131m',
#   'EUR76m',
#   'period',
#   'year',
#   'earlier',
#   ',',
#   'moved',
#   'zero',
#   'pre-tax',
#   'profit',
#   'pre-tax',
#   'loss',
#   'EUR7m',
#   '.'],
#  ['According',
#   'Finnish-Russian',
#   'Chamber',
#   'Commerce',
#   ',',
#   'major',
#   'construction',
#   'companies',
#   'Finland',
#   'operating',
#   'Russia',
#   '.'],
#  ['The',
#   'Swedish',
#   'buyout',
#   'firm',
#   'sold',
#   'remaining',
#   '22.4',
#   'percent',
#   'stake',
#   ',',
#   'almost',
#   'eighteen',
#   'months',
#   'taking',
#   'company',
#   'public',
#   'Finland',
#   '.'],
#  ['$', 'SPY', 'would', "n't", 'surprised', 'see', 'green', 'close'],
#  ['Shell',
#   "'s",
#   '$',
#   '70',
#   'Billion',
#   'BG',
#   'Deal',
#   'Meets',
#   'Shareholder',
#   'Skepticism'],
#  ['SSH',
#   'COMMUNICATIONS',
#   'SECURITY',
#   'CORP',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   'OCTOBER',
#   '14',
#   ',',
#   '2008',
#   'AT',
#   '2:45',
#   'PM',
#   'The',
#   'Company',
#   'updates',
#   'full',
#   'year',
#   'outlook',
#   'estimates',
#   'results',
#   'remain',
#   'loss',
#   'full',
#   'year',
#   '.'],
#  ['Kone',
#   "'s",
#   'net',
#   'sales',
#   'rose',
#   '14',
#   '%',
#   'year-on-year',
#   'first',
#   'nine',
#   'months',
#   '2008',
#   '.'],
#  ['The',
#   'Stockmann',
#   'department',
#   'store',
#   'total',
#   'floor',
#   'space',
#   '8,000',
#   'square',
#   'metres',
#   'Stockmann',
#   "'s",
#   'investment',
#   'project',
#   'price',
#   'tag',
#   'EUR',
#   '12',
#   'million',
#   '.'],
#  ['Circulation',
#   'revenue',
#   'increased',
#   '5',
#   '%',
#   'Finland',
#   '4',
#   '%',
#   'Sweden',
#   '2008',
#   '.'],
#  ['$',
#   'SAP',
#   'Q1',
#   'disappoints',
#   '#',
#   'software',
#   'licenses',
#   '.',
#   'Real',
#   'problem',
#   '?',
#   '#',
#   'Cloud',
#   'growth',
#   'trails',
#   '$',
#   'MSFT',
#   '$',
#   'ORCL',
#   '$',
#   'GOOG',
#   '$',
#   'CRM',
#   '$',
#   'ADBE',
#   'https',
#   ':',
#   '//t.co/jNDphllzq5'],
#  ['The',
#   'subdivision',
#   'made',
#   'sales',
#   'revenues',
#   'last',
#   'year',
#   'EUR',
#   '480.7',
#   'million',
#   'EUR',
#   '414.9',
#   'million',
#   '2008',
#   ',',
#   'operating',
#   'profits',
#   'EUR',
#   '44.5',
#   'million',
#   'EUR',
#   '7.4',
#   'million',
#   '.'],
#  ['Viking', 'Line', 'canceled', 'services', '.'],
#  ['Ahlstrom',
#   'Corporation',
#   'STOCK',
#   'EXCHANGE',
#   'ANNOUNCEMENT',
#   '7.2.2007',
#   '10.30',
#   'A',
#   'total',
#   '56,955',
#   'new',
#   'shares',
#   'Ahlstrom',
#   'Corporation',
#   'subscribed',
#   'option',
#   'rights',
#   'company',
#   "'s",
#   'stock',
#   'option',
#   'programs',
#   'I',
#   '2001',
#   'II',
#   '2001',
#   '.'],
#  ['$', 'FB', 'gone', 'green', 'day'],
#  ['$',
#   'MSFT',
#   'SQL',
#   'Server',
#   'revenue',
#   'grew',
#   'double-digit',
#   'SQL',
#   'Server',
#   'Premium',
#   'revenue',
#   'growing',
#   '30',
#   '%',
#   'http',
#   ':',
#   '//stks.co/ir2F'],
#  ['According',
#   'L+ñnnen',
#   'Tehtaat',
#   "'s",
#   'CEO',
#   'Matti',
#   'Karppinen',
#   ',',
#   'company',
#   'aims',
#   'deliver',
#   'fish',
#   'products',
#   'customers',
#   'day',
#   'earlier',
#   'currently',
#   '.'],
#  ['The',
#   'company',
#   "'s",
#   'share',
#   'quoted',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'Rautaruukki',
#   'Oyj',
#   ':',
#   'RTRKS',
#   '.'],
#  ['Elcoteq', 'SE', 'listed', 'Nasdaq', 'OMX', 'Helsinki', 'Ltd.', '.'],
#  ['Two',
#   'contracts',
#   'turntable',
#   'anode',
#   'vibrocompactors',
#   'delivered',
#   'Gansu',
#   'Hualu',
#   'Aluminum',
#   'Co',
#   'Ltd',
#   'another',
#   'unnamed',
#   'costumer',
#   '.'],
#  ['Aviva',
#   ',',
#   'Friends',
#   'Life',
#   'top',
#   'forecasts',
#   'ahead',
#   '5.6',
#   'billion',
#   'pound',
#   'merger'],
#  ['In',
#   'stead',
#   'based',
#   'soft',
#   'drink',
#   ',',
#   'usual',
#   ',',
#   'Teho',
#   'energy',
#   'drink',
#   'made',
#   'fresh',
#   'water',
#   '.'],
#  ['The',
#   'company',
#   'plans',
#   'increase',
#   'unit',
#   "'s",
#   'specialist',
#   'staff',
#   'several',
#   'dozen',
#   '--',
#   'depending',
#   'market',
#   'situation',
#   '2010',
#   '.'],
#  ['The',
#   'company',
#   'closed',
#   'last',
#   'year',
#   'turnover',
#   'four',
#   'million',
#   'euros',
#   '.'],
#  ['Shire', 'CEO', 'steps', 'drive', 'get', 'Baxalta', 'board', 'talking'],
#  ['Costco',
#   ':',
#   'A',
#   'Premier',
#   'Retail',
#   'Dividend',
#   'Play',
#   'https',
#   ':',
#   '//t.co/Fa5cnh2t0t',
#   '$',
#   'COST'],
#  ['The',
#   'five-storey',
#   ',',
#   'eco-efficient',
#   'building',
#   'gross',
#   'floor',
#   'area',
#   '15,000',
#   'sq',
#   'm.',
#   'It',
#   'also',
#   'include',
#   'apartments',
#   '.'],
#  ['The',
#   'first',
#   'installment',
#   'Cinema',
#   'Series',
#   'concludes',
#   'profile',
#   'Finnish',
#   'inventor',
#   'Olavi',
#   'Linden',
#   ',',
#   'whose',
#   'personal',
#   'artistic',
#   'journey',
#   'work',
#   'Fiskars',
#   'led',
#   'dozens',
#   'design',
#   'awards',
#   '.'],
#  ['All', 'welcome', '.'],
#  ['Stockmann',
#   'Swedish',
#   'sector',
#   'company',
#   'AB',
#   'Lindex',
#   'entered',
#   'agreement',
#   'September',
#   '30',
#   ',',
#   '2007',
#   ',',
#   'whereby',
#   'Stockmann',
#   ',',
#   'wholly-owned',
#   'subsidiary',
#   ',',
#   'make',
#   'public',
#   'tender',
#   'offer',
#   'Lindex',
#   "'s",
#   'issued',
#   'shares',
#   '.'],
#  ['HUHTAMAKI',
#   'OYJ',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   ',',
#   '16.9.2008',
#   'AT',
#   '13.32',
#   'Huhtamaki',
#   "'s",
#   'Capital',
#   'Markets',
#   'Day',
#   'institutional',
#   'investors',
#   'analysts',
#   'held',
#   'Espoo',
#   ',',
#   'September',
#   '16',
#   ',',
#   '2008',
#   'starting',
#   '13.30',
#   'pm',
#   'Finnish',
#   'time',
#   '.'],
#  ['``', 'We', 'pleased', 'welcome', 'Tapeks', 'Noma', 'Cramo', 'group', '.'],
#  ['-', 'Profit', 'taxes', 'EUR', '105.9', '82.7', 'million', '.'],
#  ['Royal',
#   'Dutch',
#   'Shell',
#   'Buy',
#   'BG',
#   'Group',
#   'Nearly',
#   '$',
#   '70',
#   'Billion'],
#  ['FinancialWire',
#   'tm',
#   'press',
#   'release',
#   'service',
#   ',',
#   'receives',
#   'compensation',
#   'news',
#   ',',
#   'opinions',
#   'distributions',
#   '.'],
#  ['ASSA',
#   'ABLOY',
#   'Kaupthing',
#   'Bank',
#   'gave',
#   '`',
#   'neutral',
#   "'",
#   'recommendation',
#   'share',
#   'price',
#   'target',
#   '174',
#   'crowns',
#   '$',
#   '24.7',
#   '-',
#   '19',
#   'euro',
#   'Swedish',
#   'lock',
#   'maker',
#   'Assa',
#   'Abloy',
#   'AB',
#   '.'],
#  ['The',
#   'item',
#   'included',
#   'restructuring',
#   'costs',
#   'EUR1',
#   '.6',
#   ',',
#   'year',
#   'earlier',
#   'EUR13',
#   '.1',
#   'm.',
#   'Diluted',
#   'EPS',
#   'stood',
#   'EUR0',
#   '.3',
#   'versus',
#   'loss',
#   'per',
#   'share',
#   'EUR',
#   '0.1',
#   '.'],
#  ['In', '2005', 'bank', 'posted', 'net', 'profit', 'Lt', '8.2', 'mn', '.'],
#  ['$',
#   'AAPL',
#   'afternoon',
#   'selloff',
#   'usual',
#   'brutal',
#   '.',
#   'get',
#   'ready',
#   'lose',
#   'ton',
#   'money',
#   '.'],
#  ['$',
#   'TSLA',
#   'recalling',
#   'pretty',
#   'much',
#   'every',
#   'single',
#   'model',
#   'X',
#   '@',
#   'cnnbrk',
#   'got',
#   'short',
#   'even',
#   'work',
#   'jump',
#   'money',
#   'trade'],
#  ['Dolce',
#   '&',
#   'Gabbana',
#   'asked',
#   'European',
#   'Union',
#   'declare',
#   'Marimekko',
#   'Corporation',
#   "'s",
#   '``',
#   'Unikko',
#   '``',
#   'floral',
#   'pattern',
#   'trademark',
#   'invalid',
#   ',',
#   'continuing',
#   'dispute',
#   'two',
#   'companies',
#   '.'],
#  ['InterContinental',
#   'Hotels',
#   'first-quarter',
#   'global',
#   'room',
#   'revenue',
#   'lags',
#   'estimates'],
#  ['According',
#   'Finnish',
#   'pension',
#   'insurance',
#   'company',
#   'Varma',
#   ',',
#   'Varma',
#   'recipient',
#   'two',
#   'thirds',
#   'revenue',
#   'earnings-related',
#   'pension',
#   'cover',
#   'competitive',
#   'tendering',
#   'Finland',
#   '.'],
#  ['A',
#   'portion',
#   ',',
#   '$',
#   '12.5',
#   'million',
#   ',',
#   'recorded',
#   'part',
#   'winnings',
#   'prior',
#   'patent',
#   'dispute',
#   'Finnish',
#   'phone',
#   'maker',
#   'Nokia',
#   'Oyj',
#   '.'],
#  ['L',
#   '&',
#   'G',
#   'still',
#   'paying',
#   'price',
#   'dividend',
#   'cut',
#   'crisis',
#   ',',
#   'chief',
#   'says'],
#  ['The',
#   'volume',
#   'investments',
#   'two',
#   'phases',
#   'project',
#   'estimated',
#   'USD',
#   '300mn',
#   '(',
#   'EUR',
#   '215.03',
#   'mn',
#   ')',
#   '.'],
#  ['Russia',
#   'accounted',
#   '9',
#   '%',
#   'Lagardere',
#   'magazine',
#   'division',
#   "'s",
#   'revenue',
#   ',',
#   'EUR',
#   '114.40',
#   'mn',
#   '(',
#   'USD',
#   '148.11',
#   'mn',
#   ')',
#   '2009',
#   ',',
#   'USA',
#   '-',
#   '18',
#   '%',
#   '.'],
#  ['The',
#   'company',
#   'also',
#   'estimates',
#   'already',
#   'carried',
#   'investments',
#   'lead',
#   'increase',
#   'net',
#   'sales',
#   '2010',
#   '2009',
#   'reached',
#   'EUR',
#   '141.7',
#   'million',
#   '.'],
#  ['Profit', 'accounting', 'period', 'EUR', '0.3', 'mn', '.'],
#  ['The',
#   'six',
#   'breweries',
#   'recorded',
#   '5.2',
#   'percent',
#   'growth',
#   'domestic',
#   'beer',
#   'sales',
#   'last',
#   'year',
#   '270.21',
#   'million',
#   'liters',
#   ',',
#   '256.88',
#   'million',
#   'liters',
#   'sold',
#   '2005',
#   '.'],
#  ['In',
#   'August-October',
#   '2010',
#   ',',
#   'company',
#   "'s",
#   'result',
#   'taxes',
#   'totalled',
#   'EUR',
#   '9.6',
#   'mn',
#   ',',
#   'EUR',
#   '0.5',
#   'mn',
#   'corresponding',
#   'period',
#   '2009',
#   '.'],
#  ['Systeemitiimi',
#   "'s",
#   'sales',
#   'project',
#   'resources',
#   'also',
#   'strengthened',
#   ',',
#   'director',
#   'Paul',
#   'Skogberg',
#   'said',
#   '.'],
#  ['Tesco', 'share', 'price', 'jumps', 'Q3', 'sales', 'top', 'estimates'],
#  ['The', 'fine', 'print', '.'],
#  ['The',
#   'price',
#   'logs',
#   'clearly',
#   'improved',
#   '2009',
#   'also',
#   'price',
#   'pulpwood',
#   'gone',
#   '.'],
#  ['Thus',
#   ',',
#   'SysOpen',
#   'Digia',
#   ',',
#   'accordance',
#   'Chapter',
#   '14',
#   'Section',
#   '21',
#   'Finnish',
#   'Companies',
#   'Act',
#   '29.9.1978',
#   '-',
#   '734',
#   ',',
#   'obtained',
#   'title',
#   'shares',
#   'Sentera',
#   'redeemed',
#   '.'],
#  ['Diluted',
#   'earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'fell',
#   'EUR',
#   '0.63',
#   'EUR',
#   '1.71',
#   '.'],
#  ['At',
#   '3:37',
#   'p.m.',
#   'Eastern',
#   'time',
#   ',',
#   'block',
#   '2,400',
#   'contracts',
#   'changed',
#   'hands',
#   'bid',
#   'price',
#   '$',
#   '0.45',
#   '.'],
#  ['Some',
#   'recent',
#   'technology',
#   'deliveries',
#   'include',
#   'refinery',
#   'technology',
#   'Anrak',
#   'Aluminium',
#   ',',
#   'iron',
#   'ore',
#   'pelletizing',
#   'plant',
#   'Tata',
#   'Steel',
#   'iron',
#   'ore',
#   'sintering',
#   'plants',
#   'Bhushan',
#   'Steel',
#   '.'],
#  ['$',
#   'VIPS',
#   'similar',
#   'pattern',
#   'like',
#   'beginning',
#   'May',
#   '.',
#   'Did',
#   'u',
#   'sell',
#   '?',
#   'Same',
#   '..',
#   'go',
#   'much',
#   'higher',
#   'drop',
#   '.'],
#  ['The', 'firm', 'generated', 'sales', '187', 'mln', 'eur', '2005', '.'],
#  ['Stora',
#   'Enso',
#   'also',
#   'meetings',
#   'labor',
#   'authorities',
#   ',',
#   'Employment',
#   'Economic',
#   'Development',
#   'Centres',
#   'representatives',
#   'government',
#   'order',
#   'find',
#   'solutions',
#   '.'],
#  ['AstraZeneca', 'profit', 'sales', 'stalwarts', 'fade'],
#  ['RT',
#   '@',
#   'andrewnyquist',
#   'Chartology',
#   ':',
#   'Yahoo',
#   ':',
#   'http',
#   ':',
#   '//stks.co/1itr',
#   '$',
#   'YHOO',
#   'Crazy',
#   'looking',
#   'chart',
#   ',',
#   'nearing',
#   'breakout',
#   'resistance',
#   'line',
#   '...'],
#  ['Most',
#   'bullish',
#   'stocks',
#   'Twitter',
#   'dip',
#   '.',
#   '$',
#   'YHOO',
#   '$',
#   'GDX',
#   '$',
#   'GOOGL',
#   '$',
#   'STZ',
#   '$',
#   'GOLD',
#   '$',
#   'EW',
#   '$',
#   'VZ',
#   '$',
#   'CELG',
#   '$',
#   'SBUX',
#   '$',
#   'SCTY',
#   ':',
#   'https',
#   ':',
#   '//t.co/iuZJelfwt3'],
#  ['Finnish',
#   'GeoSentric',
#   "'s",
#   'net',
#   'sales',
#   'decreased',
#   'EUR',
#   '939,000',
#   'January-March',
#   '2009',
#   '.'],
#  ['Cohen',
#   '&',
#   'Steers',
#   ',',
#   'Inc.',
#   ':',
#   '5',
#   '534',
#   '626',
#   'shares',
#   'representing',
#   '4.985',
#   '%',
#   'share',
#   'capital',
#   'voting',
#   'rights',
#   '.'],
#  ['More',
#   'staff',
#   'recruited',
#   'Japan',
#   'complement',
#   'network',
#   'close',
#   '50',
#   'service',
#   'locations',
#   '20',
#   'countries',
#   'worldwide',
#   '.'],
#  ['Paper',
#   'companies',
#   'negative',
#   'territories',
#   ',',
#   'Stora',
#   'Enso',
#   'R',
#   'shedding',
#   '1.62',
#   'pct',
#   '12.73',
#   'eur',
#   ',',
#   'UPM-Kymmene',
#   '0.80',
#   'pct',
#   '18.64',
#   'eur',
#   'M-real',
#   'B',
#   '0.18',
#   'pct',
#   'lower',
#   '5.57',
#   'eur',
#   '.'],
#  ['Kauko-Telko',
#   "'s",
#   'centralized',
#   'administration',
#   'dissolved',
#   'appropriate',
#   'parts',
#   'transferred',
#   'operating',
#   'activities',
#   'Group',
#   'administration',
#   'end',
#   'year',
#   '.'],
#  ['Operating',
#   'profit',
#   'quarter',
#   'April-June',
#   '2006',
#   'amounted',
#   'EUR182',
#   '.2',
#   'sales',
#   'EUR3',
#   '.62',
#   'bn',
#   '.'],
#  ['Atria',
#   'chose',
#   'DeLight',
#   'attract',
#   'consumers',
#   '25-45',
#   'age',
#   'group',
#   'Atria',
#   'Fresh',
#   'range',
#   'microwaveable',
#   'meals',
#   '.'],
#  ['Finnish',
#   'IT',
#   'solutions',
#   'provider',
#   'Affecto',
#   'Oyj',
#   'HEL',
#   ':',
#   'AFE1V',
#   'said',
#   'today',
#   'slipped',
#   'net',
#   'loss',
#   'EUR',
#   '115,000',
#   'USD',
#   '152,000',
#   'second',
#   'quarter',
#   '2010',
#   'profit',
#   'EUR',
#   '845,000',
#   'corresponding',
#   'period',
#   'year',
#   'earlier',
#   '.'],
#  ['US', 'sanctions', 'put', 'Gazprom-Shell', 'alliance', 'plans', 'jeopardy'],
#  ['Profit',
#   'period',
#   'EUR',
#   '10.9',
#   'mn',
#   ',',
#   'EUR',
#   '14.3',
#   'mn',
#   '2009',
#   '.'],
#  ['Profit', 'period', 'EUR', '5.9', 'mn', ',', 'EUR', '1.3', 'mn', '.'],
#  ['Operating',
#   'profit',
#   'fell',
#   'EUR',
#   '20.3',
#   'mn',
#   'EUR',
#   '74.2',
#   'mn',
#   'second',
#   'quarter',
#   '2008',
#   '.'],
#  ['However',
#   ',',
#   'sales',
#   'returned',
#   'growth',
#   'April-June',
#   '2010',
#   ',',
#   'CEO',
#   'Pekka',
#   'Eloholma',
#   'said',
#   '.'],
#  ['Operating',
#   'profit',
#   'totaled',
#   'EUR',
#   '18.6',
#   'mn',
#   '8.3',
#   '%',
#   'net',
#   'sales',
#   '.'],
#  ['Changes',
#   'market',
#   'situation',
#   'tougher',
#   'price',
#   'competition',
#   'substantially',
#   'reduced',
#   'demand',
#   'bread',
#   'packaging',
#   'manufactured',
#   'Kauhava',
#   'plant',
#   ',',
#   'according',
#   'company',
#   '.'],
#  ['In',
#   'connection',
#   'deal',
#   ',',
#   'Digia',
#   'employ',
#   '19',
#   'persons',
#   'Nokia',
#   'Oslo',
#   'Silicon',
#   'Valley',
#   'USA',
#   '.'],
#  ['The',
#   'Brazilian',
#   'unit',
#   'Finnish',
#   'security',
#   'solutions',
#   'provider',
#   'F-Secure',
#   'signed',
#   '1,500',
#   'new',
#   'clients',
#   'last',
#   'year',
#   ',',
#   'online',
#   'news',
#   'source',
#   'Reseller',
#   'Web',
#   'quoted',
#   'division',
#   "'s",
#   'commercial',
#   'director',
#   ',',
#   'Vladimir',
#   'Brand+úo',
#   ',',
#   'saying',
#   '.'],
#  ['The',
#   'fair',
#   'value',
#   'company',
#   "'s",
#   'investment',
#   'properties',
#   'went',
#   'EUR',
#   '2.768',
#   'billion',
#   'end',
#   '2009',
#   'EUR',
#   '2.916',
#   'billion',
#   'year',
#   'earlier',
#   '.'],
#  ['Dealers',
#   'said',
#   'share',
#   'largely',
#   'hit',
#   'investor',
#   'disappointment',
#   'refining',
#   'margin',
#   '9.48',
#   'usd',
#   'per',
#   'barrel',
#   'quarter',
#   'performance',
#   'shipping',
#   'unit',
#   ',',
#   'saw',
#   'EBIT',
#   'drop',
#   '5',
#   'mln',
#   'eur',
#   '20',
#   'mln',
#   'eur',
#   'year',
#   'amid',
#   'fall',
#   'volumes',
#   'tanker',
#   'rates',
#   '.'],
#  ['`',
#   'It',
#   'testament',
#   'quality',
#   'LTE',
#   'solution',
#   'commitment',
#   'Japanese',
#   'market',
#   "'",
#   ',',
#   'added',
#   '.'],
#  ['The',
#   'companies',
#   "'",
#   'aim',
#   'finalize',
#   'negotiations',
#   'sign',
#   'contracts',
#   'start',
#   'October',
#   '2008',
#   '.'],
#  ['Metso',
#   'Foundries',
#   'Jyvaskyla',
#   'Oy',
#   'discontinue',
#   'production',
#   'line',
#   '30',
#   'September',
#   '2008',
#   ',',
#   'company',
#   'said',
#   '.'],
#  ['A',
#   'total',
#   'six',
#   'polled',
#   'analysts',
#   'rated',
#   'M-real',
#   '--',
#   'two',
#   'gave',
#   '``',
#   'buy',
#   '``',
#   '-',
#   '``',
#   'accumulate',
#   '``',
#   ',',
#   'three',
#   'gave',
#   '``',
#   'hold',
#   '``',
#   'one',
#   'gave',
#   '``',
#   'sell',
#   '``',
#   '.'],
#  ['In',
#   'September',
#   '2010',
#   ',',
#   'Finnish',
#   'group',
#   'agreed',
#   'buy',
#   'Danish',
#   'company',
#   'Rose',
#   'Poultry',
#   'A-S',
#   'EUR23',
#   '.9',
#   'combination',
#   'cash',
#   'stock',
#   '.'],
#  ['$', 'YANG', 'Double', 'bottom', '5.2'],
#  ['Tesco',
#   'share',
#   'price',
#   'grocer',
#   'faces',
#   'SFO',
#   'investigation',
#   'outcome'],
#  ['$', 'aapl', 'news', 'becoming', 'bullish', 'http', ':', '//stks.co/tMU'],
#  ['GS',
#   'Engineering',
#   'install',
#   'valves',
#   'liquefied',
#   'natural',
#   'gas',
#   'LNG',
#   'plant',
#   'built',
#   'UAE',
#   'LNG',
#   'extraction',
#   'gas',
#   'plants',
#   'operator',
#   'GASCO',
#   'Ruwais',
#   ',',
#   'UAE',
#   '.'],
#  ['The',
#   'percentages',
#   'shares',
#   'voting',
#   'rights',
#   'calculated',
#   'proportion',
#   'total',
#   'number',
#   'shares',
#   'registered',
#   'Trade',
#   'Register',
#   'total',
#   'number',
#   'voting',
#   'rights',
#   'related',
#   '.'],
#  ['M-Real',
#   'said',
#   '`',
#   'grounds',
#   "'",
#   'rumors',
#   ',',
#   '`',
#   'circulating',
#   'market',
#   'months',
#   '.',
#   "'"],
#  ['Lember',
#   'said',
#   'matter',
#   'topical',
#   'also',
#   'Estonia',
#   ',',
#   'bill',
#   'drafted',
#   'Social',
#   'Affairs',
#   'Ministry',
#   'would',
#   'scrap',
#   'old-age',
#   'pensions',
#   'favorable',
#   'conditions',
#   '.'],
#  ['-',
#   'Moody',
#   "'s",
#   'said',
#   'gave',
#   'P',
#   'A1',
#   'long-term',
#   'senior',
#   'unsecured',
#   'P',
#   'P-1',
#   'short-term',
#   'debt',
#   'ratings',
#   'Finnish',
#   'lender',
#   'Aktia',
#   'Bank',
#   "'s",
#   'EUR1bn',
#   'USD1',
#   '.4',
#   'bn',
#   'euro',
#   'medium-term',
#   'note',
#   'EMTN',
#   'program',
#   '25',
#   'March',
#   '2011',
#   '.'],
#  ['$', 'TSLA', 'recall'],
#  ['The',
#   'liquidity',
#   'providing',
#   'interrupted',
#   'May',
#   '11',
#   ',',
#   '2007',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   "'s",
#   'shares',
#   'traded',
#   '0.50',
#   'cent',
#   '(',
#   'Aspocomp',
#   "'s",
#   'stock',
#   'exchange',
#   'release',
#   '11.5.2007',
#   ')',
#   '.'],
#  ['Hargreaves',
#   'Lansdown',
#   'bucks',
#   'weak',
#   'markets',
#   'see',
#   'assets',
#   'rise',
#   '2.6',
#   'percent'],
#  ['At',
#   '12.59',
#   'pm',
#   ',',
#   'OMX',
#   'Helsinki',
#   '25',
#   'index',
#   '0.32',
#   'pct',
#   'lower',
#   '2,694.81',
#   '.'],
#  ['The',
#   'decision',
#   'means',
#   'temporary',
#   'lay-offs',
#   'fixed',
#   'duration',
#   'company',
#   "'s",
#   'Nastola',
#   'Jyvaskyla',
#   'units',
#   ',',
#   'southern',
#   'central',
#   'Finland',
#   ',',
#   'respectively',
#   '.'],
#  ['The', 'value', 'orders', 'EUR', '10mn', '.'],
#  ['Ms',
#   'Laakso',
#   'responsible',
#   'HKScan',
#   "'s",
#   'HR',
#   'functions',
#   'development',
#   'Group',
#   '`',
#   'smarket',
#   'areas',
#   '.'],
#  ['Fiskars',
#   'also',
#   'engaged',
#   'global',
#   'supply',
#   'marine',
#   'energy',
#   'equipment',
#   'solutions',
#   'services',
#   'associated',
#   'company',
#   ',',
#   'Wartsila',
#   'Corporation',
#   '.'],
#  ['Aberdeen', 'Asset', 'Management', 'Gains', 'Foothold', 'In', 'China'],
#  ['Finland',
#   "'s",
#   'dominating',
#   'rail',
#   'company',
#   'VR',
#   'planning',
#   'set',
#   'infected',
#   'passengers',
#   'long-distance',
#   'trip',
#   'separate',
#   'carriage',
#   '.'],
#  ['In',
#   'November',
#   ',',
#   'Finnish',
#   'government',
#   'decreased',
#   'ownership',
#   'company',
#   '31.1',
#   'percent',
#   '38',
#   'percent',
#   '.'],
#  ['Finnish',
#   'Exel',
#   'Composites',
#   ',',
#   'technology',
#   'company',
#   'designs',
#   ',',
#   'manufactures',
#   ',',
#   'markets',
#   'composite',
#   'profiles',
#   'tubes',
#   'various',
#   'industrial',
#   'applications',
#   ',',
#   'reports',
#   'net',
#   'sales',
#   'decreased',
#   '0.6',
#   '%',
#   'second',
#   'quarter',
#   '2010',
#   'EUR',
#   '19.2',
#   'mn',
#   'EUR',
#   '19.3',
#   'mn',
#   'corresponding',
#   'period',
#   '2009',
#   '.'],
#  ['Of',
#   'Bavelloni',
#   "'s",
#   'NST',
#   "'s",
#   'joint',
#   'ventures',
#   ',',
#   'Bavelloni',
#   'Tools',
#   ',',
#   'completes',
#   'semiproducts',
#   'produced',
#   'Italy',
#   'high-quality',
#   'tools',
#   'sold',
#   'DiaPol',
#   'brand',
#   '.'],
#  ['The',
#   'tool',
#   'patent',
#   'pending',
#   'design',
#   'allows',
#   'consumers',
#   'lay',
#   'entire',
#   'project',
#   'removable',
#   'plate',
#   'using',
#   'multiple',
#   'clear',
#   'stamps',
#   'kind',
#   '.'],
#  ['$', 'GOOGL', 'short', '740', 'upper', 'BB', 'overbought'],
#  ['LIGHTS',
#   'OUT',
#   'Before',
#   'curfew',
#   ',',
#   'curl',
#   'latest',
#   'bestseller',
#   'treat',
#   'eyes',
#   'perfect',
#   'reading',
#   'light',
#   'Luceplan',
#   '.'],
#  ['UPM-Kymmene',
#   'Corp.',
#   ',',
#   'world',
#   "'s",
#   'largest',
#   'maker',
#   'magazine',
#   'paper',
#   ',',
#   'Tuesday',
#   'reported',
#   '19-percent',
#   'profit',
#   'drop',
#   'lower',
#   'paper',
#   'prices',
#   ',',
#   'higher',
#   'costs',
#   'strong',
#   'euro',
#   'hurt',
#   'revenue',
#   '.'],
#  ['The', 'total', 'value', 'contract', 'EUR', '8', 'million', '.'],
#  ['The',
#   'prerequisite',
#   'inclusion',
#   'program',
#   'receipt',
#   'gains',
#   'key',
#   'employees',
#   'acquire',
#   'Aspo',
#   'shares',
#   'amount',
#   'determined',
#   'Board',
#   'advance',
#   ',',
#   'maximum',
#   '.'],
#  ['Mr.',
#   'Doring',
#   'Eaton',
#   'since',
#   '1989',
#   'acted',
#   'Business',
#   'Unit',
#   'Manager',
#   'Eaton',
#   "'s",
#   'Power',
#   'Controls',
#   'Business',
#   'Unit',
#   'since',
#   'January',
#   '2007',
#   '.'],
#  ['The',
#   '250',
#   'sq',
#   '2,691',
#   'sq',
#   'ft',
#   'store',
#   'Copenhagen',
#   "'s",
#   'premier',
#   'shopping',
#   'district',
#   'inaugurated',
#   'today',
#   ',',
#   'strengthening',
#   'company',
#   "'s",
#   'presence',
#   'Nordic',
#   'capitals',
#   '.'],
#  ['In',
#   'financial',
#   'statement',
#   'first',
#   'quarter',
#   '2010',
#   ',',
#   'Tikkurila',
#   'reported',
#   'discontinued',
#   'operations',
#   '.'],
#  ['The',
#   'world',
#   "'s",
#   'second',
#   'largest',
#   'stainless',
#   'steel',
#   'maker',
#   'said',
#   'net',
#   'profit',
#   'three-month',
#   'period',
#   'Dec.',
#   '31',
#   'surged',
#   'euro603',
#   'million',
#   'US',
#   '$',
#   '781',
#   'million',
#   ',',
#   'euro3',
#   '.33',
#   'US',
#   '$',
#   '4.31',
#   'per',
#   'share',
#   ',',
#   'euro172',
#   'million',
#   ',',
#   'euro0',
#   '.94',
#   'per',
#   'share',
#   ',',
#   'previous',
#   'year',
#   '.'],
#  ['Name',
#   'Applicant',
#   ':',
#   'Jot',
#   'Automation',
#   'OYName',
#   'Inventor',
#   ':',
#   'Mammila',
#   'Tuomo',
#   ',',
#   'Piirainen',
#   'Mika',
#   'Kellokoski',
#   'MikaApplication',
#   'No',
#   '.',
#   ':',
#   '2424-KOLNP-2008',
#   'ADate',
#   'filing',
#   'Application',
#   ':',
#   '16-06-2008Publication',
#   'Date',
#   ':',
#   '30/01/2009'],
#  ['Netflix',
#   'Grows',
#   'Efforts',
#   'To',
#   'Create',
#   'Loyal',
#   'Customers',
#   '$',
#   'NFLX',
#   'https',
#   ':',
#   '//t.co/5QXBkoBphe'],
#  ['The',
#   'OMX',
#   'Nordic',
#   '40',
#   'OMXN40',
#   'index',
#   ',',
#   'comprising',
#   '40',
#   'traded',
#   'Nordic',
#   'stocks',
#   'Nasdaq',
#   'OMX',
#   'exchange',
#   ',',
#   'closed',
#   '0.87',
#   '%',
#   '1,064.14',
#   'points',
#   'Thursday',
#   '.'],
#  ['$',
#   'AAPL',
#   'nibbling',
#   'small',
#   'long',
#   'via',
#   '525',
#   '..',
#   'buying',
#   '13min',
#   'charts',
#   '..'],
#  ['The',
#   'operating',
#   'margin',
#   'Aker',
#   'Yards',
#   'Cruise',
#   '&',
#   'Ferries',
#   'division',
#   'went',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['$',
#   'TYC',
#   'break',
#   'new',
#   'highs',
#   ',',
#   'lots',
#   'technicals',
#   'looking',
#   'great',
#   'right',
#   '.'],
#  ['Eero',
#   'Katajavuori',
#   ',',
#   'currently',
#   'Group',
#   'Vice',
#   'President',
#   ',',
#   'Human',
#   'Resources',
#   ',',
#   'take',
#   'year-long',
#   'sabbatical',
#   'starting',
#   'October',
#   '1',
#   ',',
#   '2010',
#   '.'],
#  ['Whats',
#   '$',
#   'LULU',
#   '?',
#   'Numbers',
#   'looked',
#   'good',
#   ',',
#   'great',
#   ',',
#   'good',
#   '.',
#   'I',
#   'think',
#   'conference',
#   'call',
#   'instill',
#   'confidence',
#   '.'],
#  ['The',
#   'adjustment',
#   'measures',
#   'carried',
#   'phases',
#   'secure',
#   'delivery',
#   'capability',
#   '.'],
#  ['Alma',
#   'Media',
#   'Corporation',
#   'Press',
#   'Release',
#   '15',
#   'March',
#   '2010',
#   'TYRVAAN',
#   'SANOMAT',
#   'AND',
#   'PAIKALLISSANOMAT',
#   'BEING',
#   'BOUGHT',
#   'BY',
#   'SUOMEN',
#   'PAIKALLISSANOMAT',
#   'Two',
#   'local',
#   'papers',
#   ',',
#   'Tyrvaan',
#   'Sanomat',
#   'Paikallissanomat',
#   ',',
#   'appearing',
#   'Sastamala',
#   'neighbouring',
#   'municipalities',
#   ',',
#   'bought',
#   'Suomen',
#   'Paikallissanomat',
#   'Oy',
#   '.'],
#  ['Temporary',
#   'lay-offs',
#   ',',
#   'affecting',
#   'entire',
#   'workforce',
#   ',',
#   'also',
#   'implemented',
#   '.'],
#  ['A',
#   'meeting',
#   'media',
#   'analysts',
#   'held',
#   'day',
#   '10:30',
#   'a.m.',
#   'Stonesoft',
#   'Headquarters',
#   'Helsinki',
#   ',',
#   'Italahdenkatu',
#   '22',
#   'A',
#   '.',
#   'The',
#   'Interim',
#   'report',
#   'presented',
#   'Stonesoft',
#   "'s",
#   'CEO',
#   'Ilkka',
#   'Hiidenheimo',
#   '.'],
#  ['Finnish',
#   'Sampo-Rosenlew',
#   'manufactures',
#   'approximately',
#   'seven',
#   'forest',
#   'machines',
#   'monthly',
#   ',',
#   'half',
#   'machines',
#   'exported',
#   '.'],
#  ['Facebook',
#   ',',
#   'near',
#   'buy',
#   'point',
#   'last',
#   'week',
#   ',',
#   'faces',
#   'different',
#   'technical',
#   'test',
#   'today',
#   'https',
#   ':',
#   '//t.co/c72LLMpiNM',
#   '$',
#   'FB',
#   '$',
#   'AAPL',
#   '$',
#   'NFLX',
#   'https',
#   ':',
#   '//t.co/fPFbYTYPuY'],
#  ['4',
#   'February',
#   '2011',
#   '-',
#   'Finnish',
#   'broadband',
#   'data',
#   'communication',
#   'systems',
#   'provider',
#   'Teleste',
#   'Oyj',
#   'HEL',
#   ':',
#   'TLT1V',
#   'said',
#   'Wednesday',
#   'net',
#   'profit',
#   'rocketed',
#   'EUR4',
#   '.8',
#   '2010',
#   'EUR416',
#   ',000',
#   '2009',
#   'lifted',
#   'dividend',
#   'proposal',
#   '.'],
#  ['$',
#   'FREE',
#   'Ha',
#   'Heeeeeere',
#   'comes',
#   'pump',
#   '!',
#   'So',
#   'glad',
#   'I',
#   'picked',
#   '9K',
#   'end',
#   'day',
#   '!',
#   'Get',
#   'ready',
#   'bull',
#   'ride',
#   '!'],
#  ['Finnish',
#   'technology',
#   'group',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   '(',
#   'OMX',
#   'Helsinki',
#   ':',
#   'ACG1V',
#   ')',
#   'issued',
#   'third',
#   'quarter',
#   'report',
#   'Thursday',
#   '(',
#   '13',
#   'November',
#   ')',
#   ',',
#   'posting',
#   'operating',
#   'profit',
#   'EUR0',
#   '.4',
#   ',',
#   'compared',
#   'loss',
#   'EUR0',
#   '.5',
#   'third',
#   'quarter',
#   '2007',
#   '.'],
#  ['The',
#   'building',
#   'complex',
#   'consists',
#   'high-quality',
#   'office',
#   'retail',
#   'space',
#   'totalling',
#   '49,200',
#   'square',
#   'metres',
#   ',',
#   'company',
#   'said',
#   '.'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'Kesko',
#   'Group',
#   'ending',
#   'loyal',
#   'customer',
#   'cooperation',
#   '.'],
#  ['The',
#   'unit',
#   'planned',
#   'operational',
#   'second',
#   'half',
#   '2007',
#   'full',
#   'stream',
#   '2008',
#   '.'],
#  ['ITG',
#   "'s",
#   'share',
#   'deal',
#   'estimated',
#   '500,000',
#   'euro',
#   '$',
#   '627,000',
#   '.'],
#  ['The',
#   'plant',
#   'expected',
#   'enter',
#   'commercial',
#   'operation',
#   'mid-2009',
#   '.'],
#  ['Aspo',
#   'also',
#   'investigated',
#   'sales',
#   'opportunities',
#   'Kaukomarkkinat',
#   "'s",
#   'electronics',
#   'business',
#   '.'],
#  ['BG', 'Group', 'appoints', 'new', 'CEO', 'one', 'month', 'early'],
#  ['The',
#   'acquisition',
#   'immediate',
#   'positive',
#   'impact',
#   'Aspocomp',
#   "'s",
#   'financial',
#   'result',
#   '.'],
#  ['Finnair',
#   "'s",
#   'passenger',
#   'load',
#   'factor',
#   ',',
#   'measures',
#   'number',
#   'sold',
#   'seats',
#   'share',
#   'available',
#   'seats',
#   ',',
#   'dropped',
#   '1.3',
#   'percentage',
#   'points',
#   '76.7',
#   '%',
#   'September',
#   '.'],
#  ['RT',
#   '@',
#   'bman1',
#   '$',
#   'LNG',
#   'looks',
#   'primed',
#   'also',
#   '$',
#   'EGHT',
#   'poised',
#   'run',
#   '...'],
#  ['It',
#   'also',
#   '7.7',
#   'pct',
#   '12-month',
#   'volume',
#   'weighted',
#   'average',
#   'price',
#   'stock',
#   '.'],
#  ['Coke',
#   'dividend',
#   '-',
#   '3',
#   '%',
#   '.',
#   'Google',
#   'dividend',
#   '-',
#   '0',
#   '%',
#   '.',
#   'For',
#   'passive',
#   'income',
#   'Coke',
#   'takes',
#   '.',
#   '$',
#   'GOOG',
#   '$',
#   'KO',
#   'https',
#   ':',
#   '//t.co/QBsoWjxOST'],
#  ['Profit',
#   'taxes',
#   'EUR',
#   '5.4',
#   'mn',
#   ',',
#   'EUR',
#   '3.6',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['The',
#   'subsidiary',
#   'setting',
#   'facility',
#   'manufacturing',
#   'high-density',
#   'interconnection',
#   'printed',
#   'circuit',
#   'boards',
#   'PCBs',
#   'Nokia',
#   "'s",
#   'special',
#   'economic',
#   'zone',
#   'Sriperumbudur',
#   'near',
#   'Chennai',
#   '.'],
#  ['$',
#   'CRM',
#   'Sep',
#   '40',
#   'calls',
#   '+35',
#   '%',
#   'since',
#   'entry',
#   '#',
#   'BANG',
#   'http',
#   ':',
#   '//stks.co/deDm'],
#  ['In',
#   'January-June',
#   '2010',
#   ',',
#   'diluted',
#   'loss',
#   'per',
#   'share',
#   'stood',
#   'EUR0',
#   '.3',
#   'versus',
#   'EUR0',
#   '.1',
#   'first',
#   'half',
#   '2009',
#   '.'],
#  ['Rapala',
#   'said',
#   'estimates',
#   'make',
#   'savings',
#   '1-2',
#   'mln',
#   'eur',
#   'year',
#   'centralising',
#   'French',
#   'operations',
#   'one',
#   'site',
#   '.'],
#  ['$',
#   'VMW',
#   'Got',
#   'nice',
#   'push',
#   'today',
#   'following',
#   'small',
#   'sweepers',
#   'May',
#   'C',
#   'morning'],
#  ['That',
#   'topped',
#   'consensus',
#   'forecasts',
#   'earnings',
#   '0.21',
#   'euros',
#   'share',
#   '.'],
#  ['R', '&', 'D', 'Loan', ')', '.'],
#  ['In',
#   'future',
#   ',',
#   'company',
#   'intends',
#   'look',
#   'know-how',
#   'outside',
#   'company',
#   'cooperate',
#   'actors',
#   'sector',
#   '.'],
#  ['You', 'need', 'ready', 'window', 'opens', ',', 'Rosberg', 'said', '.'],
#  ['More', '50,000', 'tonnes', 'asphalt', 'mix', 'used', 'contract', '.'],
#  ['PA',
#   ')',
#   ',',
#   'JPMorgan',
#   'Chase',
#   'Co',
#   '(',
#   'NYSE',
#   ':',
#   'JPM',
#   ')',
#   'Pohjoa',
#   'Bank',
#   'joint',
#   'lead-managers',
#   'senior',
#   ',',
#   'unsecured',
#   'deal',
#   '.'],
#  ['$',
#   'CTRP',
#   'breaking',
#   'good',
#   'vol',
#   'parser',
#   'buy',
#   'signal',
#   '..',
#   'noticed',
#   'bob',
#   'langs',
#   'comments',
#   'looking',
#   '48',
#   'fast'],
#  ['Sales',
#   'Finland',
#   'decreased',
#   '10.5',
#   '%',
#   'January',
#   ',',
#   'sales',
#   'outside',
#   'Finland',
#   'dropped',
#   '17',
#   '%',
#   '.'],
#  ['The',
#   'pulp',
#   'production',
#   'Finnish',
#   'Kemij+ñrvi',
#   'also',
#   'liquidated',
#   '1,100',
#   'employees',
#   'loose',
#   'jobs',
#   '.'],
#  ['Nordea', 'cheapest', 'also', 'couple', '30s', 'debt', '.'],
#  ['Jussi',
#   'Pesonen',
#   ',',
#   'member',
#   'Sampo',
#   'Board',
#   'since',
#   '2006',
#   ',',
#   'renounce',
#   'seat',
#   'Sampo',
#   'Board',
#   '.'],
#  ['Tesla',
#   'recalling',
#   '2,700',
#   'Model',
#   'X',
#   'cars',
#   ':',
#   'https',
#   ':',
#   '//t.co/8Z7BkVsTl9',
#   '$',
#   'TSLA'],
#  ['Adjusted',
#   'changes',
#   'Group',
#   'structure',
#   ',',
#   'Division',
#   "'s",
#   'net',
#   'sales',
#   'increased',
#   '1.7',
#   '%',
#   '.'],
#  ['Making',
#   'matters',
#   'difficult',
#   ',',
#   'company',
#   'said',
#   'grappling',
#   'higher',
#   'oil',
#   'gas',
#   'prices',
#   ',',
#   'pushed',
#   'cost',
#   'energy',
#   ',',
#   'raw',
#   'materials',
#   'transportation',
#   '.'],
#  ['The',
#   'amending',
#   'proposal',
#   'simplifies',
#   'proposed',
#   'plan',
#   'increases',
#   'incentive',
#   'key',
#   'employees',
#   'stay',
#   'Company',
#   '.'],
#  ['The', 'solution', 'expanded', 'include', 'ground', 'staff', 'tasks', '.'],
#  ['Operating',
#   'loss',
#   'totalled',
#   'EUR',
#   '3.2',
#   'mn',
#   ',',
#   'compared',
#   'profit',
#   'EUR',
#   '7.2',
#   'mn',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['On',
#   '#',
#   'FEDDAY',
#   'looking',
#   'sharp',
#   'move',
#   'equities',
#   '$',
#   'AAPL',
#   '$',
#   'HD',
#   '$',
#   'LOW',
#   '$',
#   'FB',
#   'seeing',
#   '$',
#   'UVXY',
#   '$',
#   'TVIX',
#   'getting',
#   'hammered',
#   ',',
#   'even',
#   'though',
#   'market',
#   '.'],
#  ['Net',
#   'sales',
#   'totaled',
#   'EUR',
#   '93.6',
#   'mn',
#   ',',
#   'EUR',
#   '93.2',
#   'mn',
#   'corresponding',
#   'period',
#   '2005',
#   '.'],
#  ['As',
#   'consequence',
#   'Works',
#   'Council',
#   'withdrawn',
#   'petition',
#   'suspend',
#   'reorganisation',
#   '.'],
#  ['CEO',
#   'Erkki',
#   'J+ñrvinen',
#   'happy',
#   'company',
#   "'s",
#   'performance',
#   '2010',
#   '.'],
#  ['Comparable',
#   'net',
#   'sales',
#   'expected',
#   'increase',
#   '10',
#   '%',
#   '2008',
#   ',',
#   'line',
#   'group',
#   'target',
#   '.'],
#  ['Following',
#   'transaction',
#   ',',
#   'Lundbeck',
#   'worldwide',
#   'rights',
#   'nalmefene',
#   ',',
#   'excluding',
#   'North',
#   'America',
#   ',',
#   'Mexico',
#   ',',
#   'Turkey',
#   'South-Korea',
#   '.'],
#  ['The',
#   'government',
#   'started',
#   'sell-off',
#   'last',
#   'month',
#   ',',
#   'putting',
#   '8',
#   'percent',
#   'stake',
#   'TeliaSonera',
#   'auction',
#   'bloc',
#   '.'],
#  ['The',
#   'report',
#   'goes',
#   'provide',
#   'detailed',
#   'profiles',
#   'ten',
#   'leading',
#   'European',
#   'specialty',
#   'chemicals',
#   'companies',
#   ',',
#   'brief',
#   'profiles',
#   'major',
#   'players',
#   '.'],
#  ['Both',
#   'operating',
#   'profit',
#   'net',
#   'sales',
#   'three-month',
#   'period',
#   'increased',
#   ',',
#   'respectively',
#   'EUR16',
#   '.0',
#   'EUR139m',
#   ',',
#   'compared',
#   'corresponding',
#   'quarter',
#   '2006',
#   '.'],
#  ['The',
#   'company',
#   'expects',
#   'net',
#   'sales',
#   'whole',
#   '2009',
#   'previous',
#   'year',
#   'levels',
#   '.'],
#  ['The',
#   'company',
#   'headquartered',
#   'Sievi',
#   ',',
#   'Finland',
#   ',',
#   'listed',
#   'Nordic',
#   'Exchange',
#   'Helsinki',
#   '.'],
#  ['Commission',
#   'income',
#   'increased',
#   '22',
#   '%',
#   'EUR',
#   '4.4',
#   'mn',
#   ',',
#   'lending',
#   'volume',
#   'rose',
#   '13.5',
#   '%',
#   '.'],
#  ['The',
#   'Finnish',
#   'company',
#   'sold',
#   'UK',
#   'operation',
#   '-',
#   'consisting',
#   '50',
#   'staff',
#   'offices',
#   'London',
#   ',',
#   'Birmingham',
#   'Manchester',
#   '-',
#   'part',
#   'deal',
#   'Hampden',
#   'July',
#   '2001',
#   'European-wide',
#   'property',
#   'casualty',
#   'arm',
#   'Sampo',
#   'Industrial',
#   '.'],
#  ['In',
#   'building',
#   'home',
#   'improvement',
#   'trade',
#   ',',
#   'sales',
#   'decreased',
#   '22.5',
#   '%',
#   'EUR',
#   '201.4',
#   'mn',
#   '.'],
#  ['The',
#   'Innova',
#   '2',
#   'building',
#   'located',
#   'close',
#   'downtown',
#   ',',
#   'immediate',
#   'vicinity',
#   'Paviljonki',
#   'travel',
#   'center',
#   ',',
#   'within',
#   'walking',
#   'distance',
#   'heart',
#   'city',
#   'thanks',
#   'trade',
#   'fair',
#   'bridge',
#   '.'],
#  ['Finnish',
#   'textiles',
#   'clothing',
#   'group',
#   'Marimekko',
#   'Oyj',
#   'posted',
#   'net',
#   'profit',
#   '7.99',
#   'mln',
#   'euro',
#   '$',
#   '10.4',
#   'mln',
#   '2006',
#   ',',
#   'compared',
#   '8.4',
#   'mln',
#   'euro',
#   '$',
#   '10.9',
#   'mln',
#   '2005',
#   '.'],
#  ['The',
#   'main',
#   'strength',
#   'cooperation',
#   'project',
#   'lies',
#   'merging',
#   'know-how',
#   'two',
#   'large',
#   'companies',
#   '.'],
#  ['Shareholders',
#   'right',
#   'put',
#   'agenda',
#   'AGM',
#   'items',
#   'within',
#   'competence',
#   'general',
#   'meeting',
#   '.'],
#  ['Kazgiprotsvetmet',
#   'Outotec',
#   'Finland',
#   'signed',
#   'agreement',
#   'strategic',
#   'cooperation',
#   'marketing',
#   'providing',
#   'minerals',
#   'processing',
#   'metallurgical',
#   'plants',
#   'related',
#   'services',
#   'Kazakhstan',
#   'surrounding',
#   'countries',
#   '.'],
#  ['Due',
#   'rapid',
#   'decrease',
#   'net',
#   'sales',
#   ',',
#   'personnel',
#   'reductions',
#   'carried',
#   'wider',
#   'scale',
#   'initially',
#   'expected',
#   '.'],
#  ['The',
#   'government',
#   'instead',
#   'proposed',
#   'exchange',
#   'state',
#   "'s",
#   'stake',
#   'LMT',
#   'TeliaSonera',
#   "'s",
#   'stake',
#   'Lattelecom',
#   '.'],
#  ['Stora',
#   'due',
#   'release',
#   'fourth-quarter',
#   '2009',
#   'full-year',
#   'earnings',
#   'Feb.',
#   '4',
#   '.'],
#  ['Full-year',
#   'operating',
#   'result',
#   '2008',
#   '3.6',
#   'million',
#   'negative',
#   '.'],
#  ['$',
#   'NQ',
#   'got',
#   'hit',
#   'hard',
#   'lower',
#   'AM',
#   '--',
#   '>',
#   'looks',
#   'like',
#   'found',
#   'support',
#   '18.89',
#   'http',
#   ':',
#   '//stks.co/s052z'],
#  ['In',
#   '2008',
#   ',',
#   'AVC',
#   'Systemhaus',
#   'net',
#   'sales',
#   'EUR',
#   '10',
#   'million',
#   'USD',
#   '7.1',
#   '.'],
#  ['The',
#   'company',
#   'established',
#   '3G',
#   'base',
#   'station',
#   '17,000',
#   'feet',
#   'foot',
#   'Mount',
#   'Everest',
#   'enable',
#   'mountain',
#   'climbers',
#   '29,035-foot',
#   'summit',
#   'surf',
#   'Internet',
#   'even',
#   'send',
#   'videos',
#   'exploits',
#   '.'],
#  ['We',
#   'offer',
#   'customers',
#   'solutions',
#   'based',
#   'renewable',
#   'raw',
#   'materials',
#   '.'],
#  ['A',
#   'survey',
#   'conducted',
#   'Taloustutkimus',
#   'Sampo',
#   'Life',
#   'shows',
#   'companies',
#   'badly',
#   'prepared',
#   'losing',
#   'key',
#   'staff',
#   'members',
#   '.'],
#  ['Antti',
#   'Orkola',
#   ',',
#   'president',
#   'Kemira',
#   'GrowHow',
#   "'s",
#   'Industrial',
#   'Solutions',
#   'unit',
#   ',',
#   'told',
#   'Thomson',
#   'Financial',
#   'News',
#   'company',
#   'put',
#   'opening',
#   'mine',
#   'prices',
#   'phosphate',
#   '`',
#   'quite',
#   'depressed',
#   'long',
#   'time',
#   "'",
#   '.',
#   "'"],
#  ['The',
#   'pretax',
#   'profit',
#   'group',
#   "'s",
#   'life',
#   'insurance',
#   'business',
#   'increased',
#   'EUR36m',
#   'EUR27m',
#   '.'],
#  ['We',
#   'make',
#   'available',
#   'following',
#   'brand-new',
#   'market',
#   'analyses',
#   'Cement',
#   '-',
#   'Pakistan',
#   'Cement',
#   '-',
#   'Malaysia',
#   'Cement',
#   '-',
#   'Taiwan',
#   'Cement',
#   '-',
#   'Philippines',
#   'These',
#   'analyses',
#   'give',
#   'clear',
#   'overview',
#   'actual',
#   'situation',
#   'future',
#   'outlook',
#   'cement',
#   'industry',
#   'Asian',
#   'countries',
#   '.'],
#  ['The',
#   'Company',
#   'serves',
#   'approximately',
#   '3,000',
#   'customers',
#   '100',
#   'countries',
#   '.'],
#  ['RT',
#   '@',
#   'alphatrends',
#   'VMarkets',
#   'Are',
#   'Still',
#   'Acting',
#   'Weak',
#   'http',
#   ':',
#   '//stks.co/1agn',
#   '$',
#   'SPY',
#   '$',
#   'QQQ',
#   '$',
#   'XLF',
#   '$',
#   'SMH',
#   '$',
#   'IWM'],
#  ['Operating',
#   'profit',
#   'totalled',
#   'EUR',
#   '30.2',
#   'mn',
#   ',',
#   'EUR',
#   '43.8',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['One',
#   'installed',
#   'elevators',
#   'double-deck',
#   'elevator',
#   ',',
#   'enables',
#   'efficient',
#   'use',
#   'building',
#   "'s",
#   'core',
#   'space',
#   '.'],
#  ['HELSINKI',
#   '(',
#   'AFX',
#   ')',
#   '-',
#   'Outokumpu',
#   'said',
#   'agreed',
#   'sell',
#   'Hitura',
#   'nickel',
#   'mine',
#   'Finland',
#   'Canadian',
#   'group',
#   'Belvedere',
#   'Resources',
#   'Ltd',
#   '10',
#   'mln',
#   'eur',
#   'worth',
#   'Belvedere',
#   'shares',
#   '.'],
#  ['Just', 'went', 'long', '$', 'ILMN'],
#  ['``',
#   'Social',
#   'networking',
#   'location-based',
#   'service',
#   'trends',
#   'comprise',
#   'significant',
#   'share',
#   'Internet',
#   'traffic',
#   'today',
#   'appealing',
#   'MID',
#   'users',
#   '.'],
#  ['A',
#   'total',
#   '30',
#   '%',
#   'order',
#   'value',
#   'booked',
#   'fourth',
#   'quarter',
#   '2009',
#   'remainder',
#   'booked',
#   'second',
#   'quarter',
#   '2010',
#   '.'],
#  ['Johnson',
#   'Matthey',
#   'share',
#   'price',
#   'slumps',
#   'company',
#   'posts',
#   'full-year',
#   'results'],
#  ['There',
#   'previous',
#   'share',
#   'subscriptions',
#   '2004',
#   'stock',
#   'options',
#   '.'],
#  ['AffectoGenimap',
#   'builds',
#   'highly',
#   'customised',
#   'IT',
#   'solutions',
#   'customers',
#   'Finland',
#   'Baltic',
#   'countries',
#   '.'],
#  ['The',
#   'closing',
#   'transaction',
#   'scheduled',
#   'take',
#   'place',
#   'January',
#   '10',
#   ',',
#   '2008',
#   '.'],
#  ['However',
#   ',',
#   'offering',
#   'probably',
#   'made',
#   'current',
#   'valuation',
#   ',',
#   'partly',
#   'derives',
#   'deal',
#   'company',
#   'merged',
#   'stock',
#   'market',
#   'shell',
#   '.'],
#  ['Operating',
#   'result',
#   '12-month',
#   'period',
#   'decreased',
#   'profit',
#   'EUR0',
#   '.4',
#   'turnover',
#   'decreased',
#   'EUR5',
#   '.6',
#   ',',
#   'compared',
#   '2004',
#   '.'],
#  ['The',
#   'administrators',
#   'indicated',
#   'need',
#   '900',
#   'job',
#   'cuts',
#   'Irish',
#   'insurer',
#   'next',
#   '15',
#   'months',
#   '.'],
#  ['Net', 'sales', '2008', 'expected', 'level', '2007', '.'],
#  ['Technical',
#   'indicators',
#   'stock',
#   'bullish',
#   'S',
#   '&',
#   'P',
#   'gives',
#   'NOK',
#   'positive',
#   '4',
#   'STARS',
#   '5',
#   'buy',
#   'ranking',
#   '.'],
#  ['Revenue',
#   'quarter',
#   'totaled',
#   '27.4',
#   'billion',
#   ',',
#   '2',
#   'percent',
#   '28.1',
#   'billion',
#   'fourth',
#   'quarter',
#   '2008',
#   '.'],
#  ['N-Viro',
#   'operates',
#   'processing',
#   'facilities',
#   'independently',
#   'well',
#   'partnership',
#   'municipalities',
#   '.'],
#  ['The',
#   'number',
#   'bodily',
#   'injury',
#   'cases',
#   'quadrupled',
#   '2000-2006',
#   '.'],
#  ['According',
#   'Ringman',
#   ',',
#   'Finnish',
#   'paper',
#   'companies',
#   'acquired',
#   'know-how',
#   'capacity',
#   'paper',
#   'recycling',
#   ',',
#   'turned',
#   'successful',
#   'strategy',
#   '.'],
#  ['The',
#   'company',
#   'also',
#   'said',
#   'Poland',
#   'profitability',
#   'program',
#   'launched',
#   'Oborniki',
#   'steel',
#   'frame',
#   'sandwich',
#   'panel',
#   'plant',
#   '.'],
#  ['And',
#   'U.S.',
#   'energy',
#   'executives',
#   'say',
#   'high',
#   'steel',
#   'prices',
#   'threatening',
#   'energy',
#   'exploration',
#   '.'],
#  ['Tesco', 'sales', 'rise', 'shows', 'tentative', 'recovery', 'continues'],
#  ['In',
#   'Finland',
#   ',',
#   'launch',
#   'tie-in',
#   'sales',
#   '3G',
#   'mobile',
#   'phones',
#   'cause',
#   'dramatic',
#   'rush',
#   'mobile',
#   'retail',
#   'outlets',
#   'first',
#   'days',
#   '.'],
#  ['$',
#   'NUAN',
#   'held',
#   'well',
#   'big',
#   'gains',
#   '!',
#   'Maybe',
#   "'re",
#   'finally',
#   'move',
#   '!',
#   '!',
#   'still',
#   'undervalued',
#   'major',
#   'upside'],
#  ['The',
#   'company',
#   'split',
#   'two',
#   'parts',
#   'coming',
#   'months',
#   ',',
#   'Essent',
#   'owning',
#   'operating',
#   'production',
#   'supply',
#   ',',
#   'Enexis',
#   'owning',
#   'operating',
#   'grid',
#   '.'],
#  ['Officials', 'disclose', 'contract', 'value', '.'],
#  ['London',
#   "'s",
#   'leading',
#   'shares',
#   'today',
#   'jumped',
#   'almost',
#   '100',
#   'points',
#   ',',
#   '1.7',
#   '%',
#   ',',
#   'market',
#   'opened',
#   '.'],
#  ['In',
#   'third',
#   'quarter',
#   'fiscal',
#   '2008',
#   'Efore',
#   'swung',
#   'net',
#   'loss',
#   'EUR',
#   '400,000',
#   'versus',
#   'net',
#   'profit',
#   'EUR',
#   '200,000',
#   'corresponding',
#   'period',
#   'fiscal',
#   '2007',
#   '.'],
#  ['The',
#   'group',
#   "'s",
#   'operating',
#   'loss',
#   'EUR',
#   '0.8',
#   'mn',
#   ',',
#   'profit',
#   'EUR',
#   '2.5',
#   'mn',
#   '2004',
#   '.'],
#  ['The',
#   'move',
#   'triggered',
#   'weak',
#   'demand',
#   'forestry',
#   'equipment',
#   'uncertain',
#   'market',
#   'situation',
#   '.'],
#  ['The',
#   'combined',
#   'company',
#   'pro-forma',
#   'net',
#   'sales',
#   '140',
#   'mln',
#   'euro',
#   '$',
#   '188.9',
#   'mln',
#   'operating',
#   'profit',
#   '13',
#   'mln',
#   'euro',
#   '$',
#   '17.5',
#   'mln',
#   '2006',
#   '.'],
#  ['Managing',
#   'Director',
#   'Kari',
#   'Inkinen',
#   'says',
#   'Sponda',
#   "'s",
#   'leasing',
#   'operations',
#   'developed',
#   'highly',
#   'favourably',
#   '.'],
#  ['17',
#   'March',
#   '2011',
#   '-',
#   'Goldman',
#   'Sachs',
#   'estimates',
#   'negative',
#   'prospects',
#   'Norwegian',
#   'mobile',
#   'operations',
#   'Norway',
#   "'s",
#   'Telenor',
#   'ASA',
#   'OSL',
#   ':',
#   'TEL',
#   'Sweden',
#   "'s",
#   'TeliaSonera',
#   'AB',
#   'STO',
#   ':',
#   'TLSN',
#   'short',
#   'term',
#   '.'],
#  ['$', 'TSLA', 'steaming', ',', 'stock', 'relentless', 'moment'],
#  ['Marathon',
#   'estimates',
#   'value',
#   'remaining',
#   'stake',
#   'Protalix',
#   '$',
#   '27',
#   'million',
#   '.'],
#  ['Whitbread', 'share', 'price', 'climbs', 'Q4', 'sales', 'growth'],
#  ['Incap',
#   'Contract',
#   'Manufacturing',
#   'subsidiary',
#   'Incap',
#   'Corporation',
#   'Finland',
#   '.'],
#  ['Operating',
#   'profit',
#   'totaled',
#   'EUR',
#   '37,7',
#   'mn',
#   ',',
#   'slightly',
#   'EUR',
#   '37.2',
#   'mn',
#   'corresponding',
#   'period',
#   '2006',
#   '.'],
#  ['We',
#   'went',
#   'market',
#   'yield',
#   'guidance',
#   '7.25',
#   '%',
#   'area',
#   ',',
#   'gave',
#   'us',
#   'flexibility',
#   'go',
#   '1-8th',
#   '.'],
#  ['RT',
#   '@',
#   'stockdemons',
#   'think',
#   'shorting',
#   'close',
#   'might',
#   'play',
#   ',',
#   '$',
#   'SPY',
#   '-',
#   'high',
#   'beta',
#   'reversing',
#   '..',
#   'looks',
#   'worth',
#   'shot'],
#  ['VDW',
#   'combined',
#   'LXE',
#   'devices',
#   'enhances',
#   'productivity',
#   ',',
#   'enabling',
#   'workers',
#   'use',
#   'single',
#   'device',
#   'perform',
#   'voice',
#   ',',
#   'scanning',
#   'keyboard',
#   'functions',
#   '.'],
#  ['Thus',
#   'method',
#   'cut',
#   'working',
#   'costs',
#   ',',
#   'fasten',
#   'planning',
#   'building',
#   'processes',
#   '.'],
#  ['Talentum', "'s", 'net', 'sales', 'September', 'smaller', 'expected', '.'],
#  ['COPYRIGHT',
#   'AFX',
#   'News',
#   'AFX',
#   'Financial',
#   'News',
#   'Logo',
#   'registered',
#   'trademarks',
#   'AFX',
#   'News',
#   'Limited'],
#  ['$',
#   'LNKD',
#   'Daily',
#   'Phase',
#   '2',
#   'retest',
#   '-',
#   'Price',
#   'experiencing',
#   'early',
#   'rejection',
#   '.',
#   'Can',
#   'retest',
#   '?',
#   'http',
#   ':',
#   '//stks.co/t04xX'],
#  ['RBS', 'reportedly', 'appoint', 'Howard', 'Davies', 'next', 'chairman'],
#  ['Tesco',
#   ',',
#   'Asda',
#   'sales',
#   'fall',
#   'march',
#   'discounters',
#   'continues-Kantar'],
#  ['``',
#   'With',
#   'new',
#   'version',
#   'important',
#   'us',
#   'introduce',
#   'BIM',
#   'process',
#   'based',
#   'detailed',
#   'building',
#   'information',
#   'model',
#   '.'],
#  ['SAMPO',
#   'PLC',
#   'Jarmo',
#   'Salonen',
#   'Head',
#   'Investor',
#   'Relations',
#   'Group',
#   'Communications',
#   'tel',
#   '.',
#   '+358',
#   '10',
#   '516',
#   '0030',
#   'Distribution',
#   ':',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'The',
#   'principal',
#   'media',
#   'Financial',
#   'Supervisory',
#   'Authority',
#   'www.sampo.com',
#   'This',
#   'announcement',
#   'distributed',
#   'Thomson',
#   'Reuters',
#   'behalf',
#   'Thomson',
#   'Reuters',
#   'clients',
#   '.'],
#  ['.',
#   '@',
#   'barronsonline',
#   'sees',
#   '#',
#   'Apple',
#   '$',
#   '150/share',
#   'year',
#   '(',
#   '+36',
#   '%',
#   'today',
#   ')',
#   'growing',
#   'services',
#   'business',
#   '.',
#   '$',
#   'AAPL',
#   'https',
#   ':',
#   '//t.co/3BDNEKN7l1'],
#  ['Pharmaceutical',
#   'market',
#   'Poland',
#   'Global',
#   'Research',
#   '&',
#   'Data',
#   'Services',
#   'published',
#   'recently',
#   'market',
#   'analysis',
#   'pharmaceutical',
#   'markets',
#   'Poland',
#   '.'],
#  ['Altogether', 'Finnair', 'canceled', '500', 'flights', 'strike', '.'],
#  ['The',
#   'employer',
#   ',',
#   'together',
#   'health',
#   'personnel',
#   ',',
#   'supports',
#   'quitting',
#   'pays',
#   'part',
#   'cost',
#   'nicotine',
#   'treatments',
#   '.'],
#  ['Pretax',
#   'loss',
#   'totaled',
#   'EUR',
#   '117mn',
#   'compared',
#   'loss',
#   'EUR',
#   '65mn',
#   'corresponding',
#   'period',
#   '.'],
#  ['The',
#   'order',
#   'includes',
#   '48',
#   'ship',
#   'cranes',
#   'delivered',
#   '12',
#   'container',
#   'feeders',
#   'built',
#   'Wenchong',
#   'shipyard',
#   'China',
#   '.'],
#  ['Copper',
#   ',',
#   'lead',
#   'nickel',
#   'also',
#   'dropped',
#   '...',
#   'HBOS',
#   '(',
#   'HBOS',
#   ')',
#   'plummeted',
#   '20',
#   '%',
#   '70.3',
#   'pence',
#   'saying',
#   'year+ó',
#   '?',
#   '?'],
#  ['$',
#   'GOOG',
#   'Testing',
#   '200',
#   'day',
#   'consolidation',
#   'http',
#   ':',
#   '//stks.co/h0cPJ'],
#  ['He',
#   'joins',
#   'Technopolis',
#   'KONE',
#   'held',
#   'various',
#   'positions',
#   'within',
#   'Group',
#   ',',
#   'recently',
#   'Director',
#   'Service',
#   'Business',
#   'Business',
#   'Development',
#   'KONE',
#   'Middle',
#   'Eastern',
#   'operations',
#   '.'],
#  ['We',
#   'succeeded',
#   'increasing',
#   'market',
#   'share',
#   'sold',
#   'apartment',
#   '``',
#   ',',
#   'comments',
#   'Mr',
#   'Kari',
#   'Kauniskangas',
#   ',',
#   'Head',
#   'YIT',
#   'International',
#   'Construction',
#   'Services',
#   '.'],
#  ['Profitability',
#   '(',
#   'EBIT',
#   '%',
#   ')',
#   '13.9',
#   '%',
#   ',',
#   'compared',
#   '13.1',
#   '%',
#   'previous-year',
#   'period',
#   '.'],
#  ['Finnish',
#   'GeoSentric',
#   "'s",
#   'net',
#   'sales',
#   'decreased',
#   'EUR',
#   '939,000',
#   'January-March',
#   '2009',
#   '.'],
#  ['The',
#   'plant',
#   'scheduled',
#   'completion',
#   'late',
#   'February',
#   '2007',
#   'hand',
#   'areas',
#   'January',
#   'Two',
#   'suppliers',
#   'Nokia',
#   '-',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   'Perlos',
#   '-',
#   'announced',
#   'plans',
#   'establish',
#   'plants',
#   'within',
#   'Nokia',
#   'complex',
#   'Together',
#   ',',
#   'invest',
#   'Rs',
#   '365',
#   'crore',
#   '.'],
#  ['-',
#   'UPM-Kymmene',
#   'upgraded',
#   '`',
#   'in-line',
#   "'",
#   '`',
#   'underperform',
#   "'",
#   'Goldman',
#   'Sachs',
#   '.'],
#  ['Slump', 'Weir', 'leads', 'FTSE', 'record', 'high'],
#  ['Jan.',
#   '6',
#   '--',
#   'Ford',
#   'struggling',
#   'face',
#   'slowing',
#   'truck',
#   'SUV',
#   'sales',
#   'surfeit',
#   'up-to-date',
#   ',',
#   'got',
#   'ta',
#   '-have',
#   'cars',
#   '.'],
#  ['Royal',
#   'Mail',
#   "'breached",
#   'competition',
#   'law',
#   "'",
#   'delivery',
#   'service',
#   'changes',
#   ',',
#   'Ofcom',
#   'claims'],
#  ['The',
#   'cooperation',
#   'involve',
#   'Arena',
#   'Partners',
#   'buying',
#   '35',
#   '%',
#   'share',
#   'new',
#   'joint',
#   'venture',
#   'company',
#   ',',
#   'operating',
#   'Alma',
#   'Media',
#   "'s",
#   'home',
#   'sales',
#   ',',
#   'vehicle',
#   'consumer',
#   'advertising',
#   'marketplace',
#   'businesses',
#   '.'],
#  ['The',
#   'Efore',
#   'plant',
#   'Saarijarvi',
#   'central',
#   'Finland',
#   'one',
#   'largest',
#   'employers',
#   'region',
#   '.'],
#  ['However', 'short-term', 'rentals', 'becoming', 'popular', '.'],
#  ['EMSA',
#   'Deputy',
#   'Chairman',
#   'Board',
#   'Juri',
#   'Lember',
#   'told',
#   'BNS',
#   'Wednesday',
#   'first',
#   'time',
#   'heard',
#   'strike',
#   'Swedish',
#   'side',
#   'informed',
#   'Estonian',
#   'union',
#   'yet',
#   '.'],
#  ['Tesco',
#   'closes',
#   'new',
#   'chairman',
#   'Dixons',
#   'Carphone',
#   "'s",
#   'John',
#   'Allan',
#   'frame'],
#  ['The',
# ...
#   'excluding',
#   'non-recurring',
#   'items',
#   ',',
#   'totaled',
#   'EUR',
#   '0.2',
#   'mn',
#   ',',
#   'EUR',
#   '0.8',
#   'mn',
#   'corresponding',
#   'period',
#   '2006',
#   '.'],
#  ['Finnish',
#   'Metso',
#   'Paper',
#   'awarded',
#   'contract',
#   'rebuild',
#   'Sabah',
#   'Forest',
#   'Industries',
#   "'",
#   '(',
#   'SFI',
#   ')',
#   'pulp',
#   'mill',
#   'Sabah',
#   ',',
#   'Malaysia',
#   '.'],
#  ['Ruukki',
#   'forecast',
#   '15-20',
#   '%',
#   'annual',
#   'sales',
#   'growth',
#   'positive',
#   'pretax',
#   'result',
#   '2010',
#   '.'],
#  ['The', 'price', 'GMO', 'soy', '5', '%', '-7', '%', 'lower', 'non-GMO', '.'],
#  ['Finland',
#   "'s",
#   'Nokian',
#   'Tyres',
#   'Kazakhstan',
#   "'s",
#   'Ordabasy',
#   'Corporation',
#   'signed',
#   'agreement',
#   'build',
#   'plant',
#   'Astana',
#   'produce',
#   'car',
#   'tires',
#   ',',
#   'Ordabasy',
#   'chairman',
#   'Dinmukhamet',
#   'Idrisov',
#   'said',
#   'press',
#   'conference',
#   '.'],
#  ['With',
#   'sales',
#   '$',
#   '12.7',
#   'billion',
#   'last',
#   'twelve',
#   'months',
#   'ending',
#   'October',
#   ',',
#   '2010',
#   '9,200',
#   'stores',
#   '35',
#   'states',
#   ',',
#   'Dollar',
#   'General',
#   'nation',
#   "'s",
#   'largest',
#   'small',
#   'box',
#   'discount',
#   'retailer',
#   '.'],
#  ['GET',
#   'MIDNIGHTTRADER',
#   'IN',
#   'REALTIME',
#   ':',
#   'This',
#   'report',
#   'delayed',
#   '.'],
#  ['Danish',
#   'company',
#   'FLSmidth',
#   'acknowledged',
#   'violated',
#   'patent',
#   'held',
#   'Finnish',
#   'Metso',
#   '.'],
#  ['The',
#   'share',
#   'issue',
#   ',',
#   'derogating',
#   'pre-emptive',
#   'right',
#   'shareholders',
#   'comprising',
#   'six',
#   'million',
#   'new',
#   'shares',
#   'market',
#   'price',
#   ',',
#   'offered',
#   'subscription',
#   'shareholders',
#   ',',
#   'holders',
#   'capital',
#   'notes',
#   'professional',
#   'clients',
#   '.'],
#  ['Tielinja',
#   'generated',
#   'net',
#   'sales',
#   '7.5',
#   'mln',
#   'euro',
#   '$',
#   '9.6',
#   'mln',
#   '2005',
#   '.'],
#  ['Karachi',
#   ',',
#   'Sept.',
#   '14',
#   '--',
#   'Ixonos',
#   ',',
#   'world',
#   'leader',
#   'development',
#   'integration',
#   'solutions',
#   'handheld',
#   'devices',
#   ',',
#   'announced',
#   'implementing',
#   'touch',
#   'screen',
#   'mobile',
#   'user',
#   'interface',
#   'solution',
#   'Intel',
#   'Atom',
#   'processor',
#   'Z6xx',
#   'based',
#   'smartphones',
#   '.'],
#  ['``',
#   'Neste',
#   'Oil',
#   'working',
#   '20',
#   'research',
#   'communities',
#   'Europe',
#   ',',
#   'America',
#   ',',
#   'Africa',
#   ',',
#   'Asia',
#   ',',
#   'Australia',
#   'develop',
#   'introduce',
#   'new',
#   'raw',
#   'materials',
#   '.'],
#  ['The',
#   'new',
#   'agreement',
#   ',',
#   'expands',
#   'long-established',
#   'cooperation',
#   'companies',
#   ',',
#   'involves',
#   'transfer',
#   'certain',
#   'engineering',
#   'documentation',
#   'functions',
#   'Larox',
#   'Etteplan',
#   '.'],
#  ['It', "'s", '.'],
#  ['took', '$', 'ENDP', 'long', ',', 'using', 'VWAP', 'guide'],
#  ['Despite',
#   'sales',
#   'growth',
#   ',',
#   'UK',
#   "'s",
#   'Tesco',
#   'cautions',
#   'recovery',
#   'bumpy'],
#  ['In',
#   'Finland',
#   ',',
#   'metal',
#   'sector',
#   'company',
#   'Componenta',
#   'laying',
#   'temporarily',
#   'staff',
#   'Pori',
#   'mill',
#   'Christmas',
#   '2008',
#   'till',
#   '6',
#   'January',
#   '2009',
#   '.'],
#  ['In',
#   'Middle',
#   'East',
#   '&',
#   'North',
#   'Africa',
#   ',',
#   'Tecnotree',
#   'grown',
#   'considerably',
#   'recent',
#   'years',
#   '.'],
#  ['Both',
#   'operating',
#   'profit',
#   'net',
#   'sales',
#   'six-month',
#   'period',
#   'increased',
#   ',',
#   'respectively',
#   'EUR18',
#   '.1',
#   'EUR127',
#   '.6',
#   ',',
#   'compared',
#   'corresponding',
#   'period',
#   '2006',
#   '.'],
#  ['Insurer',
#   'Axa',
#   '(',
#   'PAR',
#   ':',
#   'CS',
#   ')',
#   'slid',
#   '5.35',
#   '%',
#   'EUR',
#   '14.15',
#   ',',
#   'Citigroup',
#   'ING',
#   'slashed',
#   'targets',
#   'stock',
#   '.'],
#  ['The',
#   'order',
#   'values',
#   'EUR',
#   '6.9',
#   'mn',
#   ',',
#   'consists',
#   'design',
#   'services',
#   'hardware',
#   'software',
#   'licences',
#   '.'],
#  ['Scanfil', 'also', 'issued', 'profit', 'warning', '.'],
#  ['A',
#   'spokesman',
#   'said',
#   ':',
#   '``',
#   'The',
#   'food',
#   'store',
#   'center',
#   ',',
#   'subject',
#   'council',
#   'local',
#   'support',
#   ',',
#   'could',
#   'comprise',
#   'supermarket',
#   'smaller',
#   'store',
#   'niche',
#   'outlets',
#   ',',
#   'firmed',
#   'following',
#   'consultation',
#   'council',
#   'local',
#   'community',
#   'regarding',
#   'appropriate',
#   'uses',
#   'occupiers',
#   '.',
#   '``'],
#  ['The', 'bond', 'value', 'EUR150m', 'maturity', '4', 'years', '.'],
#  ['MillerCoors', 'Board', 'Names', 'Gavin', 'Hattersley', 'Interim', 'CEO'],
#  ['Airbus',
#   'attempt',
#   'evacuate',
#   '873',
#   'people',
#   'within',
#   '90',
#   'seconds',
#   '.'],
#  ['First',
#   'quarter',
#   'underlying',
#   'operating',
#   'profit',
#   'rose',
#   '41',
#   'mln',
#   'eur',
#   '33',
#   'mln',
#   'year',
#   'earlier',
#   '.'],
#  ['EPS',
#   'quarter',
#   'EUR0',
#   '.00',
#   ',',
#   'compared',
#   'EUR0',
#   '.01',
#   'third',
#   'quarter',
#   '2008',
#   ',',
#   'representing',
#   'Group',
#   'net',
#   'sales',
#   'third',
#   'quarter',
#   'EUR15',
#   '.3',
#   ',',
#   '2.8',
#   '%',
#   'compared',
#   'EUR14',
#   '.9',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['Royal', 'Dutch', 'Shell', 'profit', 'rises', ';', 'dividend', '4', '%'],
#  ['Meanwhile',
#   ',',
#   'Electrowatt-Ekono',
#   'Philippines',
#   ',',
#   'Inc.',
#   'also',
#   'awarded',
#   'three-year',
#   'operation',
#   'maintenance',
#   '(',
#   'O',
#   '&',
#   'M',
#   ')',
#   'contract',
#   'FR',
#   'Cement',
#   'Corporation',
#   '.'],
#  ['The',
#   'agreement',
#   'includes',
#   'application',
#   'maintenance',
#   'support',
#   'services',
#   '.'],
#  ['``', 'Nokia', 'interested', 'bring', 'Nokia', 'market', '.', '``'],
#  ['Affecto',
#   'expects',
#   'net',
#   'sales',
#   'whole',
#   '2010',
#   'increase',
#   '2009',
#   'level',
#   'reached',
#   'EUR',
#   '103',
#   'million',
#   '.'],
#  ['The',
#   'report',
#   'profiles',
#   '158',
#   'companies',
#   'including',
#   'many',
#   'key',
#   'niche',
#   'players',
#   'including',
#   'major',
#   'Nonwovens',
#   'manufacturers',
#   'Ahlstrom',
#   'Corporation',
#   ',',
#   'Asahi',
#   'Kasei',
#   'Corporation',
#   ',',
#   'Buckeye',
#   'Technologies',
#   ',',
#   'Inc.',
#   ',',
#   'EI',
#   '.'],
#  ['The',
#   'lay-offs',
#   'affect',
#   '240',
#   'people',
#   'total',
#   '320',
#   'Okmetic',
#   'employees',
#   'Finland',
#   '.'],
#  ['``',
#   'The',
#   'acquisition',
#   'Elektros',
#   'Pavara',
#   'completes',
#   'KONE',
#   "'s",
#   'market',
#   'expansion',
#   'strategy',
#   'Baltic',
#   'Countries',
#   '.'],
#  ['18',
#   'May',
#   '2010',
#   '-',
#   'Finnish',
#   'electronics',
#   'producer',
#   'Elcoteq',
#   'SE',
#   'HEL',
#   ':',
#   'ELQAV',
#   'said',
#   'today',
#   'signed',
#   'extensive',
#   'cooperation',
#   'agreement',
#   'industrialisation',
#   ',',
#   'manufacturing',
#   ',',
#   'distribution',
#   'after-market',
#   'services',
#   'mobile',
#   'phones',
#   'Japan',
#   "'s",
#   'Sharp',
#   'TYO',
#   ':',
#   '6753',
#   '.'],
#  ['Morrisons', 'book', 'second', 'consecutive', 'quarter', 'sales', 'growth'],
#  ['Marimekko',
#   'today',
#   '(',
#   '20',
#   'November',
#   ')',
#   'signed',
#   'license',
#   'agreement',
#   'Swedish',
#   'chain',
#   ',',
#   'whereby',
#   'Marimekko',
#   'license',
#   'popular',
#   'patterns',
#   '1950s',
#   ',',
#   '1960s',
#   '1970s',
#   'H',
#   '&',
#   'M',
#   '.'],
#  ['quick',
#   ',',
#   '$',
#   'FIO',
#   '21.35',
#   ',',
#   'market',
#   'tanking',
#   ',',
#   'scaling',
#   'longs'],
#  ['The',
#   'announcement',
#   'pushed',
#   'Freenet',
#   'shares',
#   '6.3',
#   '%',
#   ',',
#   'EUR0',
#   '.71',
#   ',',
#   'Frankfurt',
#   'trade',
#   'EUR10',
#   '.65',
#   'investors',
#   'gave',
#   'hope',
#   'United',
#   'Internet',
#   'AG',
#   'Drillisch',
#   'would',
#   'pursue',
#   'takeover',
#   'breakup',
#   'Freenet',
#   '.'],
#  ['Finnish',
#   'telecoms',
#   'software',
#   'developer',
#   'Tecnomen',
#   'Oyj',
#   'said',
#   'December',
#   '5',
#   ',',
#   '2006',
#   '$',
#   '3.3',
#   'mln',
#   '(',
#   '2.5',
#   'mln',
#   'euro',
#   ')',
#   'order',
#   'supply',
#   'expansion',
#   'charging',
#   'messaging',
#   'systems',
#   'mobile',
#   'fixed',
#   'networks',
#   'Brasil',
#   'Telecom',
#   '.'],
#  ['CompaniesUnilever', 'sales', 'lifted', 'ice', 'cream', 'soft', 'economy'],
#  ['EPS', 'dropped', 'EUR0', '.2', 'EUR0', '.3', '.'],
#  ['@',
#   'saltwaternurse',
#   '$',
#   'INO',
#   'test',
#   '10',
#   'next',
#   'days',
#   '.',
#   'time',
#   'take',
#   'profits',
#   '.',
#   'hedge',
#   'puts',
#   '.'],
#  ['No', 'financial', 'information', 'provided', '.'],
#  ['EasyJet', 'attracts', 'passengers', 'June', 'still', 'lags', 'Ryanair'],
#  ['Morning', 'Agenda', ':', 'Shire', "'s", 'Deal', 'NPS'],
#  ['Metso',
#   'supply',
#   'equipment',
#   'two',
#   'process',
#   'lines',
#   'Northland',
#   'Resources',
#   "'",
#   'new',
#   'Kaunisvaara',
#   'iron',
#   'ore',
#   'project',
#   'Sweden',
#   'exploits',
#   'Tapuli',
#   'Sahavaara',
#   'iron',
#   'ore',
#   'deposits',
#   '.'],
#  ['Under',
#   'agreement',
#   'Biohit',
#   'becomes',
#   'focus',
#   'supplier',
#   'pipettors',
#   'disposable',
#   'pipettor',
#   'tips',
#   'VWR',
#   'customers',
#   'throughout',
#   'Europe',
#   '.'],
#  ['The',
#   'company',
#   "'s",
#   'previous',
#   'estimate',
#   'lower',
#   'revenue',
#   'year-ago',
#   'EUR',
#   '93.9',
#   'million',
#   '.'],
#  ['Earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'dropped',
#   'EUR',
#   '0.21',
#   'EUR',
#   '0.31',
#   '.'],
#  ['Bids',
#   'offers',
#   'include',
#   'least',
#   '1,000',
#   'shares',
#   'value',
#   'shares',
#   'must',
#   'correspond',
#   'least',
#   'EUR4',
#   ',000',
#   '.'],
#  ['Earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'amounted',
#   'loss',
#   'EUR0',
#   '.06',
#   '.'],
#  ['NetApp',
#   'downgraded',
#   'Macquarie',
#   'underperform',
#   '.',
#   '$',
#   '22.00',
#   'PT',
#   '.',
#   'https',
#   ':',
#   '//t.co/XCNgws0t4q',
#   '$',
#   'NTAP',
#   '#',
#   'NTAP',
#   'via',
#   '@',
#   'RatingsNetwork'],
#  ['``',
#   'Russia',
#   'ready',
#   'participate',
#   'open',
#   'tender',
#   'Lattelecom',
#   "'s",
#   'privatization',
#   '.'],
#  ['Technopolis',
#   'St.',
#   'Petersburg',
#   'government',
#   'signed',
#   'cooperation',
#   'memorandum',
#   'October',
#   '2005',
#   'set',
#   'techno-park',
#   'Neudorf',
#   'production',
#   'zone',
#   'village',
#   'Strelny',
#   ',',
#   'St.',
#   'Petersburg',
#   'suburbs',
#   '.'],
#  ['The',
#   'owners',
#   'participated',
#   'business',
#   'operations',
#   'company',
#   'continue',
#   'Poyry',
#   "'s",
#   'employment',
#   'transaction',
#   '.'],
#  ['The',
#   'goal',
#   'secure',
#   'company',
#   "'s",
#   'profitability',
#   'competitiveness',
#   '.'],
#  ['However',
#   ',',
#   'company',
#   'saw',
#   'net',
#   'profit',
#   'third',
#   'quarter',
#   'EUR',
#   '1.4',
#   'million',
#   'EUR',
#   '1.5',
#   'million',
#   'corresponding',
#   'period',
#   '2009',
#   '.'],
#  ['Neste',
#   'oil',
#   "'s",
#   'board',
#   'proposed',
#   '1.00',
#   'eur',
#   'dividend',
#   'full-year',
#   '2007',
#   ',',
#   'compared',
#   '0.90',
#   'eur',
#   'year',
#   'ago',
#   '.'],
#  ['Basware',
#   'Einvoices',
#   'Oy',
#   'merged',
#   'parent',
#   'company',
#   'present',
#   'fiscal',
#   'period',
#   '.'],
#  ['#',
#   'Fintech',
#   'provider',
#   '$',
#   'CAFN',
#   'Cachet',
#   'Financial',
#   'Solutions',
#   'Surging',
#   'Forward',
#   'today',
#   'post',
#   'earnings',
#   'Up',
#   '+13.26',
#   '%',
#   'https',
#   ':',
#   '//t.co/9BJ3csk2i9',
#   '$',
#   'JKHY',
#   '$',
#   'FISV',
#   '#',
#   'Momo'],
#  ['Before',
#   'Kemira',
#   "'s",
#   'installation',
#   'NordAlu',
#   'producing',
#   '3,500',
#   'tons',
#   'liquid',
#   'solid',
#   'aluminum',
#   'waste',
#   'per',
#   'year',
#   '.'],
#  ['He',
#   'Chartered',
#   'Accountant',
#   'British',
#   'Columbia',
#   'Alberta',
#   'well',
#   'Certified',
#   'Public',
#   'Accountant',
#   'Washington',
#   'State',
#   '.'],
#  ['`',
#   'Very',
#   'recommendable',
#   "'",
#   'Nokian',
#   'Z',
#   'G2',
#   'according',
#   '`',
#   'ADAC',
#   'judgement',
#   "'",
#   'latest',
#   'summer',
#   'tyre',
#   'test',
#   'German',
#   'automobile',
#   'association',
#   'ADAC',
#   '.'],
#  ['-',
#   'The',
#   'Group',
#   '-¦',
#   'result',
#   'taxes',
#   'loss',
#   'EUR',
#   '0.6',
#   '(',
#   '+0.6',
#   ')',
#   'million',
#   '.'],
#  ['-',
#   'Cash',
#   'flow',
#   'operating',
#   'activities',
#   'investments',
#   'EUR',
#   '0.8',
#   '-1.2',
#   'million',
#   '.'],
#  ['Viking', 'Line', 'canceled', 'services', '.'],
#  ['Exel', 'headquartered', 'Mantyharju', 'Finland', '.'],
#  ['Stora',
#   'Chief',
#   'Executive',
#   'Jouko',
#   'Karvinen',
#   'described',
#   'Russian',
#   'tariff',
#   'hikes',
#   'threat',
#   'future',
#   'forest',
#   'products',
#   'industry',
#   'Finland',
#   '.'],
#  ['After',
#   'Barclays',
#   'Bank',
#   'America',
#   ',',
#   'Citigroup',
#   'blockchain',
#   'sight'],
#  ['Google',
#   ',',
#   'Inc.',
#   'completes',
#   'acquisition',
#   'ICOA',
#   ',',
#   'Inc.',
#   'http',
#   ':',
#   '//stks.co/nFEI',
#   '$',
#   'ICOA',
#   '$',
#   'GOOG'],
#  ['$',
#   'TSLA',
#   'looking',
#   'good',
#   '..',
#   "'d",
#   'love',
#   'see',
#   'basing',
#   'action',
#   ',',
#   'letting',
#   'RSI',
#   'take',
#   'breather',
#   '.',
#   'http',
#   ':',
#   '//stks.co/g1T7c'],
#  ['Finnish',
#   'plumbing',
#   'heating',
#   'systems',
#   'supplier',
#   'Uponor',
#   "'s",
#   'net',
#   'sales',
#   'continuing',
#   'operations',
#   'decreased',
#   '9.4',
#   '%',
#   '2008',
#   'EUR',
#   '949.2',
#   'mn',
#   'EUR',
#   '1,047.4',
#   'mn',
#   '2007',
#   '.'],
#  ['This',
#   'location',
#   'makes',
#   'mall',
#   'convenient',
#   'place',
#   'shop',
#   'consumers',
#   'three',
#   'large',
#   'residential',
#   'areas',
#   'nearby',
#   ':',
#   'Jaroszowka',
#   ',',
#   'Wysockiego',
#   'Zgody',
#   '.'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'Kesko',
#   'Group',
#   'ending',
#   'loyal',
#   'customer',
#   'cooperation',
#   '.'],
#  ['The',
#   'casing',
#   'comprises',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'first',
#   'side',
#   'vat',
#   'segment',
#   'second',
#   'side',
#   'casing',
#   'member',
#   'provided',
#   'second',
#   'side',
#   'vat',
#   'segment',
#   ',',
#   'least',
#   'first',
#   'side',
#   'casing',
#   'member',
#   'pivotable',
#   'rotation',
#   'axis',
#   '.'],
#  ['Finland-based',
#   'Elcoteq',
#   'SE',
#   ',',
#   'privately',
#   'held',
#   'provider',
#   'electronics',
#   'manufacturing',
#   'services',
#   'communications',
#   'companies',
#   ',',
#   'said',
#   'Thursday',
#   'signed',
#   'long-term',
#   'manufacturing',
#   'supply',
#   'deal',
#   'communications',
#   'equipment',
#   'company',
#   'Andrew',
#   'Corp.',
#   '.'],
#  ['In',
#   'Q1',
#   '2009',
#   ',',
#   'Bank',
#   '+àland',
#   "'s",
#   'net',
#   'interest',
#   'income',
#   'weakened',
#   '10',
#   '%',
#   'EUR',
#   '9.1',
#   'mn',
#   '.'],
#  ['RBS',
#   'Pays',
#   '$',
#   '1.7',
#   'Billion',
#   'Scrap',
#   'U.K.',
#   'Treasury',
#   "'s",
#   'Dividend',
#   'Rights'],
#  ['Increased',
#   'trust',
#   'clients',
#   'YIT',
#   'seen',
#   'apartment',
#   'sales',
#   'accelerated',
#   '.'],
#  ['Talvivaara',
#   'Mining',
#   'Company',
#   'Plc',
#   'Talvivaara',
#   'Mining',
#   'Company',
#   'internationally',
#   'significant',
#   'base',
#   'metals',
#   'producer',
#   'primary',
#   'focus',
#   'nickel',
#   'zinc',
#   'using',
#   'technology',
#   'known',
#   'bioheapleaching',
#   'extract',
#   'metals',
#   'ore',
#   '.'],
#  ['Operating',
#   'profit',
#   '2009',
#   'lower',
#   'outlook',
#   'published',
#   'earlier',
#   '.'],
#  ['Less', 'ten', 'people', 'face', 'pension', 'agreements', '.'],
#  ['The',
#   'company',
#   "'s",
#   'consolidated',
#   'operating',
#   'profit',
#   'amounted',
#   'EUR',
#   '15.86',
#   'mn',
#   ',',
#   'EUR',
#   '4.14',
#   'mn',
#   'year-on-year',
#   '.'],
#  ['AstraZeneca', 'Buy', 'ZS', 'Pharma', '$', '2.7', 'Billion'],
#  ['Finnish',
#   'waste',
#   'management',
#   'cleaning',
#   'group',
#   'Lassila',
#   '&',
#   'Tikanoja',
#   'Oyj',
#   '(',
#   'L',
#   '&',
#   'T',
#   ')',
#   'net',
#   'profit',
#   'went',
#   '32.2',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '47.7',
#   'mln',
#   ')',
#   '2007',
#   '35.3',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '52.3',
#   'mln',
#   ')',
#   '2006',
#   '.'],
#  ['The',
#   'operating',
#   'margin',
#   'Aker',
#   'Yards',
#   'Cruise',
#   '&',
#   'Ferries',
#   'division',
#   'went',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['HELSINKI',
#   'Thomson',
#   'Financial',
#   '-',
#   'Shares',
#   'Cargotec',
#   'fell',
#   'sharply',
#   'early',
#   'afternoon',
#   'trade',
#   'cargo',
#   'handling',
#   'group',
#   'posted',
#   'surprise',
#   'drop',
#   'April-June',
#   'profits',
#   ',',
#   'overshadowed',
#   'large',
#   'number',
#   'new',
#   'orders',
#   'received',
#   'three',
#   'months',
#   '.'],
#  ['The',
#   'program',
#   "'s",
#   'target',
#   'structural',
#   'cost',
#   'reductions',
#   'EUR',
#   '30mn',
#   '2009',
#   '.'],
#  ['Our',
#   'tools',
#   'specifically',
#   'designed',
#   'needs',
#   'business',
#   'users',
#   'ICT',
#   'experts',
#   'mind',
#   '.'],
#  ...]

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
stemedata =[]
for message in stop_token:
  st = [ps.stem(word) for word in message]
  stemedata.append(st)

# %%
stemedata
# Out:
# [['the',
#   'geosolut',
#   'technolog',
#   'leverag',
#   'benefon',
#   "'s",
#   'gp',
#   'solut',
#   'provid',
#   'locat',
#   'base',
#   'search',
#   'technolog',
#   ',',
#   'commun',
#   'platform',
#   ',',
#   'locat',
#   'relev',
#   'multimedia',
#   'content',
#   'new',
#   'power',
#   'commerci',
#   'model',
#   '.'],
#  ['$', 'esi', 'low', ',', '$', '1.50', '$', '2.50', 'bk', 'real', 'possibl'],
#  ['for',
#   'last',
#   'quarter',
#   '2010',
#   ',',
#   'componenta',
#   "'s",
#   'net',
#   'sale',
#   'doubl',
#   'eur131m',
#   'eur76m',
#   'period',
#   'year',
#   'earlier',
#   ',',
#   'move',
#   'zero',
#   'pre-tax',
#   'profit',
#   'pre-tax',
#   'loss',
#   'eur7m',
#   '.'],
#  ['accord',
#   'finnish-russian',
#   'chamber',
#   'commerc',
#   ',',
#   'major',
#   'construct',
#   'compani',
#   'finland',
#   'oper',
#   'russia',
#   '.'],
#  ['the',
#   'swedish',
#   'buyout',
#   'firm',
#   'sold',
#   'remain',
#   '22.4',
#   'percent',
#   'stake',
#   ',',
#   'almost',
#   'eighteen',
#   'month',
#   'take',
#   'compani',
#   'public',
#   'finland',
#   '.'],
#  ['$', 'spi', 'would', "n't", 'surpris', 'see', 'green', 'close'],
#  ['shell',
#   "'s",
#   '$',
#   '70',
#   'billion',
#   'bg',
#   'deal',
#   'meet',
#   'sharehold',
#   'skeptic'],
#  ['ssh',
#   'commun',
#   'secur',
#   'corp',
#   'stock',
#   'exchang',
#   'releas',
#   'octob',
#   '14',
#   ',',
#   '2008',
#   'at',
#   '2:45',
#   'pm',
#   'the',
#   'compani',
#   'updat',
#   'full',
#   'year',
#   'outlook',
#   'estim',
#   'result',
#   'remain',
#   'loss',
#   'full',
#   'year',
#   '.'],
#  ['kone',
#   "'s",
#   'net',
#   'sale',
#   'rose',
#   '14',
#   '%',
#   'year-on-year',
#   'first',
#   'nine',
#   'month',
#   '2008',
#   '.'],
#  ['the',
#   'stockmann',
#   'depart',
#   'store',
#   'total',
#   'floor',
#   'space',
#   '8,000',
#   'squar',
#   'metr',
#   'stockmann',
#   "'s",
#   'invest',
#   'project',
#   'price',
#   'tag',
#   'eur',
#   '12',
#   'million',
#   '.'],
#  ['circul',
#   'revenu',
#   'increas',
#   '5',
#   '%',
#   'finland',
#   '4',
#   '%',
#   'sweden',
#   '2008',
#   '.'],
#  ['$',
#   'sap',
#   'q1',
#   'disappoint',
#   '#',
#   'softwar',
#   'licens',
#   '.',
#   'real',
#   'problem',
#   '?',
#   '#',
#   'cloud',
#   'growth',
#   'trail',
#   '$',
#   'msft',
#   '$',
#   'orcl',
#   '$',
#   'goog',
#   '$',
#   'crm',
#   '$',
#   'adb',
#   'http',
#   ':',
#   '//t.co/jndphllzq5'],
#  ['the',
#   'subdivis',
#   'made',
#   'sale',
#   'revenu',
#   'last',
#   'year',
#   'eur',
#   '480.7',
#   'million',
#   'eur',
#   '414.9',
#   'million',
#   '2008',
#   ',',
#   'oper',
#   'profit',
#   'eur',
#   '44.5',
#   'million',
#   'eur',
#   '7.4',
#   'million',
#   '.'],
#  ['vike', 'line', 'cancel', 'servic', '.'],
#  ['ahlstrom',
#   'corpor',
#   'stock',
#   'exchang',
#   'announc',
#   '7.2.2007',
#   '10.30',
#   'a',
#   'total',
#   '56,955',
#   'new',
#   'share',
#   'ahlstrom',
#   'corpor',
#   'subscrib',
#   'option',
#   'right',
#   'compani',
#   "'s",
#   'stock',
#   'option',
#   'program',
#   'i',
#   '2001',
#   'ii',
#   '2001',
#   '.'],
#  ['$', 'fb', 'gone', 'green', 'day'],
#  ['$',
#   'msft',
#   'sql',
#   'server',
#   'revenu',
#   'grew',
#   'double-digit',
#   'sql',
#   'server',
#   'premium',
#   'revenu',
#   'grow',
#   '30',
#   '%',
#   'http',
#   ':',
#   '//stks.co/ir2f'],
#  ['accord',
#   'l+ñnnen',
#   'tehtaat',
#   "'s",
#   'ceo',
#   'matti',
#   'karppinen',
#   ',',
#   'compani',
#   'aim',
#   'deliv',
#   'fish',
#   'product',
#   'custom',
#   'day',
#   'earlier',
#   'current',
#   '.'],
#  ['the',
#   'compani',
#   "'s",
#   'share',
#   'quot',
#   'nasdaq',
#   'omx',
#   'helsinki',
#   'rautaruukki',
#   'oyj',
#   ':',
#   'rtrk',
#   '.'],
#  ['elcoteq', 'se', 'list', 'nasdaq', 'omx', 'helsinki', 'ltd.', '.'],
#  ['two',
#   'contract',
#   'turntabl',
#   'anod',
#   'vibrocompactor',
#   'deliv',
#   'gansu',
#   'hualu',
#   'aluminum',
#   'co',
#   'ltd',
#   'anoth',
#   'unnam',
#   'costum',
#   '.'],
#  ['aviva',
#   ',',
#   'friend',
#   'life',
#   'top',
#   'forecast',
#   'ahead',
#   '5.6',
#   'billion',
#   'pound',
#   'merger'],
#  ['in',
#   'stead',
#   'base',
#   'soft',
#   'drink',
#   ',',
#   'usual',
#   ',',
#   'teho',
#   'energi',
#   'drink',
#   'made',
#   'fresh',
#   'water',
#   '.'],
#  ['the',
#   'compani',
#   'plan',
#   'increas',
#   'unit',
#   "'s",
#   'specialist',
#   'staff',
#   'sever',
#   'dozen',
#   '--',
#   'depend',
#   'market',
#   'situat',
#   '2010',
#   '.'],
#  ['the',
#   'compani',
#   'close',
#   'last',
#   'year',
#   'turnov',
#   'four',
#   'million',
#   'euro',
#   '.'],
#  ['shire', 'ceo', 'step', 'drive', 'get', 'baxalta', 'board', 'talk'],
#  ['costco',
#   ':',
#   'a',
#   'premier',
#   'retail',
#   'dividend',
#   'play',
#   'http',
#   ':',
#   '//t.co/fa5cnh2t0t',
#   '$',
#   'cost'],
#  ['the',
#   'five-storey',
#   ',',
#   'eco-effici',
#   'build',
#   'gross',
#   'floor',
#   'area',
#   '15,000',
#   'sq',
#   'm.',
#   'it',
#   'also',
#   'includ',
#   'apart',
#   '.'],
#  ['the',
#   'first',
#   'instal',
#   'cinema',
#   'seri',
#   'conclud',
#   'profil',
#   'finnish',
#   'inventor',
#   'olavi',
#   'linden',
#   ',',
#   'whose',
#   'person',
#   'artist',
#   'journey',
#   'work',
#   'fiskar',
#   'led',
#   'dozen',
#   'design',
#   'award',
#   '.'],
#  ['all', 'welcom', '.'],
#  ['stockmann',
#   'swedish',
#   'sector',
#   'compani',
#   'ab',
#   'lindex',
#   'enter',
#   'agreement',
#   'septemb',
#   '30',
#   ',',
#   '2007',
#   ',',
#   'wherebi',
#   'stockmann',
#   ',',
#   'wholly-own',
#   'subsidiari',
#   ',',
#   'make',
#   'public',
#   'tender',
#   'offer',
#   'lindex',
#   "'s",
#   'issu',
#   'share',
#   '.'],
#  ['huhtamaki',
#   'oyj',
#   'stock',
#   'exchang',
#   'releas',
#   ',',
#   '16.9.2008',
#   'at',
#   '13.32',
#   'huhtamaki',
#   "'s",
#   'capit',
#   'market',
#   'day',
#   'institut',
#   'investor',
#   'analyst',
#   'held',
#   'espoo',
#   ',',
#   'septemb',
#   '16',
#   ',',
#   '2008',
#   'start',
#   '13.30',
#   'pm',
#   'finnish',
#   'time',
#   '.'],
#  ['``', 'we', 'pleas', 'welcom', 'tapek', 'noma', 'cramo', 'group', '.'],
#  ['-', 'profit', 'tax', 'eur', '105.9', '82.7', 'million', '.'],
#  ['royal',
#   'dutch',
#   'shell',
#   'buy',
#   'bg',
#   'group',
#   'nearli',
#   '$',
#   '70',
#   'billion'],
#  ['financialwir',
#   'tm',
#   'press',
#   'releas',
#   'servic',
#   ',',
#   'receiv',
#   'compens',
#   'news',
#   ',',
#   'opinion',
#   'distribut',
#   '.'],
#  ['assa',
#   'abloy',
#   'kaupth',
#   'bank',
#   'gave',
#   '`',
#   'neutral',
#   "'",
#   'recommend',
#   'share',
#   'price',
#   'target',
#   '174',
#   'crown',
#   '$',
#   '24.7',
#   '-',
#   '19',
#   'euro',
#   'swedish',
#   'lock',
#   'maker',
#   'assa',
#   'abloy',
#   'ab',
#   '.'],
#  ['the',
#   'item',
#   'includ',
#   'restructur',
#   'cost',
#   'eur1',
#   '.6',
#   ',',
#   'year',
#   'earlier',
#   'eur13',
#   '.1',
#   'm.',
#   'dilut',
#   'ep',
#   'stood',
#   'eur0',
#   '.3',
#   'versu',
#   'loss',
#   'per',
#   'share',
#   'eur',
#   '0.1',
#   '.'],
#  ['in', '2005', 'bank', 'post', 'net', 'profit', 'lt', '8.2', 'mn', '.'],
#  ['$',
#   'aapl',
#   'afternoon',
#   'selloff',
#   'usual',
#   'brutal',
#   '.',
#   'get',
#   'readi',
#   'lose',
#   'ton',
#   'money',
#   '.'],
#  ['$',
#   'tsla',
#   'recal',
#   'pretti',
#   'much',
#   'everi',
#   'singl',
#   'model',
#   'x',
#   '@',
#   'cnnbrk',
#   'got',
#   'short',
#   'even',
#   'work',
#   'jump',
#   'money',
#   'trade'],
#  ['dolc',
#   '&',
#   'gabbana',
#   'ask',
#   'european',
#   'union',
#   'declar',
#   'marimekko',
#   'corpor',
#   "'s",
#   '``',
#   'unikko',
#   '``',
#   'floral',
#   'pattern',
#   'trademark',
#   'invalid',
#   ',',
#   'continu',
#   'disput',
#   'two',
#   'compani',
#   '.'],
#  ['intercontinent',
#   'hotel',
#   'first-quart',
#   'global',
#   'room',
#   'revenu',
#   'lag',
#   'estim'],
#  ['accord',
#   'finnish',
#   'pension',
#   'insur',
#   'compani',
#   'varma',
#   ',',
#   'varma',
#   'recipi',
#   'two',
#   'third',
#   'revenu',
#   'earnings-rel',
#   'pension',
#   'cover',
#   'competit',
#   'tender',
#   'finland',
#   '.'],
#  ['a',
#   'portion',
#   ',',
#   '$',
#   '12.5',
#   'million',
#   ',',
#   'record',
#   'part',
#   'win',
#   'prior',
#   'patent',
#   'disput',
#   'finnish',
#   'phone',
#   'maker',
#   'nokia',
#   'oyj',
#   '.'],
#  ['l',
#   '&',
#   'g',
#   'still',
#   'pay',
#   'price',
#   'dividend',
#   'cut',
#   'crisi',
#   ',',
#   'chief',
#   'say'],
#  ['the',
#   'volum',
#   'invest',
#   'two',
#   'phase',
#   'project',
#   'estim',
#   'usd',
#   '300mn',
#   '(',
#   'eur',
#   '215.03',
#   'mn',
#   ')',
#   '.'],
#  ['russia',
#   'account',
#   '9',
#   '%',
#   'lagarder',
#   'magazin',
#   'divis',
#   "'s",
#   'revenu',
#   ',',
#   'eur',
#   '114.40',
#   'mn',
#   '(',
#   'usd',
#   '148.11',
#   'mn',
#   ')',
#   '2009',
#   ',',
#   'usa',
#   '-',
#   '18',
#   '%',
#   '.'],
#  ['the',
#   'compani',
#   'also',
#   'estim',
#   'alreadi',
#   'carri',
#   'invest',
#   'lead',
#   'increas',
#   'net',
#   'sale',
#   '2010',
#   '2009',
#   'reach',
#   'eur',
#   '141.7',
#   'million',
#   '.'],
#  ['profit', 'account', 'period', 'eur', '0.3', 'mn', '.'],
#  ['the',
#   'six',
#   'breweri',
#   'record',
#   '5.2',
#   'percent',
#   'growth',
#   'domest',
#   'beer',
#   'sale',
#   'last',
#   'year',
#   '270.21',
#   'million',
#   'liter',
#   ',',
#   '256.88',
#   'million',
#   'liter',
#   'sold',
#   '2005',
#   '.'],
#  ['in',
#   'august-octob',
#   '2010',
#   ',',
#   'compani',
#   "'s",
#   'result',
#   'tax',
#   'total',
#   'eur',
#   '9.6',
#   'mn',
#   ',',
#   'eur',
#   '0.5',
#   'mn',
#   'correspond',
#   'period',
#   '2009',
#   '.'],
#  ['systeemitiimi',
#   "'s",
#   'sale',
#   'project',
#   'resourc',
#   'also',
#   'strengthen',
#   ',',
#   'director',
#   'paul',
#   'skogberg',
#   'said',
#   '.'],
#  ['tesco', 'share', 'price', 'jump', 'q3', 'sale', 'top', 'estim'],
#  ['the', 'fine', 'print', '.'],
#  ['the',
#   'price',
#   'log',
#   'clearli',
#   'improv',
#   '2009',
#   'also',
#   'price',
#   'pulpwood',
#   'gone',
#   '.'],
#  ['thu',
#   ',',
#   'sysopen',
#   'digia',
#   ',',
#   'accord',
#   'chapter',
#   '14',
#   'section',
#   '21',
#   'finnish',
#   'compani',
#   'act',
#   '29.9.1978',
#   '-',
#   '734',
#   ',',
#   'obtain',
#   'titl',
#   'share',
#   'sentera',
#   'redeem',
#   '.'],
#  ['dilut',
#   'earn',
#   'per',
#   'share',
#   '(',
#   'ep',
#   ')',
#   'fell',
#   'eur',
#   '0.63',
#   'eur',
#   '1.71',
#   '.'],
#  ['at',
#   '3:37',
#   'p.m.',
#   'eastern',
#   'time',
#   ',',
#   'block',
#   '2,400',
#   'contract',
#   'chang',
#   'hand',
#   'bid',
#   'price',
#   '$',
#   '0.45',
#   '.'],
#  ['some',
#   'recent',
#   'technolog',
#   'deliveri',
#   'includ',
#   'refineri',
#   'technolog',
#   'anrak',
#   'aluminium',
#   ',',
#   'iron',
#   'ore',
#   'pellet',
#   'plant',
#   'tata',
#   'steel',
#   'iron',
#   'ore',
#   'sinter',
#   'plant',
#   'bhushan',
#   'steel',
#   '.'],
#  ['$',
#   'vip',
#   'similar',
#   'pattern',
#   'like',
#   'begin',
#   'may',
#   '.',
#   'did',
#   'u',
#   'sell',
#   '?',
#   'same',
#   '..',
#   'go',
#   'much',
#   'higher',
#   'drop',
#   '.'],
#  ['the', 'firm', 'gener', 'sale', '187', 'mln', 'eur', '2005', '.'],
#  ['stora',
#   'enso',
#   'also',
#   'meet',
#   'labor',
#   'author',
#   ',',
#   'employ',
#   'econom',
#   'develop',
#   'centr',
#   'repres',
#   'govern',
#   'order',
#   'find',
#   'solut',
#   '.'],
#  ['astrazeneca', 'profit', 'sale', 'stalwart', 'fade'],
#  ['rt',
#   '@',
#   'andrewnyquist',
#   'chartolog',
#   ':',
#   'yahoo',
#   ':',
#   'http',
#   ':',
#   '//stks.co/1itr',
#   '$',
#   'yhoo',
#   'crazi',
#   'look',
#   'chart',
#   ',',
#   'near',
#   'breakout',
#   'resist',
#   'line',
#   '...'],
#  ['most',
#   'bullish',
#   'stock',
#   'twitter',
#   'dip',
#   '.',
#   '$',
#   'yhoo',
#   '$',
#   'gdx',
#   '$',
#   'googl',
#   '$',
#   'stz',
#   '$',
#   'gold',
#   '$',
#   'ew',
#   '$',
#   'vz',
#   '$',
#   'celg',
#   '$',
#   'sbux',
#   '$',
#   'scti',
#   ':',
#   'http',
#   ':',
#   '//t.co/iuzjelfwt3'],
#  ['finnish',
#   'geosentr',
#   "'s",
#   'net',
#   'sale',
#   'decreas',
#   'eur',
#   '939,000',
#   'january-march',
#   '2009',
#   '.'],
#  ['cohen',
#   '&',
#   'steer',
#   ',',
#   'inc.',
#   ':',
#   '5',
#   '534',
#   '626',
#   'share',
#   'repres',
#   '4.985',
#   '%',
#   'share',
#   'capit',
#   'vote',
#   'right',
#   '.'],
#  ['more',
#   'staff',
#   'recruit',
#   'japan',
#   'complement',
#   'network',
#   'close',
#   '50',
#   'servic',
#   'locat',
#   '20',
#   'countri',
#   'worldwid',
#   '.'],
#  ['paper',
#   'compani',
#   'neg',
#   'territori',
#   ',',
#   'stora',
#   'enso',
#   'r',
#   'shed',
#   '1.62',
#   'pct',
#   '12.73',
#   'eur',
#   ',',
#   'upm-kymmen',
#   '0.80',
#   'pct',
#   '18.64',
#   'eur',
#   'm-real',
#   'b',
#   '0.18',
#   'pct',
#   'lower',
#   '5.57',
#   'eur',
#   '.'],
#  ['kauko-telko',
#   "'s",
#   'central',
#   'administr',
#   'dissolv',
#   'appropri',
#   'part',
#   'transfer',
#   'oper',
#   'activ',
#   'group',
#   'administr',
#   'end',
#   'year',
#   '.'],
#  ['oper',
#   'profit',
#   'quarter',
#   'april-jun',
#   '2006',
#   'amount',
#   'eur182',
#   '.2',
#   'sale',
#   'eur3',
#   '.62',
#   'bn',
#   '.'],
#  ['atria',
#   'chose',
#   'delight',
#   'attract',
#   'consum',
#   '25-45',
#   'age',
#   'group',
#   'atria',
#   'fresh',
#   'rang',
#   'microwav',
#   'meal',
#   '.'],
#  ['finnish',
#   'it',
#   'solut',
#   'provid',
#   'affecto',
#   'oyj',
#   'hel',
#   ':',
#   'afe1v',
#   'said',
#   'today',
#   'slip',
#   'net',
#   'loss',
#   'eur',
#   '115,000',
#   'usd',
#   '152,000',
#   'second',
#   'quarter',
#   '2010',
#   'profit',
#   'eur',
#   '845,000',
#   'correspond',
#   'period',
#   'year',
#   'earlier',
#   '.'],
#  ['us', 'sanction', 'put', 'gazprom-shel', 'allianc', 'plan', 'jeopardi'],
#  ['profit',
#   'period',
#   'eur',
#   '10.9',
#   'mn',
#   ',',
#   'eur',
#   '14.3',
#   'mn',
#   '2009',
#   '.'],
#  ['profit', 'period', 'eur', '5.9', 'mn', ',', 'eur', '1.3', 'mn', '.'],
#  ['oper',
#   'profit',
#   'fell',
#   'eur',
#   '20.3',
#   'mn',
#   'eur',
#   '74.2',
#   'mn',
#   'second',
#   'quarter',
#   '2008',
#   '.'],
#  ['howev',
#   ',',
#   'sale',
#   'return',
#   'growth',
#   'april-jun',
#   '2010',
#   ',',
#   'ceo',
#   'pekka',
#   'eloholma',
#   'said',
#   '.'],
#  ['oper',
#   'profit',
#   'total',
#   'eur',
#   '18.6',
#   'mn',
#   '8.3',
#   '%',
#   'net',
#   'sale',
#   '.'],
#  ['chang',
#   'market',
#   'situat',
#   'tougher',
#   'price',
#   'competit',
#   'substanti',
#   'reduc',
#   'demand',
#   'bread',
#   'packag',
#   'manufactur',
#   'kauhava',
#   'plant',
#   ',',
#   'accord',
#   'compani',
#   '.'],
#  ['in',
#   'connect',
#   'deal',
#   ',',
#   'digia',
#   'employ',
#   '19',
#   'person',
#   'nokia',
#   'oslo',
#   'silicon',
#   'valley',
#   'usa',
#   '.'],
#  ['the',
#   'brazilian',
#   'unit',
#   'finnish',
#   'secur',
#   'solut',
#   'provid',
#   'f-secur',
#   'sign',
#   '1,500',
#   'new',
#   'client',
#   'last',
#   'year',
#   ',',
#   'onlin',
#   'news',
#   'sourc',
#   'resel',
#   'web',
#   'quot',
#   'divis',
#   "'s",
#   'commerci',
#   'director',
#   ',',
#   'vladimir',
#   'brand+úo',
#   ',',
#   'say',
#   '.'],
#  ['the',
#   'fair',
#   'valu',
#   'compani',
#   "'s",
#   'invest',
#   'properti',
#   'went',
#   'eur',
#   '2.768',
#   'billion',
#   'end',
#   '2009',
#   'eur',
#   '2.916',
#   'billion',
#   'year',
#   'earlier',
#   '.'],
#  ['dealer',
#   'said',
#   'share',
#   'larg',
#   'hit',
#   'investor',
#   'disappoint',
#   'refin',
#   'margin',
#   '9.48',
#   'usd',
#   'per',
#   'barrel',
#   'quarter',
#   'perform',
#   'ship',
#   'unit',
#   ',',
#   'saw',
#   'ebit',
#   'drop',
#   '5',
#   'mln',
#   'eur',
#   '20',
#   'mln',
#   'eur',
#   'year',
#   'amid',
#   'fall',
#   'volum',
#   'tanker',
#   'rate',
#   '.'],
#  ['`',
#   'it',
#   'testament',
#   'qualiti',
#   'lte',
#   'solut',
#   'commit',
#   'japanes',
#   'market',
#   "'",
#   ',',
#   'ad',
#   '.'],
#  ['the',
#   'compani',
#   "'",
#   'aim',
#   'final',
#   'negoti',
#   'sign',
#   'contract',
#   'start',
#   'octob',
#   '2008',
#   '.'],
#  ['metso',
#   'foundri',
#   'jyvaskyla',
#   'oy',
#   'discontinu',
#   'product',
#   'line',
#   '30',
#   'septemb',
#   '2008',
#   ',',
#   'compani',
#   'said',
#   '.'],
#  ['a',
#   'total',
#   'six',
#   'poll',
#   'analyst',
#   'rate',
#   'm-real',
#   '--',
#   'two',
#   'gave',
#   '``',
#   'buy',
#   '``',
#   '-',
#   '``',
#   'accumul',
#   '``',
#   ',',
#   'three',
#   'gave',
#   '``',
#   'hold',
#   '``',
#   'one',
#   'gave',
#   '``',
#   'sell',
#   '``',
#   '.'],
#  ['in',
#   'septemb',
#   '2010',
#   ',',
#   'finnish',
#   'group',
#   'agre',
#   'buy',
#   'danish',
#   'compani',
#   'rose',
#   'poultri',
#   'a-',
#   'eur23',
#   '.9',
#   'combin',
#   'cash',
#   'stock',
#   '.'],
#  ['$', 'yang', 'doubl', 'bottom', '5.2'],
#  ['tesco', 'share', 'price', 'grocer', 'face', 'sfo', 'investig', 'outcom'],
#  ['$', 'aapl', 'news', 'becom', 'bullish', 'http', ':', '//stks.co/tmu'],
#  ['gs',
#   'engin',
#   'instal',
#   'valv',
#   'liquefi',
#   'natur',
#   'ga',
#   'lng',
#   'plant',
#   'built',
#   'uae',
#   'lng',
#   'extract',
#   'ga',
#   'plant',
#   'oper',
#   'gasco',
#   'ruwai',
#   ',',
#   'uae',
#   '.'],
#  ['the',
#   'percentag',
#   'share',
#   'vote',
#   'right',
#   'calcul',
#   'proport',
#   'total',
#   'number',
#   'share',
#   'regist',
#   'trade',
#   'regist',
#   'total',
#   'number',
#   'vote',
#   'right',
#   'relat',
#   '.'],
#  ['m-real',
#   'said',
#   '`',
#   'ground',
#   "'",
#   'rumor',
#   ',',
#   '`',
#   'circul',
#   'market',
#   'month',
#   '.',
#   "'"],
#  ['lember',
#   'said',
#   'matter',
#   'topic',
#   'also',
#   'estonia',
#   ',',
#   'bill',
#   'draft',
#   'social',
#   'affair',
#   'ministri',
#   'would',
#   'scrap',
#   'old-ag',
#   'pension',
#   'favor',
#   'condit',
#   '.'],
#  ['-',
#   'moodi',
#   "'s",
#   'said',
#   'gave',
#   'p',
#   'a1',
#   'long-term',
#   'senior',
#   'unsecur',
#   'p',
#   'p-1',
#   'short-term',
#   'debt',
#   'rate',
#   'finnish',
#   'lender',
#   'aktia',
#   'bank',
#   "'s",
#   'eur1bn',
#   'usd1',
#   '.4',
#   'bn',
#   'euro',
#   'medium-term',
#   'note',
#   'emtn',
#   'program',
#   '25',
#   'march',
#   '2011',
#   '.'],
#  ['$', 'tsla', 'recal'],
#  ['the',
#   'liquid',
#   'provid',
#   'interrupt',
#   'may',
#   '11',
#   ',',
#   '2007',
#   'aspocomp',
#   'group',
#   'oyj',
#   "'s",
#   'share',
#   'trade',
#   '0.50',
#   'cent',
#   '(',
#   'aspocomp',
#   "'s",
#   'stock',
#   'exchang',
#   'releas',
#   '11.5.2007',
#   ')',
#   '.'],
#  ['hargreav',
#   'lansdown',
#   'buck',
#   'weak',
#   'market',
#   'see',
#   'asset',
#   'rise',
#   '2.6',
#   'percent'],
#  ['at',
#   '12.59',
#   'pm',
#   ',',
#   'omx',
#   'helsinki',
#   '25',
#   'index',
#   '0.32',
#   'pct',
#   'lower',
#   '2,694.81',
#   '.'],
#  ['the',
#   'decis',
#   'mean',
#   'temporari',
#   'lay-off',
#   'fix',
#   'durat',
#   'compani',
#   "'s",
#   'nastola',
#   'jyvaskyla',
#   'unit',
#   ',',
#   'southern',
#   'central',
#   'finland',
#   ',',
#   'respect',
#   '.'],
#  ['the', 'valu', 'order', 'eur', '10mn', '.'],
#  ['ms',
#   'laakso',
#   'respons',
#   'hkscan',
#   "'s",
#   'hr',
#   'function',
#   'develop',
#   'group',
#   '`',
#   'smarket',
#   'area',
#   '.'],
#  ['fiskar',
#   'also',
#   'engag',
#   'global',
#   'suppli',
#   'marin',
#   'energi',
#   'equip',
#   'solut',
#   'servic',
#   'associ',
#   'compani',
#   ',',
#   'wartsila',
#   'corpor',
#   '.'],
#  ['aberdeen', 'asset', 'manag', 'gain', 'foothold', 'in', 'china'],
#  ['finland',
#   "'s",
#   'domin',
#   'rail',
#   'compani',
#   'vr',
#   'plan',
#   'set',
#   'infect',
#   'passeng',
#   'long-dist',
#   'trip',
#   'separ',
#   'carriag',
#   '.'],
#  ['in',
#   'novemb',
#   ',',
#   'finnish',
#   'govern',
#   'decreas',
#   'ownership',
#   'compani',
#   '31.1',
#   'percent',
#   '38',
#   'percent',
#   '.'],
#  ['finnish',
#   'exel',
#   'composit',
#   ',',
#   'technolog',
#   'compani',
#   'design',
#   ',',
#   'manufactur',
#   ',',
#   'market',
#   'composit',
#   'profil',
#   'tube',
#   'variou',
#   'industri',
#   'applic',
#   ',',
#   'report',
#   'net',
#   'sale',
#   'decreas',
#   '0.6',
#   '%',
#   'second',
#   'quarter',
#   '2010',
#   'eur',
#   '19.2',
#   'mn',
#   'eur',
#   '19.3',
#   'mn',
#   'correspond',
#   'period',
#   '2009',
#   '.'],
#  ['of',
#   'bavelloni',
#   "'s",
#   'nst',
#   "'s",
#   'joint',
#   'ventur',
#   ',',
#   'bavelloni',
#   'tool',
#   ',',
#   'complet',
#   'semiproduct',
#   'produc',
#   'itali',
#   'high-qual',
#   'tool',
#   'sold',
#   'diapol',
#   'brand',
#   '.'],
#  ['the',
#   'tool',
#   'patent',
#   'pend',
#   'design',
#   'allow',
#   'consum',
#   'lay',
#   'entir',
#   'project',
#   'remov',
#   'plate',
#   'use',
#   'multipl',
#   'clear',
#   'stamp',
#   'kind',
#   '.'],
#  ['$', 'googl', 'short', '740', 'upper', 'bb', 'overbought'],
#  ['light',
#   'out',
#   'befor',
#   'curfew',
#   ',',
#   'curl',
#   'latest',
#   'bestsel',
#   'treat',
#   'eye',
#   'perfect',
#   'read',
#   'light',
#   'luceplan',
#   '.'],
#  ['upm-kymmen',
#   'corp.',
#   ',',
#   'world',
#   "'s",
#   'largest',
#   'maker',
#   'magazin',
#   'paper',
#   ',',
#   'tuesday',
#   'report',
#   '19-percent',
#   'profit',
#   'drop',
#   'lower',
#   'paper',
#   'price',
#   ',',
#   'higher',
#   'cost',
#   'strong',
#   'euro',
#   'hurt',
#   'revenu',
#   '.'],
#  ['the', 'total', 'valu', 'contract', 'eur', '8', 'million', '.'],
#  ['the',
#   'prerequisit',
#   'inclus',
#   'program',
#   'receipt',
#   'gain',
#   'key',
#   'employe',
#   'acquir',
#   'aspo',
#   'share',
#   'amount',
#   'determin',
#   'board',
#   'advanc',
#   ',',
#   'maximum',
#   '.'],
#  ['mr.',
#   'dore',
#   'eaton',
#   'sinc',
#   '1989',
#   'act',
#   'busi',
#   'unit',
#   'manag',
#   'eaton',
#   "'s",
#   'power',
#   'control',
#   'busi',
#   'unit',
#   'sinc',
#   'januari',
#   '2007',
#   '.'],
#  ['the',
#   '250',
#   'sq',
#   '2,691',
#   'sq',
#   'ft',
#   'store',
#   'copenhagen',
#   "'s",
#   'premier',
#   'shop',
#   'district',
#   'inaugur',
#   'today',
#   ',',
#   'strengthen',
#   'compani',
#   "'s",
#   'presenc',
#   'nordic',
#   'capit',
#   '.'],
#  ['in',
#   'financi',
#   'statement',
#   'first',
#   'quarter',
#   '2010',
#   ',',
#   'tikkurila',
#   'report',
#   'discontinu',
#   'oper',
#   '.'],
#  ['the',
#   'world',
#   "'s",
#   'second',
#   'largest',
#   'stainless',
#   'steel',
#   'maker',
#   'said',
#   'net',
#   'profit',
#   'three-month',
#   'period',
#   'dec.',
#   '31',
#   'surg',
#   'euro603',
#   'million',
#   'us',
#   '$',
#   '781',
#   'million',
#   ',',
#   'euro3',
#   '.33',
#   'us',
#   '$',
#   '4.31',
#   'per',
#   'share',
#   ',',
#   'euro172',
#   'million',
#   ',',
#   'euro0',
#   '.94',
#   'per',
#   'share',
#   ',',
#   'previou',
#   'year',
#   '.'],
#  ['name',
#   'applic',
#   ':',
#   'jot',
#   'autom',
#   'oynam',
#   'inventor',
#   ':',
#   'mammila',
#   'tuomo',
#   ',',
#   'piirainen',
#   'mika',
#   'kellokoski',
#   'mikaappl',
#   'no',
#   '.',
#   ':',
#   '2424-kolnp-2008',
#   'adat',
#   'file',
#   'applic',
#   ':',
#   '16-06-2008public',
#   'date',
#   ':',
#   '30/01/2009'],
#  ['netflix',
#   'grow',
#   'effort',
#   'to',
#   'creat',
#   'loyal',
#   'custom',
#   '$',
#   'nflx',
#   'http',
#   ':',
#   '//t.co/5qxbkobph'],
#  ['the',
#   'omx',
#   'nordic',
#   '40',
#   'omxn40',
#   'index',
#   ',',
#   'compris',
#   '40',
#   'trade',
#   'nordic',
#   'stock',
#   'nasdaq',
#   'omx',
#   'exchang',
#   ',',
#   'close',
#   '0.87',
#   '%',
#   '1,064.14',
#   'point',
#   'thursday',
#   '.'],
#  ['$',
#   'aapl',
#   'nibbl',
#   'small',
#   'long',
#   'via',
#   '525',
#   '..',
#   'buy',
#   '13min',
#   'chart',
#   '..'],
#  ['the',
#   'oper',
#   'margin',
#   'aker',
#   'yard',
#   'cruis',
#   '&',
#   'ferri',
#   'divis',
#   'went',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['$',
#   'tyc',
#   'break',
#   'new',
#   'high',
#   ',',
#   'lot',
#   'technic',
#   'look',
#   'great',
#   'right',
#   '.'],
#  ['eero',
#   'katajavuori',
#   ',',
#   'current',
#   'group',
#   'vice',
#   'presid',
#   ',',
#   'human',
#   'resourc',
#   ',',
#   'take',
#   'year-long',
#   'sabbat',
#   'start',
#   'octob',
#   '1',
#   ',',
#   '2010',
#   '.'],
#  ['what',
#   '$',
#   'lulu',
#   '?',
#   'number',
#   'look',
#   'good',
#   ',',
#   'great',
#   ',',
#   'good',
#   '.',
#   'i',
#   'think',
#   'confer',
#   'call',
#   'instil',
#   'confid',
#   '.'],
#  ['the',
#   'adjust',
#   'measur',
#   'carri',
#   'phase',
#   'secur',
#   'deliveri',
#   'capabl',
#   '.'],
#  ['alma',
#   'media',
#   'corpor',
#   'press',
#   'releas',
#   '15',
#   'march',
#   '2010',
#   'tyrvaan',
#   'sanomat',
#   'and',
#   'paikallissanomat',
#   'be',
#   'bought',
#   'by',
#   'suomen',
#   'paikallissanomat',
#   'two',
#   'local',
#   'paper',
#   ',',
#   'tyrvaan',
#   'sanomat',
#   'paikallissanomat',
#   ',',
#   'appear',
#   'sastamala',
#   'neighbour',
#   'municip',
#   ',',
#   'bought',
#   'suomen',
#   'paikallissanomat',
#   'oy',
#   '.'],
#  ['temporari',
#   'lay-off',
#   ',',
#   'affect',
#   'entir',
#   'workforc',
#   ',',
#   'also',
#   'implement',
#   '.'],
#  ['a',
#   'meet',
#   'media',
#   'analyst',
#   'held',
#   'day',
#   '10:30',
#   'a.m.',
#   'stonesoft',
#   'headquart',
#   'helsinki',
#   ',',
#   'italahdenkatu',
#   '22',
#   'a',
#   '.',
#   'the',
#   'interim',
#   'report',
#   'present',
#   'stonesoft',
#   "'s",
#   'ceo',
#   'ilkka',
#   'hiidenheimo',
#   '.'],
#  ['finnish',
#   'sampo-rosenlew',
#   'manufactur',
#   'approxim',
#   'seven',
#   'forest',
#   'machin',
#   'monthli',
#   ',',
#   'half',
#   'machin',
#   'export',
#   '.'],
#  ['facebook',
#   ',',
#   'near',
#   'buy',
#   'point',
#   'last',
#   'week',
#   ',',
#   'face',
#   'differ',
#   'technic',
#   'test',
#   'today',
#   'http',
#   ':',
#   '//t.co/c72llmpinm',
#   '$',
#   'fb',
#   '$',
#   'aapl',
#   '$',
#   'nflx',
#   'http',
#   ':',
#   '//t.co/fpfbytypuy'],
#  ['4',
#   'februari',
#   '2011',
#   '-',
#   'finnish',
#   'broadband',
#   'data',
#   'commun',
#   'system',
#   'provid',
#   'telest',
#   'oyj',
#   'hel',
#   ':',
#   'tlt1v',
#   'said',
#   'wednesday',
#   'net',
#   'profit',
#   'rocket',
#   'eur4',
#   '.8',
#   '2010',
#   'eur416',
#   ',000',
#   '2009',
#   'lift',
#   'dividend',
#   'propos',
#   '.'],
#  ['$',
#   'free',
#   'ha',
#   'heeeeeer',
#   'come',
#   'pump',
#   '!',
#   'so',
#   'glad',
#   'i',
#   'pick',
#   '9k',
#   'end',
#   'day',
#   '!',
#   'get',
#   'readi',
#   'bull',
#   'ride',
#   '!'],
#  ['finnish',
#   'technolog',
#   'group',
#   'aspocomp',
#   'group',
#   'oyj',
#   '(',
#   'omx',
#   'helsinki',
#   ':',
#   'acg1v',
#   ')',
#   'issu',
#   'third',
#   'quarter',
#   'report',
#   'thursday',
#   '(',
#   '13',
#   'novemb',
#   ')',
#   ',',
#   'post',
#   'oper',
#   'profit',
#   'eur0',
#   '.4',
#   ',',
#   'compar',
#   'loss',
#   'eur0',
#   '.5',
#   'third',
#   'quarter',
#   '2007',
#   '.'],
#  ['the',
#   'build',
#   'complex',
#   'consist',
#   'high-qual',
#   'offic',
#   'retail',
#   'space',
#   'total',
#   '49,200',
#   'squar',
#   'metr',
#   ',',
#   'compani',
#   'said',
#   '.'],
#  ['finnish',
#   'insur',
#   'compani',
#   'fennia',
#   'kesko',
#   'group',
#   'end',
#   'loyal',
#   'custom',
#   'cooper',
#   '.'],
#  ['the',
#   'unit',
#   'plan',
#   'oper',
#   'second',
#   'half',
#   '2007',
#   'full',
#   'stream',
#   '2008',
#   '.'],
#  ['itg',
#   "'s",
#   'share',
#   'deal',
#   'estim',
#   '500,000',
#   'euro',
#   '$',
#   '627,000',
#   '.'],
#  ['the', 'plant', 'expect', 'enter', 'commerci', 'oper', 'mid-2009', '.'],
#  ['aspo',
#   'also',
#   'investig',
#   'sale',
#   'opportun',
#   'kaukomarkkinat',
#   "'s",
#   'electron',
#   'busi',
#   '.'],
#  ['bg', 'group', 'appoint', 'new', 'ceo', 'one', 'month', 'earli'],
#  ['the',
#   'acquisit',
#   'immedi',
#   'posit',
#   'impact',
#   'aspocomp',
#   "'s",
#   'financi',
#   'result',
#   '.'],
#  ['finnair',
#   "'s",
#   'passeng',
#   'load',
#   'factor',
#   ',',
#   'measur',
#   'number',
#   'sold',
#   'seat',
#   'share',
#   'avail',
#   'seat',
#   ',',
#   'drop',
#   '1.3',
#   'percentag',
#   'point',
#   '76.7',
#   '%',
#   'septemb',
#   '.'],
#  ['rt',
#   '@',
#   'bman1',
#   '$',
#   'lng',
#   'look',
#   'prime',
#   'also',
#   '$',
#   'eght',
#   'pois',
#   'run',
#   '...'],
#  ['it',
#   'also',
#   '7.7',
#   'pct',
#   '12-month',
#   'volum',
#   'weight',
#   'averag',
#   'price',
#   'stock',
#   '.'],
#  ['coke',
#   'dividend',
#   '-',
#   '3',
#   '%',
#   '.',
#   'googl',
#   'dividend',
#   '-',
#   '0',
#   '%',
#   '.',
#   'for',
#   'passiv',
#   'incom',
#   'coke',
#   'take',
#   '.',
#   '$',
#   'goog',
#   '$',
#   'ko',
#   'http',
#   ':',
#   '//t.co/qbsowjxost'],
#  ['profit',
#   'tax',
#   'eur',
#   '5.4',
#   'mn',
#   ',',
#   'eur',
#   '3.6',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['the',
#   'subsidiari',
#   'set',
#   'facil',
#   'manufactur',
#   'high-dens',
#   'interconnect',
#   'print',
#   'circuit',
#   'board',
#   'pcb',
#   'nokia',
#   "'s",
#   'special',
#   'econom',
#   'zone',
#   'sriperumbudur',
#   'near',
#   'chennai',
#   '.'],
#  ['$',
#   'crm',
#   'sep',
#   '40',
#   'call',
#   '+35',
#   '%',
#   'sinc',
#   'entri',
#   '#',
#   'bang',
#   'http',
#   ':',
#   '//stks.co/dedm'],
#  ['in',
#   'january-jun',
#   '2010',
#   ',',
#   'dilut',
#   'loss',
#   'per',
#   'share',
#   'stood',
#   'eur0',
#   '.3',
#   'versu',
#   'eur0',
#   '.1',
#   'first',
#   'half',
#   '2009',
#   '.'],
#  ['rapala',
#   'said',
#   'estim',
#   'make',
#   'save',
#   '1-2',
#   'mln',
#   'eur',
#   'year',
#   'centralis',
#   'french',
#   'oper',
#   'one',
#   'site',
#   '.'],
#  ['$',
#   'vmw',
#   'got',
#   'nice',
#   'push',
#   'today',
#   'follow',
#   'small',
#   'sweeper',
#   'may',
#   'c',
#   'morn'],
#  ['that', 'top', 'consensu', 'forecast', 'earn', '0.21', 'euro', 'share', '.'],
#  ['r', '&', 'd', 'loan', ')', '.'],
#  ['in',
#   'futur',
#   ',',
#   'compani',
#   'intend',
#   'look',
#   'know-how',
#   'outsid',
#   'compani',
#   'cooper',
#   'actor',
#   'sector',
#   '.'],
#  ['you', 'need', 'readi', 'window', 'open', ',', 'rosberg', 'said', '.'],
#  ['more', '50,000', 'tonn', 'asphalt', 'mix', 'use', 'contract', '.'],
#  ['pa',
#   ')',
#   ',',
#   'jpmorgan',
#   'chase',
#   'co',
#   '(',
#   'nyse',
#   ':',
#   'jpm',
#   ')',
#   'pohjoa',
#   'bank',
#   'joint',
#   'lead-manag',
#   'senior',
#   ',',
#   'unsecur',
#   'deal',
#   '.'],
#  ['$',
#   'ctrp',
#   'break',
#   'good',
#   'vol',
#   'parser',
#   'buy',
#   'signal',
#   '..',
#   'notic',
#   'bob',
#   'lang',
#   'comment',
#   'look',
#   '48',
#   'fast'],
#  ['sale',
#   'finland',
#   'decreas',
#   '10.5',
#   '%',
#   'januari',
#   ',',
#   'sale',
#   'outsid',
#   'finland',
#   'drop',
#   '17',
#   '%',
#   '.'],
#  ['the',
#   'pulp',
#   'product',
#   'finnish',
#   'kemij+ñrvi',
#   'also',
#   'liquid',
#   '1,100',
#   'employe',
#   'loos',
#   'job',
#   '.'],
#  ['nordea', 'cheapest', 'also', 'coupl', '30', 'debt', '.'],
#  ['jussi',
#   'pesonen',
#   ',',
#   'member',
#   'sampo',
#   'board',
#   'sinc',
#   '2006',
#   ',',
#   'renounc',
#   'seat',
#   'sampo',
#   'board',
#   '.'],
#  ['tesla',
#   'recal',
#   '2,700',
#   'model',
#   'x',
#   'car',
#   ':',
#   'http',
#   ':',
#   '//t.co/8z7bkvstl9',
#   '$',
#   'tsla'],
#  ['adjust',
#   'chang',
#   'group',
#   'structur',
#   ',',
#   'divis',
#   "'s",
#   'net',
#   'sale',
#   'increas',
#   '1.7',
#   '%',
#   '.'],
#  ['make',
#   'matter',
#   'difficult',
#   ',',
#   'compani',
#   'said',
#   'grappl',
#   'higher',
#   'oil',
#   'ga',
#   'price',
#   ',',
#   'push',
#   'cost',
#   'energi',
#   ',',
#   'raw',
#   'materi',
#   'transport',
#   '.'],
#  ['the',
#   'amend',
#   'propos',
#   'simplifi',
#   'propos',
#   'plan',
#   'increas',
#   'incent',
#   'key',
#   'employe',
#   'stay',
#   'compani',
#   '.'],
#  ['the', 'solut', 'expand', 'includ', 'ground', 'staff', 'task', '.'],
#  ['oper',
#   'loss',
#   'total',
#   'eur',
#   '3.2',
#   'mn',
#   ',',
#   'compar',
#   'profit',
#   'eur',
#   '7.2',
#   'mn',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['on',
#   '#',
#   'fedday',
#   'look',
#   'sharp',
#   'move',
#   'equiti',
#   '$',
#   'aapl',
#   '$',
#   'hd',
#   '$',
#   'low',
#   '$',
#   'fb',
#   'see',
#   '$',
#   'uvxi',
#   '$',
#   'tvix',
#   'get',
#   'hammer',
#   ',',
#   'even',
#   'though',
#   'market',
#   '.'],
#  ['net',
#   'sale',
#   'total',
#   'eur',
#   '93.6',
#   'mn',
#   ',',
#   'eur',
#   '93.2',
#   'mn',
#   'correspond',
#   'period',
#   '2005',
#   '.'],
#  ['as',
#   'consequ',
#   'work',
#   'council',
#   'withdrawn',
#   'petit',
#   'suspend',
#   'reorganis',
#   '.'],
#  ['ceo',
#   'erkki',
#   'j+ñrvinen',
#   'happi',
#   'compani',
#   "'s",
#   'perform',
#   '2010',
#   '.'],
#  ['compar',
#   'net',
#   'sale',
#   'expect',
#   'increas',
#   '10',
#   '%',
#   '2008',
#   ',',
#   'line',
#   'group',
#   'target',
#   '.'],
#  ['follow',
#   'transact',
#   ',',
#   'lundbeck',
#   'worldwid',
#   'right',
#   'nalmefen',
#   ',',
#   'exclud',
#   'north',
#   'america',
#   ',',
#   'mexico',
#   ',',
#   'turkey',
#   'south-korea',
#   '.'],
#  ['the',
#   'govern',
#   'start',
#   'sell-off',
#   'last',
#   'month',
#   ',',
#   'put',
#   '8',
#   'percent',
#   'stake',
#   'teliasonera',
#   'auction',
#   'bloc',
#   '.'],
#  ['the',
#   'report',
#   'goe',
#   'provid',
#   'detail',
#   'profil',
#   'ten',
#   'lead',
#   'european',
#   'specialti',
#   'chemic',
#   'compani',
#   ',',
#   'brief',
#   'profil',
#   'major',
#   'player',
#   '.'],
#  ['both',
#   'oper',
#   'profit',
#   'net',
#   'sale',
#   'three-month',
#   'period',
#   'increas',
#   ',',
#   'respect',
#   'eur16',
#   '.0',
#   'eur139m',
#   ',',
#   'compar',
#   'correspond',
#   'quarter',
#   '2006',
#   '.'],
#  ['the',
#   'compani',
#   'expect',
#   'net',
#   'sale',
#   'whole',
#   '2009',
#   'previou',
#   'year',
#   'level',
#   '.'],
#  ['the',
#   'compani',
#   'headquart',
#   'sievi',
#   ',',
#   'finland',
#   ',',
#   'list',
#   'nordic',
#   'exchang',
#   'helsinki',
#   '.'],
#  ['commiss',
#   'incom',
#   'increas',
#   '22',
#   '%',
#   'eur',
#   '4.4',
#   'mn',
#   ',',
#   'lend',
#   'volum',
#   'rose',
#   '13.5',
#   '%',
#   '.'],
#  ['the',
#   'finnish',
#   'compani',
#   'sold',
#   'uk',
#   'oper',
#   '-',
#   'consist',
#   '50',
#   'staff',
#   'offic',
#   'london',
#   ',',
#   'birmingham',
#   'manchest',
#   '-',
#   'part',
#   'deal',
#   'hampden',
#   'juli',
#   '2001',
#   'european-wid',
#   'properti',
#   'casualti',
#   'arm',
#   'sampo',
#   'industri',
#   '.'],
#  ['in',
#   'build',
#   'home',
#   'improv',
#   'trade',
#   ',',
#   'sale',
#   'decreas',
#   '22.5',
#   '%',
#   'eur',
#   '201.4',
#   'mn',
#   '.'],
#  ['the',
#   'innova',
#   '2',
#   'build',
#   'locat',
#   'close',
#   'downtown',
#   ',',
#   'immedi',
#   'vicin',
#   'paviljonki',
#   'travel',
#   'center',
#   ',',
#   'within',
#   'walk',
#   'distanc',
#   'heart',
#   'citi',
#   'thank',
#   'trade',
#   'fair',
#   'bridg',
#   '.'],
#  ['finnish',
#   'textil',
#   'cloth',
#   'group',
#   'marimekko',
#   'oyj',
#   'post',
#   'net',
#   'profit',
#   '7.99',
#   'mln',
#   'euro',
#   '$',
#   '10.4',
#   'mln',
#   '2006',
#   ',',
#   'compar',
#   '8.4',
#   'mln',
#   'euro',
#   '$',
#   '10.9',
#   'mln',
#   '2005',
#   '.'],
#  ['the',
#   'main',
#   'strength',
#   'cooper',
#   'project',
#   'lie',
#   'merg',
#   'know-how',
#   'two',
#   'larg',
#   'compani',
#   '.'],
#  ['sharehold',
#   'right',
#   'put',
#   'agenda',
#   'agm',
#   'item',
#   'within',
#   'compet',
#   'gener',
#   'meet',
#   '.'],
#  ['kazgiprotsvetmet',
#   'outotec',
#   'finland',
#   'sign',
#   'agreement',
#   'strateg',
#   'cooper',
#   'market',
#   'provid',
#   'miner',
#   'process',
#   'metallurg',
#   'plant',
#   'relat',
#   'servic',
#   'kazakhstan',
#   'surround',
#   'countri',
#   '.'],
#  ['due',
#   'rapid',
#   'decreas',
#   'net',
#   'sale',
#   ',',
#   'personnel',
#   'reduct',
#   'carri',
#   'wider',
#   'scale',
#   'initi',
#   'expect',
#   '.'],
#  ['the',
#   'govern',
#   'instead',
#   'propos',
#   'exchang',
#   'state',
#   "'s",
#   'stake',
#   'lmt',
#   'teliasonera',
#   "'s",
#   'stake',
#   'lattelecom',
#   '.'],
#  ['stora',
#   'due',
#   'releas',
#   'fourth-quart',
#   '2009',
#   'full-year',
#   'earn',
#   'feb.',
#   '4',
#   '.'],
#  ['full-year', 'oper', 'result', '2008', '3.6', 'million', 'neg', '.'],
#  ['$',
#   'nq',
#   'got',
#   'hit',
#   'hard',
#   'lower',
#   'am',
#   '--',
#   '>',
#   'look',
#   'like',
#   'found',
#   'support',
#   '18.89',
#   'http',
#   ':',
#   '//stks.co/s052z'],
#  ['in',
#   '2008',
#   ',',
#   'avc',
#   'systemhau',
#   'net',
#   'sale',
#   'eur',
#   '10',
#   'million',
#   'usd',
#   '7.1',
#   '.'],
#  ['the',
#   'compani',
#   'establish',
#   '3g',
#   'base',
#   'station',
#   '17,000',
#   'feet',
#   'foot',
#   'mount',
#   'everest',
#   'enabl',
#   'mountain',
#   'climber',
#   '29,035-foot',
#   'summit',
#   'surf',
#   'internet',
#   'even',
#   'send',
#   'video',
#   'exploit',
#   '.'],
#  ['we', 'offer', 'custom', 'solut', 'base', 'renew', 'raw', 'materi', '.'],
#  ['a',
#   'survey',
#   'conduct',
#   'taloustutkimu',
#   'sampo',
#   'life',
#   'show',
#   'compani',
#   'badli',
#   'prepar',
#   'lose',
#   'key',
#   'staff',
#   'member',
#   '.'],
#  ['antti',
#   'orkola',
#   ',',
#   'presid',
#   'kemira',
#   'growhow',
#   "'s",
#   'industri',
#   'solut',
#   'unit',
#   ',',
#   'told',
#   'thomson',
#   'financi',
#   'new',
#   'compani',
#   'put',
#   'open',
#   'mine',
#   'price',
#   'phosphat',
#   '`',
#   'quit',
#   'depress',
#   'long',
#   'time',
#   "'",
#   '.',
#   "'"],
#  ['the',
#   'pretax',
#   'profit',
#   'group',
#   "'s",
#   'life',
#   'insur',
#   'busi',
#   'increas',
#   'eur36m',
#   'eur27m',
#   '.'],
#  ['we',
#   'make',
#   'avail',
#   'follow',
#   'brand-new',
#   'market',
#   'analys',
#   'cement',
#   '-',
#   'pakistan',
#   'cement',
#   '-',
#   'malaysia',
#   'cement',
#   '-',
#   'taiwan',
#   'cement',
#   '-',
#   'philippin',
#   'these',
#   'analys',
#   'give',
#   'clear',
#   'overview',
#   'actual',
#   'situat',
#   'futur',
#   'outlook',
#   'cement',
#   'industri',
#   'asian',
#   'countri',
#   '.'],
#  ['the',
#   'compani',
#   'serv',
#   'approxim',
#   '3,000',
#   'custom',
#   '100',
#   'countri',
#   '.'],
#  ['rt',
#   '@',
#   'alphatrend',
#   'vmarket',
#   'are',
#   'still',
#   'act',
#   'weak',
#   'http',
#   ':',
#   '//stks.co/1agn',
#   '$',
#   'spi',
#   '$',
#   'qqq',
#   '$',
#   'xlf',
#   '$',
#   'smh',
#   '$',
#   'iwm'],
#  ['oper',
#   'profit',
#   'total',
#   'eur',
#   '30.2',
#   'mn',
#   ',',
#   'eur',
#   '43.8',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['one',
#   'instal',
#   'elev',
#   'double-deck',
#   'elev',
#   ',',
#   'enabl',
#   'effici',
#   'use',
#   'build',
#   "'s",
#   'core',
#   'space',
#   '.'],
#  ['helsinki',
#   '(',
#   'afx',
#   ')',
#   '-',
#   'outokumpu',
#   'said',
#   'agre',
#   'sell',
#   'hitura',
#   'nickel',
#   'mine',
#   'finland',
#   'canadian',
#   'group',
#   'belveder',
#   'resourc',
#   'ltd',
#   '10',
#   'mln',
#   'eur',
#   'worth',
#   'belveder',
#   'share',
#   '.'],
#  ['just', 'went', 'long', '$', 'ilmn'],
#  ['``',
#   'social',
#   'network',
#   'location-bas',
#   'servic',
#   'trend',
#   'compris',
#   'signific',
#   'share',
#   'internet',
#   'traffic',
#   'today',
#   'appeal',
#   'mid',
#   'user',
#   '.'],
#  ['a',
#   'total',
#   '30',
#   '%',
#   'order',
#   'valu',
#   'book',
#   'fourth',
#   'quarter',
#   '2009',
#   'remaind',
#   'book',
#   'second',
#   'quarter',
#   '2010',
#   '.'],
#  ['johnson',
#   'matthey',
#   'share',
#   'price',
#   'slump',
#   'compani',
#   'post',
#   'full-year',
#   'result'],
#  ['there', 'previou', 'share', 'subscript', '2004', 'stock', 'option', '.'],
#  ['affectogenimap',
#   'build',
#   'highli',
#   'customis',
#   'it',
#   'solut',
#   'custom',
#   'finland',
#   'baltic',
#   'countri',
#   '.'],
#  ['the',
#   'close',
#   'transact',
#   'schedul',
#   'take',
#   'place',
#   'januari',
#   '10',
#   ',',
#   '2008',
#   '.'],
#  ['howev',
#   ',',
#   'offer',
#   'probabl',
#   'made',
#   'current',
#   'valuat',
#   ',',
#   'partli',
#   'deriv',
#   'deal',
#   'compani',
#   'merg',
#   'stock',
#   'market',
#   'shell',
#   '.'],
#  ['oper',
#   'result',
#   '12-month',
#   'period',
#   'decreas',
#   'profit',
#   'eur0',
#   '.4',
#   'turnov',
#   'decreas',
#   'eur5',
#   '.6',
#   ',',
#   'compar',
#   '2004',
#   '.'],
#  ['the',
#   'administr',
#   'indic',
#   'need',
#   '900',
#   'job',
#   'cut',
#   'irish',
#   'insur',
#   'next',
#   '15',
#   'month',
#   '.'],
#  ['net', 'sale', '2008', 'expect', 'level', '2007', '.'],
#  ['technic',
#   'indic',
#   'stock',
#   'bullish',
#   's',
#   '&',
#   'p',
#   'give',
#   'nok',
#   'posit',
#   '4',
#   'star',
#   '5',
#   'buy',
#   'rank',
#   '.'],
#  ['revenu',
#   'quarter',
#   'total',
#   '27.4',
#   'billion',
#   ',',
#   '2',
#   'percent',
#   '28.1',
#   'billion',
#   'fourth',
#   'quarter',
#   '2008',
#   '.'],
#  ['n-viro',
#   'oper',
#   'process',
#   'facil',
#   'independ',
#   'well',
#   'partnership',
#   'municip',
#   '.'],
#  ['the', 'number', 'bodili', 'injuri', 'case', 'quadrupl', '2000-2006', '.'],
#  ['accord',
#   'ringman',
#   ',',
#   'finnish',
#   'paper',
#   'compani',
#   'acquir',
#   'know-how',
#   'capac',
#   'paper',
#   'recycl',
#   ',',
#   'turn',
#   'success',
#   'strategi',
#   '.'],
#  ['the',
#   'compani',
#   'also',
#   'said',
#   'poland',
#   'profit',
#   'program',
#   'launch',
#   'oborniki',
#   'steel',
#   'frame',
#   'sandwich',
#   'panel',
#   'plant',
#   '.'],
#  ['and',
#   'u.s.',
#   'energi',
#   'execut',
#   'say',
#   'high',
#   'steel',
#   'price',
#   'threaten',
#   'energi',
#   'explor',
#   '.'],
#  ['tesco', 'sale', 'rise', 'show', 'tent', 'recoveri', 'continu'],
#  ['in',
#   'finland',
#   ',',
#   'launch',
#   'tie-in',
#   'sale',
#   '3g',
#   'mobil',
#   'phone',
#   'caus',
#   'dramat',
#   'rush',
#   'mobil',
#   'retail',
#   'outlet',
#   'first',
#   'day',
#   '.'],
#  ['$',
#   'nuan',
#   'held',
#   'well',
#   'big',
#   'gain',
#   '!',
#   'mayb',
#   "'re",
#   'final',
#   'move',
#   '!',
#   '!',
#   'still',
#   'undervalu',
#   'major',
#   'upsid'],
#  ['the',
#   'compani',
#   'split',
#   'two',
#   'part',
#   'come',
#   'month',
#   ',',
#   'essent',
#   'own',
#   'oper',
#   'product',
#   'suppli',
#   ',',
#   'enexi',
#   'own',
#   'oper',
#   'grid',
#   '.'],
#  ['offici', 'disclos', 'contract', 'valu', '.'],
#  ['london',
#   "'s",
#   'lead',
#   'share',
#   'today',
#   'jump',
#   'almost',
#   '100',
#   'point',
#   ',',
#   '1.7',
#   '%',
#   ',',
#   'market',
#   'open',
#   '.'],
#  ['in',
#   'third',
#   'quarter',
#   'fiscal',
#   '2008',
#   'efor',
#   'swung',
#   'net',
#   'loss',
#   'eur',
#   '400,000',
#   'versu',
#   'net',
#   'profit',
#   'eur',
#   '200,000',
#   'correspond',
#   'period',
#   'fiscal',
#   '2007',
#   '.'],
#  ['the',
#   'group',
#   "'s",
#   'oper',
#   'loss',
#   'eur',
#   '0.8',
#   'mn',
#   ',',
#   'profit',
#   'eur',
#   '2.5',
#   'mn',
#   '2004',
#   '.'],
#  ['the',
#   'move',
#   'trigger',
#   'weak',
#   'demand',
#   'forestri',
#   'equip',
#   'uncertain',
#   'market',
#   'situat',
#   '.'],
#  ['the',
#   'combin',
#   'compani',
#   'pro-forma',
#   'net',
#   'sale',
#   '140',
#   'mln',
#   'euro',
#   '$',
#   '188.9',
#   'mln',
#   'oper',
#   'profit',
#   '13',
#   'mln',
#   'euro',
#   '$',
#   '17.5',
#   'mln',
#   '2006',
#   '.'],
#  ['manag',
#   'director',
#   'kari',
#   'inkinen',
#   'say',
#   'sponda',
#   "'s",
#   'leas',
#   'oper',
#   'develop',
#   'highli',
#   'favour',
#   '.'],
#  ['17',
#   'march',
#   '2011',
#   '-',
#   'goldman',
#   'sach',
#   'estim',
#   'neg',
#   'prospect',
#   'norwegian',
#   'mobil',
#   'oper',
#   'norway',
#   "'s",
#   'telenor',
#   'asa',
#   'osl',
#   ':',
#   'tel',
#   'sweden',
#   "'s",
#   'teliasonera',
#   'ab',
#   'sto',
#   ':',
#   'tlsn',
#   'short',
#   'term',
#   '.'],
#  ['$', 'tsla', 'steam', ',', 'stock', 'relentless', 'moment'],
#  ['marathon',
#   'estim',
#   'valu',
#   'remain',
#   'stake',
#   'protalix',
#   '$',
#   '27',
#   'million',
#   '.'],
#  ['whitbread', 'share', 'price', 'climb', 'q4', 'sale', 'growth'],
#  ['incap',
#   'contract',
#   'manufactur',
#   'subsidiari',
#   'incap',
#   'corpor',
#   'finland',
#   '.'],
#  ['oper',
#   'profit',
#   'total',
#   'eur',
#   '37,7',
#   'mn',
#   ',',
#   'slightli',
#   'eur',
#   '37.2',
#   'mn',
#   'correspond',
#   'period',
#   '2006',
#   '.'],
#  ['we',
#   'went',
#   'market',
#   'yield',
#   'guidanc',
#   '7.25',
#   '%',
#   'area',
#   ',',
#   'gave',
#   'us',
#   'flexibl',
#   'go',
#   '1-8th',
#   '.'],
#  ['rt',
#   '@',
#   'stockdemon',
#   'think',
#   'short',
#   'close',
#   'might',
#   'play',
#   ',',
#   '$',
#   'spi',
#   '-',
#   'high',
#   'beta',
#   'revers',
#   '..',
#   'look',
#   'worth',
#   'shot'],
#  ['vdw',
#   'combin',
#   'lxe',
#   'devic',
#   'enhanc',
#   'product',
#   ',',
#   'enabl',
#   'worker',
#   'use',
#   'singl',
#   'devic',
#   'perform',
#   'voic',
#   ',',
#   'scan',
#   'keyboard',
#   'function',
#   '.'],
#  ['thu',
#   'method',
#   'cut',
#   'work',
#   'cost',
#   ',',
#   'fasten',
#   'plan',
#   'build',
#   'process',
#   '.'],
#  ['talentum', "'s", 'net', 'sale', 'septemb', 'smaller', 'expect', '.'],
#  ['copyright',
#   'afx',
#   'new',
#   'afx',
#   'financi',
#   'new',
#   'logo',
#   'regist',
#   'trademark',
#   'afx',
#   'new',
#   'limit'],
#  ['$',
#   'lnkd',
#   'daili',
#   'phase',
#   '2',
#   'retest',
#   '-',
#   'price',
#   'experienc',
#   'earli',
#   'reject',
#   '.',
#   'can',
#   'retest',
#   '?',
#   'http',
#   ':',
#   '//stks.co/t04xx'],
#  ['rb', 'reportedli', 'appoint', 'howard', 'davi', 'next', 'chairman'],
#  ['tesco',
#   ',',
#   'asda',
#   'sale',
#   'fall',
#   'march',
#   'discount',
#   'continues-kantar'],
#  ['``',
#   'with',
#   'new',
#   'version',
#   'import',
#   'us',
#   'introduc',
#   'bim',
#   'process',
#   'base',
#   'detail',
#   'build',
#   'inform',
#   'model',
#   '.'],
#  ['sampo',
#   'plc',
#   'jarmo',
#   'salonen',
#   'head',
#   'investor',
#   'relat',
#   'group',
#   'commun',
#   'tel',
#   '.',
#   '+358',
#   '10',
#   '516',
#   '0030',
#   'distribut',
#   ':',
#   'nasdaq',
#   'omx',
#   'helsinki',
#   'the',
#   'princip',
#   'media',
#   'financi',
#   'supervisori',
#   'author',
#   'www.sampo.com',
#   'thi',
#   'announc',
#   'distribut',
#   'thomson',
#   'reuter',
#   'behalf',
#   'thomson',
#   'reuter',
#   'client',
#   '.'],
#  ['.',
#   '@',
#   'barronsonlin',
#   'see',
#   '#',
#   'appl',
#   '$',
#   '150/share',
#   'year',
#   '(',
#   '+36',
#   '%',
#   'today',
#   ')',
#   'grow',
#   'servic',
#   'busi',
#   '.',
#   '$',
#   'aapl',
#   'http',
#   ':',
#   '//t.co/3bdnekn7l1'],
#  ['pharmaceut',
#   'market',
#   'poland',
#   'global',
#   'research',
#   '&',
#   'data',
#   'servic',
#   'publish',
#   'recent',
#   'market',
#   'analysi',
#   'pharmaceut',
#   'market',
#   'poland',
#   '.'],
#  ['altogeth', 'finnair', 'cancel', '500', 'flight', 'strike', '.'],
#  ['the',
#   'employ',
#   ',',
#   'togeth',
#   'health',
#   'personnel',
#   ',',
#   'support',
#   'quit',
#   'pay',
#   'part',
#   'cost',
#   'nicotin',
#   'treatment',
#   '.'],
#  ['pretax',
#   'loss',
#   'total',
#   'eur',
#   '117mn',
#   'compar',
#   'loss',
#   'eur',
#   '65mn',
#   'correspond',
#   'period',
#   '.'],
#  ['the',
#   'order',
#   'includ',
#   '48',
#   'ship',
#   'crane',
#   'deliv',
#   '12',
#   'contain',
#   'feeder',
#   'built',
#   'wenchong',
#   'shipyard',
#   'china',
#   '.'],
#  ['copper',
#   ',',
#   'lead',
#   'nickel',
#   'also',
#   'drop',
#   '...',
#   'hbo',
#   '(',
#   'hbo',
#   ')',
#   'plummet',
#   '20',
#   '%',
#   '70.3',
#   'penc',
#   'say',
#   'year+ó',
#   '?',
#   '?'],
#  ['$',
#   'goog',
#   'test',
#   '200',
#   'day',
#   'consolid',
#   'http',
#   ':',
#   '//stks.co/h0cpj'],
#  ['he',
#   'join',
#   'technopoli',
#   'kone',
#   'held',
#   'variou',
#   'posit',
#   'within',
#   'group',
#   ',',
#   'recent',
#   'director',
#   'servic',
#   'busi',
#   'busi',
#   'develop',
#   'kone',
#   'middl',
#   'eastern',
#   'oper',
#   '.'],
#  ['we',
#   'succeed',
#   'increas',
#   'market',
#   'share',
#   'sold',
#   'apart',
#   '``',
#   ',',
#   'comment',
#   'mr',
#   'kari',
#   'kauniskanga',
#   ',',
#   'head',
#   'yit',
#   'intern',
#   'construct',
#   'servic',
#   '.'],
#  ['profit',
#   '(',
#   'ebit',
#   '%',
#   ')',
#   '13.9',
#   '%',
#   ',',
#   'compar',
#   '13.1',
#   '%',
#   'previous-year',
#   'period',
#   '.'],
#  ['finnish',
#   'geosentr',
#   "'s",
#   'net',
#   'sale',
#   'decreas',
#   'eur',
#   '939,000',
#   'january-march',
#   '2009',
#   '.'],
#  ['the',
#   'plant',
#   'schedul',
#   'complet',
#   'late',
#   'februari',
#   '2007',
#   'hand',
#   'area',
#   'januari',
#   'two',
#   'supplier',
#   'nokia',
#   '-',
#   'aspocomp',
#   'group',
#   'oyj',
#   'perlo',
#   '-',
#   'announc',
#   'plan',
#   'establish',
#   'plant',
#   'within',
#   'nokia',
#   'complex',
#   'togeth',
#   ',',
#   'invest',
#   'rs',
#   '365',
#   'crore',
#   '.'],
#  ['-',
#   'upm-kymmen',
#   'upgrad',
#   '`',
#   'in-lin',
#   "'",
#   '`',
#   'underperform',
#   "'",
#   'goldman',
#   'sach',
#   '.'],
#  ['slump', 'weir', 'lead', 'ftse', 'record', 'high'],
#  ['jan.',
#   '6',
#   '--',
#   'ford',
#   'struggl',
#   'face',
#   'slow',
#   'truck',
#   'suv',
#   'sale',
#   'surfeit',
#   'up-to-d',
#   ',',
#   'got',
#   'ta',
#   '-have',
#   'car',
#   '.'],
#  ['royal',
#   'mail',
#   "'breach",
#   'competit',
#   'law',
#   "'",
#   'deliveri',
#   'servic',
#   'chang',
#   ',',
#   'ofcom',
#   'claim'],
#  ['the',
#   'cooper',
#   'involv',
#   'arena',
#   'partner',
#   'buy',
#   '35',
#   '%',
#   'share',
#   'new',
#   'joint',
#   'ventur',
#   'compani',
#   ',',
#   'oper',
#   'alma',
#   'media',
#   "'s",
#   'home',
#   'sale',
#   ',',
#   'vehicl',
#   'consum',
#   'advertis',
#   'marketplac',
#   'busi',
#   '.'],
#  ['the',
#   'efor',
#   'plant',
#   'saarijarvi',
#   'central',
#   'finland',
#   'one',
#   'largest',
#   'employ',
#   'region',
#   '.'],
#  ['howev', 'short-term', 'rental', 'becom', 'popular', '.'],
#  ['emsa',
#   'deputi',
#   'chairman',
#   'board',
#   'juri',
#   'lember',
#   'told',
#   'bn',
#   'wednesday',
#   'first',
#   'time',
#   'heard',
#   'strike',
#   'swedish',
#   'side',
#   'inform',
#   'estonian',
#   'union',
#   'yet',
#   '.'],
#  ['tesco',
#   'close',
#   'new',
#   'chairman',
#   'dixon',
#   'carphon',
#   "'s",
#   'john',
#   'allan',
#   'frame'],
#  ['the',
#   'devic',
#   'offer',
#   'multimedia',
#   'perform',
#   'along',
#   'host',
#   'product',
#   'applic',
#   ',',
#   'includ',
#   'live',
#   'stock',
#   'price',
#   '.'],
#  ['sale',
#   'climb',
#   '19.2',
#   'pct',
#   '1.002',
#   'bln',
#   'eur',
#   ',',
#   'surpass',
#   '953',
#   'mln',
#   'eur',
#   'consensu',
#   'figur',
#   '.'],
#  ['$',
#   'fb',
#   'turn',
#   'back',
#   'earli',
#   'trade',
#   '....',
#   'http',
#   ':',
#   '//t.co/reuf5pzhbm'],
#  ['utah',
#   "'s",
#   'capit',
#   'want',
#   'next',
#   'u.s.',
#   'headquart',
#   'amer',
#   'sport',
#   'corp.',
#   ',',
#   'ski-equip',
#   'compani',
#   '.'],
#  ['old',
#   'mutual',
#   'first-quart',
#   'sale',
#   'up',
#   '18',
#   '%',
#   'buoy',
#   'emerg',
#   'market'],
#  ['the',
#   'dividend',
#   'payabl',
#   'februari',
#   '1',
#   ',',
#   '2010',
#   'sharehold',
#   'record',
#   'januari',
#   '19',
#   ',',
#   '2010',
#   '.'],
#  ['sale',
#   'finland',
#   'decreas',
#   '10.5',
#   '%',
#   'januari',
#   ',',
#   'sale',
#   'outsid',
#   'finland',
#   'drop',
#   '17',
#   '%',
#   '.'],
#  ['furthermor',
#   ',',
#   'bung',
#   'also',
#   'sign',
#   'licens',
#   'agreement',
#   'sunnuntai',
#   'carlshamn',
#   'mejeri',
#   'brand',
#   '.'],
#  ['kesko',
#   'corpor',
#   'stock',
#   'exchang',
#   'releas',
#   '28.02.2008',
#   'at',
#   '09.30',
#   '1',
#   '(',
#   '1',
#   ')',
#   'kesko',
#   'corpor',
#   'aspo',
#   'plc',
#   'today',
#   'sign',
#   'agreement',
#   'aspo',
#   'acquir',
#   'share',
#   'capit',
#   'kauko-telko',
#   'ltd',
#   ',',
#   'subsidiari',
#   'wholli',
#   'own',
#   'kesko',
#   '.'],
#  ['$',
#   'lulu',
#   '#',
#   'outlook',
#   '#',
#   'q1',
#   '2013',
#   '#',
#   'lost',
#   'revenu',
#   'rang',
#   '$',
#   '12',
#   'million',
#   '$',
#   '17',
#   'million',
#   '-not',
#   'good'],
#  ['mobil',
#   'commun',
#   'wireless',
#   'broadband',
#   'provid',
#   'nokia',
#   'inc',
#   'nyse',
#   ':',
#   'nok',
#   'today',
#   'set',
#   'new',
#   'financi',
#   'target',
#   'forecast',
#   'nokia',
#   'mobil',
#   'devic',
#   'industri',
#   'also',
#   'nokia',
#   'siemen',
#   'network',
#   'mobil',
#   'fix',
#   'infrastructur',
#   'relat',
#   'servic',
#   'market',
#   '.'],
#  ['poyri',
#   'plc',
#   'addit',
#   'inform',
#   ':',
#   'heikki',
#   'malinen',
#   ',',
#   'presid',
#   'ceo',
#   ',',
#   'poyri',
#   'plc',
#   'tel',
#   '.',
#   '+358',
#   '10',
#   '33',
#   '21307',
#   'poyri',
#   'global',
#   'expert',
#   'consult',
#   'engin',
#   '.'],
#  ['danish',
#   'compani',
#   'flsmidth',
#   'acknowledg',
#   'violat',
#   'patent',
#   'held',
#   'finnish',
#   'metso',
#   '.'],
#  ['amanda',
#   'capit',
#   'invest',
#   '22',
#   'privat',
#   'equiti',
#   'fund',
#   '200',
#   'unquot',
#   'compani',
#   'mainli',
#   'europ',
#   '.'],
#  ['net',
#   'interest',
#   'incom',
#   'eur',
#   '39.3',
#   'mn',
#   ',',
#   'eur',
#   '32.7',
#   'mn',
#   '.'],
#  ['jeder',
#   'beta-test',
#   'erh+ñlt',
#   'kostenlo',
#   'sech',
#   'monat',
#   'lang',
#   'updat',
#   'und',
#   'hat',
#   'laut',
#   'eigen',
#   'aussag',
#   'die',
#   'm+âglichkeit',
#   ',',
#   'die',
#   'final',
#   'version',
#   'zu',
#   'beeinflussen',
#   '.'],
#  ['jp',
#   'morgan',
#   'expect',
#   'scala',
#   'lower',
# ...
#   'plc',
#   'and',
#   'prudenti',
#   'plc',
#   'now',
#   '?'],
#  ['finland',
#   'finnish',
#   'pharmaceut',
#   'compani',
#   'orion',
#   'corpor',
#   'omx',
#   'helsinki',
#   ':',
#   'ornav',
#   'said',
#   'wednesday',
#   '7',
#   'januari',
#   'conclud',
#   'personnel',
#   'negoti',
#   'finland',
#   'reduc',
#   'number',
#   'personnel',
#   '205',
#   '.'],
#  ['finnish',
#   'retail',
#   'stockmann',
#   'approv',
#   'board',
#   'swedish',
#   'rival',
#   'lindex',
#   'public',
#   'tender',
#   'offer',
#   'aim',
#   'expand',
#   'compani',
#   "'",
#   'presenc',
#   'russia',
#   'cee',
#   'countri',
#   ',',
#   'stockmann',
#   'said',
#   'monday',
#   '.'],
#  ['in',
#   'releas',
#   ',',
#   'compani',
#   'said',
#   'vocollect',
#   't2',
#   'custom',
#   'north',
#   'america',
#   'take',
#   'advantag',
#   'voic',
#   'direct',
#   'wareh',
#   'solut',
#   'increas',
#   'warehous',
#   'effici',
#   'product',
#   'gain',
#   'discount',
#   'price',
#   '.'],
#  ['nikla',
#   'skogster',
#   'employ',
#   'abb',
#   'group',
#   'variou',
#   'posit',
#   'concern',
#   'develop',
#   'oper',
#   '.'],
#  ['oper',
#   'profit',
#   ',',
#   'exclud',
#   'non-recur',
#   'item',
#   ',',
#   'total',
#   'eur',
#   '0.2',
#   'mn',
#   ',',
#   'eur',
#   '0.8',
#   'mn',
#   'correspond',
#   'period',
#   '2006',
#   '.'],
#  ['finnish',
#   'metso',
#   'paper',
#   'award',
#   'contract',
#   'rebuild',
#   'sabah',
#   'forest',
#   'industri',
#   "'",
#   '(',
#   'sfi',
#   ')',
#   'pulp',
#   'mill',
#   'sabah',
#   ',',
#   'malaysia',
#   '.'],
#  ['ruukki',
#   'forecast',
#   '15-20',
#   '%',
#   'annual',
#   'sale',
#   'growth',
#   'posit',
#   'pretax',
#   'result',
#   '2010',
#   '.'],
#  ['the', 'price', 'gmo', 'soy', '5', '%', '-7', '%', 'lower', 'non-gmo', '.'],
#  ['finland',
#   "'s",
#   'nokian',
#   'tyre',
#   'kazakhstan',
#   "'s",
#   'ordabasi',
#   'corpor',
#   'sign',
#   'agreement',
#   'build',
#   'plant',
#   'astana',
#   'produc',
#   'car',
#   'tire',
#   ',',
#   'ordabasi',
#   'chairman',
#   'dinmukhamet',
#   'idrisov',
#   'said',
#   'press',
#   'confer',
#   '.'],
#  ['with',
#   'sale',
#   '$',
#   '12.7',
#   'billion',
#   'last',
#   'twelv',
#   'month',
#   'end',
#   'octob',
#   ',',
#   '2010',
#   '9,200',
#   'store',
#   '35',
#   'state',
#   ',',
#   'dollar',
#   'gener',
#   'nation',
#   "'s",
#   'largest',
#   'small',
#   'box',
#   'discount',
#   'retail',
#   '.'],
#  ['get', 'midnighttrad', 'in', 'realtim', ':', 'thi', 'report', 'delay', '.'],
#  ['danish',
#   'compani',
#   'flsmidth',
#   'acknowledg',
#   'violat',
#   'patent',
#   'held',
#   'finnish',
#   'metso',
#   '.'],
#  ['the',
#   'share',
#   'issu',
#   ',',
#   'derog',
#   'pre-empt',
#   'right',
#   'sharehold',
#   'compris',
#   'six',
#   'million',
#   'new',
#   'share',
#   'market',
#   'price',
#   ',',
#   'offer',
#   'subscript',
#   'sharehold',
#   ',',
#   'holder',
#   'capit',
#   'note',
#   'profession',
#   'client',
#   '.'],
#  ['tielinja',
#   'gener',
#   'net',
#   'sale',
#   '7.5',
#   'mln',
#   'euro',
#   '$',
#   '9.6',
#   'mln',
#   '2005',
#   '.'],
#  ['karachi',
#   ',',
#   'sept.',
#   '14',
#   '--',
#   'ixono',
#   ',',
#   'world',
#   'leader',
#   'develop',
#   'integr',
#   'solut',
#   'handheld',
#   'devic',
#   ',',
#   'announc',
#   'implement',
#   'touch',
#   'screen',
#   'mobil',
#   'user',
#   'interfac',
#   'solut',
#   'intel',
#   'atom',
#   'processor',
#   'z6xx',
#   'base',
#   'smartphon',
#   '.'],
#  ['``',
#   'nest',
#   'oil',
#   'work',
#   '20',
#   'research',
#   'commun',
#   'europ',
#   ',',
#   'america',
#   ',',
#   'africa',
#   ',',
#   'asia',
#   ',',
#   'australia',
#   'develop',
#   'introduc',
#   'new',
#   'raw',
#   'materi',
#   '.'],
#  ['the',
#   'new',
#   'agreement',
#   ',',
#   'expand',
#   'long-establish',
#   'cooper',
#   'compani',
#   ',',
#   'involv',
#   'transfer',
#   'certain',
#   'engin',
#   'document',
#   'function',
#   'larox',
#   'etteplan',
#   '.'],
#  ['it', "'s", '.'],
#  ['took', '$', 'endp', 'long', ',', 'use', 'vwap', 'guid'],
#  ['despit',
#   'sale',
#   'growth',
#   ',',
#   'uk',
#   "'s",
#   'tesco',
#   'caution',
#   'recoveri',
#   'bumpi'],
#  ['in',
#   'finland',
#   ',',
#   'metal',
#   'sector',
#   'compani',
#   'componenta',
#   'lay',
#   'temporarili',
#   'staff',
#   'pori',
#   'mill',
#   'christma',
#   '2008',
#   'till',
#   '6',
#   'januari',
#   '2009',
#   '.'],
#  ['in',
#   'middl',
#   'east',
#   '&',
#   'north',
#   'africa',
#   ',',
#   'tecnotre',
#   'grown',
#   'consider',
#   'recent',
#   'year',
#   '.'],
#  ['both',
#   'oper',
#   'profit',
#   'net',
#   'sale',
#   'six-month',
#   'period',
#   'increas',
#   ',',
#   'respect',
#   'eur18',
#   '.1',
#   'eur127',
#   '.6',
#   ',',
#   'compar',
#   'correspond',
#   'period',
#   '2006',
#   '.'],
#  ['insur',
#   'axa',
#   '(',
#   'par',
#   ':',
#   'cs',
#   ')',
#   'slid',
#   '5.35',
#   '%',
#   'eur',
#   '14.15',
#   ',',
#   'citigroup',
#   'ing',
#   'slash',
#   'target',
#   'stock',
#   '.'],
#  ['the',
#   'order',
#   'valu',
#   'eur',
#   '6.9',
#   'mn',
#   ',',
#   'consist',
#   'design',
#   'servic',
#   'hardwar',
#   'softwar',
#   'licenc',
#   '.'],
#  ['scanfil', 'also', 'issu', 'profit', 'warn', '.'],
#  ['a',
#   'spokesman',
#   'said',
#   ':',
#   '``',
#   'the',
#   'food',
#   'store',
#   'center',
#   ',',
#   'subject',
#   'council',
#   'local',
#   'support',
#   ',',
#   'could',
#   'compris',
#   'supermarket',
#   'smaller',
#   'store',
#   'nich',
#   'outlet',
#   ',',
#   'firm',
#   'follow',
#   'consult',
#   'council',
#   'local',
#   'commun',
#   'regard',
#   'appropri',
#   'use',
#   'occupi',
#   '.',
#   '``'],
#  ['the', 'bond', 'valu', 'eur150m', 'matur', '4', 'year', '.'],
#  ['millercoor', 'board', 'name', 'gavin', 'hattersley', 'interim', 'ceo'],
#  ['airbu', 'attempt', 'evacu', '873', 'peopl', 'within', '90', 'second', '.'],
#  ['first',
#   'quarter',
#   'underli',
#   'oper',
#   'profit',
#   'rose',
#   '41',
#   'mln',
#   'eur',
#   '33',
#   'mln',
#   'year',
#   'earlier',
#   '.'],
#  ['ep',
#   'quarter',
#   'eur0',
#   '.00',
#   ',',
#   'compar',
#   'eur0',
#   '.01',
#   'third',
#   'quarter',
#   '2008',
#   ',',
#   'repres',
#   'group',
#   'net',
#   'sale',
#   'third',
#   'quarter',
#   'eur15',
#   '.3',
#   ',',
#   '2.8',
#   '%',
#   'compar',
#   'eur14',
#   '.9',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['royal', 'dutch', 'shell', 'profit', 'rise', ';', 'dividend', '4', '%'],
#  ['meanwhil',
#   ',',
#   'electrowatt-ekono',
#   'philippin',
#   ',',
#   'inc.',
#   'also',
#   'award',
#   'three-year',
#   'oper',
#   'mainten',
#   '(',
#   'o',
#   '&',
#   'm',
#   ')',
#   'contract',
#   'fr',
#   'cement',
#   'corpor',
#   '.'],
#  ['the', 'agreement', 'includ', 'applic', 'mainten', 'support', 'servic', '.'],
#  ['``', 'nokia', 'interest', 'bring', 'nokia', 'market', '.', '``'],
#  ['affecto',
#   'expect',
#   'net',
#   'sale',
#   'whole',
#   '2010',
#   'increas',
#   '2009',
#   'level',
#   'reach',
#   'eur',
#   '103',
#   'million',
#   '.'],
#  ['the',
#   'report',
#   'profil',
#   '158',
#   'compani',
#   'includ',
#   'mani',
#   'key',
#   'nich',
#   'player',
#   'includ',
#   'major',
#   'nonwoven',
#   'manufactur',
#   'ahlstrom',
#   'corpor',
#   ',',
#   'asahi',
#   'kasei',
#   'corpor',
#   ',',
#   'buckey',
#   'technolog',
#   ',',
#   'inc.',
#   ',',
#   'ei',
#   '.'],
#  ['the',
#   'lay-off',
#   'affect',
#   '240',
#   'peopl',
#   'total',
#   '320',
#   'okmet',
#   'employe',
#   'finland',
#   '.'],
#  ['``',
#   'the',
#   'acquisit',
#   'elektro',
#   'pavara',
#   'complet',
#   'kone',
#   "'s",
#   'market',
#   'expans',
#   'strategi',
#   'baltic',
#   'countri',
#   '.'],
#  ['18',
#   'may',
#   '2010',
#   '-',
#   'finnish',
#   'electron',
#   'produc',
#   'elcoteq',
#   'se',
#   'hel',
#   ':',
#   'elqav',
#   'said',
#   'today',
#   'sign',
#   'extens',
#   'cooper',
#   'agreement',
#   'industrialis',
#   ',',
#   'manufactur',
#   ',',
#   'distribut',
#   'after-market',
#   'servic',
#   'mobil',
#   'phone',
#   'japan',
#   "'s",
#   'sharp',
#   'tyo',
#   ':',
#   '6753',
#   '.'],
#  ['morrison', 'book', 'second', 'consecut', 'quarter', 'sale', 'growth'],
#  ['marimekko',
#   'today',
#   '(',
#   '20',
#   'novemb',
#   ')',
#   'sign',
#   'licens',
#   'agreement',
#   'swedish',
#   'chain',
#   ',',
#   'wherebi',
#   'marimekko',
#   'licens',
#   'popular',
#   'pattern',
#   '1950',
#   ',',
#   '1960',
#   '1970',
#   'h',
#   '&',
#   'm',
#   '.'],
#  ['quick',
#   ',',
#   '$',
#   'fio',
#   '21.35',
#   ',',
#   'market',
#   'tank',
#   ',',
#   'scale',
#   'long'],
#  ['the',
#   'announc',
#   'push',
#   'freenet',
#   'share',
#   '6.3',
#   '%',
#   ',',
#   'eur0',
#   '.71',
#   ',',
#   'frankfurt',
#   'trade',
#   'eur10',
#   '.65',
#   'investor',
#   'gave',
#   'hope',
#   'unit',
#   'internet',
#   'ag',
#   'drillisch',
#   'would',
#   'pursu',
#   'takeov',
#   'breakup',
#   'freenet',
#   '.'],
#  ['finnish',
#   'telecom',
#   'softwar',
#   'develop',
#   'tecnomen',
#   'oyj',
#   'said',
#   'decemb',
#   '5',
#   ',',
#   '2006',
#   '$',
#   '3.3',
#   'mln',
#   '(',
#   '2.5',
#   'mln',
#   'euro',
#   ')',
#   'order',
#   'suppli',
#   'expans',
#   'charg',
#   'messag',
#   'system',
#   'mobil',
#   'fix',
#   'network',
#   'brasil',
#   'telecom',
#   '.'],
#  ['companiesunilev', 'sale', 'lift', 'ice', 'cream', 'soft', 'economi'],
#  ['ep', 'drop', 'eur0', '.2', 'eur0', '.3', '.'],
#  ['@',
#   'saltwaternurs',
#   '$',
#   'ino',
#   'test',
#   '10',
#   'next',
#   'day',
#   '.',
#   'time',
#   'take',
#   'profit',
#   '.',
#   'hedg',
#   'put',
#   '.'],
#  ['no', 'financi', 'inform', 'provid', '.'],
#  ['easyjet', 'attract', 'passeng', 'june', 'still', 'lag', 'ryanair'],
#  ['morn', 'agenda', ':', 'shire', "'s", 'deal', 'np'],
#  ['metso',
#   'suppli',
#   'equip',
#   'two',
#   'process',
#   'line',
#   'northland',
#   'resourc',
#   "'",
#   'new',
#   'kaunisvaara',
#   'iron',
#   'ore',
#   'project',
#   'sweden',
#   'exploit',
#   'tapuli',
#   'sahavaara',
#   'iron',
#   'ore',
#   'deposit',
#   '.'],
#  ['under',
#   'agreement',
#   'biohit',
#   'becom',
#   'focu',
#   'supplier',
#   'pipettor',
#   'dispos',
#   'pipettor',
#   'tip',
#   'vwr',
#   'custom',
#   'throughout',
#   'europ',
#   '.'],
#  ['the',
#   'compani',
#   "'s",
#   'previou',
#   'estim',
#   'lower',
#   'revenu',
#   'year-ago',
#   'eur',
#   '93.9',
#   'million',
#   '.'],
#  ['earn',
#   'per',
#   'share',
#   '(',
#   'ep',
#   ')',
#   'drop',
#   'eur',
#   '0.21',
#   'eur',
#   '0.31',
#   '.'],
#  ['bid',
#   'offer',
#   'includ',
#   'least',
#   '1,000',
#   'share',
#   'valu',
#   'share',
#   'must',
#   'correspond',
#   'least',
#   'eur4',
#   ',000',
#   '.'],
#  ['earn',
#   'per',
#   'share',
#   '(',
#   'ep',
#   ')',
#   'amount',
#   'loss',
#   'eur0',
#   '.06',
#   '.'],
#  ['netapp',
#   'downgrad',
#   'macquari',
#   'underperform',
#   '.',
#   '$',
#   '22.00',
#   'pt',
#   '.',
#   'http',
#   ':',
#   '//t.co/xcngws0t4q',
#   '$',
#   'ntap',
#   '#',
#   'ntap',
#   'via',
#   '@',
#   'ratingsnetwork'],
#  ['``',
#   'russia',
#   'readi',
#   'particip',
#   'open',
#   'tender',
#   'lattelecom',
#   "'s",
#   'privat',
#   '.'],
#  ['technopoli',
#   'st.',
#   'petersburg',
#   'govern',
#   'sign',
#   'cooper',
#   'memorandum',
#   'octob',
#   '2005',
#   'set',
#   'techno-park',
#   'neudorf',
#   'product',
#   'zone',
#   'villag',
#   'strelni',
#   ',',
#   'st.',
#   'petersburg',
#   'suburb',
#   '.'],
#  ['the',
#   'owner',
#   'particip',
#   'busi',
#   'oper',
#   'compani',
#   'continu',
#   'poyri',
#   "'s",
#   'employ',
#   'transact',
#   '.'],
#  ['the', 'goal', 'secur', 'compani', "'s", 'profit', 'competit', '.'],
#  ['howev',
#   ',',
#   'compani',
#   'saw',
#   'net',
#   'profit',
#   'third',
#   'quarter',
#   'eur',
#   '1.4',
#   'million',
#   'eur',
#   '1.5',
#   'million',
#   'correspond',
#   'period',
#   '2009',
#   '.'],
#  ['nest',
#   'oil',
#   "'s",
#   'board',
#   'propos',
#   '1.00',
#   'eur',
#   'dividend',
#   'full-year',
#   '2007',
#   ',',
#   'compar',
#   '0.90',
#   'eur',
#   'year',
#   'ago',
#   '.'],
#  ['baswar',
#   'einvoic',
#   'oy',
#   'merg',
#   'parent',
#   'compani',
#   'present',
#   'fiscal',
#   'period',
#   '.'],
#  ['#',
#   'fintech',
#   'provid',
#   '$',
#   'cafn',
#   'cachet',
#   'financi',
#   'solut',
#   'surg',
#   'forward',
#   'today',
#   'post',
#   'earn',
#   'up',
#   '+13.26',
#   '%',
#   'http',
#   ':',
#   '//t.co/9bj3csk2i9',
#   '$',
#   'jkhi',
#   '$',
#   'fisv',
#   '#',
#   'momo'],
#  ['befor',
#   'kemira',
#   "'s",
#   'instal',
#   'nordalu',
#   'produc',
#   '3,500',
#   'ton',
#   'liquid',
#   'solid',
#   'aluminum',
#   'wast',
#   'per',
#   'year',
#   '.'],
#  ['he',
#   'charter',
#   'account',
#   'british',
#   'columbia',
#   'alberta',
#   'well',
#   'certifi',
#   'public',
#   'account',
#   'washington',
#   'state',
#   '.'],
#  ['`',
#   'veri',
#   'recommend',
#   "'",
#   'nokian',
#   'z',
#   'g2',
#   'accord',
#   '`',
#   'adac',
#   'judgement',
#   "'",
#   'latest',
#   'summer',
#   'tyre',
#   'test',
#   'german',
#   'automobil',
#   'associ',
#   'adac',
#   '.'],
#  ['-',
#   'the',
#   'group',
#   '-¦',
#   'result',
#   'tax',
#   'loss',
#   'eur',
#   '0.6',
#   '(',
#   '+0.6',
#   ')',
#   'million',
#   '.'],
#  ['-',
#   'cash',
#   'flow',
#   'oper',
#   'activ',
#   'invest',
#   'eur',
#   '0.8',
#   '-1.2',
#   'million',
#   '.'],
#  ['vike', 'line', 'cancel', 'servic', '.'],
#  ['exel', 'headquart', 'mantyharju', 'finland', '.'],
#  ['stora',
#   'chief',
#   'execut',
#   'jouko',
#   'karvinen',
#   'describ',
#   'russian',
#   'tariff',
#   'hike',
#   'threat',
#   'futur',
#   'forest',
#   'product',
#   'industri',
#   'finland',
#   '.'],
#  ['after',
#   'barclay',
#   'bank',
#   'america',
#   ',',
#   'citigroup',
#   'blockchain',
#   'sight'],
#  ['googl',
#   ',',
#   'inc.',
#   'complet',
#   'acquisit',
#   'icoa',
#   ',',
#   'inc.',
#   'http',
#   ':',
#   '//stks.co/nfei',
#   '$',
#   'icoa',
#   '$',
#   'goog'],
#  ['$',
#   'tsla',
#   'look',
#   'good',
#   '..',
#   "'d",
#   'love',
#   'see',
#   'base',
#   'action',
#   ',',
#   'let',
#   'rsi',
#   'take',
#   'breather',
#   '.',
#   'http',
#   ':',
#   '//stks.co/g1t7c'],
#  ['finnish',
#   'plumb',
#   'heat',
#   'system',
#   'supplier',
#   'uponor',
#   "'s",
#   'net',
#   'sale',
#   'continu',
#   'oper',
#   'decreas',
#   '9.4',
#   '%',
#   '2008',
#   'eur',
#   '949.2',
#   'mn',
#   'eur',
#   '1,047.4',
#   'mn',
#   '2007',
#   '.'],
#  ['thi',
#   'locat',
#   'make',
#   'mall',
#   'conveni',
#   'place',
#   'shop',
#   'consum',
#   'three',
#   'larg',
#   'residenti',
#   'area',
#   'nearbi',
#   ':',
#   'jaroszowka',
#   ',',
#   'wysockiego',
#   'zgodi',
#   '.'],
#  ['finnish',
#   'insur',
#   'compani',
#   'fennia',
#   'kesko',
#   'group',
#   'end',
#   'loyal',
#   'custom',
#   'cooper',
#   '.'],
#  ['the',
#   'case',
#   'compris',
#   'first',
#   'side',
#   'case',
#   'member',
#   'provid',
#   'first',
#   'side',
#   'vat',
#   'segment',
#   'second',
#   'side',
#   'case',
#   'member',
#   'provid',
#   'second',
#   'side',
#   'vat',
#   'segment',
#   ',',
#   'least',
#   'first',
#   'side',
#   'case',
#   'member',
#   'pivot',
#   'rotat',
#   'axi',
#   '.'],
#  ['finland-bas',
#   'elcoteq',
#   'se',
#   ',',
#   'privat',
#   'held',
#   'provid',
#   'electron',
#   'manufactur',
#   'servic',
#   'commun',
#   'compani',
#   ',',
#   'said',
#   'thursday',
#   'sign',
#   'long-term',
#   'manufactur',
#   'suppli',
#   'deal',
#   'commun',
#   'equip',
#   'compani',
#   'andrew',
#   'corp.',
#   '.'],
#  ['in',
#   'q1',
#   '2009',
#   ',',
#   'bank',
#   '+àland',
#   "'s",
#   'net',
#   'interest',
#   'incom',
#   'weaken',
#   '10',
#   '%',
#   'eur',
#   '9.1',
#   'mn',
#   '.'],
#  ['rb',
#   'pay',
#   '$',
#   '1.7',
#   'billion',
#   'scrap',
#   'u.k.',
#   'treasuri',
#   "'s",
#   'dividend',
#   'right'],
#  ['increas',
#   'trust',
#   'client',
#   'yit',
#   'seen',
#   'apart',
#   'sale',
#   'acceler',
#   '.'],
#  ['talvivaara',
#   'mine',
#   'compani',
#   'plc',
#   'talvivaara',
#   'mine',
#   'compani',
#   'intern',
#   'signific',
#   'base',
#   'metal',
#   'produc',
#   'primari',
#   'focu',
#   'nickel',
#   'zinc',
#   'use',
#   'technolog',
#   'known',
#   'bioheapleach',
#   'extract',
#   'metal',
#   'ore',
#   '.'],
#  ['oper', 'profit', '2009', 'lower', 'outlook', 'publish', 'earlier', '.'],
#  ['less', 'ten', 'peopl', 'face', 'pension', 'agreement', '.'],
#  ['the',
#   'compani',
#   "'s",
#   'consolid',
#   'oper',
#   'profit',
#   'amount',
#   'eur',
#   '15.86',
#   'mn',
#   ',',
#   'eur',
#   '4.14',
#   'mn',
#   'year-on-year',
#   '.'],
#  ['astrazeneca', 'buy', 'zs', 'pharma', '$', '2.7', 'billion'],
#  ['finnish',
#   'wast',
#   'manag',
#   'clean',
#   'group',
#   'lassila',
#   '&',
#   'tikanoja',
#   'oyj',
#   '(',
#   'l',
#   '&',
#   't',
#   ')',
#   'net',
#   'profit',
#   'went',
#   '32.2',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '47.7',
#   'mln',
#   ')',
#   '2007',
#   '35.3',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '52.3',
#   'mln',
#   ')',
#   '2006',
#   '.'],
#  ['the',
#   'oper',
#   'margin',
#   'aker',
#   'yard',
#   'cruis',
#   '&',
#   'ferri',
#   'divis',
#   'went',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['helsinki',
#   'thomson',
#   'financi',
#   '-',
#   'share',
#   'cargotec',
#   'fell',
#   'sharpli',
#   'earli',
#   'afternoon',
#   'trade',
#   'cargo',
#   'handl',
#   'group',
#   'post',
#   'surpris',
#   'drop',
#   'april-jun',
#   'profit',
#   ',',
#   'overshadow',
#   'larg',
#   'number',
#   'new',
#   'order',
#   'receiv',
#   'three',
#   'month',
#   '.'],
#  ['the',
#   'program',
#   "'s",
#   'target',
#   'structur',
#   'cost',
#   'reduct',
#   'eur',
#   '30mn',
#   '2009',
#   '.'],
#  ['our',
#   'tool',
#   'specif',
#   'design',
#   'need',
#   'busi',
#   'user',
#   'ict',
#   'expert',
#   'mind',
#   '.'],
#  ...]

# %%
pos_token=[pos_tag(message) for message in stop_token]

# %%
pos_token
# Out:
# [[('The', 'DT'),
#   ('GeoSolutions', 'NNP'),
#   ('technology', 'NN'),
#   ('leverage', 'NN'),
#   ('Benefon', 'NNP'),
#   ("'s", 'POS'),
#   ('GPS', 'NNP'),
#   ('solutions', 'NNS'),
#   ('providing', 'VBG'),
#   ('Location', 'NNP'),
#   ('Based', 'VBD'),
#   ('Search', 'NNP'),
#   ('Technology', 'NNP'),
#   (',', ','),
#   ('Communities', 'NNP'),
#   ('Platform', 'NNP'),
#   (',', ','),
#   ('location', 'NN'),
#   ('relevant', 'JJ'),
#   ('multimedia', 'NN'),
#   ('content', 'JJ'),
#   ('new', 'JJ'),
#   ('powerful', 'JJ'),
#   ('commercial', 'JJ'),
#   ('model', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('ESI', 'NNP'),
#   ('lows', 'VBZ'),
#   (',', ','),
#   ('$', '$'),
#   ('1.50', 'CD'),
#   ('$', '$'),
#   ('2.50', 'CD'),
#   ('BK', 'NNP'),
#   ('real', 'JJ'),
#   ('possibility', 'NN')],
#  [('For', 'IN'),
#   ('last', 'JJ'),
#   ('quarter', 'NN'),
#   ('2010', 'CD'),
#   (',', ','),
#   ('Componenta', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('doubled', 'VBD'),
#   ('EUR131m', 'NNP'),
#   ('EUR76m', 'NNP'),
#   ('period', 'NN'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   (',', ','),
#   ('moved', 'VBD'),
#   ('zero', 'CD'),
#   ('pre-tax', 'JJ'),
#   ('profit', 'NN'),
#   ('pre-tax', 'JJ'),
#   ('loss', 'NN'),
#   ('EUR7m', 'NNP'),
#   ('.', '.')],
#  [('According', 'VBG'),
#   ('Finnish-Russian', 'JJ'),
#   ('Chamber', 'NNP'),
#   ('Commerce', 'NNP'),
#   (',', ','),
#   ('major', 'JJ'),
#   ('construction', 'NN'),
#   ('companies', 'NNS'),
#   ('Finland', 'NNP'),
#   ('operating', 'VBG'),
#   ('Russia', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Swedish', 'JJ'),
#   ('buyout', 'NN'),
#   ('firm', 'NN'),
#   ('sold', 'VBD'),
#   ('remaining', 'VBG'),
#   ('22.4', 'CD'),
#   ('percent', 'JJ'),
#   ('stake', 'NN'),
#   (',', ','),
#   ('almost', 'RB'),
#   ('eighteen', 'JJ'),
#   ('months', 'NNS'),
#   ('taking', 'VBG'),
#   ('company', 'NN'),
#   ('public', 'JJ'),
#   ('Finland', 'NNP'),
#   ('.', '.')],
#  [('$', '$'),
#   ('SPY', 'NNP'),
#   ('would', 'MD'),
#   ("n't", 'RB'),
#   ('surprised', 'VB'),
#   ('see', 'VB'),
#   ('green', 'JJ'),
#   ('close', 'RB')],
#  [('Shell', 'NNP'),
#   ("'s", 'POS'),
#   ('$', '$'),
#   ('70', 'CD'),
#   ('Billion', 'NNP'),
#   ('BG', 'NNP'),
#   ('Deal', 'NNP'),
#   ('Meets', 'NNP'),
#   ('Shareholder', 'NNP'),
#   ('Skepticism', 'NNP')],
#  [('SSH', 'NNP'),
#   ('COMMUNICATIONS', 'NNP'),
#   ('SECURITY', 'NNP'),
#   ('CORP', 'NNP'),
#   ('STOCK', 'NNP'),
#   ('EXCHANGE', 'NNP'),
#   ('RELEASE', 'NNP'),
#   ('OCTOBER', 'NNP'),
#   ('14', 'CD'),
#   (',', ','),
#   ('2008', 'CD'),
#   ('AT', 'NNP'),
#   ('2:45', 'CD'),
#   ('PM', 'NNP'),
#   ('The', 'DT'),
#   ('Company', 'NNP'),
#   ('updates', 'VBZ'),
#   ('full', 'JJ'),
#   ('year', 'NN'),
#   ('outlook', 'NN'),
#   ('estimates', 'VBZ'),
#   ('results', 'NNS'),
#   ('remain', 'VBP'),
#   ('loss', 'NN'),
#   ('full', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Kone', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('14', 'CD'),
#   ('%', 'NN'),
#   ('year-on-year', 'JJ'),
#   ('first', 'JJ'),
#   ('nine', 'CD'),
#   ('months', 'NNS'),
#   ('2008', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Stockmann', 'NNP'),
#   ('department', 'NN'),
#   ('store', 'NN'),
#   ('total', 'JJ'),
#   ('floor', 'NN'),
#   ('space', 'NN'),
#   ('8,000', 'CD'),
#   ('square', 'JJ'),
#   ('metres', 'NNS'),
#   ('Stockmann', 'NNP'),
#   ("'s", 'POS'),
#   ('investment', 'NN'),
#   ('project', 'NN'),
#   ('price', 'NN'),
#   ('tag', 'NN'),
#   ('EUR', 'NNP'),
#   ('12', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Circulation', 'NNP'),
#   ('revenue', 'NN'),
#   ('increased', 'VBD'),
#   ('5', 'CD'),
#   ('%', 'NN'),
#   ('Finland', 'NNP'),
#   ('4', 'CD'),
#   ('%', 'NN'),
#   ('Sweden', 'JJ'),
#   ('2008', 'CD'),
#   ('.', '.')],
#  [('$', '$'),
#   ('SAP', 'NNP'),
#   ('Q1', 'NNP'),
#   ('disappoints', 'NNS'),
#   ('#', '#'),
#   ('software', 'NN'),
#   ('licenses', 'NNS'),
#   ('.', '.'),
#   ('Real', 'VB'),
#   ('problem', 'NN'),
#   ('?', '.'),
#   ('#', '#'),
#   ('Cloud', 'NNP'),
#   ('growth', 'NN'),
#   ('trails', 'VBZ'),
#   ('$', '$'),
#   ('MSFT', 'NNP'),
#   ('$', '$'),
#   ('ORCL', 'NNP'),
#   ('$', '$'),
#   ('GOOG', 'NNP'),
#   ('$', '$'),
#   ('CRM', 'NNP'),
#   ('$', '$'),
#   ('ADBE', 'NNP'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/jNDphllzq5', 'NN')],
#  [('The', 'DT'),
#   ('subdivision', 'NN'),
#   ('made', 'VBD'),
#   ('sales', 'NNS'),
#   ('revenues', 'NNS'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('EUR', 'VBD'),
#   ('480.7', 'CD'),
#   ('million', 'CD'),
#   ('EUR', 'NNP'),
#   ('414.9', 'CD'),
#   ('million', 'CD'),
#   ('2008', 'CD'),
#   (',', ','),
#   ('operating', 'VBG'),
#   ('profits', 'NNS'),
#   ('EUR', 'NNP'),
#   ('44.5', 'CD'),
#   ('million', 'CD'),
#   ('EUR', 'NNP'),
#   ('7.4', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Viking', 'VBG'),
#   ('Line', 'NNP'),
#   ('canceled', 'VBD'),
#   ('services', 'NNS'),
#   ('.', '.')],
#  [('Ahlstrom', 'IN'),
#   ('Corporation', 'NNP'),
#   ('STOCK', 'NNP'),
#   ('EXCHANGE', 'NNP'),
#   ('ANNOUNCEMENT', 'NNP'),
#   ('7.2.2007', 'CD'),
#   ('10.30', 'CD'),
#   ('A', 'NNP'),
#   ('total', 'JJ'),
#   ('56,955', 'CD'),
#   ('new', 'JJ'),
#   ('shares', 'NNS'),
#   ('Ahlstrom', 'NNP'),
#   ('Corporation', 'NNP'),
#   ('subscribed', 'VBD'),
#   ('option', 'NN'),
#   ('rights', 'NNS'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('stock', 'NN'),
#   ('option', 'NN'),
#   ('programs', 'NNS'),
#   ('I', 'PRP'),
#   ('2001', 'CD'),
#   ('II', 'NNP'),
#   ('2001', 'CD'),
#   ('.', '.')],
#  [('$', '$'), ('FB', 'NNP'), ('gone', 'VBN'), ('green', 'JJ'), ('day', 'NN')],
#  [('$', '$'),
#   ('MSFT', 'NNP'),
#   ('SQL', 'NNP'),
#   ('Server', 'NNP'),
#   ('revenue', 'NN'),
#   ('grew', 'VBD'),
#   ('double-digit', 'JJ'),
#   ('SQL', 'NNP'),
#   ('Server', 'NNP'),
#   ('Premium', 'NNP'),
#   ('revenue', 'NN'),
#   ('growing', 'VBG'),
#   ('30', 'CD'),
#   ('%', 'NN'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//stks.co/ir2F', 'NN')],
#  [('According', 'VBG'),
#   ('L+ñnnen', 'NNP'),
#   ('Tehtaat', 'NNP'),
#   ("'s", 'POS'),
#   ('CEO', 'NNP'),
#   ('Matti', 'NNP'),
#   ('Karppinen', 'NNP'),
#   (',', ','),
#   ('company', 'NN'),
#   ('aims', 'VBZ'),
#   ('deliver', 'RB'),
#   ('fish', 'JJ'),
#   ('products', 'NNS'),
#   ('customers', 'NNS'),
#   ('day', 'NN'),
#   ('earlier', 'RBR'),
#   ('currently', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('share', 'NN'),
#   ('quoted', 'VBN'),
#   ('NASDAQ', 'NNP'),
#   ('OMX', 'NNP'),
#   ('Helsinki', 'NNP'),
#   ('Rautaruukki', 'NNP'),
#   ('Oyj', 'NNP'),
#   (':', ':'),
#   ('RTRKS', 'NNP'),
#   ('.', '.')],
#  [('Elcoteq', 'NNP'),
#   ('SE', 'NNP'),
#   ('listed', 'VBD'),
#   ('Nasdaq', 'NNP'),
#   ('OMX', 'NNP'),
#   ('Helsinki', 'NNP'),
#   ('Ltd.', 'NNP'),
#   ('.', '.')],
#  [('Two', 'CD'),
#   ('contracts', 'NNS'),
#   ('turntable', 'JJ'),
#   ('anode', 'NN'),
#   ('vibrocompactors', 'NNS'),
#   ('delivered', 'VBD'),
#   ('Gansu', 'NNP'),
#   ('Hualu', 'NNP'),
#   ('Aluminum', 'NNP'),
#   ('Co', 'NNP'),
#   ('Ltd', 'NNP'),
#   ('another', 'DT'),
#   ('unnamed', 'JJ'),
#   ('costumer', 'NN'),
#   ('.', '.')],
#  [('Aviva', 'NNP'),
#   (',', ','),
#   ('Friends', 'NNP'),
#   ('Life', 'NNP'),
#   ('top', 'JJ'),
#   ('forecasts', 'NNS'),
#   ('ahead', 'RB'),
#   ('5.6', 'CD'),
#   ('billion', 'CD'),
#   ('pound', 'NN'),
#   ('merger', 'NN')],
#  [('In', 'IN'),
#   ('stead', 'NN'),
#   ('based', 'VBN'),
#   ('soft', 'JJ'),
#   ('drink', 'NN'),
#   (',', ','),
#   ('usual', 'JJ'),
#   (',', ','),
#   ('Teho', 'NNP'),
#   ('energy', 'NN'),
#   ('drink', 'NN'),
#   ('made', 'VBN'),
#   ('fresh', 'JJ'),
#   ('water', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ('plans', 'VBZ'),
#   ('increase', 'VBP'),
#   ('unit', 'NN'),
#   ("'s", 'POS'),
#   ('specialist', 'JJ'),
#   ('staff', 'NN'),
#   ('several', 'JJ'),
#   ('dozen', 'NN'),
#   ('--', ':'),
#   ('depending', 'VBG'),
#   ('market', 'NN'),
#   ('situation', 'NN'),
#   ('2010', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ('closed', 'VBD'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('turnover', 'RB'),
#   ('four', 'CD'),
#   ('million', 'CD'),
#   ('euros', 'NN'),
#   ('.', '.')],
#  [('Shire', 'NNP'),
#   ('CEO', 'NNP'),
#   ('steps', 'VBZ'),
#   ('drive', 'JJ'),
#   ('get', 'NN'),
#   ('Baxalta', 'NNP'),
#   ('board', 'NN'),
#   ('talking', 'VBG')],
#  [('Costco', 'NN'),
#   (':', ':'),
#   ('A', 'DT'),
#   ('Premier', 'NNP'),
#   ('Retail', 'NNP'),
#   ('Dividend', 'NNP'),
#   ('Play', 'NNP'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/Fa5cnh2t0t', 'JJ'),
#   ('$', '$'),
#   ('COST', 'NN')],
#  [('The', 'DT'),
#   ('five-storey', 'JJ'),
#   (',', ','),
#   ('eco-efficient', 'JJ'),
#   ('building', 'NN'),
#   ('gross', 'JJ'),
#   ('floor', 'NN'),
#   ('area', 'NN'),
#   ('15,000', 'CD'),
#   ('sq', 'NN'),
#   ('m.', 'NN'),
#   ('It', 'PRP'),
#   ('also', 'RB'),
#   ('include', 'VBP'),
#   ('apartments', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('first', 'JJ'),
#   ('installment', 'NN'),
#   ('Cinema', 'NNP'),
#   ('Series', 'NNP'),
#   ('concludes', 'VBZ'),
#   ('profile', 'JJ'),
#   ('Finnish', 'JJ'),
#   ('inventor', 'NN'),
#   ('Olavi', 'NNP'),
#   ('Linden', 'NNP'),
#   (',', ','),
#   ('whose', 'WP$'),
#   ('personal', 'JJ'),
#   ('artistic', 'JJ'),
#   ('journey', 'NN'),
#   ('work', 'NN'),
#   ('Fiskars', 'NNP'),
#   ('led', 'VBD'),
#   ('dozens', 'NNS'),
#   ('design', 'NN'),
#   ('awards', 'NNS'),
#   ('.', '.')],
#  [('All', 'DT'), ('welcome', 'NN'), ('.', '.')],
#  [('Stockmann', 'NNP'),
#   ('Swedish', 'NNP'),
#   ('sector', 'NN'),
#   ('company', 'NN'),
#   ('AB', 'NNP'),
#   ('Lindex', 'NNP'),
#   ('entered', 'VBD'),
#   ('agreement', 'NN'),
#   ('September', 'NNP'),
#   ('30', 'CD'),
#   (',', ','),
#   ('2007', 'CD'),
#   (',', ','),
#   ('whereby', 'WRB'),
#   ('Stockmann', 'NNP'),
#   (',', ','),
#   ('wholly-owned', 'JJ'),
#   ('subsidiary', 'NN'),
#   (',', ','),
#   ('make', 'VBP'),
#   ('public', 'JJ'),
#   ('tender', 'NN'),
#   ('offer', 'NN'),
#   ('Lindex', 'NNP'),
#   ("'s", 'POS'),
#   ('issued', 'JJ'),
#   ('shares', 'NNS'),
#   ('.', '.')],
#  [('HUHTAMAKI', 'NNP'),
#   ('OYJ', 'NNP'),
#   ('STOCK', 'NNP'),
#   ('EXCHANGE', 'NNP'),
#   ('RELEASE', 'NNP'),
#   (',', ','),
#   ('16.9.2008', 'CD'),
#   ('AT', 'NNP'),
#   ('13.32', 'CD'),
#   ('Huhtamaki', 'NNP'),
#   ("'s", 'POS'),
#   ('Capital', 'NN'),
#   ('Markets', 'NNPS'),
#   ('Day', 'NNP'),
#   ('institutional', 'JJ'),
#   ('investors', 'NNS'),
#   ('analysts', 'NNS'),
#   ('held', 'VBD'),
#   ('Espoo', 'NNP'),
#   (',', ','),
#   ('September', 'NNP'),
#   ('16', 'CD'),
#   (',', ','),
#   ('2008', 'CD'),
#   ('starting', 'VBG'),
#   ('13.30', 'CD'),
#   ('pm', 'JJ'),
#   ('Finnish', 'JJ'),
#   ('time', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('We', 'PRP'),
#   ('pleased', 'VBD'),
#   ('welcome', 'JJ'),
#   ('Tapeks', 'NNP'),
#   ('Noma', 'NNP'),
#   ('Cramo', 'NNP'),
#   ('group', 'NN'),
#   ('.', '.')],
#  [('-', ':'),
#   ('Profit', 'NN'),
#   ('taxes', 'NNS'),
#   ('EUR', 'NNP'),
#   ('105.9', 'CD'),
#   ('82.7', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Royal', 'NNP'),
#   ('Dutch', 'NNP'),
#   ('Shell', 'NNP'),
#   ('Buy', 'NNP'),
#   ('BG', 'NNP'),
#   ('Group', 'NNP'),
#   ('Nearly', 'NNP'),
#   ('$', '$'),
#   ('70', 'CD'),
#   ('Billion', 'NNP')],
#  [('FinancialWire', 'NNP'),
#   ('tm', 'NN'),
#   ('press', 'NN'),
#   ('release', 'NN'),
#   ('service', 'NN'),
#   (',', ','),
#   ('receives', 'VBZ'),
#   ('compensation', 'NN'),
#   ('news', 'NN'),
#   (',', ','),
#   ('opinions', 'NNS'),
#   ('distributions', 'NNS'),
#   ('.', '.')],
#  [('ASSA', 'NNP'),
#   ('ABLOY', 'NNP'),
#   ('Kaupthing', 'NNP'),
#   ('Bank', 'NNP'),
#   ('gave', 'VBD'),
#   ('`', '``'),
#   ('neutral', 'JJ'),
#   ("'", "''"),
#   ('recommendation', 'NN'),
#   ('share', 'NN'),
#   ('price', 'NN'),
#   ('target', 'NN'),
#   ('174', 'CD'),
#   ('crowns', 'JJ'),
#   ('$', '$'),
#   ('24.7', 'CD'),
#   ('-', ':'),
#   ('19', 'CD'),
#   ('euro', 'JJ'),
#   ('Swedish', 'JJ'),
#   ('lock', 'NN'),
#   ('maker', 'NN'),
#   ('Assa', 'NNP'),
#   ('Abloy', 'NNP'),
#   ('AB', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('item', 'NN'),
#   ('included', 'VBD'),
#   ('restructuring', 'NN'),
#   ('costs', 'NNS'),
#   ('EUR1', 'NNP'),
#   ('.6', 'NNP'),
#   (',', ','),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('EUR13', 'NNP'),
#   ('.1', 'NNP'),
#   ('m.', 'NN'),
#   ('Diluted', 'NNP'),
#   ('EPS', 'NNP'),
#   ('stood', 'VBD'),
#   ('EUR0', 'NNP'),
#   ('.3', 'NNP'),
#   ('versus', 'NN'),
#   ('loss', 'NN'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   ('EUR', 'NNP'),
#   ('0.1', 'CD'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('2005', 'CD'),
#   ('bank', 'NN'),
#   ('posted', 'VBD'),
#   ('net', 'JJ'),
#   ('profit', 'NN'),
#   ('Lt', 'NNP'),
#   ('8.2', 'CD'),
#   ('mn', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('AAPL', 'NNP'),
#   ('afternoon', 'NN'),
#   ('selloff', 'NN'),
#   ('usual', 'JJ'),
#   ('brutal', 'NN'),
#   ('.', '.'),
#   ('get', 'VB'),
#   ('ready', 'JJ'),
#   ('lose', 'VB'),
#   ('ton', 'JJ'),
#   ('money', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('TSLA', 'CD'),
#   ('recalling', 'VBG'),
#   ('pretty', 'RB'),
#   ('much', 'JJ'),
#   ('every', 'DT'),
#   ('single', 'JJ'),
#   ('model', 'NN'),
#   ('X', 'NNP'),
#   ('@', 'NNP'),
#   ('cnnbrk', 'NN'),
#   ('got', 'VBD'),
#   ('short', 'JJ'),
#   ('even', 'RB'),
#   ('work', 'VBP'),
#   ('jump', 'NN'),
#   ('money', 'NN'),
#   ('trade', 'NN')],
#  [('Dolce', 'NNP'),
#   ('&', 'CC'),
#   ('Gabbana', 'NNP'),
#   ('asked', 'VBD'),
#   ('European', 'NNP'),
#   ('Union', 'NNP'),
#   ('declare', 'NN'),
#   ('Marimekko', 'NNP'),
#   ('Corporation', 'NNP'),
#   ("'s", 'POS'),
#   ('``', '``'),
#   ('Unikko', 'NNP'),
#   ('``', '``'),
#   ('floral', 'JJ'),
#   ('pattern', 'NN'),
#   ('trademark', 'NN'),
#   ('invalid', 'NN'),
#   (',', ','),
#   ('continuing', 'VBG'),
#   ('dispute', 'JJ'),
#   ('two', 'CD'),
#   ('companies', 'NNS'),
#   ('.', '.')],
#  [('InterContinental', 'JJ'),
#   ('Hotels', 'NNP'),
#   ('first-quarter', 'NN'),
#   ('global', 'JJ'),
#   ('room', 'NN'),
#   ('revenue', 'NN'),
#   ('lags', 'VBZ'),
#   ('estimates', 'NNS')],
#  [('According', 'VBG'),
#   ('Finnish', 'JJ'),
#   ('pension', 'NN'),
#   ('insurance', 'NN'),
#   ('company', 'NN'),
#   ('Varma', 'NNP'),
#   (',', ','),
#   ('Varma', 'NNP'),
#   ('recipient', 'NN'),
#   ('two', 'CD'),
#   ('thirds', 'NNS'),
#   ('revenue', 'NN'),
#   ('earnings-related', 'JJ'),
#   ('pension', 'NN'),
#   ('cover', 'NN'),
#   ('competitive', 'JJ'),
#   ('tendering', 'NN'),
#   ('Finland', 'NNP'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('portion', 'NN'),
#   (',', ','),
#   ('$', '$'),
#   ('12.5', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('recorded', 'VBN'),
#   ('part', 'NN'),
#   ('winnings', 'NNS'),
#   ('prior', 'JJ'),
#   ('patent', 'NN'),
#   ('dispute', 'NN'),
#   ('Finnish', 'NNP'),
#   ('phone', 'NN'),
#   ('maker', 'NN'),
#   ('Nokia', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('.', '.')],
#  [('L', 'NNP'),
#   ('&', 'CC'),
#   ('G', 'NNP'),
#   ('still', 'RB'),
#   ('paying', 'VBG'),
#   ('price', 'NN'),
#   ('dividend', 'NN'),
#   ('cut', 'NN'),
#   ('crisis', 'NN'),
#   (',', ','),
#   ('chief', 'NN'),
#   ('says', 'VBZ')],
#  [('The', 'DT'),
#   ('volume', 'NN'),
#   ('investments', 'NNS'),
#   ('two', 'CD'),
#   ('phases', 'NNS'),
#   ('project', 'VBP'),
#   ('estimated', 'VBN'),
#   ('USD', 'NNP'),
#   ('300mn', 'CD'),
#   ('(', '('),
#   ('EUR', 'NNP'),
#   ('215.03', 'CD'),
#   ('mn', 'NN'),
#   (')', ')'),
#   ('.', '.')],
#  [('Russia', 'NNP'),
#   ('accounted', 'VBD'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('Lagardere', 'NNP'),
#   ('magazine', 'NN'),
#   ('division', 'NN'),
#   ("'s", 'POS'),
#   ('revenue', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('114.40', 'CD'),
#   ('mn', 'NN'),
#   ('(', '('),
#   ('USD', 'NNP'),
#   ('148.11', 'CD'),
#   ('mn', 'NN'),
#   (')', ')'),
#   ('2009', 'CD'),
#   (',', ','),
#   ('USA', 'NNP'),
#   ('-', ':'),
#   ('18', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ('also', 'RB'),
#   ('estimates', 'VBZ'),
#   ('already', 'RB'),
#   ('carried', 'VBN'),
#   ('investments', 'NNS'),
#   ('lead', 'JJ'),
#   ('increase', 'JJ'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('2010', 'CD'),
#   ('2009', 'CD'),
#   ('reached', 'VBD'),
#   ('EUR', 'NNP'),
#   ('141.7', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Profit', 'NN'),
#   ('accounting', 'NN'),
#   ('period', 'NN'),
#   ('EUR', 'NNP'),
#   ('0.3', 'CD'),
#   ('mn', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('six', 'CD'),
#   ('breweries', 'NNS'),
#   ('recorded', 'VBD'),
#   ('5.2', 'CD'),
#   ('percent', 'NN'),
#   ('growth', 'NN'),
#   ('domestic', 'JJ'),
#   ('beer', 'NN'),
#   ('sales', 'NNS'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('270.21', 'CD'),
#   ('million', 'CD'),
#   ('liters', 'NNS'),
#   (',', ','),
#   ('256.88', 'CD'),
#   ('million', 'CD'),
#   ('liters', 'NNS'),
#   ('sold', 'JJ'),
#   ('2005', 'CD'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('August-October', 'NNP'),
#   ('2010', 'CD'),
#   (',', ','),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('result', 'NN'),
#   ('taxes', 'NNS'),
#   ('totalled', 'VBD'),
#   ('EUR', 'NNP'),
#   ('9.6', 'CD'),
#   ('mn', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('0.5', 'CD'),
#   ('mn', 'NN'),
#   ('corresponding', 'VBG'),
#   ('period', 'NN'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Systeemitiimi', 'NNP'),
#   ("'s", 'POS'),
#   ('sales', 'NNS'),
#   ('project', 'NN'),
#   ('resources', 'NNS'),
#   ('also', 'RB'),
#   ('strengthened', 'VBD'),
#   (',', ','),
#   ('director', 'NN'),
#   ('Paul', 'NNP'),
#   ('Skogberg', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Tesco', 'NNP'),
#   ('share', 'NN'),
#   ('price', 'NN'),
#   ('jumps', 'NNS'),
#   ('Q3', 'NNP'),
#   ('sales', 'NNS'),
#   ('top', 'NN'),
#   ('estimates', 'NNS')],
#  [('The', 'DT'), ('fine', 'JJ'), ('print', 'NN'), ('.', '.')],
#  [('The', 'DT'),
#   ('price', 'NN'),
#   ('logs', 'NNS'),
#   ('clearly', 'RB'),
#   ('improved', 'VBN'),
#   ('2009', 'CD'),
#   ('also', 'RB'),
#   ('price', 'NN'),
#   ('pulpwood', 'NN'),
#   ('gone', 'VBN'),
#   ('.', '.')],
#  [('Thus', 'RB'),
#   (',', ','),
#   ('SysOpen', 'NNP'),
#   ('Digia', 'NNP'),
#   (',', ','),
#   ('accordance', 'NN'),
#   ('Chapter', 'NN'),
#   ('14', 'CD'),
#   ('Section', 'NN'),
#   ('21', 'CD'),
#   ('Finnish', 'JJ'),
#   ('Companies', 'NNP'),
#   ('Act', 'NNP'),
#   ('29.9.1978', 'CD'),
#   ('-', ':'),
#   ('734', 'CD'),
#   (',', ','),
#   ('obtained', 'VBD'),
#   ('title', 'JJ'),
#   ('shares', 'NNS'),
#   ('Sentera', 'NNP'),
#   ('redeemed', 'VBD'),
#   ('.', '.')],
#  [('Diluted', 'VBN'),
#   ('earnings', 'NNS'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   ('(', '('),
#   ('EPS', 'NNP'),
#   (')', ')'),
#   ('fell', 'VBD'),
#   ('EUR', 'NNP'),
#   ('0.63', 'CD'),
#   ('EUR', 'NNP'),
#   ('1.71', 'CD'),
#   ('.', '.')],
#  [('At', 'IN'),
#   ('3:37', 'CD'),
#   ('p.m.', 'NN'),
#   ('Eastern', 'NNP'),
#   ('time', 'NN'),
#   (',', ','),
#   ('block', 'VB'),
#   ('2,400', 'CD'),
#   ('contracts', 'NNS'),
#   ('changed', 'VBD'),
#   ('hands', 'NNS'),
#   ('bid', 'JJ'),
#   ('price', 'NN'),
#   ('$', '$'),
#   ('0.45', 'CD'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('recent', 'JJ'),
#   ('technology', 'NN'),
#   ('deliveries', 'NNS'),
#   ('include', 'VBP'),
#   ('refinery', 'JJ'),
#   ('technology', 'NN'),
#   ('Anrak', 'NNP'),
#   ('Aluminium', 'NNP'),
#   (',', ','),
#   ('iron', 'NN'),
#   ('ore', 'NN'),
#   ('pelletizing', 'NN'),
#   ('plant', 'NN'),
#   ('Tata', 'NNP'),
#   ('Steel', 'NNP'),
#   ('iron', 'NN'),
#   ('ore', 'RB'),
#   ('sintering', 'VBG'),
#   ('plants', 'NNS'),
#   ('Bhushan', 'NNP'),
#   ('Steel', 'NNP'),
#   ('.', '.')],
#  [('$', '$'),
#   ('VIPS', 'NNP'),
#   ('similar', 'JJ'),
#   ('pattern', 'NN'),
#   ('like', 'IN'),
#   ('beginning', 'VBG'),
#   ('May', 'NNP'),
#   ('.', '.'),
#   ('Did', 'NNP'),
#   ('u', 'VB'),
#   ('sell', 'VB'),
#   ('?', '.'),
#   ('Same', 'NNP'),
#   ('..', 'NNP'),
#   ('go', 'VB'),
#   ('much', 'RB'),
#   ('higher', 'JJR'),
#   ('drop', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('firm', 'NN'),
#   ('generated', 'VBD'),
#   ('sales', 'NNS'),
#   ('187', 'CD'),
#   ('mln', 'NNS'),
#   ('eur', 'JJ'),
#   ('2005', 'CD'),
#   ('.', '.')],
#  [('Stora', 'NNP'),
#   ('Enso', 'NNP'),
#   ('also', 'RB'),
#   ('meetings', 'NNS'),
#   ('labor', 'NN'),
#   ('authorities', 'NNS'),
#   (',', ','),
#   ('Employment', 'NNP'),
#   ('Economic', 'NNP'),
#   ('Development', 'NNP'),
#   ('Centres', 'NNP'),
#   ('representatives', 'NNS'),
#   ('government', 'NN'),
#   ('order', 'NN'),
#   ('find', 'VBP'),
#   ('solutions', 'NNS'),
#   ('.', '.')],
#  [('AstraZeneca', 'JJ'),
#   ('profit', 'NN'),
#   ('sales', 'NNS'),
#   ('stalwarts', 'NNS'),
#   ('fade', 'VBD')],
#  [('RT', 'NNP'),
#   ('@', 'NNP'),
#   ('andrewnyquist', 'JJ'),
#   ('Chartology', 'NNP'),
#   (':', ':'),
#   ('Yahoo', 'NN'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//stks.co/1itr', 'JJ'),
#   ('$', '$'),
#   ('YHOO', 'NNP'),
#   ('Crazy', 'NNP'),
#   ('looking', 'VBG'),
#   ('chart', 'NN'),
#   (',', ','),
#   ('nearing', 'VBG'),
#   ('breakout', 'NN'),
#   ('resistance', 'NN'),
#   ('line', 'NN'),
#   ('...', ':')],
#  [('Most', 'JJS'),
#   ('bullish', 'JJ'),
#   ('stocks', 'NNS'),
#   ('Twitter', 'NNP'),
#   ('dip', 'NN'),
#   ('.', '.'),
#   ('$', '$'),
#   ('YHOO', 'JJ'),
#   ('$', '$'),
#   ('GDX', 'NNP'),
#   ('$', '$'),
#   ('GOOGL', 'NNP'),
#   ('$', '$'),
#   ('STZ', 'NNP'),
#   ('$', '$'),
#   ('GOLD', 'NNP'),
#   ('$', '$'),
#   ('EW', 'NNP'),
#   ('$', '$'),
#   ('VZ', 'NNP'),
#   ('$', '$'),
#   ('CELG', 'NNP'),
#   ('$', '$'),
#   ('SBUX', 'NNP'),
#   ('$', '$'),
#   ('SCTY', 'NNP'),
#   (':', ':'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/iuZJelfwt3', 'NN')],
#  [('Finnish', 'JJ'),
#   ('GeoSentric', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('decreased', 'VBD'),
#   ('EUR', 'JJ'),
#   ('939,000', 'CD'),
#   ('January-March', 'JJ'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Cohen', 'NNP'),
#   ('&', 'CC'),
#   ('Steers', 'NNP'),
#   (',', ','),
#   ('Inc.', 'NNP'),
#   (':', ':'),
#   ('5', 'CD'),
#   ('534', 'CD'),
#   ('626', 'CD'),
#   ('shares', 'NNS'),
#   ('representing', 'VBG'),
#   ('4.985', 'CD'),
#   ('%', 'NN'),
#   ('share', 'NN'),
#   ('capital', 'NN'),
#   ('voting', 'NN'),
#   ('rights', 'NNS'),
#   ('.', '.')],
#  [('More', 'RBR'),
#   ('staff', 'NN'),
#   ('recruited', 'VBN'),
#   ('Japan', 'NNP'),
#   ('complement', 'NN'),
#   ('network', 'NN'),
#   ('close', 'RB'),
#   ('50', 'CD'),
#   ('service', 'NN'),
#   ('locations', 'NNS'),
#   ('20', 'CD'),
#   ('countries', 'NNS'),
#   ('worldwide', 'RB'),
#   ('.', '.')],
#  [('Paper', 'NN'),
#   ('companies', 'NNS'),
#   ('negative', 'JJ'),
#   ('territories', 'NNS'),
#   (',', ','),
#   ('Stora', 'NNP'),
#   ('Enso', 'NNP'),
#   ('R', 'NNP'),
#   ('shedding', 'VBG'),
#   ('1.62', 'CD'),
#   ('pct', 'JJ'),
#   ('12.73', 'CD'),
#   ('eur', 'NN'),
#   (',', ','),
#   ('UPM-Kymmene', 'JJ'),
#   ('0.80', 'CD'),
#   ('pct', 'NN'),
#   ('18.64', 'CD'),
#   ('eur', 'NN'),
#   ('M-real', 'NNP'),
#   ('B', 'NNP'),
#   ('0.18', 'CD'),
#   ('pct', 'NN'),
#   ('lower', 'JJR'),
#   ('5.57', 'CD'),
#   ('eur', 'NN'),
#   ('.', '.')],
#  [('Kauko-Telko', 'NNP'),
#   ("'s", 'POS'),
#   ('centralized', 'JJ'),
#   ('administration', 'NN'),
#   ('dissolved', 'VBD'),
#   ('appropriate', 'JJ'),
#   ('parts', 'NNS'),
#   ('transferred', 'VBD'),
#   ('operating', 'NN'),
#   ('activities', 'NNS'),
#   ('Group', 'NNP'),
#   ('administration', 'NN'),
#   ('end', 'NN'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Operating', 'NN'),
#   ('profit', 'NN'),
#   ('quarter', 'NN'),
#   ('April-June', 'JJ'),
#   ('2006', 'CD'),
#   ('amounted', 'VBD'),
#   ('EUR182', 'NNP'),
#   ('.2', 'NNP'),
#   ('sales', 'NNS'),
#   ('EUR3', 'NNP'),
#   ('.62', 'NNP'),
#   ('bn', 'NN'),
#   ('.', '.')],
#  [('Atria', 'NNP'),
#   ('chose', 'VBD'),
#   ('DeLight', 'NNP'),
#   ('attract', 'JJ'),
#   ('consumers', 'NNS'),
#   ('25-45', 'JJ'),
#   ('age', 'NN'),
#   ('group', 'NN'),
#   ('Atria', 'NNP'),
#   ('Fresh', 'NNP'),
#   ('range', 'NN'),
#   ('microwaveable', 'JJ'),
#   ('meals', 'NNS'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('IT', 'NNP'),
#   ('solutions', 'NNS'),
#   ('provider', 'NN'),
#   ('Affecto', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('HEL', 'NNP'),
#   (':', ':'),
#   ('AFE1V', 'NNP'),
#   ('said', 'VBD'),
#   ('today', 'NN'),
#   ('slipped', 'VBD'),
#   ('net', 'JJ'),
#   ('loss', 'NN'),
#   ('EUR', 'NNP'),
#   ('115,000', 'CD'),
#   ('USD', 'NNP'),
#   ('152,000', 'CD'),
#   ('second', 'JJ'),
#   ('quarter', 'NN'),
#   ('2010', 'CD'),
#   ('profit', 'NN'),
#   ('EUR', 'NNP'),
#   ('845,000', 'CD'),
#   ('corresponding', 'VBG'),
#   ('period', 'NN'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('US', 'JJ'),
#   ('sanctions', 'NNS'),
#   ('put', 'VBD'),
#   ('Gazprom-Shell', 'NNP'),
#   ('alliance', 'NN'),
#   ('plans', 'NNS'),
#   ('jeopardy', 'VBP')],
#  [('Profit', 'NN'),
#   ('period', 'NN'),
#   ('EUR', 'NNP'),
#   ('10.9', 'CD'),
#   ('mn', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('14.3', 'CD'),
#   ('mn', 'NN'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Profit', 'NN'),
#   ('period', 'NN'),
#   ('EUR', 'NNP'),
#   ('5.9', 'CD'),
#   ('mn', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('1.3', 'CD'),
#   ('mn', 'NN'),
#   ('.', '.')],
#  [('Operating', 'NN'),
#   ('profit', 'NN'),
#   ('fell', 'VBD'),
#   ('EUR', 'NNP'),
#   ('20.3', 'CD'),
#   ('mn', 'NN'),
#   ('EUR', 'NNP'),
#   ('74.2', 'CD'),
#   ('mn', 'JJ'),
#   ('second', 'JJ'),
#   ('quarter', 'NN'),
#   ('2008', 'CD'),
#   ('.', '.')],
#  [('However', 'RB'),
#   (',', ','),
#   ('sales', 'NNS'),
#   ('returned', 'VBD'),
#   ('growth', 'NN'),
#   ('April-June', 'NNP'),
#   ('2010', 'CD'),
#   (',', ','),
#   ('CEO', 'NNP'),
#   ('Pekka', 'NNP'),
#   ('Eloholma', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Operating', 'NN'),
#   ('profit', 'NN'),
#   ('totaled', 'VBD'),
#   ('EUR', 'NNP'),
#   ('18.6', 'CD'),
#   ('mn', 'VBD'),
#   ('8.3', 'CD'),
#   ('%', 'NN'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('.', '.')],
#  [('Changes', 'NNS'),
#   ('market', 'NN'),
#   ('situation', 'NN'),
#   ('tougher', 'RB'),
#   ('price', 'NN'),
#   ('competition', 'NN'),
#   ('substantially', 'RB'),
#   ('reduced', 'VBN'),
#   ('demand', 'NN'),
#   ('bread', 'NN'),
#   ('packaging', 'NN'),
#   ('manufactured', 'VBD'),
#   ('Kauhava', 'NNP'),
#   ('plant', 'NN'),
#   (',', ','),
#   ('according', 'VBG'),
#   ('company', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('connection', 'NN'),
#   ('deal', 'NN'),
#   (',', ','),
#   ('Digia', 'NNP'),
#   ('employ', 'VBZ'),
#   ('19', 'CD'),
#   ('persons', 'NNS'),
#   ('Nokia', 'NNP'),
#   ('Oslo', 'NNP'),
#   ('Silicon', 'NNP'),
#   ('Valley', 'NNP'),
#   ('USA', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Brazilian', 'JJ'),
#   ('unit', 'NN'),
#   ('Finnish', 'JJ'),
#   ('security', 'NN'),
#   ('solutions', 'NNS'),
#   ('provider', 'VBP'),
#   ('F-Secure', 'NN'),
#   ('signed', 'VBD'),
#   ('1,500', 'CD'),
#   ('new', 'JJ'),
#   ('clients', 'NNS'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   (',', ','),
#   ('online', 'JJ'),
#   ('news', 'NN'),
#   ('source', 'NN'),
#   ('Reseller', 'NNP'),
#   ('Web', 'NNP'),
#   ('quoted', 'VBD'),
#   ('division', 'NN'),
#   ("'s", 'POS'),
#   ('commercial', 'JJ'),
#   ('director', 'NN'),
#   (',', ','),
#   ('Vladimir', 'NNP'),
#   ('Brand+úo', 'NNP'),
#   (',', ','),
#   ('saying', 'VBG'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('fair', 'JJ'),
#   ('value', 'NN'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('investment', 'NN'),
#   ('properties', 'NNS'),
#   ('went', 'VBD'),
#   ('EUR', 'NNP'),
#   ('2.768', 'CD'),
#   ('billion', 'CD'),
#   ('end', 'NN'),
#   ('2009', 'CD'),
#   ('EUR', 'NNP'),
#   ('2.916', 'CD'),
#   ('billion', 'CD'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Dealers', 'NNS'),
#   ('said', 'VBD'),
#   ('share', 'NN'),
#   ('largely', 'RB'),
#   ('hit', 'VBD'),
#   ('investor', 'NN'),
#   ('disappointment', 'NN'),
#   ('refining', 'VBG'),
#   ('margin', 'NN'),
#   ('9.48', 'CD'),
#   ('usd', 'JJ'),
#   ('per', 'IN'),
#   ('barrel', 'JJ'),
#   ('quarter', 'NN'),
#   ('performance', 'NN'),
#   ('shipping', 'VBG'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('saw', 'VBD'),
#   ('EBIT', 'NNP'),
#   ('drop', 'NN'),
#   ('5', 'CD'),
#   ('mln', 'NN'),
#   ('eur', 'NN'),
#   ('20', 'CD'),
#   ('mln', 'NN'),
#   ('eur', 'NN'),
#   ('year', 'NN'),
#   ('amid', 'IN'),
#   ('fall', 'NN'),
#   ('volumes', 'NNS'),
#   ('tanker', 'NN'),
#   ('rates', 'NNS'),
#   ('.', '.')],
#  [('`', '``'),
#   ('It', 'PRP'),
#   ('testament', 'JJ'),
#   ('quality', 'NN'),
#   ('LTE', 'NNP'),
#   ('solution', 'NN'),
#   ('commitment', 'NN'),
#   ('Japanese', 'JJ'),
#   ('market', 'NN'),
#   ("'", "''"),
#   (',', ','),
#   ('added', 'VBD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('companies', 'NNS'),
#   ("'", 'POS'),
#   ('aim', 'NN'),
#   ('finalize', 'VBP'),
#   ('negotiations', 'NNS'),
#   ('sign', 'NN'),
#   ('contracts', 'NNS'),
#   ('start', 'VBP'),
#   ('October', 'NNP'),
#   ('2008', 'CD'),
#   ('.', '.')],
#  [('Metso', 'NNP'),
#   ('Foundries', 'NNP'),
#   ('Jyvaskyla', 'NNP'),
#   ('Oy', 'NNP'),
#   ('discontinue', 'NN'),
#   ('production', 'NN'),
#   ('line', 'NN'),
#   ('30', 'CD'),
#   ('September', 'NNP'),
#   ('2008', 'CD'),
#   (',', ','),
#   ('company', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('total', 'JJ'),
#   ('six', 'CD'),
#   ('polled', 'VBD'),
#   ('analysts', 'NNS'),
#   ('rated', 'VBN'),
#   ('M-real', 'JJ'),
#   ('--', ':'),
#   ('two', 'CD'),
#   ('gave', 'VBD'),
#   ('``', '``'),
#   ('buy', 'VB'),
#   ('``', '``'),
#   ('-', ':'),
#   ('``', '``'),
#   ('accumulate', 'NN'),
#   ('``', '``'),
#   (',', ','),
#   ('three', 'CD'),
#   ('gave', 'VBD'),
#   ('``', '``'),
#   ('hold', 'VB'),
#   ('``', '``'),
#   ('one', 'CD'),
#   ('gave', 'VBD'),
#   ('``', '``'),
#   ('sell', 'VB'),
#   ('``', '``'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('September', 'NNP'),
#   ('2010', 'CD'),
#   (',', ','),
#   ('Finnish', 'NNP'),
#   ('group', 'NN'),
#   ('agreed', 'VBD'),
#   ('buy', 'VBP'),
#   ('Danish', 'JJ'),
#   ('company', 'NN'),
#   ('Rose', 'NNP'),
#   ('Poultry', 'NNP'),
#   ('A-S', 'NNP'),
#   ('EUR23', 'NNP'),
#   ('.9', 'NNP'),
#   ('combination', 'NN'),
#   ('cash', 'NN'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('YANG', 'NNP'),
#   ('Double', 'NNP'),
#   ('bottom', 'NN'),
#   ('5.2', 'CD')],
#  [('Tesco', 'NNP'),
#   ('share', 'NN'),
#   ('price', 'NN'),
#   ('grocer', 'NN'),
#   ('faces', 'VBZ'),
#   ('SFO', 'NNP'),
#   ('investigation', 'NN'),
#   ('outcome', 'NN')],
#  [('$', '$'),
#   ('aapl', 'JJ'),
#   ('news', 'NN'),
#   ('becoming', 'VBG'),
#   ('bullish', 'JJ'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//stks.co/tMU', 'NN')],
#  [('GS', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('install', 'NN'),
#   ('valves', 'NNS'),
#   ('liquefied', 'VBD'),
#   ('natural', 'JJ'),
#   ('gas', 'NN'),
#   ('LNG', 'NNP'),
#   ('plant', 'NN'),
#   ('built', 'VBN'),
#   ('UAE', 'NNP'),
#   ('LNG', 'NNP'),
#   ('extraction', 'NN'),
#   ('gas', 'NN'),
#   ('plants', 'NNS'),
#   ('operator', 'VBP'),
#   ('GASCO', 'NNP'),
#   ('Ruwais', 'NNP'),
#   (',', ','),
#   ('UAE', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('percentages', 'NNS'),
#   ('shares', 'NNS'),
#   ('voting', 'VBG'),
#   ('rights', 'NNS'),
#   ('calculated', 'VBN'),
#   ('proportion', 'NN'),
#   ('total', 'JJ'),
#   ('number', 'NN'),
#   ('shares', 'NNS'),
#   ('registered', 'VBD'),
#   ('Trade', 'NNP'),
#   ('Register', 'NNP'),
#   ('total', 'JJ'),
#   ('number', 'NN'),
#   ('voting', 'NN'),
#   ('rights', 'NNS'),
#   ('related', 'VBN'),
#   ('.', '.')],
#  [('M-Real', 'NNP'),
#   ('said', 'VBD'),
#   ('`', '``'),
#   ('grounds', 'NNS'),
#   ("'", "''"),
#   ('rumors', 'NNS'),
#   (',', ','),
#   ('`', '``'),
#   ('circulating', 'VBG'),
#   ('market', 'NN'),
#   ('months', 'NNS'),
#   ('.', '.'),
#   ("'", "''")],
#  [('Lember', 'NNP'),
#   ('said', 'VBD'),
#   ('matter', 'RBR'),
#   ('topical', 'JJ'),
#   ('also', 'RB'),
#   ('Estonia', 'NNP'),
#   (',', ','),
#   ('bill', 'NN'),
#   ('drafted', 'VBN'),
#   ('Social', 'NNP'),
#   ('Affairs', 'NNPS'),
#   ('Ministry', 'NNP'),
#   ('would', 'MD'),
#   ('scrap', 'VB'),
#   ('old-age', 'JJ'),
#   ('pensions', 'NNS'),
#   ('favorable', 'JJ'),
#   ('conditions', 'NNS'),
#   ('.', '.')],
#  [('-', ':'),
#   ('Moody', 'NNP'),
#   ("'s", 'POS'),
#   ('said', 'VBD'),
#   ('gave', 'VBD'),
#   ('P', 'NNP'),
#   ('A1', 'NNP'),
#   ('long-term', 'JJ'),
#   ('senior', 'JJ'),
#   ('unsecured', 'JJ'),
#   ('P', 'NNP'),
#   ('P-1', 'NNP'),
#   ('short-term', 'JJ'),
#   ('debt', 'NN'),
#   ('ratings', 'NNS'),
#   ('Finnish', 'JJ'),
#   ('lender', 'NN'),
#   ('Aktia', 'NNP'),
#   ('Bank', 'NNP'),
#   ("'s", 'POS'),
#   ('EUR1bn', 'NNP'),
#   ('USD1', 'NNP'),
#   ('.4', 'NNP'),
#   ('bn', 'VBD'),
#   ('euro', 'JJ'),
#   ('medium-term', 'JJ'),
#   ('note', 'NN'),
#   ('EMTN', 'NNP'),
#   ('program', 'NN'),
#   ('25', 'CD'),
#   ('March', 'NNP'),
#   ('2011', 'CD'),
#   ('.', '.')],
#  [('$', '$'), ('TSLA', 'CD'), ('recall', 'NN')],
#  [('The', 'DT'),
#   ('liquidity', 'NN'),
#   ('providing', 'VBG'),
#   ('interrupted', 'VBN'),
#   ('May', 'NNP'),
#   ('11', 'CD'),
#   (',', ','),
#   ('2007', 'CD'),
#   ('Aspocomp', 'NNP'),
#   ('Group', 'NNP'),
#   ('Oyj', 'NNP'),
#   ("'s", 'POS'),
#   ('shares', 'NNS'),
#   ('traded', 'VBD'),
#   ('0.50', 'CD'),
#   ('cent', 'NN'),
#   ('(', '('),
#   ('Aspocomp', 'NNP'),
#   ("'s", 'POS'),
#   ('stock', 'NN'),
#   ('exchange', 'NN'),
#   ('release', 'NN'),
#   ('11.5.2007', 'CD'),
#   (')', ')'),
#   ('.', '.')],
#  [('Hargreaves', 'NNS'),
#   ('Lansdown', 'NNP'),
#   ('bucks', 'VBZ'),
#   ('weak', 'JJ'),
#   ('markets', 'NNS'),
#   ('see', 'VBP'),
#   ('assets', 'NNS'),
#   ('rise', 'VB'),
#   ('2.6', 'CD'),
#   ('percent', 'NN')],
#  [('At', 'IN'),
#   ('12.59', 'CD'),
#   ('pm', 'NN'),
#   (',', ','),
#   ('OMX', 'NNP'),
#   ('Helsinki', 'NNP'),
#   ('25', 'CD'),
#   ('index', 'NN'),
#   ('0.32', 'CD'),
#   ('pct', 'NN'),
#   ('lower', 'JJR'),
#   ('2,694.81', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('decision', 'NN'),
#   ('means', 'VBZ'),
#   ('temporary', 'JJ'),
#   ('lay-offs', 'NNS'),
#   ('fixed', 'VBN'),
#   ('duration', 'NN'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('Nastola', 'NNP'),
#   ('Jyvaskyla', 'NNP'),
#   ('units', 'NNS'),
#   (',', ','),
#   ('southern', 'JJ'),
#   ('central', 'JJ'),
#   ('Finland', 'NNP'),
#   (',', ','),
#   ('respectively', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('value', 'NN'),
#   ('orders', 'NNS'),
#   ('EUR', 'NNP'),
#   ('10mn', 'CD'),
#   ('.', '.')],
#  [('Ms', 'NNP'),
#   ('Laakso', 'NNP'),
#   ('responsible', 'JJ'),
#   ('HKScan', 'NNP'),
#   ("'s", 'POS'),
#   ('HR', 'NNP'),
#   ('functions', 'NNS'),
#   ('development', 'NN'),
#   ('Group', 'NNP'),
#   ('`', '``'),
#   ('smarket', 'NN'),
#   ('areas', 'NNS'),
#   ('.', '.')],
#  [('Fiskars', 'NNS'),
#   ('also', 'RB'),
#   ('engaged', 'VBD'),
#   ('global', 'JJ'),
#   ('supply', 'NN'),
#   ('marine', 'JJ'),
#   ('energy', 'NN'),
#   ('equipment', 'NN'),
#   ('solutions', 'NNS'),
#   ('services', 'NNS'),
#   ('associated', 'VBN'),
#   ('company', 'NN'),
#   (',', ','),
#   ('Wartsila', 'NNP'),
#   ('Corporation', 'NNP'),
#   ('.', '.')],
#  [('Aberdeen', 'JJ'),
#   ('Asset', 'NNP'),
#   ('Management', 'NNP'),
#   ('Gains', 'NNP'),
#   ('Foothold', 'NNP'),
#   ('In', 'IN'),
#   ('China', 'NNP')],
#  [('Finland', 'NNP'),
#   ("'s", 'POS'),
#   ('dominating', 'VBG'),
#   ('rail', 'NN'),
#   ('company', 'NN'),
#   ('VR', 'NNP'),
#   ('planning', 'NN'),
#   ('set', 'NN'),
#   ('infected', 'VBD'),
#   ('passengers', 'NNS'),
#   ('long-distance', 'JJ'),
#   ('trip', 'NN'),
#   ('separate', 'JJ'),
#   ('carriage', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('November', 'NNP'),
#   (',', ','),
#   ('Finnish', 'JJ'),
#   ('government', 'NN'),
#   ('decreased', 'VBD'),
#   ('ownership', 'NN'),
#   ('company', 'NN'),
#   ('31.1', 'CD'),
#   ('percent', 'NN'),
#   ('38', 'CD'),
#   ('percent', 'NN'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('Exel', 'NNP'),
#   ('Composites', 'NNP'),
#   (',', ','),
#   ('technology', 'NN'),
#   ('company', 'NN'),
#   ('designs', 'VBZ'),
#   (',', ','),
#   ('manufactures', 'NNS'),
#   (',', ','),
#   ('markets', 'NNS'),
#   ('composite', 'VBP'),
#   ('profiles', 'NNS'),
#   ('tubes', 'RB'),
#   ('various', 'JJ'),
#   ('industrial', 'JJ'),
#   ('applications', 'NNS'),
#   (',', ','),
#   ('reports', 'NNS'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('decreased', 'VBD'),
#   ('0.6', 'CD'),
#   ('%', 'NN'),
#   ('second', 'JJ'),
#   ('quarter', 'NN'),
#   ('2010', 'CD'),
#   ('EUR', 'NNP'),
#   ('19.2', 'CD'),
#   ('mn', 'NN'),
#   ('EUR', 'NNP'),
#   ('19.3', 'CD'),
#   ('mn', 'NN'),
#   ('corresponding', 'VBG'),
#   ('period', 'NN'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Of', 'IN'),
#   ('Bavelloni', 'NNP'),
#   ("'s", 'POS'),
#   ('NST', 'NNP'),
#   ("'s", 'POS'),
#   ('joint', 'JJ'),
#   ('ventures', 'NNS'),
#   (',', ','),
#   ('Bavelloni', 'NNP'),
#   ('Tools', 'NNP'),
#   (',', ','),
#   ('completes', 'VBZ'),
#   ('semiproducts', 'NNS'),
#   ('produced', 'VBN'),
#   ('Italy', 'NNP'),
#   ('high-quality', 'NN'),
#   ('tools', 'NNS'),
#   ('sold', 'VBD'),
#   ('DiaPol', 'NNP'),
#   ('brand', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('tool', 'NN'),
#   ('patent', 'NN'),
#   ('pending', 'VBG'),
#   ('design', 'NN'),
#   ('allows', 'VBZ'),
#   ('consumers', 'NNS'),
#   ('lay', 'VBD'),
#   ('entire', 'JJ'),
#   ('project', 'NN'),
#   ('removable', 'JJ'),
#   ('plate', 'NN'),
#   ('using', 'VBG'),
#   ('multiple', 'JJ'),
#   ('clear', 'JJ'),
#   ('stamps', 'NNS'),
#   ('kind', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('GOOGL', 'NNP'),
#   ('short', 'JJ'),
#   ('740', 'CD'),
#   ('upper', 'JJ'),
#   ('BB', 'NNP'),
#   ('overbought', 'NN')],
#  [('LIGHTS', 'NNP'),
#   ('OUT', 'NNP'),
#   ('Before', 'IN'),
#   ('curfew', 'NN'),
#   (',', ','),
#   ('curl', 'NN'),
#   ('latest', 'JJS'),
#   ('bestseller', 'NN'),
#   ('treat', 'NN'),
#   ('eyes', 'NNS'),
#   ('perfect', 'VBP'),
#   ('reading', 'VBG'),
#   ('light', 'NN'),
#   ('Luceplan', 'NNP'),
#   ('.', '.')],
#  [('UPM-Kymmene', 'NNP'),
#   ('Corp.', 'NNP'),
#   (',', ','),
#   ('world', 'NN'),
#   ("'s", 'POS'),
#   ('largest', 'JJS'),
#   ('maker', 'NN'),
#   ('magazine', 'NN'),
#   ('paper', 'NN'),
#   (',', ','),
#   ('Tuesday', 'NNP'),
#   ('reported', 'VBD'),
#   ('19-percent', 'JJ'),
#   ('profit', 'NN'),
#   ('drop', 'NN'),
#   ('lower', 'JJR'),
#   ('paper', 'NN'),
#   ('prices', 'NNS'),
#   (',', ','),
#   ('higher', 'JJR'),
#   ('costs', 'NNS'),
#   ('strong', 'JJ'),
#   ('euro', 'RB'),
#   ('hurt', 'VBN'),
#   ('revenue', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('total', 'JJ'),
#   ('value', 'NN'),
#   ('contract', 'NN'),
#   ('EUR', 'NNP'),
#   ('8', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('prerequisite', 'JJ'),
#   ('inclusion', 'NN'),
#   ('program', 'NN'),
#   ('receipt', 'NN'),
#   ('gains', 'NNS'),
#   ('key', 'JJ'),
#   ('employees', 'NNS'),
#   ('acquire', 'VB'),
#   ('Aspo', 'NNP'),
#   ('shares', 'NNS'),
#   ('amount', 'NN'),
#   ('determined', 'VBD'),
#   ('Board', 'NNP'),
#   ('advance', 'NN'),
#   (',', ','),
#   ('maximum', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Doring', 'NNP'),
#   ('Eaton', 'NNP'),
#   ('since', 'IN'),
#   ('1989', 'CD'),
#   ('acted', 'VBD'),
#   ('Business', 'NNP'),
#   ('Unit', 'NNP'),
#   ('Manager', 'NNP'),
#   ('Eaton', 'NNP'),
#   ("'s", 'POS'),
#   ('Power', 'NNP'),
#   ('Controls', 'NNP'),
#   ('Business', 'NNP'),
#   ('Unit', 'NNP'),
#   ('since', 'IN'),
#   ('January', 'NNP'),
#   ('2007', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('250', 'CD'),
#   ('sq', 'NN'),
#   ('2,691', 'CD'),
#   ('sq', 'NN'),
#   ('ft', 'NN'),
#   ('store', 'NN'),
#   ('Copenhagen', 'NNP'),
#   ("'s", 'POS'),
#   ('premier', 'JJR'),
#   ('shopping', 'NN'),
#   ('district', 'NN'),
#   ('inaugurated', 'VBN'),
#   ('today', 'NN'),
#   (',', ','),
#   ('strengthening', 'VBG'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('presence', 'NN'),
#   ('Nordic', 'NNP'),
#   ('capitals', 'NNS'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('financial', 'JJ'),
#   ('statement', 'NN'),
#   ('first', 'RB'),
#   ('quarter', 'NN'),
#   ('2010', 'CD'),
#   (',', ','),
#   ('Tikkurila', 'NNP'),
#   ('reported', 'VBD'),
#   ('discontinued', 'VBN'),
#   ('operations', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('world', 'NN'),
#   ("'s", 'POS'),
#   ('second', 'JJ'),
#   ('largest', 'JJS'),
#   ('stainless', 'NN'),
#   ('steel', 'NN'),
#   ('maker', 'NN'),
#   ('said', 'VBD'),
#   ('net', 'JJ'),
#   ('profit', 'NN'),
#   ('three-month', 'JJ'),
#   ('period', 'NN'),
#   ('Dec.', 'NNP'),
#   ('31', 'CD'),
#   ('surged', 'VBD'),
#   ('euro603', 'NN'),
#   ('million', 'CD'),
#   ('US', 'NNP'),
#   ('$', '$'),
#   ('781', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('euro3', 'FW'),
#   ('.33', 'FW'),
#   ('US', 'NNP'),
#   ('$', '$'),
#   ('4.31', 'CD'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   (',', ','),
#   ('euro172', 'FW'),
#   ('million', 'CD'),
#   (',', ','),
#   ('euro0', 'FW'),
#   ('.94', 'FW'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   (',', ','),
#   ('previous', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Name', 'NN'),
#   ('Applicant', 'NNP'),
#   (':', ':'),
#   ('Jot', 'NNP'),
#   ('Automation', 'NNP'),
#   ('OYName', 'NNP'),
#   ('Inventor', 'NNP'),
#   (':', ':'),
#   ('Mammila', 'NNP'),
#   ('Tuomo', 'NNP'),
#   (',', ','),
#   ('Piirainen', 'NNP'),
#   ('Mika', 'NNP'),
#   ('Kellokoski', 'NNP'),
#   ('MikaApplication', 'NNP'),
#   ('No', 'NNP'),
#   ('.', '.'),
#   (':', ':'),
#   ('2424-KOLNP-2008', 'JJ'),
#   ('ADate', 'NNP'),
#   ('filing', 'NN'),
#   ('Application', 'NN'),
#   (':', ':'),
#   ('16-06-2008Publication', 'JJ'),
#   ('Date', 'NNP'),
#   (':', ':'),
#   ('30/01/2009', 'CD')],
#  [('Netflix', 'NNP'),
#   ('Grows', 'NNP'),
#   ('Efforts', 'NNP'),
#   ('To', 'TO'),
#   ('Create', 'VB'),
#   ('Loyal', 'NNP'),
#   ('Customers', 'NNP'),
#   ('$', '$'),
#   ('NFLX', 'NNP'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/5QXBkoBphe', 'NN')],
#  [('The', 'DT'),
#   ('OMX', 'NNP'),
#   ('Nordic', 'NNP'),
#   ('40', 'CD'),
#   ('OMXN40', 'NNP'),
#   ('index', 'NN'),
#   (',', ','),
#   ('comprising', 'VBG'),
#   ('40', 'CD'),
#   ('traded', 'JJ'),
#   ('Nordic', 'JJ'),
#   ('stocks', 'NNS'),
#   ('Nasdaq', 'NNP'),
#   ('OMX', 'NNP'),
#   ('exchange', 'NN'),
#   (',', ','),
#   ('closed', 'VBD'),
#   ('0.87', 'CD'),
#   ('%', 'NN'),
#   ('1,064.14', 'CD'),
#   ('points', 'NNS'),
#   ('Thursday', 'NNP'),
#   ('.', '.')],
#  [('$', '$'),
#   ('AAPL', 'NNP'),
#   ('nibbling', 'VBG'),
#   ('small', 'JJ'),
#   ('long', 'JJ'),
#   ('via', 'IN'),
#   ('525', 'CD'),
#   ('..', 'JJ'),
#   ('buying', 'NN'),
#   ('13min', 'CD'),
#   ('charts', 'NNS'),
#   ('..', 'NN')],
#  [('The', 'DT'),
#   ('operating', 'NN'),
#   ('margin', 'NN'),
#   ('Aker', 'NNP'),
#   ('Yards', 'NNP'),
#   ('Cruise', 'NNP'),
#   ('&', 'CC'),
#   ('Ferries', 'NNP'),
#   ('division', 'NN'),
#   ('went', 'VBD'),
#   ('8.3', 'CD'),
#   ('%', 'NN'),
#   ('6.4', 'CD'),
#   ('%', 'NN'),
#   ('first', 'JJ'),
#   ('quarter', 'NN'),
#   ('2007', 'CD'),
#   ('.', '.')],
#  [('$', '$'),
#   ('TYC', 'NNP'),
#   ('break', 'VB'),
#   ('new', 'JJ'),
#   ('highs', 'NNS'),
#   (',', ','),
#   ('lots', 'NNS'),
#   ('technicals', 'NNS'),
#   ('looking', 'VBG'),
#   ('great', 'JJ'),
#   ('right', 'NN'),
#   ('.', '.')],
#  [('Eero', 'NNP'),
#   ('Katajavuori', 'NNP'),
#   (',', ','),
#   ('currently', 'RB'),
#   ('Group', 'NNP'),
#   ('Vice', 'NNP'),
#   ('President', 'NNP'),
#   (',', ','),
#   ('Human', 'NNP'),
#   ('Resources', 'NNPS'),
#   (',', ','),
#   ('take', 'VB'),
#   ('year-long', 'JJ'),
#   ('sabbatical', 'JJ'),
#   ('starting', 'VBG'),
#   ('October', 'NNP'),
#   ('1', 'CD'),
#   (',', ','),
#   ('2010', 'CD'),
#   ('.', '.')],
#  [('Whats', 'NNP'),
#   ('$', '$'),
#   ('LULU', 'NNP'),
#   ('?', '.'),
#   ('Numbers', 'NNP'),
#   ('looked', 'VBD'),
#   ('good', 'JJ'),
#   (',', ','),
#   ('great', 'JJ'),
#   (',', ','),
#   ('good', 'JJ'),
#   ('.', '.'),
#   ('I', 'PRP'),
#   ('think', 'VBP'),
#   ('conference', 'NN'),
#   ('call', 'NN'),
#   ('instill', 'NN'),
#   ('confidence', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('adjustment', 'NN'),
#   ('measures', 'NNS'),
#   ('carried', 'VBD'),
#   ('phases', 'NNS'),
#   ('secure', 'JJ'),
#   ('delivery', 'NN'),
#   ('capability', 'NN'),
#   ('.', '.')],
#  [('Alma', 'NNP'),
#   ('Media', 'NNP'),
#   ('Corporation', 'NNP'),
#   ('Press', 'NNP'),
#   ('Release', 'NNP'),
#   ('15', 'CD'),
#   ('March', 'NNP'),
#   ('2010', 'CD'),
#   ('TYRVAAN', 'NNP'),
#   ('SANOMAT', 'NNP'),
#   ('AND', 'NNP'),
#   ('PAIKALLISSANOMAT', 'NNP'),
#   ('BEING', 'NNP'),
#   ('BOUGHT', 'NNP'),
#   ('BY', 'NNP'),
#   ('SUOMEN', 'NNP'),
#   ('PAIKALLISSANOMAT', 'NNP'),
#   ('Two', 'CD'),
#   ('local', 'JJ'),
#   ('papers', 'NNS'),
#   (',', ','),
#   ('Tyrvaan', 'NNP'),
#   ('Sanomat', 'NNP'),
#   ('Paikallissanomat', 'NNP'),
#   (',', ','),
#   ('appearing', 'VBG'),
#   ('Sastamala', 'NNP'),
#   ('neighbouring', 'VBG'),
#   ('municipalities', 'NNS'),
#   (',', ','),
#   ('bought', 'VBD'),
#   ('Suomen', 'NNP'),
#   ('Paikallissanomat', 'NNP'),
#   ('Oy', 'NNP'),
#   ('.', '.')],
#  [('Temporary', 'JJ'),
#   ('lay-offs', 'NNS'),
#   (',', ','),
#   ('affecting', 'VBG'),
#   ('entire', 'JJ'),
#   ('workforce', 'NN'),
#   (',', ','),
#   ('also', 'RB'),
#   ('implemented', 'VBN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('meeting', 'NN'),
#   ('media', 'NNS'),
#   ('analysts', 'NNS'),
#   ('held', 'VBD'),
#   ('day', 'NN'),
#   ('10:30', 'CD'),
#   ('a.m.', 'RB'),
#   ('Stonesoft', 'NNP'),
#   ('Headquarters', 'NNP'),
#   ('Helsinki', 'NNP'),
#   (',', ','),
#   ('Italahdenkatu', 'NNP'),
#   ('22', 'CD'),
#   ('A', 'NNP'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('Interim', 'NNP'),
#   ('report', 'NN'),
#   ('presented', 'VBD'),
#   ('Stonesoft', 'NNP'),
#   ("'s", 'POS'),
#   ('CEO', 'NNP'),
#   ('Ilkka', 'NNP'),
#   ('Hiidenheimo', 'NNP'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('Sampo-Rosenlew', 'NNP'),
#   ('manufactures', 'NNS'),
#   ('approximately', 'RB'),
#   ('seven', 'CD'),
#   ('forest', 'JJS'),
#   ('machines', 'NNS'),
#   ('monthly', 'RB'),
#   (',', ','),
#   ('half', 'JJ'),
#   ('machines', 'NNS'),
#   ('exported', 'VBN'),
#   ('.', '.')],
#  [('Facebook', 'NNP'),
#   (',', ','),
#   ('near', 'IN'),
#   ('buy', 'NN'),
#   ('point', 'NN'),
#   ('last', 'JJ'),
#   ('week', 'NN'),
#   (',', ','),
#   ('faces', 'VBZ'),
#   ('different', 'JJ'),
#   ('technical', 'JJ'),
#   ('test', 'NN'),
#   ('today', 'NN'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/c72LLMpiNM', 'JJ'),
#   ('$', '$'),
#   ('FB', 'NNP'),
#   ('$', '$'),
#   ('AAPL', 'NNP'),
#   ('$', '$'),
#   ('NFLX', 'NNP'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/fPFbYTYPuY', 'NN')],
#  [('4', 'CD'),
#   ('February', 'NNP'),
#   ('2011', 'CD'),
#   ('-', ':'),
#   ('Finnish', 'JJ'),
#   ('broadband', 'NN'),
#   ('data', 'NNS'),
#   ('communication', 'NN'),
#   ('systems', 'NNS'),
#   ('provider', 'NN'),
#   ('Teleste', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('HEL', 'NNP'),
#   (':', ':'),
#   ('TLT1V', 'NNP'),
#   ('said', 'VBD'),
#   ('Wednesday', 'NNP'),
#   ('net', 'JJ'),
#   ('profit', 'NN'),
#   ('rocketed', 'VBD'),
#   ('EUR4', 'NNP'),
#   ('.8', 'NNP'),
#   ('2010', 'CD'),
#   ('EUR416', 'NNP'),
#   (',000', 'NN'),
#   ('2009', 'CD'),
#   ('lifted', 'VBD'),
#   ('dividend', 'NN'),
#   ('proposal', 'NN'),
#   ('.', '.')],
#  [('$', '$'),
#   ('FREE', 'NNP'),
#   ('Ha', 'NNP'),
#   ('Heeeeeere', 'NNP'),
#   ('comes', 'VBZ'),
#   ('pump', 'RB'),
#   ('!', '.'),
#   ('So', 'IN'),
#   ('glad', 'JJ'),
#   ('I', 'PRP'),
#   ('picked', 'VBD'),
#   ('9K', 'CD'),
#   ('end', 'JJ'),
#   ('day', 'NN'),
#   ('!', '.'),
#   ('Get', 'NNP'),
#   ('ready', 'JJ'),
#   ('bull', 'NN'),
#   ('ride', 'NN'),
#   ('!', '.')],
#  [('Finnish', 'JJ'),
#   ('technology', 'NN'),
#   ('group', 'NN'),
#   ('Aspocomp', 'NNP'),
#   ('Group', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('(', '('),
#   ('OMX', 'NNP'),
#   ('Helsinki', 'NNP'),
#   (':', ':'),
#   ('ACG1V', 'NNP'),
#   (')', ')'),
#   ('issued', 'VBD'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   ('report', 'NN'),
#   ('Thursday', 'NNP'),
#   ('(', '('),
#   ('13', 'CD'),
#   ('November', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('posting', 'VBG'),
#   ('operating', 'NN'),
#   ('profit', 'NN'),
#   ('EUR0', 'NNP'),
#   ('.4', 'NNP'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('loss', 'NN'),
#   ('EUR0', 'NNP'),
#   ('.5', 'NNP'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   ('2007', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('building', 'NN'),
#   ('complex', 'JJ'),
#   ('consists', 'VBZ'),
#   ('high-quality', 'NN'),
#   ('office', 'NN'),
#   ('retail', 'JJ'),
#   ('space', 'NN'),
#   ('totalling', 'VBG'),
#   ('49,200', 'CD'),
#   ('square', 'JJ'),
#   ('metres', 'NNS'),
#   (',', ','),
#   ('company', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('insurance', 'NN'),
#   ('company', 'NN'),
#   ('Fennia', 'NNP'),
#   ('Kesko', 'NNP'),
#   ('Group', 'NNP'),
#   ('ending', 'VBG'),
#   ('loyal', 'JJ'),
#   ('customer', 'NN'),
#   ('cooperation', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('unit', 'NN'),
#   ('planned', 'VBD'),
#   ('operational', 'JJ'),
#   ('second', 'NN'),
#   ('half', 'NN'),
#   ('2007', 'CD'),
#   ('full', 'JJ'),
#   ('stream', 'NN'),
#   ('2008', 'CD'),
#   ('.', '.')],
#  [('ITG', 'NNP'),
#   ("'s", 'POS'),
#   ('share', 'NN'),
#   ('deal', 'NN'),
#   ('estimated', 'VBD'),
#   ('500,000', 'CD'),
#   ('euro', 'JJ'),
#   ('$', '$'),
#   ('627,000', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('plant', 'NN'),
#   ('expected', 'VBN'),
#   ('enter', 'RBR'),
#   ('commercial', 'JJ'),
#   ('operation', 'NN'),
#   ('mid-2009', 'NNS'),
#   ('.', '.')],
#  [('Aspo', 'NNP'),
#   ('also', 'RB'),
#   ('investigated', 'VBD'),
#   ('sales', 'NNS'),
#   ('opportunities', 'NNS'),
#   ('Kaukomarkkinat', 'NNP'),
#   ("'s", 'POS'),
#   ('electronics', 'NNS'),
#   ('business', 'NN'),
#   ('.', '.')],
#  [('BG', 'NNP'),
#   ('Group', 'NNP'),
#   ('appoints', 'VBZ'),
#   ('new', 'JJ'),
#   ('CEO', 'NNP'),
#   ('one', 'CD'),
#   ('month', 'NN'),
#   ('early', 'RB')],
#  [('The', 'DT'),
#   ('acquisition', 'NN'),
#   ('immediate', 'JJ'),
#   ('positive', 'JJ'),
#   ('impact', 'NN'),
#   ('Aspocomp', 'NNP'),
#   ("'s", 'POS'),
#   ('financial', 'JJ'),
#   ('result', 'NN'),
#   ('.', '.')],
#  [('Finnair', 'NNP'),
#   ("'s", 'POS'),
#   ('passenger', 'NN'),
#   ('load', 'NN'),
#   ('factor', 'NN'),
#   (',', ','),
#   ('measures', 'NNS'),
#   ('number', 'NN'),
#   ('sold', 'VBN'),
#   ('seats', 'NNS'),
#   ('share', 'NN'),
#   ('available', 'JJ'),
#   ('seats', 'NNS'),
#   (',', ','),
#   ('dropped', 'VBD'),
#   ('1.3', 'CD'),
#   ('percentage', 'NN'),
#   ('points', 'NNS'),
#   ('76.7', 'CD'),
#   ('%', 'NN'),
#   ('September', 'NNP'),
#   ('.', '.')],
#  [('RT', 'NNP'),
#   ('@', 'NNP'),
#   ('bman1', 'VBD'),
#   ('$', '$'),
#   ('LNG', 'NNP'),
#   ('looks', 'VBZ'),
#   ('primed', 'VBD'),
#   ('also', 'RB'),
#   ('$', '$'),
#   ('EGHT', 'NNP'),
#   ('poised', 'VBN'),
#   ('run', 'NN'),
#   ('...', ':')],
#  [('It', 'PRP'),
#   ('also', 'RB'),
#   ('7.7', 'CD'),
#   ('pct', 'JJ'),
#   ('12-month', 'JJ'),
#   ('volume', 'NN'),
#   ('weighted', 'VBD'),
#   ('average', 'JJ'),
#   ('price', 'NN'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('Coke', 'NNP'),
#   ('dividend', 'NN'),
#   ('-', ':'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('Google', 'NNP'),
#   ('dividend', 'NN'),
#   ('-', ':'),
#   ('0', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('For', 'IN'),
#   ('passive', 'JJ'),
#   ('income', 'NN'),
#   ('Coke', 'NNP'),
#   ('takes', 'VBZ'),
#   ('.', '.'),
#   ('$', '$'),
#   ('GOOG', 'NNP'),
#   ('$', '$'),
#   ('KO', 'NNP'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/QBsoWjxOST', 'NN')],
#  [('Profit', 'NN'),
#   ('taxes', 'NNS'),
#   ('EUR', 'NNP'),
#   ('5.4', 'CD'),
#   ('mn', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('3.6', 'CD'),
#   ('mn', 'NN'),
#   ('year', 'NN'),
# ...
#   ('chain', 'NN'),
#   (',', ','),
#   ('whereby', 'WRB'),
#   ('Marimekko', 'NNP'),
#   ('license', 'NN'),
#   ('popular', 'JJ'),
#   ('patterns', 'NNS'),
#   ('1950s', 'CD'),
#   (',', ','),
#   ('1960s', 'CD'),
#   ('1970s', 'CD'),
#   ('H', 'NNP'),
#   ('&', 'CC'),
#   ('M', 'NNP'),
#   ('.', '.')],
#  [('quick', 'NN'),
#   (',', ','),
#   ('$', '$'),
#   ('FIO', 'NNP'),
#   ('21.35', 'CD'),
#   (',', ','),
#   ('market', 'NN'),
#   ('tanking', 'NN'),
#   (',', ','),
#   ('scaling', 'VBG'),
#   ('longs', 'NNS')],
#  [('The', 'DT'),
#   ('announcement', 'NN'),
#   ('pushed', 'VBD'),
#   ('Freenet', 'NNP'),
#   ('shares', 'NNS'),
#   ('6.3', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('EUR0', 'NNP'),
#   ('.71', 'NNP'),
#   (',', ','),
#   ('Frankfurt', 'NNP'),
#   ('trade', 'NN'),
#   ('EUR10', 'NNP'),
#   ('.65', 'NNP'),
#   ('investors', 'NNS'),
#   ('gave', 'VBD'),
#   ('hope', 'NN'),
#   ('United', 'NNP'),
#   ('Internet', 'NNP'),
#   ('AG', 'NNP'),
#   ('Drillisch', 'NNP'),
#   ('would', 'MD'),
#   ('pursue', 'VB'),
#   ('takeover', 'NN'),
#   ('breakup', 'NN'),
#   ('Freenet', 'NNP'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('telecoms', 'NNS'),
#   ('software', 'NN'),
#   ('developer', 'IN'),
#   ('Tecnomen', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('said', 'VBD'),
#   ('December', 'NNP'),
#   ('5', 'CD'),
#   (',', ','),
#   ('2006', 'CD'),
#   ('$', '$'),
#   ('3.3', 'CD'),
#   ('mln', 'NN'),
#   ('(', '('),
#   ('2.5', 'CD'),
#   ('mln', 'RB'),
#   ('euro', 'NN'),
#   (')', ')'),
#   ('order', 'NN'),
#   ('supply', 'NN'),
#   ('expansion', 'NN'),
#   ('charging', 'VBG'),
#   ('messaging', 'VBG'),
#   ('systems', 'NNS'),
#   ('mobile', 'JJ'),
#   ('fixed', 'JJ'),
#   ('networks', 'NNS'),
#   ('Brasil', 'NNP'),
#   ('Telecom', 'NNP'),
#   ('.', '.')],
#  [('CompaniesUnilever', 'NNP'),
#   ('sales', 'NNS'),
#   ('lifted', 'VBD'),
#   ('ice', 'JJ'),
#   ('cream', 'NN'),
#   ('soft', 'JJ'),
#   ('economy', 'NN')],
#  [('EPS', 'NNP'),
#   ('dropped', 'VBD'),
#   ('EUR0', 'NNP'),
#   ('.2', 'NNP'),
#   ('EUR0', 'NNP'),
#   ('.3', 'NNP'),
#   ('.', '.')],
#  [('@', 'JJ'),
#   ('saltwaternurse', 'JJ'),
#   ('$', '$'),
#   ('INO', 'NNP'),
#   ('test', 'NN'),
#   ('10', 'CD'),
#   ('next', 'JJ'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('time', 'NN'),
#   ('take', 'VB'),
#   ('profits', 'NNS'),
#   ('.', '.'),
#   ('hedge', 'NN'),
#   ('puts', 'VBZ'),
#   ('.', '.')],
#  [('No', 'DT'),
#   ('financial', 'JJ'),
#   ('information', 'NN'),
#   ('provided', 'VBD'),
#   ('.', '.')],
#  [('EasyJet', 'NNP'),
#   ('attracts', 'VBZ'),
#   ('passengers', 'NNS'),
#   ('June', 'NNP'),
#   ('still', 'RB'),
#   ('lags', 'VBZ'),
#   ('Ryanair', 'NNP')],
#  [('Morning', 'VBG'),
#   ('Agenda', 'NN'),
#   (':', ':'),
#   ('Shire', 'NNP'),
#   ("'s", 'POS'),
#   ('Deal', 'NNP'),
#   ('NPS', 'NNP')],
#  [('Metso', 'NNP'),
#   ('supply', 'NN'),
#   ('equipment', 'NN'),
#   ('two', 'CD'),
#   ('process', 'NN'),
#   ('lines', 'NNS'),
#   ('Northland', 'NNP'),
#   ('Resources', 'NNPS'),
#   ("'", 'POS'),
#   ('new', 'JJ'),
#   ('Kaunisvaara', 'NNP'),
#   ('iron', 'NN'),
#   ('ore', 'NN'),
#   ('project', 'NN'),
#   ('Sweden', 'NNP'),
#   ('exploits', 'VBZ'),
#   ('Tapuli', 'NNP'),
#   ('Sahavaara', 'NNP'),
#   ('iron', 'NN'),
#   ('ore', 'NN'),
#   ('deposits', 'NNS'),
#   ('.', '.')],
#  [('Under', 'IN'),
#   ('agreement', 'NN'),
#   ('Biohit', 'NNP'),
#   ('becomes', 'VBZ'),
#   ('focus', 'VB'),
#   ('supplier', 'JJ'),
#   ('pipettors', 'NNS'),
#   ('disposable', 'JJ'),
#   ('pipettor', 'NN'),
#   ('tips', 'NNS'),
#   ('VWR', 'NNP'),
#   ('customers', 'NNS'),
#   ('throughout', 'IN'),
#   ('Europe', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('previous', 'JJ'),
#   ('estimate', 'NN'),
#   ('lower', 'RBR'),
#   ('revenue', 'NN'),
#   ('year-ago', 'JJ'),
#   ('EUR', 'NNP'),
#   ('93.9', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Earnings', 'NNS'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   ('(', '('),
#   ('EPS', 'NNP'),
#   (')', ')'),
#   ('dropped', 'VBD'),
#   ('EUR', 'NNP'),
#   ('0.21', 'CD'),
#   ('EUR', 'NNP'),
#   ('0.31', 'CD'),
#   ('.', '.')],
#  [('Bids', 'NNS'),
#   ('offers', 'NNS'),
#   ('include', 'VBP'),
#   ('least', 'JJS'),
#   ('1,000', 'CD'),
#   ('shares', 'NNS'),
#   ('value', 'NN'),
#   ('shares', 'NNS'),
#   ('must', 'MD'),
#   ('correspond', 'VB'),
#   ('least', 'JJS'),
#   ('EUR4', 'NNP'),
#   (',000', 'NN'),
#   ('.', '.')],
#  [('Earnings', 'NNS'),
#   ('per', 'IN'),
#   ('share', 'NN'),
#   ('(', '('),
#   ('EPS', 'NNP'),
#   (')', ')'),
#   ('amounted', 'VBD'),
#   ('loss', 'NN'),
#   ('EUR0', 'NNP'),
#   ('.06', 'NNP'),
#   ('.', '.')],
#  [('NetApp', 'NNP'),
#   ('downgraded', 'VBD'),
#   ('Macquarie', 'NNP'),
#   ('underperform', 'NN'),
#   ('.', '.'),
#   ('$', '$'),
#   ('22.00', 'CD'),
#   ('PT', 'NNP'),
#   ('.', '.'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/XCNgws0t4q', 'JJ'),
#   ('$', '$'),
#   ('NTAP', 'NNP'),
#   ('#', '#'),
#   ('NTAP', 'NNP'),
#   ('via', 'IN'),
#   ('@', 'NNP'),
#   ('RatingsNetwork', 'NNP')],
#  [('``', '``'),
#   ('Russia', 'NNP'),
#   ('ready', 'JJ'),
#   ('participate', 'VB'),
#   ('open', 'JJ'),
#   ('tender', 'NN'),
#   ('Lattelecom', 'NNP'),
#   ("'s", 'POS'),
#   ('privatization', 'NN'),
#   ('.', '.')],
#  [('Technopolis', 'NNP'),
#   ('St.', 'NNP'),
#   ('Petersburg', 'NNP'),
#   ('government', 'NN'),
#   ('signed', 'VBD'),
#   ('cooperation', 'NN'),
#   ('memorandum', 'NN'),
#   ('October', 'NNP'),
#   ('2005', 'CD'),
#   ('set', 'VBD'),
#   ('techno-park', 'NN'),
#   ('Neudorf', 'NNP'),
#   ('production', 'NN'),
#   ('zone', 'NN'),
#   ('village', 'NN'),
#   ('Strelny', 'NNP'),
#   (',', ','),
#   ('St.', 'NNP'),
#   ('Petersburg', 'NNP'),
#   ('suburbs', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('owners', 'NNS'),
#   ('participated', 'VBD'),
#   ('business', 'NN'),
#   ('operations', 'NNS'),
#   ('company', 'NN'),
#   ('continue', 'VBP'),
#   ('Poyry', 'NNP'),
#   ("'s", 'POS'),
#   ('employment', 'NN'),
#   ('transaction', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('goal', 'NN'),
#   ('secure', 'NN'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('profitability', 'NN'),
#   ('competitiveness', 'NN'),
#   ('.', '.')],
#  [('However', 'RB'),
#   (',', ','),
#   ('company', 'NN'),
#   ('saw', 'VBD'),
#   ('net', 'JJ'),
#   ('profit', 'NN'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   ('EUR', 'NNP'),
#   ('1.4', 'CD'),
#   ('million', 'CD'),
#   ('EUR', 'NNP'),
#   ('1.5', 'CD'),
#   ('million', 'CD'),
#   ('corresponding', 'JJ'),
#   ('period', 'NN'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Neste', 'NNP'),
#   ('oil', 'NN'),
#   ("'s", 'POS'),
#   ('board', 'NN'),
#   ('proposed', 'VBD'),
#   ('1.00', 'CD'),
#   ('eur', 'JJ'),
#   ('dividend', 'NN'),
#   ('full-year', 'JJ'),
#   ('2007', 'CD'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('0.90', 'CD'),
#   ('eur', 'JJ'),
#   ('year', 'NN'),
#   ('ago', 'RB'),
#   ('.', '.')],
#  [('Basware', 'NNP'),
#   ('Einvoices', 'NNP'),
#   ('Oy', 'NNP'),
#   ('merged', 'VBD'),
#   ('parent', 'NN'),
#   ('company', 'NN'),
#   ('present', 'JJ'),
#   ('fiscal', 'JJ'),
#   ('period', 'NN'),
#   ('.', '.')],
#  [('#', '#'),
#   ('Fintech', 'NNP'),
#   ('provider', 'NN'),
#   ('$', '$'),
#   ('CAFN', 'NNP'),
#   ('Cachet', 'NNP'),
#   ('Financial', 'NNP'),
#   ('Solutions', 'NNP'),
#   ('Surging', 'NNP'),
#   ('Forward', 'NNP'),
#   ('today', 'NN'),
#   ('post', 'NN'),
#   ('earnings', 'NNS'),
#   ('Up', 'RP'),
#   ('+13.26', 'CD'),
#   ('%', 'NN'),
#   ('https', 'NN'),
#   (':', ':'),
#   ('//t.co/9BJ3csk2i9', 'JJ'),
#   ('$', '$'),
#   ('JKHY', 'NNP'),
#   ('$', '$'),
#   ('FISV', 'NNP'),
#   ('#', '#'),
#   ('Momo', 'NNP')],
#  [('Before', 'IN'),
#   ('Kemira', 'NNP'),
#   ("'s", 'POS'),
#   ('installation', 'NN'),
#   ('NordAlu', 'NNP'),
#   ('producing', 'VBG'),
#   ('3,500', 'CD'),
#   ('tons', 'NNS'),
#   ('liquid', 'JJ'),
#   ('solid', 'JJ'),
#   ('aluminum', 'NN'),
#   ('waste', 'NN'),
#   ('per', 'IN'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('Chartered', 'VBD'),
#   ('Accountant', 'NNP'),
#   ('British', 'NNP'),
#   ('Columbia', 'NNP'),
#   ('Alberta', 'NNP'),
#   ('well', 'RB'),
#   ('Certified', 'NNP'),
#   ('Public', 'NNP'),
#   ('Accountant', 'NNP'),
#   ('Washington', 'NNP'),
#   ('State', 'NNP'),
#   ('.', '.')],
#  [('`', '``'),
#   ('Very', 'RB'),
#   ('recommendable', 'JJ'),
#   ("'", "''"),
#   ('Nokian', 'JJ'),
#   ('Z', 'NNP'),
#   ('G2', 'NNP'),
#   ('according', 'VBG'),
#   ('`', '``'),
#   ('ADAC', 'RB'),
#   ('judgement', 'NN'),
#   ("'", "''"),
#   ('latest', 'JJS'),
#   ('summer', 'NN'),
#   ('tyre', 'NN'),
#   ('test', 'JJ'),
#   ('German', 'NNP'),
#   ('automobile', 'NN'),
#   ('association', 'NN'),
#   ('ADAC', 'NNP'),
#   ('.', '.')],
#  [('-', ':'),
#   ('The', 'DT'),
#   ('Group', 'NNP'),
#   ('-¦', 'NNP'),
#   ('result', 'NN'),
#   ('taxes', 'NNS'),
#   ('loss', 'NN'),
#   ('EUR', 'NNP'),
#   ('0.6', 'CD'),
#   ('(', '('),
#   ('+0.6', 'NN'),
#   (')', ')'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('-', ':'),
#   ('Cash', 'NN'),
#   ('flow', 'NN'),
#   ('operating', 'NN'),
#   ('activities', 'NNS'),
#   ('investments', 'NNS'),
#   ('EUR', 'NNP'),
#   ('0.8', 'CD'),
#   ('-1.2', 'NNP'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Viking', 'VBG'),
#   ('Line', 'NNP'),
#   ('canceled', 'VBD'),
#   ('services', 'NNS'),
#   ('.', '.')],
#  [('Exel', 'NNP'),
#   ('headquartered', 'VBD'),
#   ('Mantyharju', 'NNP'),
#   ('Finland', 'NNP'),
#   ('.', '.')],
#  [('Stora', 'NNP'),
#   ('Chief', 'NNP'),
#   ('Executive', 'NNP'),
#   ('Jouko', 'NNP'),
#   ('Karvinen', 'NNP'),
#   ('described', 'VBD'),
#   ('Russian', 'JJ'),
#   ('tariff', 'NN'),
#   ('hikes', 'NNS'),
#   ('threat', 'NN'),
#   ('future', 'JJ'),
#   ('forest', 'NN'),
#   ('products', 'NNS'),
#   ('industry', 'NN'),
#   ('Finland', 'NNP'),
#   ('.', '.')],
#  [('After', 'IN'),
#   ('Barclays', 'NNP'),
#   ('Bank', 'NNP'),
#   ('America', 'NNP'),
#   (',', ','),
#   ('Citigroup', 'NNP'),
#   ('blockchain', 'NN'),
#   ('sight', 'NN')],
#  [('Google', 'NNP'),
#   (',', ','),
#   ('Inc.', 'NNP'),
#   ('completes', 'VBZ'),
#   ('acquisition', 'NN'),
#   ('ICOA', 'NNP'),
#   (',', ','),
#   ('Inc.', 'NNP'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//stks.co/nFEI', 'JJ'),
#   ('$', '$'),
#   ('ICOA', 'NNP'),
#   ('$', '$'),
#   ('GOOG', 'NNP')],
#  [('$', '$'),
#   ('TSLA', 'CD'),
#   ('looking', 'VBG'),
#   ('good', 'JJ'),
#   ('..', 'NN'),
#   ("'d", 'MD'),
#   ('love', 'VB'),
#   ('see', 'VB'),
#   ('basing', 'VBG'),
#   ('action', 'NN'),
#   (',', ','),
#   ('letting', 'VBG'),
#   ('RSI', 'NNP'),
#   ('take', 'VB'),
#   ('breather', 'NN'),
#   ('.', '.'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//stks.co/g1T7c', 'NN')],
#  [('Finnish', 'JJ'),
#   ('plumbing', 'NN'),
#   ('heating', 'VBG'),
#   ('systems', 'NNS'),
#   ('supplier', 'JJR'),
#   ('Uponor', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('sales', 'NNS'),
#   ('continuing', 'VBG'),
#   ('operations', 'NNS'),
#   ('decreased', 'VBD'),
#   ('9.4', 'CD'),
#   ('%', 'NN'),
#   ('2008', 'CD'),
#   ('EUR', 'NNP'),
#   ('949.2', 'CD'),
#   ('mn', 'NN'),
#   ('EUR', 'NNP'),
#   ('1,047.4', 'CD'),
#   ('mn', 'NN'),
#   ('2007', 'CD'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('location', 'NN'),
#   ('makes', 'VBZ'),
#   ('mall', 'JJ'),
#   ('convenient', 'JJ'),
#   ('place', 'NN'),
#   ('shop', 'NN'),
#   ('consumers', 'NNS'),
#   ('three', 'CD'),
#   ('large', 'JJ'),
#   ('residential', 'JJ'),
#   ('areas', 'NNS'),
#   ('nearby', 'RB'),
#   (':', ':'),
#   ('Jaroszowka', 'NNP'),
#   (',', ','),
#   ('Wysockiego', 'NNP'),
#   ('Zgody', 'NNP'),
#   ('.', '.')],
#  [('Finnish', 'JJ'),
#   ('insurance', 'NN'),
#   ('company', 'NN'),
#   ('Fennia', 'NNP'),
#   ('Kesko', 'NNP'),
#   ('Group', 'NNP'),
#   ('ending', 'VBG'),
#   ('loyal', 'JJ'),
#   ('customer', 'NN'),
#   ('cooperation', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('casing', 'NN'),
#   ('comprises', 'VBZ'),
#   ('first', 'JJ'),
#   ('side', 'NN'),
#   ('casing', 'VBG'),
#   ('member', 'NN'),
#   ('provided', 'VBD'),
#   ('first', 'JJ'),
#   ('side', 'NN'),
#   ('vat', 'NN'),
#   ('segment', 'NN'),
#   ('second', 'JJ'),
#   ('side', 'NN'),
#   ('casing', 'VBG'),
#   ('member', 'NN'),
#   ('provided', 'VBN'),
#   ('second', 'JJ'),
#   ('side', 'NN'),
#   ('vat', 'NN'),
#   ('segment', 'NN'),
#   (',', ','),
#   ('least', 'JJS'),
#   ('first', 'JJ'),
#   ('side', 'NN'),
#   ('casing', 'VBG'),
#   ('member', 'NN'),
#   ('pivotable', 'JJ'),
#   ('rotation', 'NN'),
#   ('axis', 'NN'),
#   ('.', '.')],
#  [('Finland-based', 'JJ'),
#   ('Elcoteq', 'NNP'),
#   ('SE', 'NNP'),
#   (',', ','),
#   ('privately', 'RB'),
#   ('held', 'VBN'),
#   ('provider', 'NN'),
#   ('electronics', 'NNS'),
#   ('manufacturing', 'NN'),
#   ('services', 'NNS'),
#   ('communications', 'NN'),
#   ('companies', 'NNS'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('Thursday', 'NNP'),
#   ('signed', 'VBD'),
#   ('long-term', 'JJ'),
#   ('manufacturing', 'NN'),
#   ('supply', 'NN'),
#   ('deal', 'NN'),
#   ('communications', 'NNS'),
#   ('equipment', 'NN'),
#   ('company', 'NN'),
#   ('Andrew', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('Q1', 'NNP'),
#   ('2009', 'CD'),
#   (',', ','),
#   ('Bank', 'NNP'),
#   ('+àland', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('interest', 'NN'),
#   ('income', 'NN'),
#   ('weakened', 'VBD'),
#   ('10', 'CD'),
#   ('%', 'NN'),
#   ('EUR', 'NNP'),
#   ('9.1', 'CD'),
#   ('mn', 'NN'),
#   ('.', '.')],
#  [('RBS', 'NNP'),
#   ('Pays', 'NNP'),
#   ('$', '$'),
#   ('1.7', 'CD'),
#   ('Billion', 'NNP'),
#   ('Scrap', 'NNP'),
#   ('U.K.', 'NNP'),
#   ('Treasury', 'NNP'),
#   ("'s", 'POS'),
#   ('Dividend', 'NNP'),
#   ('Rights', 'NNPS')],
#  [('Increased', 'VBN'),
#   ('trust', 'NN'),
#   ('clients', 'NNS'),
#   ('YIT', 'VBP'),
#   ('seen', 'VBN'),
#   ('apartment', 'NN'),
#   ('sales', 'NNS'),
#   ('accelerated', 'VBD'),
#   ('.', '.')],
#  [('Talvivaara', 'NNP'),
#   ('Mining', 'NNP'),
#   ('Company', 'NNP'),
#   ('Plc', 'NNP'),
#   ('Talvivaara', 'NNP'),
#   ('Mining', 'NNP'),
#   ('Company', 'NNP'),
#   ('internationally', 'RB'),
#   ('significant', 'JJ'),
#   ('base', 'NN'),
#   ('metals', 'NNS'),
#   ('producer', 'NN'),
#   ('primary', 'JJ'),
#   ('focus', 'NN'),
#   ('nickel', 'NN'),
#   ('zinc', 'NN'),
#   ('using', 'VBG'),
#   ('technology', 'NN'),
#   ('known', 'VBN'),
#   ('bioheapleaching', 'VBG'),
#   ('extract', 'JJ'),
#   ('metals', 'NNS'),
#   ('ore', 'RB'),
#   ('.', '.')],
#  [('Operating', 'NN'),
#   ('profit', 'NN'),
#   ('2009', 'CD'),
#   ('lower', 'JJR'),
#   ('outlook', 'NN'),
#   ('published', 'VBN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Less', 'RBR'),
#   ('ten', 'JJ'),
#   ('people', 'NNS'),
#   ('face', 'VBP'),
#   ('pension', 'NN'),
#   ('agreements', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('consolidated', 'JJ'),
#   ('operating', 'NN'),
#   ('profit', 'NN'),
#   ('amounted', 'VBD'),
#   ('EUR', 'NNP'),
#   ('15.86', 'CD'),
#   ('mn', 'NN'),
#   (',', ','),
#   ('EUR', 'NNP'),
#   ('4.14', 'CD'),
#   ('mn', 'NN'),
#   ('year-on-year', 'NN'),
#   ('.', '.')],
#  [('AstraZeneca', 'NNP'),
#   ('Buy', 'NNP'),
#   ('ZS', 'NNP'),
#   ('Pharma', 'NNP'),
#   ('$', '$'),
#   ('2.7', 'CD'),
#   ('Billion', 'NNP')],
#  [('Finnish', 'JJ'),
#   ('waste', 'NN'),
#   ('management', 'NN'),
#   ('cleaning', 'VBG'),
#   ('group', 'NN'),
#   ('Lassila', 'NNP'),
#   ('&', 'CC'),
#   ('Tikanoja', 'NNP'),
#   ('Oyj', 'NNP'),
#   ('(', '('),
#   ('L', 'NNP'),
#   ('&', 'CC'),
#   ('T', 'NNP'),
#   (')', ')'),
#   ('net', 'NN'),
#   ('profit', 'NN'),
#   ('went', 'VBD'),
#   ('32.2', 'CD'),
#   ('mln', 'NN'),
#   ('euro', 'NN'),
#   ('(', '('),
#   ('$', '$'),
#   ('47.7', 'CD'),
#   ('mln', 'NN'),
#   (')', ')'),
#   ('2007', 'CD'),
#   ('35.3', 'CD'),
#   ('mln', 'NN'),
#   ('euro', 'NN'),
#   ('(', '('),
#   ('$', '$'),
#   ('52.3', 'CD'),
#   ('mln', 'NN'),
#   (')', ')'),
#   ('2006', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('operating', 'NN'),
#   ('margin', 'NN'),
#   ('Aker', 'NNP'),
#   ('Yards', 'NNP'),
#   ('Cruise', 'NNP'),
#   ('&', 'CC'),
#   ('Ferries', 'NNP'),
#   ('division', 'NN'),
#   ('went', 'VBD'),
#   ('8.3', 'CD'),
#   ('%', 'NN'),
#   ('6.4', 'CD'),
#   ('%', 'NN'),
#   ('first', 'JJ'),
#   ('quarter', 'NN'),
#   ('2007', 'CD'),
#   ('.', '.')],
#  [('HELSINKI', 'NNP'),
#   ('Thomson', 'NNP'),
#   ('Financial', 'NNP'),
#   ('-', ':'),
#   ('Shares', 'VBZ'),
#   ('Cargotec', 'NNP'),
#   ('fell', 'VBD'),
#   ('sharply', 'RB'),
#   ('early', 'JJ'),
#   ('afternoon', 'NN'),
#   ('trade', 'NN'),
#   ('cargo', 'NN'),
#   ('handling', 'VBG'),
#   ('group', 'NN'),
#   ('posted', 'VBD'),
#   ('surprise', 'RB'),
#   ('drop', 'JJ'),
#   ('April-June', 'NNP'),
#   ('profits', 'NNS'),
#   (',', ','),
#   ('overshadowed', 'VBN'),
#   ('large', 'JJ'),
#   ('number', 'NN'),
#   ('new', 'JJ'),
#   ('orders', 'NNS'),
#   ('received', 'VBD'),
#   ('three', 'CD'),
#   ('months', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('program', 'NN'),
#   ("'s", 'POS'),
#   ('target', 'NN'),
#   ('structural', 'JJ'),
#   ('cost', 'NN'),
#   ('reductions', 'NNS'),
#   ('EUR', 'VBP'),
#   ('30mn', 'CD'),
#   ('2009', 'CD'),
#   ('.', '.')],
#  [('Our', 'PRP$'),
#   ('tools', 'NNS'),
#   ('specifically', 'RB'),
#   ('designed', 'VBN'),
#   ('needs', 'NNS'),
#   ('business', 'NN'),
#   ('users', 'NNS'),
#   ('ICT', 'NNP'),
#   ('experts', 'NNS'),
#   ('mind', 'NN'),
#   ('.', '.')],
#  ...]

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer=WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to NOUN if POS tag is unknown

# %%
pos_token[0][0]
# Out:
# ('The', 'DT')

# %%
get_wordnet_pos(pos_token[0][0][1])
# Out:
# 'n'

# %%
lem_data = []
for x in range(len(pos_token)):
  lem = [lemmatizer.lemmatize(pos_token[x][i][0],get_wordnet_pos(pos_token[x][i][1])) for i in range(len(pos_token[x]))]
  lem_data.append(lem)

# %%
lem_data
# Out:
# [['The',
#   'GeoSolutions',
#   'technology',
#   'leverage',
#   'Benefon',
#   "'s",
#   'GPS',
#   'solution',
#   'provide',
#   'Location',
#   'Based',
#   'Search',
#   'Technology',
#   ',',
#   'Communities',
#   'Platform',
#   ',',
#   'location',
#   'relevant',
#   'multimedia',
#   'content',
#   'new',
#   'powerful',
#   'commercial',
#   'model',
#   '.'],
#  ['$',
#   'ESI',
#   'low',
#   ',',
#   '$',
#   '1.50',
#   '$',
#   '2.50',
#   'BK',
#   'real',
#   'possibility'],
#  ['For',
#   'last',
#   'quarter',
#   '2010',
#   ',',
#   'Componenta',
#   "'s",
#   'net',
#   'sale',
#   'double',
#   'EUR131m',
#   'EUR76m',
#   'period',
#   'year',
#   'earlier',
#   ',',
#   'move',
#   'zero',
#   'pre-tax',
#   'profit',
#   'pre-tax',
#   'loss',
#   'EUR7m',
#   '.'],
#  ['According',
#   'Finnish-Russian',
#   'Chamber',
#   'Commerce',
#   ',',
#   'major',
#   'construction',
#   'company',
#   'Finland',
#   'operate',
#   'Russia',
#   '.'],
#  ['The',
#   'Swedish',
#   'buyout',
#   'firm',
#   'sell',
#   'remain',
#   '22.4',
#   'percent',
#   'stake',
#   ',',
#   'almost',
#   'eighteen',
#   'month',
#   'take',
#   'company',
#   'public',
#   'Finland',
#   '.'],
#  ['$', 'SPY', 'would', "n't", 'surprise', 'see', 'green', 'close'],
#  ['Shell',
#   "'s",
#   '$',
#   '70',
#   'Billion',
#   'BG',
#   'Deal',
#   'Meets',
#   'Shareholder',
#   'Skepticism'],
#  ['SSH',
#   'COMMUNICATIONS',
#   'SECURITY',
#   'CORP',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   'OCTOBER',
#   '14',
#   ',',
#   '2008',
#   'AT',
#   '2:45',
#   'PM',
#   'The',
#   'Company',
#   'update',
#   'full',
#   'year',
#   'outlook',
#   'estimate',
#   'result',
#   'remain',
#   'loss',
#   'full',
#   'year',
#   '.'],
#  ['Kone',
#   "'s",
#   'net',
#   'sale',
#   'rise',
#   '14',
#   '%',
#   'year-on-year',
#   'first',
#   'nine',
#   'month',
#   '2008',
#   '.'],
#  ['The',
#   'Stockmann',
#   'department',
#   'store',
#   'total',
#   'floor',
#   'space',
#   '8,000',
#   'square',
#   'metre',
#   'Stockmann',
#   "'s",
#   'investment',
#   'project',
#   'price',
#   'tag',
#   'EUR',
#   '12',
#   'million',
#   '.'],
#  ['Circulation',
#   'revenue',
#   'increase',
#   '5',
#   '%',
#   'Finland',
#   '4',
#   '%',
#   'Sweden',
#   '2008',
#   '.'],
#  ['$',
#   'SAP',
#   'Q1',
#   'disappoints',
#   '#',
#   'software',
#   'license',
#   '.',
#   'Real',
#   'problem',
#   '?',
#   '#',
#   'Cloud',
#   'growth',
#   'trail',
#   '$',
#   'MSFT',
#   '$',
#   'ORCL',
#   '$',
#   'GOOG',
#   '$',
#   'CRM',
#   '$',
#   'ADBE',
#   'http',
#   ':',
#   '//t.co/jNDphllzq5'],
#  ['The',
#   'subdivision',
#   'make',
#   'sale',
#   'revenue',
#   'last',
#   'year',
#   'EUR',
#   '480.7',
#   'million',
#   'EUR',
#   '414.9',
#   'million',
#   '2008',
#   ',',
#   'operate',
#   'profit',
#   'EUR',
#   '44.5',
#   'million',
#   'EUR',
#   '7.4',
#   'million',
#   '.'],
#  ['Viking', 'Line', 'cancel', 'service', '.'],
#  ['Ahlstrom',
#   'Corporation',
#   'STOCK',
#   'EXCHANGE',
#   'ANNOUNCEMENT',
#   '7.2.2007',
#   '10.30',
#   'A',
#   'total',
#   '56,955',
#   'new',
#   'share',
#   'Ahlstrom',
#   'Corporation',
#   'subscribe',
#   'option',
#   'right',
#   'company',
#   "'s",
#   'stock',
#   'option',
#   'program',
#   'I',
#   '2001',
#   'II',
#   '2001',
#   '.'],
#  ['$', 'FB', 'go', 'green', 'day'],
#  ['$',
#   'MSFT',
#   'SQL',
#   'Server',
#   'revenue',
#   'grow',
#   'double-digit',
#   'SQL',
#   'Server',
#   'Premium',
#   'revenue',
#   'grow',
#   '30',
#   '%',
#   'http',
#   ':',
#   '//stks.co/ir2F'],
#  ['According',
#   'L+ñnnen',
#   'Tehtaat',
#   "'s",
#   'CEO',
#   'Matti',
#   'Karppinen',
#   ',',
#   'company',
#   'aim',
#   'deliver',
#   'fish',
#   'product',
#   'customer',
#   'day',
#   'earlier',
#   'currently',
#   '.'],
#  ['The',
#   'company',
#   "'s",
#   'share',
#   'quote',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'Rautaruukki',
#   'Oyj',
#   ':',
#   'RTRKS',
#   '.'],
#  ['Elcoteq', 'SE', 'list', 'Nasdaq', 'OMX', 'Helsinki', 'Ltd.', '.'],
#  ['Two',
#   'contract',
#   'turntable',
#   'anode',
#   'vibrocompactors',
#   'deliver',
#   'Gansu',
#   'Hualu',
#   'Aluminum',
#   'Co',
#   'Ltd',
#   'another',
#   'unnamed',
#   'costumer',
#   '.'],
#  ['Aviva',
#   ',',
#   'Friends',
#   'Life',
#   'top',
#   'forecast',
#   'ahead',
#   '5.6',
#   'billion',
#   'pound',
#   'merger'],
#  ['In',
#   'stead',
#   'base',
#   'soft',
#   'drink',
#   ',',
#   'usual',
#   ',',
#   'Teho',
#   'energy',
#   'drink',
#   'make',
#   'fresh',
#   'water',
#   '.'],
#  ['The',
#   'company',
#   'plan',
#   'increase',
#   'unit',
#   "'s",
#   'specialist',
#   'staff',
#   'several',
#   'dozen',
#   '--',
#   'depend',
#   'market',
#   'situation',
#   '2010',
#   '.'],
#  ['The',
#   'company',
#   'close',
#   'last',
#   'year',
#   'turnover',
#   'four',
#   'million',
#   'euro',
#   '.'],
#  ['Shire', 'CEO', 'step', 'drive', 'get', 'Baxalta', 'board', 'talk'],
#  ['Costco',
#   ':',
#   'A',
#   'Premier',
#   'Retail',
#   'Dividend',
#   'Play',
#   'http',
#   ':',
#   '//t.co/Fa5cnh2t0t',
#   '$',
#   'COST'],
#  ['The',
#   'five-storey',
#   ',',
#   'eco-efficient',
#   'building',
#   'gross',
#   'floor',
#   'area',
#   '15,000',
#   'sq',
#   'm.',
#   'It',
#   'also',
#   'include',
#   'apartment',
#   '.'],
#  ['The',
#   'first',
#   'installment',
#   'Cinema',
#   'Series',
#   'conclude',
#   'profile',
#   'Finnish',
#   'inventor',
#   'Olavi',
#   'Linden',
#   ',',
#   'whose',
#   'personal',
#   'artistic',
#   'journey',
#   'work',
#   'Fiskars',
#   'lead',
#   'dozen',
#   'design',
#   'award',
#   '.'],
#  ['All', 'welcome', '.'],
#  ['Stockmann',
#   'Swedish',
#   'sector',
#   'company',
#   'AB',
#   'Lindex',
#   'enter',
#   'agreement',
#   'September',
#   '30',
#   ',',
#   '2007',
#   ',',
#   'whereby',
#   'Stockmann',
#   ',',
#   'wholly-owned',
#   'subsidiary',
#   ',',
#   'make',
#   'public',
#   'tender',
#   'offer',
#   'Lindex',
#   "'s",
#   'issued',
#   'share',
#   '.'],
#  ['HUHTAMAKI',
#   'OYJ',
#   'STOCK',
#   'EXCHANGE',
#   'RELEASE',
#   ',',
#   '16.9.2008',
#   'AT',
#   '13.32',
#   'Huhtamaki',
#   "'s",
#   'Capital',
#   'Markets',
#   'Day',
#   'institutional',
#   'investor',
#   'analyst',
#   'hold',
#   'Espoo',
#   ',',
#   'September',
#   '16',
#   ',',
#   '2008',
#   'start',
#   '13.30',
#   'pm',
#   'Finnish',
#   'time',
#   '.'],
#  ['``', 'We', 'please', 'welcome', 'Tapeks', 'Noma', 'Cramo', 'group', '.'],
#  ['-', 'Profit', 'tax', 'EUR', '105.9', '82.7', 'million', '.'],
#  ['Royal',
#   'Dutch',
#   'Shell',
#   'Buy',
#   'BG',
#   'Group',
#   'Nearly',
#   '$',
#   '70',
#   'Billion'],
#  ['FinancialWire',
#   'tm',
#   'press',
#   'release',
#   'service',
#   ',',
#   'receive',
#   'compensation',
#   'news',
#   ',',
#   'opinion',
#   'distribution',
#   '.'],
#  ['ASSA',
#   'ABLOY',
#   'Kaupthing',
#   'Bank',
#   'give',
#   '`',
#   'neutral',
#   "'",
#   'recommendation',
#   'share',
#   'price',
#   'target',
#   '174',
#   'crowns',
#   '$',
#   '24.7',
#   '-',
#   '19',
#   'euro',
#   'Swedish',
#   'lock',
#   'maker',
#   'Assa',
#   'Abloy',
#   'AB',
#   '.'],
#  ['The',
#   'item',
#   'include',
#   'restructuring',
#   'cost',
#   'EUR1',
#   '.6',
#   ',',
#   'year',
#   'earlier',
#   'EUR13',
#   '.1',
#   'm.',
#   'Diluted',
#   'EPS',
#   'stand',
#   'EUR0',
#   '.3',
#   'versus',
#   'loss',
#   'per',
#   'share',
#   'EUR',
#   '0.1',
#   '.'],
#  ['In', '2005', 'bank', 'post', 'net', 'profit', 'Lt', '8.2', 'mn', '.'],
#  ['$',
#   'AAPL',
#   'afternoon',
#   'selloff',
#   'usual',
#   'brutal',
#   '.',
#   'get',
#   'ready',
#   'lose',
#   'ton',
#   'money',
#   '.'],
#  ['$',
#   'TSLA',
#   'recall',
#   'pretty',
#   'much',
#   'every',
#   'single',
#   'model',
#   'X',
#   '@',
#   'cnnbrk',
#   'get',
#   'short',
#   'even',
#   'work',
#   'jump',
#   'money',
#   'trade'],
#  ['Dolce',
#   '&',
#   'Gabbana',
#   'ask',
#   'European',
#   'Union',
#   'declare',
#   'Marimekko',
#   'Corporation',
#   "'s",
#   '``',
#   'Unikko',
#   '``',
#   'floral',
#   'pattern',
#   'trademark',
#   'invalid',
#   ',',
#   'continue',
#   'dispute',
#   'two',
#   'company',
#   '.'],
#  ['InterContinental',
#   'Hotels',
#   'first-quarter',
#   'global',
#   'room',
#   'revenue',
#   'lag',
#   'estimate'],
#  ['According',
#   'Finnish',
#   'pension',
#   'insurance',
#   'company',
#   'Varma',
#   ',',
#   'Varma',
#   'recipient',
#   'two',
#   'third',
#   'revenue',
#   'earnings-related',
#   'pension',
#   'cover',
#   'competitive',
#   'tendering',
#   'Finland',
#   '.'],
#  ['A',
#   'portion',
#   ',',
#   '$',
#   '12.5',
#   'million',
#   ',',
#   'record',
#   'part',
#   'winning',
#   'prior',
#   'patent',
#   'dispute',
#   'Finnish',
#   'phone',
#   'maker',
#   'Nokia',
#   'Oyj',
#   '.'],
#  ['L',
#   '&',
#   'G',
#   'still',
#   'pay',
#   'price',
#   'dividend',
#   'cut',
#   'crisis',
#   ',',
#   'chief',
#   'say'],
#  ['The',
#   'volume',
#   'investment',
#   'two',
#   'phase',
#   'project',
#   'estimate',
#   'USD',
#   '300mn',
#   '(',
#   'EUR',
#   '215.03',
#   'mn',
#   ')',
#   '.'],
#  ['Russia',
#   'account',
#   '9',
#   '%',
#   'Lagardere',
#   'magazine',
#   'division',
#   "'s",
#   'revenue',
#   ',',
#   'EUR',
#   '114.40',
#   'mn',
#   '(',
#   'USD',
#   '148.11',
#   'mn',
#   ')',
#   '2009',
#   ',',
#   'USA',
#   '-',
#   '18',
#   '%',
#   '.'],
#  ['The',
#   'company',
#   'also',
#   'estimate',
#   'already',
#   'carry',
#   'investment',
#   'lead',
#   'increase',
#   'net',
#   'sale',
#   '2010',
#   '2009',
#   'reach',
#   'EUR',
#   '141.7',
#   'million',
#   '.'],
#  ['Profit', 'accounting', 'period', 'EUR', '0.3', 'mn', '.'],
#  ['The',
#   'six',
#   'brewery',
#   'record',
#   '5.2',
#   'percent',
#   'growth',
#   'domestic',
#   'beer',
#   'sale',
#   'last',
#   'year',
#   '270.21',
#   'million',
#   'liter',
#   ',',
#   '256.88',
#   'million',
#   'liter',
#   'sold',
#   '2005',
#   '.'],
#  ['In',
#   'August-October',
#   '2010',
#   ',',
#   'company',
#   "'s",
#   'result',
#   'tax',
#   'total',
#   'EUR',
#   '9.6',
#   'mn',
#   ',',
#   'EUR',
#   '0.5',
#   'mn',
#   'correspond',
#   'period',
#   '2009',
#   '.'],
#  ['Systeemitiimi',
#   "'s",
#   'sale',
#   'project',
#   'resource',
#   'also',
#   'strengthen',
#   ',',
#   'director',
#   'Paul',
#   'Skogberg',
#   'say',
#   '.'],
#  ['Tesco', 'share', 'price', 'jump', 'Q3', 'sale', 'top', 'estimate'],
#  ['The', 'fine', 'print', '.'],
#  ['The',
#   'price',
#   'log',
#   'clearly',
#   'improve',
#   '2009',
#   'also',
#   'price',
#   'pulpwood',
#   'go',
#   '.'],
#  ['Thus',
#   ',',
#   'SysOpen',
#   'Digia',
#   ',',
#   'accordance',
#   'Chapter',
#   '14',
#   'Section',
#   '21',
#   'Finnish',
#   'Companies',
#   'Act',
#   '29.9.1978',
#   '-',
#   '734',
#   ',',
#   'obtain',
#   'title',
#   'share',
#   'Sentera',
#   'redeem',
#   '.'],
#  ['Diluted',
#   'earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'fell',
#   'EUR',
#   '0.63',
#   'EUR',
#   '1.71',
#   '.'],
#  ['At',
#   '3:37',
#   'p.m.',
#   'Eastern',
#   'time',
#   ',',
#   'block',
#   '2,400',
#   'contract',
#   'change',
#   'hand',
#   'bid',
#   'price',
#   '$',
#   '0.45',
#   '.'],
#  ['Some',
#   'recent',
#   'technology',
#   'delivery',
#   'include',
#   'refinery',
#   'technology',
#   'Anrak',
#   'Aluminium',
#   ',',
#   'iron',
#   'ore',
#   'pelletizing',
#   'plant',
#   'Tata',
#   'Steel',
#   'iron',
#   'ore',
#   'sinter',
#   'plant',
#   'Bhushan',
#   'Steel',
#   '.'],
#  ['$',
#   'VIPS',
#   'similar',
#   'pattern',
#   'like',
#   'begin',
#   'May',
#   '.',
#   'Did',
#   'u',
#   'sell',
#   '?',
#   'Same',
#   '..',
#   'go',
#   'much',
#   'high',
#   'drop',
#   '.'],
#  ['The', 'firm', 'generate', 'sale', '187', 'mln', 'eur', '2005', '.'],
#  ['Stora',
#   'Enso',
#   'also',
#   'meeting',
#   'labor',
#   'authority',
#   ',',
#   'Employment',
#   'Economic',
#   'Development',
#   'Centres',
#   'representative',
#   'government',
#   'order',
#   'find',
#   'solution',
#   '.'],
#  ['AstraZeneca', 'profit', 'sale', 'stalwart', 'fade'],
#  ['RT',
#   '@',
#   'andrewnyquist',
#   'Chartology',
#   ':',
#   'Yahoo',
#   ':',
#   'http',
#   ':',
#   '//stks.co/1itr',
#   '$',
#   'YHOO',
#   'Crazy',
#   'look',
#   'chart',
#   ',',
#   'near',
#   'breakout',
#   'resistance',
#   'line',
#   '...'],
#  ['Most',
#   'bullish',
#   'stock',
#   'Twitter',
#   'dip',
#   '.',
#   '$',
#   'YHOO',
#   '$',
#   'GDX',
#   '$',
#   'GOOGL',
#   '$',
#   'STZ',
#   '$',
#   'GOLD',
#   '$',
#   'EW',
#   '$',
#   'VZ',
#   '$',
#   'CELG',
#   '$',
#   'SBUX',
#   '$',
#   'SCTY',
#   ':',
#   'http',
#   ':',
#   '//t.co/iuZJelfwt3'],
#  ['Finnish',
#   'GeoSentric',
#   "'s",
#   'net',
#   'sale',
#   'decrease',
#   'EUR',
#   '939,000',
#   'January-March',
#   '2009',
#   '.'],
#  ['Cohen',
#   '&',
#   'Steers',
#   ',',
#   'Inc.',
#   ':',
#   '5',
#   '534',
#   '626',
#   'share',
#   'represent',
#   '4.985',
#   '%',
#   'share',
#   'capital',
#   'voting',
#   'right',
#   '.'],
#  ['More',
#   'staff',
#   'recruit',
#   'Japan',
#   'complement',
#   'network',
#   'close',
#   '50',
#   'service',
#   'location',
#   '20',
#   'country',
#   'worldwide',
#   '.'],
#  ['Paper',
#   'company',
#   'negative',
#   'territory',
#   ',',
#   'Stora',
#   'Enso',
#   'R',
#   'shed',
#   '1.62',
#   'pct',
#   '12.73',
#   'eur',
#   ',',
#   'UPM-Kymmene',
#   '0.80',
#   'pct',
#   '18.64',
#   'eur',
#   'M-real',
#   'B',
#   '0.18',
#   'pct',
#   'low',
#   '5.57',
#   'eur',
#   '.'],
#  ['Kauko-Telko',
#   "'s",
#   'centralized',
#   'administration',
#   'dissolve',
#   'appropriate',
#   'part',
#   'transfer',
#   'operating',
#   'activity',
#   'Group',
#   'administration',
#   'end',
#   'year',
#   '.'],
#  ['Operating',
#   'profit',
#   'quarter',
#   'April-June',
#   '2006',
#   'amount',
#   'EUR182',
#   '.2',
#   'sale',
#   'EUR3',
#   '.62',
#   'bn',
#   '.'],
#  ['Atria',
#   'choose',
#   'DeLight',
#   'attract',
#   'consumer',
#   '25-45',
#   'age',
#   'group',
#   'Atria',
#   'Fresh',
#   'range',
#   'microwaveable',
#   'meal',
#   '.'],
#  ['Finnish',
#   'IT',
#   'solution',
#   'provider',
#   'Affecto',
#   'Oyj',
#   'HEL',
#   ':',
#   'AFE1V',
#   'say',
#   'today',
#   'slip',
#   'net',
#   'loss',
#   'EUR',
#   '115,000',
#   'USD',
#   '152,000',
#   'second',
#   'quarter',
#   '2010',
#   'profit',
#   'EUR',
#   '845,000',
#   'correspond',
#   'period',
#   'year',
#   'earlier',
#   '.'],
#  ['US', 'sanction', 'put', 'Gazprom-Shell', 'alliance', 'plan', 'jeopardy'],
#  ['Profit',
#   'period',
#   'EUR',
#   '10.9',
#   'mn',
#   ',',
#   'EUR',
#   '14.3',
#   'mn',
#   '2009',
#   '.'],
#  ['Profit', 'period', 'EUR', '5.9', 'mn', ',', 'EUR', '1.3', 'mn', '.'],
#  ['Operating',
#   'profit',
#   'fell',
#   'EUR',
#   '20.3',
#   'mn',
#   'EUR',
#   '74.2',
#   'mn',
#   'second',
#   'quarter',
#   '2008',
#   '.'],
#  ['However',
#   ',',
#   'sale',
#   'return',
#   'growth',
#   'April-June',
#   '2010',
#   ',',
#   'CEO',
#   'Pekka',
#   'Eloholma',
#   'say',
#   '.'],
#  ['Operating',
#   'profit',
#   'total',
#   'EUR',
#   '18.6',
#   'mn',
#   '8.3',
#   '%',
#   'net',
#   'sale',
#   '.'],
#  ['Changes',
#   'market',
#   'situation',
#   'tougher',
#   'price',
#   'competition',
#   'substantially',
#   'reduce',
#   'demand',
#   'bread',
#   'packaging',
#   'manufacture',
#   'Kauhava',
#   'plant',
#   ',',
#   'accord',
#   'company',
#   '.'],
#  ['In',
#   'connection',
#   'deal',
#   ',',
#   'Digia',
#   'employ',
#   '19',
#   'person',
#   'Nokia',
#   'Oslo',
#   'Silicon',
#   'Valley',
#   'USA',
#   '.'],
#  ['The',
#   'Brazilian',
#   'unit',
#   'Finnish',
#   'security',
#   'solution',
#   'provider',
#   'F-Secure',
#   'sign',
#   '1,500',
#   'new',
#   'client',
#   'last',
#   'year',
#   ',',
#   'online',
#   'news',
#   'source',
#   'Reseller',
#   'Web',
#   'quote',
#   'division',
#   "'s",
#   'commercial',
#   'director',
#   ',',
#   'Vladimir',
#   'Brand+úo',
#   ',',
#   'say',
#   '.'],
#  ['The',
#   'fair',
#   'value',
#   'company',
#   "'s",
#   'investment',
#   'property',
#   'go',
#   'EUR',
#   '2.768',
#   'billion',
#   'end',
#   '2009',
#   'EUR',
#   '2.916',
#   'billion',
#   'year',
#   'earlier',
#   '.'],
#  ['Dealers',
#   'say',
#   'share',
#   'largely',
#   'hit',
#   'investor',
#   'disappointment',
#   'refine',
#   'margin',
#   '9.48',
#   'usd',
#   'per',
#   'barrel',
#   'quarter',
#   'performance',
#   'ship',
#   'unit',
#   ',',
#   'saw',
#   'EBIT',
#   'drop',
#   '5',
#   'mln',
#   'eur',
#   '20',
#   'mln',
#   'eur',
#   'year',
#   'amid',
#   'fall',
#   'volume',
#   'tanker',
#   'rate',
#   '.'],
#  ['`',
#   'It',
#   'testament',
#   'quality',
#   'LTE',
#   'solution',
#   'commitment',
#   'Japanese',
#   'market',
#   "'",
#   ',',
#   'add',
#   '.'],
#  ['The',
#   'company',
#   "'",
#   'aim',
#   'finalize',
#   'negotiation',
#   'sign',
#   'contract',
#   'start',
#   'October',
#   '2008',
#   '.'],
#  ['Metso',
#   'Foundries',
#   'Jyvaskyla',
#   'Oy',
#   'discontinue',
#   'production',
#   'line',
#   '30',
#   'September',
#   '2008',
#   ',',
#   'company',
#   'say',
#   '.'],
#  ['A',
#   'total',
#   'six',
#   'poll',
#   'analyst',
#   'rat',
#   'M-real',
#   '--',
#   'two',
#   'give',
#   '``',
#   'buy',
#   '``',
#   '-',
#   '``',
#   'accumulate',
#   '``',
#   ',',
#   'three',
#   'give',
#   '``',
#   'hold',
#   '``',
#   'one',
#   'give',
#   '``',
#   'sell',
#   '``',
#   '.'],
#  ['In',
#   'September',
#   '2010',
#   ',',
#   'Finnish',
#   'group',
#   'agree',
#   'buy',
#   'Danish',
#   'company',
#   'Rose',
#   'Poultry',
#   'A-S',
#   'EUR23',
#   '.9',
#   'combination',
#   'cash',
#   'stock',
#   '.'],
#  ['$', 'YANG', 'Double', 'bottom', '5.2'],
#  ['Tesco',
#   'share',
#   'price',
#   'grocer',
#   'face',
#   'SFO',
#   'investigation',
#   'outcome'],
#  ['$', 'aapl', 'news', 'become', 'bullish', 'http', ':', '//stks.co/tMU'],
#  ['GS',
#   'Engineering',
#   'install',
#   'valve',
#   'liquefy',
#   'natural',
#   'gas',
#   'LNG',
#   'plant',
#   'build',
#   'UAE',
#   'LNG',
#   'extraction',
#   'gas',
#   'plant',
#   'operator',
#   'GASCO',
#   'Ruwais',
#   ',',
#   'UAE',
#   '.'],
#  ['The',
#   'percentage',
#   'share',
#   'vote',
#   'right',
#   'calculate',
#   'proportion',
#   'total',
#   'number',
#   'share',
#   'register',
#   'Trade',
#   'Register',
#   'total',
#   'number',
#   'voting',
#   'right',
#   'relate',
#   '.'],
#  ['M-Real',
#   'say',
#   '`',
#   'ground',
#   "'",
#   'rumor',
#   ',',
#   '`',
#   'circulate',
#   'market',
#   'month',
#   '.',
#   "'"],
#  ['Lember',
#   'say',
#   'matter',
#   'topical',
#   'also',
#   'Estonia',
#   ',',
#   'bill',
#   'draft',
#   'Social',
#   'Affairs',
#   'Ministry',
#   'would',
#   'scrap',
#   'old-age',
#   'pension',
#   'favorable',
#   'condition',
#   '.'],
#  ['-',
#   'Moody',
#   "'s",
#   'say',
#   'give',
#   'P',
#   'A1',
#   'long-term',
#   'senior',
#   'unsecured',
#   'P',
#   'P-1',
#   'short-term',
#   'debt',
#   'rating',
#   'Finnish',
#   'lender',
#   'Aktia',
#   'Bank',
#   "'s",
#   'EUR1bn',
#   'USD1',
#   '.4',
#   'bn',
#   'euro',
#   'medium-term',
#   'note',
#   'EMTN',
#   'program',
#   '25',
#   'March',
#   '2011',
#   '.'],
#  ['$', 'TSLA', 'recall'],
#  ['The',
#   'liquidity',
#   'provide',
#   'interrupt',
#   'May',
#   '11',
#   ',',
#   '2007',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   "'s",
#   'share',
#   'trade',
#   '0.50',
#   'cent',
#   '(',
#   'Aspocomp',
#   "'s",
#   'stock',
#   'exchange',
#   'release',
#   '11.5.2007',
#   ')',
#   '.'],
#  ['Hargreaves',
#   'Lansdown',
#   'buck',
#   'weak',
#   'market',
#   'see',
#   'asset',
#   'rise',
#   '2.6',
#   'percent'],
#  ['At',
#   '12.59',
#   'pm',
#   ',',
#   'OMX',
#   'Helsinki',
#   '25',
#   'index',
#   '0.32',
#   'pct',
#   'low',
#   '2,694.81',
#   '.'],
#  ['The',
#   'decision',
#   'mean',
#   'temporary',
#   'lay-offs',
#   'fix',
#   'duration',
#   'company',
#   "'s",
#   'Nastola',
#   'Jyvaskyla',
#   'unit',
#   ',',
#   'southern',
#   'central',
#   'Finland',
#   ',',
#   'respectively',
#   '.'],
#  ['The', 'value', 'order', 'EUR', '10mn', '.'],
#  ['Ms',
#   'Laakso',
#   'responsible',
#   'HKScan',
#   "'s",
#   'HR',
#   'function',
#   'development',
#   'Group',
#   '`',
#   'smarket',
#   'area',
#   '.'],
#  ['Fiskars',
#   'also',
#   'engage',
#   'global',
#   'supply',
#   'marine',
#   'energy',
#   'equipment',
#   'solution',
#   'service',
#   'associate',
#   'company',
#   ',',
#   'Wartsila',
#   'Corporation',
#   '.'],
#  ['Aberdeen', 'Asset', 'Management', 'Gains', 'Foothold', 'In', 'China'],
#  ['Finland',
#   "'s",
#   'dominate',
#   'rail',
#   'company',
#   'VR',
#   'planning',
#   'set',
#   'infect',
#   'passenger',
#   'long-distance',
#   'trip',
#   'separate',
#   'carriage',
#   '.'],
#  ['In',
#   'November',
#   ',',
#   'Finnish',
#   'government',
#   'decrease',
#   'ownership',
#   'company',
#   '31.1',
#   'percent',
#   '38',
#   'percent',
#   '.'],
#  ['Finnish',
#   'Exel',
#   'Composites',
#   ',',
#   'technology',
#   'company',
#   'design',
#   ',',
#   'manufacture',
#   ',',
#   'market',
#   'composite',
#   'profile',
#   'tubes',
#   'various',
#   'industrial',
#   'application',
#   ',',
#   'report',
#   'net',
#   'sale',
#   'decrease',
#   '0.6',
#   '%',
#   'second',
#   'quarter',
#   '2010',
#   'EUR',
#   '19.2',
#   'mn',
#   'EUR',
#   '19.3',
#   'mn',
#   'correspond',
#   'period',
#   '2009',
#   '.'],
#  ['Of',
#   'Bavelloni',
#   "'s",
#   'NST',
#   "'s",
#   'joint',
#   'venture',
#   ',',
#   'Bavelloni',
#   'Tools',
#   ',',
#   'complete',
#   'semiproducts',
#   'produce',
#   'Italy',
#   'high-quality',
#   'tool',
#   'sell',
#   'DiaPol',
#   'brand',
#   '.'],
#  ['The',
#   'tool',
#   'patent',
#   'pending',
#   'design',
#   'allow',
#   'consumer',
#   'lay',
#   'entire',
#   'project',
#   'removable',
#   'plate',
#   'use',
#   'multiple',
#   'clear',
#   'stamp',
#   'kind',
#   '.'],
#  ['$', 'GOOGL', 'short', '740', 'upper', 'BB', 'overbought'],
#  ['LIGHTS',
#   'OUT',
#   'Before',
#   'curfew',
#   ',',
#   'curl',
#   'late',
#   'bestseller',
#   'treat',
#   'eye',
#   'perfect',
#   'read',
#   'light',
#   'Luceplan',
#   '.'],
#  ['UPM-Kymmene',
#   'Corp.',
#   ',',
#   'world',
#   "'s",
#   'large',
#   'maker',
#   'magazine',
#   'paper',
#   ',',
#   'Tuesday',
#   'report',
#   '19-percent',
#   'profit',
#   'drop',
#   'low',
#   'paper',
#   'price',
#   ',',
#   'high',
#   'cost',
#   'strong',
#   'euro',
#   'hurt',
#   'revenue',
#   '.'],
#  ['The', 'total', 'value', 'contract', 'EUR', '8', 'million', '.'],
#  ['The',
#   'prerequisite',
#   'inclusion',
#   'program',
#   'receipt',
#   'gain',
#   'key',
#   'employee',
#   'acquire',
#   'Aspo',
#   'share',
#   'amount',
#   'determine',
#   'Board',
#   'advance',
#   ',',
#   'maximum',
#   '.'],
#  ['Mr.',
#   'Doring',
#   'Eaton',
#   'since',
#   '1989',
#   'act',
#   'Business',
#   'Unit',
#   'Manager',
#   'Eaton',
#   "'s",
#   'Power',
#   'Controls',
#   'Business',
#   'Unit',
#   'since',
#   'January',
#   '2007',
#   '.'],
#  ['The',
#   '250',
#   'sq',
#   '2,691',
#   'sq',
#   'ft',
#   'store',
#   'Copenhagen',
#   "'s",
#   'premier',
#   'shopping',
#   'district',
#   'inaugurate',
#   'today',
#   ',',
#   'strengthen',
#   'company',
#   "'s",
#   'presence',
#   'Nordic',
#   'capital',
#   '.'],
#  ['In',
#   'financial',
#   'statement',
#   'first',
#   'quarter',
#   '2010',
#   ',',
#   'Tikkurila',
#   'report',
#   'discontinue',
#   'operation',
#   '.'],
#  ['The',
#   'world',
#   "'s",
#   'second',
#   'large',
#   'stainless',
#   'steel',
#   'maker',
#   'say',
#   'net',
#   'profit',
#   'three-month',
#   'period',
#   'Dec.',
#   '31',
#   'surge',
#   'euro603',
#   'million',
#   'US',
#   '$',
#   '781',
#   'million',
#   ',',
#   'euro3',
#   '.33',
#   'US',
#   '$',
#   '4.31',
#   'per',
#   'share',
#   ',',
#   'euro172',
#   'million',
#   ',',
#   'euro0',
#   '.94',
#   'per',
#   'share',
#   ',',
#   'previous',
#   'year',
#   '.'],
#  ['Name',
#   'Applicant',
#   ':',
#   'Jot',
#   'Automation',
#   'OYName',
#   'Inventor',
#   ':',
#   'Mammila',
#   'Tuomo',
#   ',',
#   'Piirainen',
#   'Mika',
#   'Kellokoski',
#   'MikaApplication',
#   'No',
#   '.',
#   ':',
#   '2424-KOLNP-2008',
#   'ADate',
#   'filing',
#   'Application',
#   ':',
#   '16-06-2008Publication',
#   'Date',
#   ':',
#   '30/01/2009'],
#  ['Netflix',
#   'Grows',
#   'Efforts',
#   'To',
#   'Create',
#   'Loyal',
#   'Customers',
#   '$',
#   'NFLX',
#   'http',
#   ':',
#   '//t.co/5QXBkoBphe'],
#  ['The',
#   'OMX',
#   'Nordic',
#   '40',
#   'OMXN40',
#   'index',
#   ',',
#   'comprise',
#   '40',
#   'traded',
#   'Nordic',
#   'stock',
#   'Nasdaq',
#   'OMX',
#   'exchange',
#   ',',
#   'close',
#   '0.87',
#   '%',
#   '1,064.14',
#   'point',
#   'Thursday',
#   '.'],
#  ['$',
#   'AAPL',
#   'nibble',
#   'small',
#   'long',
#   'via',
#   '525',
#   '..',
#   'buying',
#   '13min',
#   'chart',
#   '..'],
#  ['The',
#   'operating',
#   'margin',
#   'Aker',
#   'Yards',
#   'Cruise',
#   '&',
#   'Ferries',
#   'division',
#   'go',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['$',
#   'TYC',
#   'break',
#   'new',
#   'high',
#   ',',
#   'lot',
#   'technical',
#   'look',
#   'great',
#   'right',
#   '.'],
#  ['Eero',
#   'Katajavuori',
#   ',',
#   'currently',
#   'Group',
#   'Vice',
#   'President',
#   ',',
#   'Human',
#   'Resources',
#   ',',
#   'take',
#   'year-long',
#   'sabbatical',
#   'start',
#   'October',
#   '1',
#   ',',
#   '2010',
#   '.'],
#  ['Whats',
#   '$',
#   'LULU',
#   '?',
#   'Numbers',
#   'look',
#   'good',
#   ',',
#   'great',
#   ',',
#   'good',
#   '.',
#   'I',
#   'think',
#   'conference',
#   'call',
#   'instill',
#   'confidence',
#   '.'],
#  ['The',
#   'adjustment',
#   'measure',
#   'carry',
#   'phase',
#   'secure',
#   'delivery',
#   'capability',
#   '.'],
#  ['Alma',
#   'Media',
#   'Corporation',
#   'Press',
#   'Release',
#   '15',
#   'March',
#   '2010',
#   'TYRVAAN',
#   'SANOMAT',
#   'AND',
#   'PAIKALLISSANOMAT',
#   'BEING',
#   'BOUGHT',
#   'BY',
#   'SUOMEN',
#   'PAIKALLISSANOMAT',
#   'Two',
#   'local',
#   'paper',
#   ',',
#   'Tyrvaan',
#   'Sanomat',
#   'Paikallissanomat',
#   ',',
#   'appear',
#   'Sastamala',
#   'neighbour',
#   'municipality',
#   ',',
#   'buy',
#   'Suomen',
#   'Paikallissanomat',
#   'Oy',
#   '.'],
#  ['Temporary',
#   'lay-offs',
#   ',',
#   'affect',
#   'entire',
#   'workforce',
#   ',',
#   'also',
#   'implement',
#   '.'],
#  ['A',
#   'meeting',
#   'medium',
#   'analyst',
#   'hold',
#   'day',
#   '10:30',
#   'a.m.',
#   'Stonesoft',
#   'Headquarters',
#   'Helsinki',
#   ',',
#   'Italahdenkatu',
#   '22',
#   'A',
#   '.',
#   'The',
#   'Interim',
#   'report',
#   'present',
#   'Stonesoft',
#   "'s",
#   'CEO',
#   'Ilkka',
#   'Hiidenheimo',
#   '.'],
#  ['Finnish',
#   'Sampo-Rosenlew',
#   'manufacture',
#   'approximately',
#   'seven',
#   'forest',
#   'machine',
#   'monthly',
#   ',',
#   'half',
#   'machine',
#   'export',
#   '.'],
#  ['Facebook',
#   ',',
#   'near',
#   'buy',
#   'point',
#   'last',
#   'week',
#   ',',
#   'face',
#   'different',
#   'technical',
#   'test',
#   'today',
#   'http',
#   ':',
#   '//t.co/c72LLMpiNM',
#   '$',
#   'FB',
#   '$',
#   'AAPL',
#   '$',
#   'NFLX',
#   'http',
#   ':',
#   '//t.co/fPFbYTYPuY'],
#  ['4',
#   'February',
#   '2011',
#   '-',
#   'Finnish',
#   'broadband',
#   'data',
#   'communication',
#   'system',
#   'provider',
#   'Teleste',
#   'Oyj',
#   'HEL',
#   ':',
#   'TLT1V',
#   'say',
#   'Wednesday',
#   'net',
#   'profit',
#   'rocket',
#   'EUR4',
#   '.8',
#   '2010',
#   'EUR416',
#   ',000',
#   '2009',
#   'lift',
#   'dividend',
#   'proposal',
#   '.'],
#  ['$',
#   'FREE',
#   'Ha',
#   'Heeeeeere',
#   'come',
#   'pump',
#   '!',
#   'So',
#   'glad',
#   'I',
#   'pick',
#   '9K',
#   'end',
#   'day',
#   '!',
#   'Get',
#   'ready',
#   'bull',
#   'ride',
#   '!'],
#  ['Finnish',
#   'technology',
#   'group',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   '(',
#   'OMX',
#   'Helsinki',
#   ':',
#   'ACG1V',
#   ')',
#   'issue',
#   'third',
#   'quarter',
#   'report',
#   'Thursday',
#   '(',
#   '13',
#   'November',
#   ')',
#   ',',
#   'post',
#   'operating',
#   'profit',
#   'EUR0',
#   '.4',
#   ',',
#   'compare',
#   'loss',
#   'EUR0',
#   '.5',
#   'third',
#   'quarter',
#   '2007',
#   '.'],
#  ['The',
#   'building',
#   'complex',
#   'consist',
#   'high-quality',
#   'office',
#   'retail',
#   'space',
#   'total',
#   '49,200',
#   'square',
#   'metre',
#   ',',
#   'company',
#   'say',
#   '.'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'Kesko',
#   'Group',
#   'end',
#   'loyal',
#   'customer',
#   'cooperation',
#   '.'],
#  ['The',
#   'unit',
#   'plan',
#   'operational',
#   'second',
#   'half',
#   '2007',
#   'full',
#   'stream',
#   '2008',
#   '.'],
#  ['ITG',
#   "'s",
#   'share',
#   'deal',
#   'estimate',
#   '500,000',
#   'euro',
#   '$',
#   '627,000',
#   '.'],
#  ['The',
#   'plant',
#   'expect',
#   'enter',
#   'commercial',
#   'operation',
#   'mid-2009',
#   '.'],
#  ['Aspo',
#   'also',
#   'investigate',
#   'sale',
#   'opportunity',
#   'Kaukomarkkinat',
#   "'s",
#   'electronics',
#   'business',
#   '.'],
#  ['BG', 'Group', 'appoint', 'new', 'CEO', 'one', 'month', 'early'],
#  ['The',
#   'acquisition',
#   'immediate',
#   'positive',
#   'impact',
#   'Aspocomp',
#   "'s",
#   'financial',
#   'result',
#   '.'],
#  ['Finnair',
#   "'s",
#   'passenger',
#   'load',
#   'factor',
#   ',',
#   'measure',
#   'number',
#   'sell',
#   'seat',
#   'share',
#   'available',
#   'seat',
#   ',',
#   'drop',
#   '1.3',
#   'percentage',
#   'point',
#   '76.7',
#   '%',
#   'September',
#   '.'],
#  ['RT',
#   '@',
#   'bman1',
#   '$',
#   'LNG',
#   'look',
#   'prim',
#   'also',
#   '$',
#   'EGHT',
#   'poise',
#   'run',
#   '...'],
#  ['It',
#   'also',
#   '7.7',
#   'pct',
#   '12-month',
#   'volume',
#   'weight',
#   'average',
#   'price',
#   'stock',
#   '.'],
#  ['Coke',
#   'dividend',
#   '-',
#   '3',
#   '%',
#   '.',
#   'Google',
#   'dividend',
#   '-',
#   '0',
#   '%',
#   '.',
#   'For',
#   'passive',
#   'income',
#   'Coke',
#   'take',
#   '.',
#   '$',
#   'GOOG',
#   '$',
#   'KO',
#   'http',
#   ':',
#   '//t.co/QBsoWjxOST'],
#  ['Profit',
#   'tax',
#   'EUR',
#   '5.4',
#   'mn',
#   ',',
#   'EUR',
#   '3.6',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['The',
#   'subsidiary',
#   'set',
#   'facility',
#   'manufacture',
#   'high-density',
#   'interconnection',
#   'print',
#   'circuit',
#   'board',
#   'PCBs',
#   'Nokia',
#   "'s",
#   'special',
#   'economic',
#   'zone',
#   'Sriperumbudur',
#   'near',
#   'Chennai',
#   '.'],
#  ['$',
#   'CRM',
#   'Sep',
#   '40',
#   'call',
#   '+35',
#   '%',
#   'since',
#   'entry',
#   '#',
#   'BANG',
#   'http',
#   ':',
#   '//stks.co/deDm'],
#  ['In',
#   'January-June',
#   '2010',
#   ',',
#   'dilute',
#   'loss',
#   'per',
#   'share',
#   'stand',
#   'EUR0',
#   '.3',
#   'versus',
#   'EUR0',
#   '.1',
#   'first',
#   'half',
#   '2009',
#   '.'],
#  ['Rapala',
#   'say',
#   'estimate',
#   'make',
#   'saving',
#   '1-2',
#   'mln',
#   'eur',
#   'year',
#   'centralise',
#   'French',
#   'operation',
#   'one',
#   'site',
#   '.'],
#  ['$',
#   'VMW',
#   'Got',
#   'nice',
#   'push',
#   'today',
#   'follow',
#   'small',
#   'sweeper',
#   'May',
#   'C',
#   'morning'],
#  ['That',
#   'top',
#   'consensus',
#   'forecast',
#   'earnings',
#   '0.21',
#   'euro',
#   'share',
#   '.'],
#  ['R', '&', 'D', 'Loan', ')', '.'],
#  ['In',
#   'future',
#   ',',
#   'company',
#   'intend',
#   'look',
#   'know-how',
#   'outside',
#   'company',
#   'cooperate',
#   'actor',
#   'sector',
#   '.'],
#  ['You', 'need', 'ready', 'window', 'open', ',', 'Rosberg', 'say', '.'],
#  ['More', '50,000', 'tonne', 'asphalt', 'mix', 'use', 'contract', '.'],
#  ['PA',
#   ')',
#   ',',
#   'JPMorgan',
#   'Chase',
#   'Co',
#   '(',
#   'NYSE',
#   ':',
#   'JPM',
#   ')',
#   'Pohjoa',
#   'Bank',
#   'joint',
#   'lead-managers',
#   'senior',
#   ',',
#   'unsecured',
#   'deal',
#   '.'],
#  ['$',
#   'CTRP',
#   'break',
#   'good',
#   'vol',
#   'parser',
#   'buy',
#   'signal',
#   '..',
#   'notice',
#   'bob',
#   'langs',
#   'comment',
#   'look',
#   '48',
#   'fast'],
#  ['Sales',
#   'Finland',
#   'decrease',
#   '10.5',
#   '%',
#   'January',
#   ',',
#   'sale',
#   'outside',
#   'Finland',
#   'drop',
#   '17',
#   '%',
#   '.'],
#  ['The',
#   'pulp',
#   'production',
#   'Finnish',
#   'Kemij+ñrvi',
#   'also',
#   'liquidate',
#   '1,100',
#   'employee',
#   'loose',
#   'job',
#   '.'],
#  ['Nordea', 'cheapest', 'also', 'couple', '30', 'debt', '.'],
#  ['Jussi',
#   'Pesonen',
#   ',',
#   'member',
#   'Sampo',
#   'Board',
#   'since',
#   '2006',
#   ',',
#   'renounce',
#   'seat',
#   'Sampo',
#   'Board',
#   '.'],
#  ['Tesla',
#   'recall',
#   '2,700',
#   'Model',
#   'X',
#   'car',
#   ':',
#   'http',
#   ':',
#   '//t.co/8Z7BkVsTl9',
#   '$',
#   'TSLA'],
#  ['Adjusted',
#   'change',
#   'Group',
#   'structure',
#   ',',
#   'Division',
#   "'s",
#   'net',
#   'sale',
#   'increase',
#   '1.7',
#   '%',
#   '.'],
#  ['Making',
#   'matter',
#   'difficult',
#   ',',
#   'company',
#   'say',
#   'grapple',
#   'high',
#   'oil',
#   'gas',
#   'price',
#   ',',
#   'push',
#   'cost',
#   'energy',
#   ',',
#   'raw',
#   'material',
#   'transportation',
#   '.'],
#  ['The',
#   'amend',
#   'proposal',
#   'simplifies',
#   'propose',
#   'plan',
#   'increase',
#   'incentive',
#   'key',
#   'employee',
#   'stay',
#   'Company',
#   '.'],
#  ['The', 'solution', 'expand', 'include', 'ground', 'staff', 'task', '.'],
#  ['Operating',
#   'loss',
#   'total',
#   'EUR',
#   '3.2',
#   'mn',
#   ',',
#   'compare',
#   'profit',
#   'EUR',
#   '7.2',
#   'mn',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['On',
#   '#',
#   'FEDDAY',
#   'look',
#   'sharp',
#   'move',
#   'equity',
#   '$',
#   'AAPL',
#   '$',
#   'HD',
#   '$',
#   'LOW',
#   '$',
#   'FB',
#   'see',
#   '$',
#   'UVXY',
#   '$',
#   'TVIX',
#   'get',
#   'hammer',
#   ',',
#   'even',
#   'though',
#   'market',
#   '.'],
#  ['Net',
#   'sale',
#   'total',
#   'EUR',
#   '93.6',
#   'mn',
#   ',',
#   'EUR',
#   '93.2',
#   'mn',
#   'correspond',
#   'period',
#   '2005',
#   '.'],
#  ['As',
#   'consequence',
#   'Works',
#   'Council',
#   'withdrawn',
#   'petition',
#   'suspend',
#   'reorganisation',
#   '.'],
#  ['CEO',
#   'Erkki',
#   'J+ñrvinen',
#   'happy',
#   'company',
#   "'s",
#   'performance',
#   '2010',
#   '.'],
#  ['Comparable',
#   'net',
#   'sale',
#   'expect',
#   'increase',
#   '10',
#   '%',
#   '2008',
#   ',',
#   'line',
#   'group',
#   'target',
#   '.'],
#  ['Following',
#   'transaction',
#   ',',
#   'Lundbeck',
#   'worldwide',
#   'right',
#   'nalmefene',
#   ',',
#   'exclude',
#   'North',
#   'America',
#   ',',
#   'Mexico',
#   ',',
#   'Turkey',
#   'South-Korea',
#   '.'],
#  ['The',
#   'government',
#   'start',
#   'sell-off',
#   'last',
#   'month',
#   ',',
#   'put',
#   '8',
#   'percent',
#   'stake',
#   'TeliaSonera',
#   'auction',
#   'bloc',
#   '.'],
#  ['The',
#   'report',
#   'go',
#   'provide',
#   'detailed',
#   'profile',
#   'ten',
#   'lead',
#   'European',
#   'specialty',
#   'chemical',
#   'company',
#   ',',
#   'brief',
#   'profile',
#   'major',
#   'player',
#   '.'],
#  ['Both',
#   'operating',
#   'profit',
#   'net',
#   'sale',
#   'three-month',
#   'period',
#   'increase',
#   ',',
#   'respectively',
#   'EUR16',
#   '.0',
#   'EUR139m',
#   ',',
#   'compare',
#   'corresponding',
#   'quarter',
#   '2006',
#   '.'],
#  ['The',
#   'company',
#   'expect',
#   'net',
#   'sale',
#   'whole',
#   '2009',
#   'previous',
#   'year',
#   'level',
#   '.'],
#  ['The',
#   'company',
#   'headquarter',
#   'Sievi',
#   ',',
#   'Finland',
#   ',',
#   'list',
#   'Nordic',
#   'Exchange',
#   'Helsinki',
#   '.'],
#  ['Commission',
#   'income',
#   'increase',
#   '22',
#   '%',
#   'EUR',
#   '4.4',
#   'mn',
#   ',',
#   'lending',
#   'volume',
#   'rise',
#   '13.5',
#   '%',
#   '.'],
#  ['The',
#   'Finnish',
#   'company',
#   'sell',
#   'UK',
#   'operation',
#   '-',
#   'consist',
#   '50',
#   'staff',
#   'office',
#   'London',
#   ',',
#   'Birmingham',
#   'Manchester',
#   '-',
#   'part',
#   'deal',
#   'Hampden',
#   'July',
#   '2001',
#   'European-wide',
#   'property',
#   'casualty',
#   'arm',
#   'Sampo',
#   'Industrial',
#   '.'],
#  ['In',
#   'building',
#   'home',
#   'improvement',
#   'trade',
#   ',',
#   'sale',
#   'decrease',
#   '22.5',
#   '%',
#   'EUR',
#   '201.4',
#   'mn',
#   '.'],
#  ['The',
#   'Innova',
#   '2',
#   'building',
#   'locate',
#   'close',
#   'downtown',
#   ',',
#   'immediate',
#   'vicinity',
#   'Paviljonki',
#   'travel',
#   'center',
#   ',',
#   'within',
#   'walk',
#   'distance',
#   'heart',
#   'city',
#   'thanks',
#   'trade',
#   'fair',
#   'bridge',
#   '.'],
#  ['Finnish',
#   'textile',
#   'clothe',
#   'group',
#   'Marimekko',
#   'Oyj',
#   'post',
#   'net',
#   'profit',
#   '7.99',
#   'mln',
#   'euro',
#   '$',
#   '10.4',
#   'mln',
#   '2006',
#   ',',
#   'compare',
#   '8.4',
#   'mln',
#   'euro',
#   '$',
#   '10.9',
#   'mln',
#   '2005',
#   '.'],
#  ['The',
#   'main',
#   'strength',
#   'cooperation',
#   'project',
#   'lie',
#   'merge',
#   'know-how',
#   'two',
#   'large',
#   'company',
#   '.'],
#  ['Shareholders',
#   'right',
#   'put',
#   'agenda',
#   'AGM',
#   'item',
#   'within',
#   'competence',
#   'general',
#   'meeting',
#   '.'],
#  ['Kazgiprotsvetmet',
#   'Outotec',
#   'Finland',
#   'sign',
#   'agreement',
#   'strategic',
#   'cooperation',
#   'marketing',
#   'provide',
#   'mineral',
#   'process',
#   'metallurgical',
#   'plant',
#   'relate',
#   'service',
#   'Kazakhstan',
#   'surround',
#   'country',
#   '.'],
#  ['Due',
#   'rapid',
#   'decrease',
#   'net',
#   'sale',
#   ',',
#   'personnel',
#   'reduction',
#   'carry',
#   'wide',
#   'scale',
#   'initially',
#   'expect',
#   '.'],
#  ['The',
#   'government',
#   'instead',
#   'propose',
#   'exchange',
#   'state',
#   "'s",
#   'stake',
#   'LMT',
#   'TeliaSonera',
#   "'s",
#   'stake',
#   'Lattelecom',
#   '.'],
#  ['Stora',
#   'due',
#   'release',
#   'fourth-quarter',
#   '2009',
#   'full-year',
#   'earnings',
#   'Feb.',
#   '4',
#   '.'],
#  ['Full-year',
#   'operating',
#   'result',
#   '2008',
#   '3.6',
#   'million',
#   'negative',
#   '.'],
#  ['$',
#   'NQ',
#   'get',
#   'hit',
#   'hard',
#   'low',
#   'AM',
#   '--',
#   '>',
#   'look',
#   'like',
#   'found',
#   'support',
#   '18.89',
#   'http',
#   ':',
#   '//stks.co/s052z'],
#  ['In',
#   '2008',
#   ',',
#   'AVC',
#   'Systemhaus',
#   'net',
#   'sale',
#   'EUR',
#   '10',
#   'million',
#   'USD',
#   '7.1',
#   '.'],
#  ['The',
#   'company',
#   'establish',
#   '3G',
#   'base',
#   'station',
#   '17,000',
#   'foot',
#   'foot',
#   'Mount',
#   'Everest',
#   'enable',
#   'mountain',
#   'climber',
#   '29,035-foot',
#   'summit',
#   'surf',
#   'Internet',
#   'even',
#   'send',
#   'videos',
#   'exploit',
#   '.'],
#  ['We',
#   'offer',
#   'customer',
#   'solution',
#   'base',
#   'renewable',
#   'raw',
#   'material',
#   '.'],
#  ['A',
#   'survey',
#   'conduct',
#   'Taloustutkimus',
#   'Sampo',
#   'Life',
#   'show',
#   'company',
#   'badly',
#   'prepare',
#   'lose',
#   'key',
#   'staff',
#   'member',
#   '.'],
#  ['Antti',
#   'Orkola',
#   ',',
#   'president',
#   'Kemira',
#   'GrowHow',
#   "'s",
#   'Industrial',
#   'Solutions',
#   'unit',
#   ',',
#   'tell',
#   'Thomson',
#   'Financial',
#   'News',
#   'company',
#   'put',
#   'open',
#   'mine',
#   'price',
#   'phosphate',
#   '`',
#   'quite',
#   'depressed',
#   'long',
#   'time',
#   "'",
#   '.',
#   "'"],
#  ['The',
#   'pretax',
#   'profit',
#   'group',
#   "'s",
#   'life',
#   'insurance',
#   'business',
#   'increase',
#   'EUR36m',
#   'EUR27m',
#   '.'],
#  ['We',
#   'make',
#   'available',
#   'follow',
#   'brand-new',
#   'market',
#   'analyse',
#   'Cement',
#   '-',
#   'Pakistan',
#   'Cement',
#   '-',
#   'Malaysia',
#   'Cement',
#   '-',
#   'Taiwan',
#   'Cement',
#   '-',
#   'Philippines',
#   'These',
#   'analysis',
#   'give',
#   'clear',
#   'overview',
#   'actual',
#   'situation',
#   'future',
#   'outlook',
#   'cement',
#   'industry',
#   'Asian',
#   'country',
#   '.'],
#  ['The',
#   'Company',
#   'serve',
#   'approximately',
#   '3,000',
#   'customer',
#   '100',
#   'country',
#   '.'],
#  ['RT',
#   '@',
#   'alphatrends',
#   'VMarkets',
#   'Are',
#   'Still',
#   'Acting',
#   'Weak',
#   'http',
#   ':',
#   '//stks.co/1agn',
#   '$',
#   'SPY',
#   '$',
#   'QQQ',
#   '$',
#   'XLF',
#   '$',
#   'SMH',
#   '$',
#   'IWM'],
#  ['Operating',
#   'profit',
#   'total',
#   'EUR',
#   '30.2',
#   'mn',
#   ',',
#   'EUR',
#   '43.8',
#   'mn',
#   'year',
#   'earlier',
#   '.'],
#  ['One',
#   'installed',
#   'elevator',
#   'double-deck',
#   'elevator',
#   ',',
#   'enable',
#   'efficient',
#   'use',
#   'building',
#   "'s",
#   'core',
#   'space',
#   '.'],
#  ['HELSINKI',
#   '(',
#   'AFX',
#   ')',
#   '-',
#   'Outokumpu',
#   'say',
#   'agree',
#   'sell',
#   'Hitura',
#   'nickel',
#   'mine',
#   'Finland',
#   'Canadian',
#   'group',
#   'Belvedere',
#   'Resources',
#   'Ltd',
#   '10',
#   'mln',
#   'eur',
#   'worth',
#   'Belvedere',
#   'share',
#   '.'],
#  ['Just', 'go', 'long', '$', 'ILMN'],
#  ['``',
#   'Social',
#   'network',
#   'location-based',
#   'service',
#   'trend',
#   'comprise',
#   'significant',
#   'share',
#   'Internet',
#   'traffic',
#   'today',
#   'appeal',
#   'MID',
#   'user',
#   '.'],
#  ['A',
#   'total',
#   '30',
#   '%',
#   'order',
#   'value',
#   'book',
#   'fourth',
#   'quarter',
#   '2009',
#   'remainder',
#   'book',
#   'second',
#   'quarter',
#   '2010',
#   '.'],
#  ['Johnson',
#   'Matthey',
#   'share',
#   'price',
#   'slump',
#   'company',
#   'post',
#   'full-year',
#   'result'],
#  ['There',
#   'previous',
#   'share',
#   'subscription',
#   '2004',
#   'stock',
#   'option',
#   '.'],
#  ['AffectoGenimap',
#   'build',
#   'highly',
#   'customise',
#   'IT',
#   'solutions',
#   'customer',
#   'Finland',
#   'Baltic',
#   'country',
#   '.'],
#  ['The',
#   'closing',
#   'transaction',
#   'schedule',
#   'take',
#   'place',
#   'January',
#   '10',
#   ',',
#   '2008',
#   '.'],
#  ['However',
#   ',',
#   'offer',
#   'probably',
#   'make',
#   'current',
#   'valuation',
#   ',',
#   'partly',
#   'derive',
#   'deal',
#   'company',
#   'merge',
#   'stock',
#   'market',
#   'shell',
#   '.'],
#  ['Operating',
#   'result',
#   '12-month',
#   'period',
#   'decrease',
#   'profit',
#   'EUR0',
#   '.4',
#   'turnover',
#   'decrease',
#   'EUR5',
#   '.6',
#   ',',
#   'compare',
#   '2004',
#   '.'],
#  ['The',
#   'administrator',
#   'indicate',
#   'need',
#   '900',
#   'job',
#   'cut',
#   'Irish',
#   'insurer',
#   'next',
#   '15',
#   'month',
#   '.'],
#  ['Net', 'sale', '2008', 'expect', 'level', '2007', '.'],
#  ['Technical',
#   'indicator',
#   'stock',
#   'bullish',
#   'S',
#   '&',
#   'P',
#   'give',
#   'NOK',
#   'positive',
#   '4',
#   'STARS',
#   '5',
#   'buy',
#   'ranking',
#   '.'],
#  ['Revenue',
#   'quarter',
#   'total',
#   '27.4',
#   'billion',
#   ',',
#   '2',
#   'percent',
#   '28.1',
#   'billion',
#   'fourth',
#   'quarter',
#   '2008',
#   '.'],
#  ['N-Viro',
#   'operate',
#   'process',
#   'facility',
#   'independently',
#   'well',
#   'partnership',
#   'municipality',
#   '.'],
#  ['The', 'number', 'bodily', 'injury', 'case', 'quadruple', '2000-2006', '.'],
#  ['According',
#   'Ringman',
#   ',',
#   'Finnish',
#   'paper',
#   'company',
#   'acquire',
#   'know-how',
#   'capacity',
#   'paper',
#   'recycling',
#   ',',
#   'turn',
#   'successful',
#   'strategy',
#   '.'],
#  ['The',
#   'company',
#   'also',
#   'say',
#   'Poland',
#   'profitability',
#   'program',
#   'launch',
#   'Oborniki',
#   'steel',
#   'frame',
#   'sandwich',
#   'panel',
#   'plant',
#   '.'],
#  ['And',
#   'U.S.',
#   'energy',
#   'executive',
#   'say',
#   'high',
#   'steel',
#   'price',
#   'threaten',
#   'energy',
#   'exploration',
#   '.'],
#  ['Tesco', 'sale', 'rise', 'show', 'tentative', 'recovery', 'continue'],
#  ['In',
#   'Finland',
#   ',',
#   'launch',
#   'tie-in',
#   'sale',
#   '3G',
#   'mobile',
#   'phone',
#   'cause',
#   'dramatic',
#   'rush',
#   'mobile',
#   'retail',
#   'outlet',
#   'first',
#   'day',
#   '.'],
#  ['$',
#   'NUAN',
#   'hold',
#   'well',
#   'big',
#   'gain',
#   '!',
#   'Maybe',
#   "'re",
#   'finally',
#   'move',
#   '!',
#   '!',
#   'still',
#   'undervalued',
#   'major',
#   'upside'],
#  ['The',
#   'company',
#   'split',
#   'two',
#   'part',
#   'come',
#   'month',
#   ',',
#   'Essent',
#   'own',
#   'operate',
#   'production',
#   'supply',
#   ',',
#   'Enexis',
#   'own',
#   'operate',
#   'grid',
#   '.'],
#  ['Officials', 'disclose', 'contract', 'value', '.'],
#  ['London',
#   "'s",
#   'leading',
#   'share',
#   'today',
#   'jump',
#   'almost',
#   '100',
#   'point',
#   ',',
#   '1.7',
#   '%',
#   ',',
#   'market',
#   'open',
#   '.'],
#  ['In',
#   'third',
#   'quarter',
#   'fiscal',
#   '2008',
#   'Efore',
#   'swung',
#   'net',
#   'loss',
#   'EUR',
#   '400,000',
#   'versus',
#   'net',
#   'profit',
#   'EUR',
#   '200,000',
#   'correspond',
#   'period',
#   'fiscal',
#   '2007',
#   '.'],
#  ['The',
#   'group',
#   "'s",
#   'operating',
#   'loss',
#   'EUR',
#   '0.8',
#   'mn',
#   ',',
#   'profit',
#   'EUR',
#   '2.5',
#   'mn',
#   '2004',
#   '.'],
#  ['The',
#   'move',
#   'trigger',
#   'weak',
#   'demand',
#   'forestry',
#   'equipment',
#   'uncertain',
#   'market',
#   'situation',
#   '.'],
#  ['The',
#   'combined',
#   'company',
#   'pro-forma',
#   'net',
#   'sale',
#   '140',
#   'mln',
#   'euro',
#   '$',
#   '188.9',
#   'mln',
#   'operating',
#   'profit',
#   '13',
#   'mln',
#   'euro',
#   '$',
#   '17.5',
#   'mln',
#   '2006',
#   '.'],
#  ['Managing',
#   'Director',
#   'Kari',
#   'Inkinen',
#   'say',
#   'Sponda',
#   "'s",
#   'lease',
#   'operation',
#   'develop',
#   'highly',
#   'favourably',
#   '.'],
#  ['17',
#   'March',
#   '2011',
#   '-',
#   'Goldman',
#   'Sachs',
#   'estimate',
#   'negative',
#   'prospect',
#   'Norwegian',
#   'mobile',
#   'operation',
#   'Norway',
#   "'s",
#   'Telenor',
#   'ASA',
#   'OSL',
#   ':',
#   'TEL',
#   'Sweden',
#   "'s",
#   'TeliaSonera',
#   'AB',
#   'STO',
#   ':',
#   'TLSN',
#   'short',
#   'term',
#   '.'],
#  ['$', 'TSLA', 'steaming', ',', 'stock', 'relentless', 'moment'],
#  ['Marathon',
#   'estimate',
#   'value',
#   'remain',
#   'stake',
#   'Protalix',
#   '$',
#   '27',
#   'million',
#   '.'],
#  ['Whitbread', 'share', 'price', 'climb', 'Q4', 'sale', 'growth'],
#  ['Incap',
#   'Contract',
#   'Manufacturing',
#   'subsidiary',
#   'Incap',
#   'Corporation',
#   'Finland',
#   '.'],
#  ['Operating',
#   'profit',
#   'total',
#   'EUR',
#   '37,7',
#   'mn',
#   ',',
#   'slightly',
#   'EUR',
#   '37.2',
#   'mn',
#   'correspond',
#   'period',
#   '2006',
#   '.'],
#  ['We',
#   'go',
#   'market',
#   'yield',
#   'guidance',
#   '7.25',
#   '%',
#   'area',
#   ',',
#   'give',
#   'u',
#   'flexibility',
#   'go',
#   '1-8th',
#   '.'],
#  ['RT',
#   '@',
#   'stockdemons',
#   'think',
#   'short',
#   'close',
#   'might',
#   'play',
#   ',',
#   '$',
#   'SPY',
#   '-',
#   'high',
#   'beta',
#   'reverse',
#   '..',
#   'look',
#   'worth',
#   'shot'],
#  ['VDW',
#   'combine',
#   'LXE',
#   'device',
#   'enhance',
#   'productivity',
#   ',',
#   'enable',
#   'worker',
#   'use',
#   'single',
#   'device',
#   'perform',
#   'voice',
#   ',',
#   'scan',
#   'keyboard',
#   'function',
#   '.'],
#  ['Thus',
#   'method',
#   'cut',
#   'work',
#   'cost',
#   ',',
#   'fasten',
#   'plan',
#   'building',
#   'process',
#   '.'],
#  ['Talentum', "'s", 'net', 'sale', 'September', 'small', 'expect', '.'],
#  ['COPYRIGHT',
#   'AFX',
#   'News',
#   'AFX',
#   'Financial',
#   'News',
#   'Logo',
#   'register',
#   'trademark',
#   'AFX',
#   'News',
#   'Limited'],
#  ['$',
#   'LNKD',
#   'Daily',
#   'Phase',
#   '2',
#   'retest',
#   '-',
#   'Price',
#   'experience',
#   'early',
#   'rejection',
#   '.',
#   'Can',
#   'retest',
#   '?',
#   'http',
#   ':',
#   '//stks.co/t04xX'],
#  ['RBS', 'reportedly', 'appoint', 'Howard', 'Davies', 'next', 'chairman'],
#  ['Tesco',
#   ',',
#   'Asda',
#   'sale',
#   'fall',
#   'march',
#   'discounter',
#   'continues-Kantar'],
#  ['``',
#   'With',
#   'new',
#   'version',
#   'important',
#   'u',
#   'introduce',
#   'BIM',
#   'process',
#   'base',
#   'detailed',
#   'building',
#   'information',
#   'model',
#   '.'],
#  ['SAMPO',
#   'PLC',
#   'Jarmo',
#   'Salonen',
#   'Head',
#   'Investor',
#   'Relations',
#   'Group',
#   'Communications',
#   'tel',
#   '.',
#   '+358',
#   '10',
#   '516',
#   '0030',
#   'Distribution',
#   ':',
#   'NASDAQ',
#   'OMX',
#   'Helsinki',
#   'The',
#   'principal',
#   'medium',
#   'Financial',
#   'Supervisory',
#   'Authority',
#   'www.sampo.com',
#   'This',
#   'announcement',
#   'distribute',
#   'Thomson',
#   'Reuters',
#   'behalf',
#   'Thomson',
#   'Reuters',
#   'client',
#   '.'],
#  ['.',
#   '@',
#   'barronsonline',
#   'see',
#   '#',
#   'Apple',
#   '$',
#   '150/share',
#   'year',
#   '(',
#   '+36',
#   '%',
#   'today',
#   ')',
#   'grow',
#   'service',
#   'business',
#   '.',
#   '$',
#   'AAPL',
#   'http',
#   ':',
#   '//t.co/3BDNEKN7l1'],
#  ['Pharmaceutical',
#   'market',
#   'Poland',
#   'Global',
#   'Research',
#   '&',
#   'Data',
#   'Services',
#   'publish',
#   'recently',
#   'market',
#   'analysis',
#   'pharmaceutical',
#   'market',
#   'Poland',
#   '.'],
#  ['Altogether', 'Finnair', 'cancel', '500', 'flight', 'strike', '.'],
#  ['The',
#   'employer',
#   ',',
#   'together',
#   'health',
#   'personnel',
#   ',',
#   'support',
#   'quit',
#   'pay',
#   'part',
#   'cost',
#   'nicotine',
#   'treatment',
#   '.'],
#  ['Pretax',
#   'loss',
#   'total',
#   'EUR',
#   '117mn',
#   'compare',
#   'loss',
#   'EUR',
#   '65mn',
#   'correspond',
#   'period',
#   '.'],
#  ['The',
#   'order',
#   'include',
#   '48',
#   'ship',
#   'crane',
#   'deliver',
#   '12',
#   'container',
#   'feeder',
#   'build',
#   'Wenchong',
#   'shipyard',
#   'China',
#   '.'],
#  ['Copper',
#   ',',
#   'lead',
#   'nickel',
#   'also',
#   'drop',
#   '...',
#   'HBOS',
#   '(',
#   'HBOS',
#   ')',
#   'plummet',
#   '20',
#   '%',
#   '70.3',
#   'penny',
#   'say',
#   'year+ó',
#   '?',
#   '?'],
#  ['$',
#   'GOOG',
#   'Testing',
#   '200',
#   'day',
#   'consolidation',
#   'http',
#   ':',
#   '//stks.co/h0cPJ'],
#  ['He',
#   'join',
#   'Technopolis',
#   'KONE',
#   'hold',
#   'various',
#   'position',
#   'within',
#   'Group',
#   ',',
#   'recently',
#   'Director',
#   'Service',
#   'Business',
#   'Business',
#   'Development',
#   'KONE',
#   'Middle',
#   'Eastern',
#   'operation',
#   '.'],
#  ['We',
#   'succeed',
#   'increase',
#   'market',
#   'share',
#   'sell',
#   'apartment',
#   '``',
#   ',',
#   'comment',
#   'Mr',
#   'Kari',
#   'Kauniskangas',
#   ',',
#   'Head',
#   'YIT',
#   'International',
#   'Construction',
#   'Services',
#   '.'],
#  ['Profitability',
#   '(',
#   'EBIT',
#   '%',
#   ')',
#   '13.9',
#   '%',
#   ',',
#   'compare',
#   '13.1',
#   '%',
#   'previous-year',
#   'period',
#   '.'],
#  ['Finnish',
#   'GeoSentric',
#   "'s",
#   'net',
#   'sale',
#   'decrease',
#   'EUR',
#   '939,000',
#   'January-March',
#   '2009',
#   '.'],
#  ['The',
#   'plant',
#   'schedule',
#   'completion',
#   'late',
#   'February',
#   '2007',
#   'hand',
#   'area',
#   'January',
#   'Two',
#   'supplier',
#   'Nokia',
#   '-',
#   'Aspocomp',
#   'Group',
#   'Oyj',
#   'Perlos',
#   '-',
#   'announce',
#   'plan',
#   'establish',
#   'plant',
#   'within',
#   'Nokia',
#   'complex',
#   'Together',
#   ',',
#   'invest',
#   'Rs',
#   '365',
#   'crore',
#   '.'],
#  ['-',
#   'UPM-Kymmene',
#   'upgraded',
#   '`',
#   'in-line',
#   "'",
#   '`',
#   'underperform',
#   "'",
#   'Goldman',
#   'Sachs',
#   '.'],
#  ['Slump', 'Weir', 'lead', 'FTSE', 'record', 'high'],
#  ['Jan.',
#   '6',
#   '--',
#   'Ford',
#   'struggle',
#   'face',
#   'slow',
#   'truck',
#   'SUV',
#   'sale',
#   'surfeit',
#   'up-to-date',
#   ',',
#   'get',
#   'ta',
#   '-have',
#   'car',
#   '.'],
#  ['Royal',
#   'Mail',
#   "'breached",
#   'competition',
#   'law',
#   "'",
#   'delivery',
#   'service',
#   'change',
#   ',',
#   'Ofcom',
#   'claim'],
#  ['The',
#   'cooperation',
#   'involve',
#   'Arena',
#   'Partners',
#   'buy',
#   '35',
#   '%',
#   'share',
#   'new',
#   'joint',
#   'venture',
#   'company',
#   ',',
#   'operate',
#   'Alma',
#   'Media',
#   "'s",
#   'home',
#   'sale',
#   ',',
#   'vehicle',
#   'consumer',
#   'advertising',
#   'marketplace',
#   'business',
#   '.'],
#  ['The',
#   'Efore',
#   'plant',
#   'Saarijarvi',
#   'central',
#   'Finland',
#   'one',
#   'large',
#   'employer',
#   'region',
#   '.'],
#  ['However', 'short-term', 'rental', 'become', 'popular', '.'],
#  ['EMSA',
#   'Deputy',
#   'Chairman',
#   'Board',
#   'Juri',
#   'Lember',
#   'tell',
#   'BNS',
#   'Wednesday',
#   'first',
#   'time',
#   'hear',
#   'strike',
#   'Swedish',
#   'side',
#   'inform',
#   'Estonian',
#   'union',
#   'yet',
#   '.'],
#  ['Tesco',
#   'close',
#   'new',
#   'chairman',
#   'Dixons',
#   'Carphone',
#   "'s",
#   'John',
#   'Allan',
#   'frame'],
#  ['The',
#   'device',
#   'offer',
#   'multimedia',
#   'performance',
#   'along',
#   'host',
#   'productivity',
#   'application',
#   ',',
#   'include',
#   'live',
#   'stock',
#   'price',
#   '.'],
#  ['Sales',
#   'climb',
#   '19.2',
#   'pct',
#   '1.002',
#   'bln',
#   'eur',
#   ',',
#   'surpass',
#   '953',
#   'mln',
#   'eur',
#   'consensus',
#   'figure',
#   '.'],
#  ['$',
#   'FB',
#   'turn',
#   'back',
#   'early',
#   'trading',
#   '....',
#   'http',
#   ':',
#   '//t.co/reuf5PzhBm'],
#  ['Utah',
#   "'s",
#   'capital',
#   'want',
#   'next',
#   'U.S.',
#   'headquarters',
#   'Amer',
#   'Sports',
#   'Corp.',
#   ',',
#   'ski-equipment',
#   'company',
#   '.'],
#  ['Old',
#   'Mutual',
#   'First-Quarter',
#   'Sales',
#   'Up',
#   '18',
#   '%',
#   'Buoyed',
#   'Emerging',
#   'Markets'],
#  ['The',
#   'dividend',
#   'payable',
#   'February',
#   '1',
#   ',',
#   '2010',
#   'shareholder',
#   'record',
#   'January',
#   '19',
#   ',',
#   '2010',
#   '.'],
#  ['Sales',
#   'Finland',
#   'decrease',
#   '10.5',
#   '%',
#   'January',
#   ',',
#   'sale',
#   'outside',
#   'Finland',
#   'drop',
#   '17',
# ...
#   'Warehousing',
#   'solution',
#   'increase',
#   'warehouse',
#   'efficiency',
#   'productivity',
#   'gain',
#   'discount',
#   'price',
#   '.'],
#  ['Niklas',
#   'Skogster',
#   'employ',
#   'ABB',
#   'Group',
#   'various',
#   'position',
#   'concern',
#   'development',
#   'operation',
#   '.'],
#  ['Operating',
#   'profit',
#   ',',
#   'exclude',
#   'non-recurring',
#   'item',
#   ',',
#   'total',
#   'EUR',
#   '0.2',
#   'mn',
#   ',',
#   'EUR',
#   '0.8',
#   'mn',
#   'correspond',
#   'period',
#   '2006',
#   '.'],
#  ['Finnish',
#   'Metso',
#   'Paper',
#   'award',
#   'contract',
#   'rebuild',
#   'Sabah',
#   'Forest',
#   'Industries',
#   "'",
#   '(',
#   'SFI',
#   ')',
#   'pulp',
#   'mill',
#   'Sabah',
#   ',',
#   'Malaysia',
#   '.'],
#  ['Ruukki',
#   'forecast',
#   '15-20',
#   '%',
#   'annual',
#   'sale',
#   'growth',
#   'positive',
#   'pretax',
#   'result',
#   '2010',
#   '.'],
#  ['The', 'price', 'GMO', 'soy', '5', '%', '-7', '%', 'low', 'non-GMO', '.'],
#  ['Finland',
#   "'s",
#   'Nokian',
#   'Tyres',
#   'Kazakhstan',
#   "'s",
#   'Ordabasy',
#   'Corporation',
#   'sign',
#   'agreement',
#   'build',
#   'plant',
#   'Astana',
#   'produce',
#   'car',
#   'tire',
#   ',',
#   'Ordabasy',
#   'chairman',
#   'Dinmukhamet',
#   'Idrisov',
#   'say',
#   'press',
#   'conference',
#   '.'],
#  ['With',
#   'sale',
#   '$',
#   '12.7',
#   'billion',
#   'last',
#   'twelve',
#   'month',
#   'end',
#   'October',
#   ',',
#   '2010',
#   '9,200',
#   'store',
#   '35',
#   'state',
#   ',',
#   'Dollar',
#   'General',
#   'nation',
#   "'s",
#   'large',
#   'small',
#   'box',
#   'discount',
#   'retailer',
#   '.'],
#  ['GET',
#   'MIDNIGHTTRADER',
#   'IN',
#   'REALTIME',
#   ':',
#   'This',
#   'report',
#   'delay',
#   '.'],
#  ['Danish',
#   'company',
#   'FLSmidth',
#   'acknowledge',
#   'violated',
#   'patent',
#   'hold',
#   'Finnish',
#   'Metso',
#   '.'],
#  ['The',
#   'share',
#   'issue',
#   ',',
#   'derogate',
#   'pre-emptive',
#   'right',
#   'shareholder',
#   'comprise',
#   'six',
#   'million',
#   'new',
#   'share',
#   'market',
#   'price',
#   ',',
#   'offer',
#   'subscription',
#   'shareholder',
#   ',',
#   'holder',
#   'capital',
#   'note',
#   'professional',
#   'client',
#   '.'],
#  ['Tielinja',
#   'generate',
#   'net',
#   'sale',
#   '7.5',
#   'mln',
#   'euro',
#   '$',
#   '9.6',
#   'mln',
#   '2005',
#   '.'],
#  ['Karachi',
#   ',',
#   'Sept.',
#   '14',
#   '--',
#   'Ixonos',
#   ',',
#   'world',
#   'leader',
#   'development',
#   'integration',
#   'solution',
#   'handheld',
#   'device',
#   ',',
#   'announce',
#   'implement',
#   'touch',
#   'screen',
#   'mobile',
#   'user',
#   'interface',
#   'solution',
#   'Intel',
#   'Atom',
#   'processor',
#   'Z6xx',
#   'base',
#   'smartphones',
#   '.'],
#  ['``',
#   'Neste',
#   'Oil',
#   'work',
#   '20',
#   'research',
#   'community',
#   'Europe',
#   ',',
#   'America',
#   ',',
#   'Africa',
#   ',',
#   'Asia',
#   ',',
#   'Australia',
#   'develop',
#   'introduce',
#   'new',
#   'raw',
#   'material',
#   '.'],
#  ['The',
#   'new',
#   'agreement',
#   ',',
#   'expand',
#   'long-established',
#   'cooperation',
#   'company',
#   ',',
#   'involve',
#   'transfer',
#   'certain',
#   'engineering',
#   'documentation',
#   'function',
#   'Larox',
#   'Etteplan',
#   '.'],
#  ['It', "'s", '.'],
#  ['take', '$', 'ENDP', 'long', ',', 'use', 'VWAP', 'guide'],
#  ['Despite',
#   'sale',
#   'growth',
#   ',',
#   'UK',
#   "'s",
#   'Tesco',
#   'caution',
#   'recovery',
#   'bumpy'],
#  ['In',
#   'Finland',
#   ',',
#   'metal',
#   'sector',
#   'company',
#   'Componenta',
#   'lay',
#   'temporarily',
#   'staff',
#   'Pori',
#   'mill',
#   'Christmas',
#   '2008',
#   'till',
#   '6',
#   'January',
#   '2009',
#   '.'],
#  ['In',
#   'Middle',
#   'East',
#   '&',
#   'North',
#   'Africa',
#   ',',
#   'Tecnotree',
#   'grown',
#   'considerably',
#   'recent',
#   'year',
#   '.'],
#  ['Both',
#   'operating',
#   'profit',
#   'net',
#   'sale',
#   'six-month',
#   'period',
#   'increase',
#   ',',
#   'respectively',
#   'EUR18',
#   '.1',
#   'EUR127',
#   '.6',
#   ',',
#   'compare',
#   'corresponding',
#   'period',
#   '2006',
#   '.'],
#  ['Insurer',
#   'Axa',
#   '(',
#   'PAR',
#   ':',
#   'CS',
#   ')',
#   'slide',
#   '5.35',
#   '%',
#   'EUR',
#   '14.15',
#   ',',
#   'Citigroup',
#   'ING',
#   'slash',
#   'target',
#   'stock',
#   '.'],
#  ['The',
#   'order',
#   'value',
#   'EUR',
#   '6.9',
#   'mn',
#   ',',
#   'consist',
#   'design',
#   'service',
#   'hardware',
#   'software',
#   'licence',
#   '.'],
#  ['Scanfil', 'also', 'issue', 'profit', 'warning', '.'],
#  ['A',
#   'spokesman',
#   'say',
#   ':',
#   '``',
#   'The',
#   'food',
#   'store',
#   'center',
#   ',',
#   'subject',
#   'council',
#   'local',
#   'support',
#   ',',
#   'could',
#   'comprise',
#   'supermarket',
#   'small',
#   'store',
#   'niche',
#   'outlet',
#   ',',
#   'firm',
#   'follow',
#   'consultation',
#   'council',
#   'local',
#   'community',
#   'regard',
#   'appropriate',
#   'us',
#   'occupier',
#   '.',
#   '``'],
#  ['The', 'bond', 'value', 'EUR150m', 'maturity', '4', 'year', '.'],
#  ['MillerCoors', 'Board', 'Names', 'Gavin', 'Hattersley', 'Interim', 'CEO'],
#  ['Airbus',
#   'attempt',
#   'evacuate',
#   '873',
#   'people',
#   'within',
#   '90',
#   'second',
#   '.'],
#  ['First',
#   'quarter',
#   'underlie',
#   'operating',
#   'profit',
#   'rise',
#   '41',
#   'mln',
#   'eur',
#   '33',
#   'mln',
#   'year',
#   'earlier',
#   '.'],
#  ['EPS',
#   'quarter',
#   'EUR0',
#   '.00',
#   ',',
#   'compare',
#   'EUR0',
#   '.01',
#   'third',
#   'quarter',
#   '2008',
#   ',',
#   'represent',
#   'Group',
#   'net',
#   'sale',
#   'third',
#   'quarter',
#   'EUR15',
#   '.3',
#   ',',
#   '2.8',
#   '%',
#   'compare',
#   'EUR14',
#   '.9',
#   'third',
#   'quarter',
#   '2008',
#   '.'],
#  ['Royal', 'Dutch', 'Shell', 'profit', 'rise', ';', 'dividend', '4', '%'],
#  ['Meanwhile',
#   ',',
#   'Electrowatt-Ekono',
#   'Philippines',
#   ',',
#   'Inc.',
#   'also',
#   'award',
#   'three-year',
#   'operation',
#   'maintenance',
#   '(',
#   'O',
#   '&',
#   'M',
#   ')',
#   'contract',
#   'FR',
#   'Cement',
#   'Corporation',
#   '.'],
#  ['The',
#   'agreement',
#   'include',
#   'application',
#   'maintenance',
#   'support',
#   'service',
#   '.'],
#  ['``', 'Nokia', 'interested', 'bring', 'Nokia', 'market', '.', '``'],
#  ['Affecto',
#   'expect',
#   'net',
#   'sale',
#   'whole',
#   '2010',
#   'increase',
#   '2009',
#   'level',
#   'reach',
#   'EUR',
#   '103',
#   'million',
#   '.'],
#  ['The',
#   'report',
#   'profile',
#   '158',
#   'company',
#   'include',
#   'many',
#   'key',
#   'niche',
#   'player',
#   'include',
#   'major',
#   'Nonwovens',
#   'manufacturer',
#   'Ahlstrom',
#   'Corporation',
#   ',',
#   'Asahi',
#   'Kasei',
#   'Corporation',
#   ',',
#   'Buckeye',
#   'Technologies',
#   ',',
#   'Inc.',
#   ',',
#   'EI',
#   '.'],
#  ['The',
#   'lay-offs',
#   'affect',
#   '240',
#   'people',
#   'total',
#   '320',
#   'Okmetic',
#   'employee',
#   'Finland',
#   '.'],
#  ['``',
#   'The',
#   'acquisition',
#   'Elektros',
#   'Pavara',
#   'complete',
#   'KONE',
#   "'s",
#   'market',
#   'expansion',
#   'strategy',
#   'Baltic',
#   'Countries',
#   '.'],
#  ['18',
#   'May',
#   '2010',
#   '-',
#   'Finnish',
#   'electronics',
#   'producer',
#   'Elcoteq',
#   'SE',
#   'HEL',
#   ':',
#   'ELQAV',
#   'say',
#   'today',
#   'sign',
#   'extensive',
#   'cooperation',
#   'agreement',
#   'industrialisation',
#   ',',
#   'manufacturing',
#   ',',
#   'distribution',
#   'after-market',
#   'service',
#   'mobile',
#   'phone',
#   'Japan',
#   "'s",
#   'Sharp',
#   'TYO',
#   ':',
#   '6753',
#   '.'],
#  ['Morrisons', 'book', 'second', 'consecutive', 'quarter', 'sale', 'growth'],
#  ['Marimekko',
#   'today',
#   '(',
#   '20',
#   'November',
#   ')',
#   'sign',
#   'license',
#   'agreement',
#   'Swedish',
#   'chain',
#   ',',
#   'whereby',
#   'Marimekko',
#   'license',
#   'popular',
#   'pattern',
#   '1950s',
#   ',',
#   '1960s',
#   '1970s',
#   'H',
#   '&',
#   'M',
#   '.'],
#  ['quick',
#   ',',
#   '$',
#   'FIO',
#   '21.35',
#   ',',
#   'market',
#   'tanking',
#   ',',
#   'scale',
#   'longs'],
#  ['The',
#   'announcement',
#   'push',
#   'Freenet',
#   'share',
#   '6.3',
#   '%',
#   ',',
#   'EUR0',
#   '.71',
#   ',',
#   'Frankfurt',
#   'trade',
#   'EUR10',
#   '.65',
#   'investor',
#   'give',
#   'hope',
#   'United',
#   'Internet',
#   'AG',
#   'Drillisch',
#   'would',
#   'pursue',
#   'takeover',
#   'breakup',
#   'Freenet',
#   '.'],
#  ['Finnish',
#   'telecom',
#   'software',
#   'developer',
#   'Tecnomen',
#   'Oyj',
#   'say',
#   'December',
#   '5',
#   ',',
#   '2006',
#   '$',
#   '3.3',
#   'mln',
#   '(',
#   '2.5',
#   'mln',
#   'euro',
#   ')',
#   'order',
#   'supply',
#   'expansion',
#   'charge',
#   'message',
#   'system',
#   'mobile',
#   'fixed',
#   'network',
#   'Brasil',
#   'Telecom',
#   '.'],
#  ['CompaniesUnilever', 'sale', 'lift', 'ice', 'cream', 'soft', 'economy'],
#  ['EPS', 'drop', 'EUR0', '.2', 'EUR0', '.3', '.'],
#  ['@',
#   'saltwaternurse',
#   '$',
#   'INO',
#   'test',
#   '10',
#   'next',
#   'day',
#   '.',
#   'time',
#   'take',
#   'profit',
#   '.',
#   'hedge',
#   'put',
#   '.'],
#  ['No', 'financial', 'information', 'provide', '.'],
#  ['EasyJet', 'attract', 'passenger', 'June', 'still', 'lag', 'Ryanair'],
#  ['Morning', 'Agenda', ':', 'Shire', "'s", 'Deal', 'NPS'],
#  ['Metso',
#   'supply',
#   'equipment',
#   'two',
#   'process',
#   'line',
#   'Northland',
#   'Resources',
#   "'",
#   'new',
#   'Kaunisvaara',
#   'iron',
#   'ore',
#   'project',
#   'Sweden',
#   'exploit',
#   'Tapuli',
#   'Sahavaara',
#   'iron',
#   'ore',
#   'deposit',
#   '.'],
#  ['Under',
#   'agreement',
#   'Biohit',
#   'become',
#   'focus',
#   'supplier',
#   'pipettors',
#   'disposable',
#   'pipettor',
#   'tip',
#   'VWR',
#   'customer',
#   'throughout',
#   'Europe',
#   '.'],
#  ['The',
#   'company',
#   "'s",
#   'previous',
#   'estimate',
#   'lower',
#   'revenue',
#   'year-ago',
#   'EUR',
#   '93.9',
#   'million',
#   '.'],
#  ['Earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'drop',
#   'EUR',
#   '0.21',
#   'EUR',
#   '0.31',
#   '.'],
#  ['Bids',
#   'offer',
#   'include',
#   'least',
#   '1,000',
#   'share',
#   'value',
#   'share',
#   'must',
#   'correspond',
#   'least',
#   'EUR4',
#   ',000',
#   '.'],
#  ['Earnings',
#   'per',
#   'share',
#   '(',
#   'EPS',
#   ')',
#   'amount',
#   'loss',
#   'EUR0',
#   '.06',
#   '.'],
#  ['NetApp',
#   'downgrade',
#   'Macquarie',
#   'underperform',
#   '.',
#   '$',
#   '22.00',
#   'PT',
#   '.',
#   'http',
#   ':',
#   '//t.co/XCNgws0t4q',
#   '$',
#   'NTAP',
#   '#',
#   'NTAP',
#   'via',
#   '@',
#   'RatingsNetwork'],
#  ['``',
#   'Russia',
#   'ready',
#   'participate',
#   'open',
#   'tender',
#   'Lattelecom',
#   "'s",
#   'privatization',
#   '.'],
#  ['Technopolis',
#   'St.',
#   'Petersburg',
#   'government',
#   'sign',
#   'cooperation',
#   'memorandum',
#   'October',
#   '2005',
#   'set',
#   'techno-park',
#   'Neudorf',
#   'production',
#   'zone',
#   'village',
#   'Strelny',
#   ',',
#   'St.',
#   'Petersburg',
#   'suburb',
#   '.'],
#  ['The',
#   'owner',
#   'participate',
#   'business',
#   'operation',
#   'company',
#   'continue',
#   'Poyry',
#   "'s",
#   'employment',
#   'transaction',
#   '.'],
#  ['The',
#   'goal',
#   'secure',
#   'company',
#   "'s",
#   'profitability',
#   'competitiveness',
#   '.'],
#  ['However',
#   ',',
#   'company',
#   'saw',
#   'net',
#   'profit',
#   'third',
#   'quarter',
#   'EUR',
#   '1.4',
#   'million',
#   'EUR',
#   '1.5',
#   'million',
#   'corresponding',
#   'period',
#   '2009',
#   '.'],
#  ['Neste',
#   'oil',
#   "'s",
#   'board',
#   'propose',
#   '1.00',
#   'eur',
#   'dividend',
#   'full-year',
#   '2007',
#   ',',
#   'compare',
#   '0.90',
#   'eur',
#   'year',
#   'ago',
#   '.'],
#  ['Basware',
#   'Einvoices',
#   'Oy',
#   'merge',
#   'parent',
#   'company',
#   'present',
#   'fiscal',
#   'period',
#   '.'],
#  ['#',
#   'Fintech',
#   'provider',
#   '$',
#   'CAFN',
#   'Cachet',
#   'Financial',
#   'Solutions',
#   'Surging',
#   'Forward',
#   'today',
#   'post',
#   'earnings',
#   'Up',
#   '+13.26',
#   '%',
#   'http',
#   ':',
#   '//t.co/9BJ3csk2i9',
#   '$',
#   'JKHY',
#   '$',
#   'FISV',
#   '#',
#   'Momo'],
#  ['Before',
#   'Kemira',
#   "'s",
#   'installation',
#   'NordAlu',
#   'produce',
#   '3,500',
#   'ton',
#   'liquid',
#   'solid',
#   'aluminum',
#   'waste',
#   'per',
#   'year',
#   '.'],
#  ['He',
#   'Chartered',
#   'Accountant',
#   'British',
#   'Columbia',
#   'Alberta',
#   'well',
#   'Certified',
#   'Public',
#   'Accountant',
#   'Washington',
#   'State',
#   '.'],
#  ['`',
#   'Very',
#   'recommendable',
#   "'",
#   'Nokian',
#   'Z',
#   'G2',
#   'accord',
#   '`',
#   'ADAC',
#   'judgement',
#   "'",
#   'late',
#   'summer',
#   'tyre',
#   'test',
#   'German',
#   'automobile',
#   'association',
#   'ADAC',
#   '.'],
#  ['-',
#   'The',
#   'Group',
#   '-¦',
#   'result',
#   'tax',
#   'loss',
#   'EUR',
#   '0.6',
#   '(',
#   '+0.6',
#   ')',
#   'million',
#   '.'],
#  ['-',
#   'Cash',
#   'flow',
#   'operating',
#   'activity',
#   'investment',
#   'EUR',
#   '0.8',
#   '-1.2',
#   'million',
#   '.'],
#  ['Viking', 'Line', 'cancel', 'service', '.'],
#  ['Exel', 'headquarter', 'Mantyharju', 'Finland', '.'],
#  ['Stora',
#   'Chief',
#   'Executive',
#   'Jouko',
#   'Karvinen',
#   'describe',
#   'Russian',
#   'tariff',
#   'hike',
#   'threat',
#   'future',
#   'forest',
#   'product',
#   'industry',
#   'Finland',
#   '.'],
#  ['After',
#   'Barclays',
#   'Bank',
#   'America',
#   ',',
#   'Citigroup',
#   'blockchain',
#   'sight'],
#  ['Google',
#   ',',
#   'Inc.',
#   'complete',
#   'acquisition',
#   'ICOA',
#   ',',
#   'Inc.',
#   'http',
#   ':',
#   '//stks.co/nFEI',
#   '$',
#   'ICOA',
#   '$',
#   'GOOG'],
#  ['$',
#   'TSLA',
#   'look',
#   'good',
#   '..',
#   "'d",
#   'love',
#   'see',
#   'base',
#   'action',
#   ',',
#   'let',
#   'RSI',
#   'take',
#   'breather',
#   '.',
#   'http',
#   ':',
#   '//stks.co/g1T7c'],
#  ['Finnish',
#   'plumbing',
#   'heat',
#   'system',
#   'supplier',
#   'Uponor',
#   "'s",
#   'net',
#   'sale',
#   'continue',
#   'operation',
#   'decrease',
#   '9.4',
#   '%',
#   '2008',
#   'EUR',
#   '949.2',
#   'mn',
#   'EUR',
#   '1,047.4',
#   'mn',
#   '2007',
#   '.'],
#  ['This',
#   'location',
#   'make',
#   'mall',
#   'convenient',
#   'place',
#   'shop',
#   'consumer',
#   'three',
#   'large',
#   'residential',
#   'area',
#   'nearby',
#   ':',
#   'Jaroszowka',
#   ',',
#   'Wysockiego',
#   'Zgody',
#   '.'],
#  ['Finnish',
#   'insurance',
#   'company',
#   'Fennia',
#   'Kesko',
#   'Group',
#   'end',
#   'loyal',
#   'customer',
#   'cooperation',
#   '.'],
#  ['The',
#   'casing',
#   'comprise',
#   'first',
#   'side',
#   'case',
#   'member',
#   'provide',
#   'first',
#   'side',
#   'vat',
#   'segment',
#   'second',
#   'side',
#   'case',
#   'member',
#   'provide',
#   'second',
#   'side',
#   'vat',
#   'segment',
#   ',',
#   'least',
#   'first',
#   'side',
#   'case',
#   'member',
#   'pivotable',
#   'rotation',
#   'axis',
#   '.'],
#  ['Finland-based',
#   'Elcoteq',
#   'SE',
#   ',',
#   'privately',
#   'hold',
#   'provider',
#   'electronics',
#   'manufacturing',
#   'service',
#   'communication',
#   'company',
#   ',',
#   'say',
#   'Thursday',
#   'sign',
#   'long-term',
#   'manufacturing',
#   'supply',
#   'deal',
#   'communication',
#   'equipment',
#   'company',
#   'Andrew',
#   'Corp.',
#   '.'],
#  ['In',
#   'Q1',
#   '2009',
#   ',',
#   'Bank',
#   '+àland',
#   "'s",
#   'net',
#   'interest',
#   'income',
#   'weaken',
#   '10',
#   '%',
#   'EUR',
#   '9.1',
#   'mn',
#   '.'],
#  ['RBS',
#   'Pays',
#   '$',
#   '1.7',
#   'Billion',
#   'Scrap',
#   'U.K.',
#   'Treasury',
#   "'s",
#   'Dividend',
#   'Rights'],
#  ['Increased',
#   'trust',
#   'client',
#   'YIT',
#   'see',
#   'apartment',
#   'sale',
#   'accelerate',
#   '.'],
#  ['Talvivaara',
#   'Mining',
#   'Company',
#   'Plc',
#   'Talvivaara',
#   'Mining',
#   'Company',
#   'internationally',
#   'significant',
#   'base',
#   'metal',
#   'producer',
#   'primary',
#   'focus',
#   'nickel',
#   'zinc',
#   'use',
#   'technology',
#   'know',
#   'bioheapleaching',
#   'extract',
#   'metal',
#   'ore',
#   '.'],
#  ['Operating', 'profit', '2009', 'low', 'outlook', 'publish', 'earlier', '.'],
#  ['Less', 'ten', 'people', 'face', 'pension', 'agreement', '.'],
#  ['The',
#   'company',
#   "'s",
#   'consolidated',
#   'operating',
#   'profit',
#   'amount',
#   'EUR',
#   '15.86',
#   'mn',
#   ',',
#   'EUR',
#   '4.14',
#   'mn',
#   'year-on-year',
#   '.'],
#  ['AstraZeneca', 'Buy', 'ZS', 'Pharma', '$', '2.7', 'Billion'],
#  ['Finnish',
#   'waste',
#   'management',
#   'clean',
#   'group',
#   'Lassila',
#   '&',
#   'Tikanoja',
#   'Oyj',
#   '(',
#   'L',
#   '&',
#   'T',
#   ')',
#   'net',
#   'profit',
#   'go',
#   '32.2',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '47.7',
#   'mln',
#   ')',
#   '2007',
#   '35.3',
#   'mln',
#   'euro',
#   '(',
#   '$',
#   '52.3',
#   'mln',
#   ')',
#   '2006',
#   '.'],
#  ['The',
#   'operating',
#   'margin',
#   'Aker',
#   'Yards',
#   'Cruise',
#   '&',
#   'Ferries',
#   'division',
#   'go',
#   '8.3',
#   '%',
#   '6.4',
#   '%',
#   'first',
#   'quarter',
#   '2007',
#   '.'],
#  ['HELSINKI',
#   'Thomson',
#   'Financial',
#   '-',
#   'Shares',
#   'Cargotec',
#   'fell',
#   'sharply',
#   'early',
#   'afternoon',
#   'trade',
#   'cargo',
#   'handle',
#   'group',
#   'post',
#   'surprise',
#   'drop',
#   'April-June',
#   'profit',
#   ',',
#   'overshadow',
#   'large',
#   'number',
#   'new',
#   'order',
#   'receive',
#   'three',
#   'month',
#   '.'],
#  ['The',
#   'program',
#   "'s",
#   'target',
#   'structural',
#   'cost',
#   'reduction',
#   'EUR',
#   '30mn',
#   '2009',
#   '.'],
#  ['Our',
#   'tool',
#   'specifically',
#   'design',
#   'need',
#   'business',
#   'user',
#   'ICT',
#   'expert',
#   'mind',
#   '.'],
#  ...]

# %%
stem_vec=[' '.join(message) for message in stemedata]

# %%
stem_vec
# Out:
# ["the geosolut technolog leverag benefon 's gp solut provid locat base search technolog , commun platform , locat relev multimedia content new power commerci model .",
#  '$ esi low , $ 1.50 $ 2.50 bk real possibl',
#  "for last quarter 2010 , componenta 's net sale doubl eur131m eur76m period year earlier , move zero pre-tax profit pre-tax loss eur7m .",
#  'accord finnish-russian chamber commerc , major construct compani finland oper russia .',
#  'the swedish buyout firm sold remain 22.4 percent stake , almost eighteen month take compani public finland .',
#  "$ spi would n't surpris see green close",
#  "shell 's $ 70 billion bg deal meet sharehold skeptic",
#  'ssh commun secur corp stock exchang releas octob 14 , 2008 at 2:45 pm the compani updat full year outlook estim result remain loss full year .',
#  "kone 's net sale rose 14 % year-on-year first nine month 2008 .",
#  "the stockmann depart store total floor space 8,000 squar metr stockmann 's invest project price tag eur 12 million .",
#  'circul revenu increas 5 % finland 4 % sweden 2008 .',
#  '$ sap q1 disappoint # softwar licens . real problem ? # cloud growth trail $ msft $ orcl $ goog $ crm $ adb http : //t.co/jndphllzq5',
#  'the subdivis made sale revenu last year eur 480.7 million eur 414.9 million 2008 , oper profit eur 44.5 million eur 7.4 million .',
#  'vike line cancel servic .',
#  "ahlstrom corpor stock exchang announc 7.2.2007 10.30 a total 56,955 new share ahlstrom corpor subscrib option right compani 's stock option program i 2001 ii 2001 .",
#  '$ fb gone green day',
#  '$ msft sql server revenu grew double-digit sql server premium revenu grow 30 % http : //stks.co/ir2f',
#  "accord l+ñnnen tehtaat 's ceo matti karppinen , compani aim deliv fish product custom day earlier current .",
#  "the compani 's share quot nasdaq omx helsinki rautaruukki oyj : rtrk .",
#  'elcoteq se list nasdaq omx helsinki ltd. .',
#  'two contract turntabl anod vibrocompactor deliv gansu hualu aluminum co ltd anoth unnam costum .',
#  'aviva , friend life top forecast ahead 5.6 billion pound merger',
#  'in stead base soft drink , usual , teho energi drink made fresh water .',
#  "the compani plan increas unit 's specialist staff sever dozen -- depend market situat 2010 .",
#  'the compani close last year turnov four million euro .',
#  'shire ceo step drive get baxalta board talk',
#  'costco : a premier retail dividend play http : //t.co/fa5cnh2t0t $ cost',
#  'the five-storey , eco-effici build gross floor area 15,000 sq m. it also includ apart .',
#  'the first instal cinema seri conclud profil finnish inventor olavi linden , whose person artist journey work fiskar led dozen design award .',
#  'all welcom .',
#  "stockmann swedish sector compani ab lindex enter agreement septemb 30 , 2007 , wherebi stockmann , wholly-own subsidiari , make public tender offer lindex 's issu share .",
#  "huhtamaki oyj stock exchang releas , 16.9.2008 at 13.32 huhtamaki 's capit market day institut investor analyst held espoo , septemb 16 , 2008 start 13.30 pm finnish time .",
#  '`` we pleas welcom tapek noma cramo group .',
#  '- profit tax eur 105.9 82.7 million .',
#  'royal dutch shell buy bg group nearli $ 70 billion',
#  'financialwir tm press releas servic , receiv compens news , opinion distribut .',
#  "assa abloy kaupth bank gave ` neutral ' recommend share price target 174 crown $ 24.7 - 19 euro swedish lock maker assa abloy ab .",
#  'the item includ restructur cost eur1 .6 , year earlier eur13 .1 m. dilut ep stood eur0 .3 versu loss per share eur 0.1 .',
#  'in 2005 bank post net profit lt 8.2 mn .',
#  '$ aapl afternoon selloff usual brutal . get readi lose ton money .',
#  '$ tsla recal pretti much everi singl model x @ cnnbrk got short even work jump money trade',
#  "dolc & gabbana ask european union declar marimekko corpor 's `` unikko `` floral pattern trademark invalid , continu disput two compani .",
#  'intercontinent hotel first-quart global room revenu lag estim',
#  'accord finnish pension insur compani varma , varma recipi two third revenu earnings-rel pension cover competit tender finland .',
#  'a portion , $ 12.5 million , record part win prior patent disput finnish phone maker nokia oyj .',
#  'l & g still pay price dividend cut crisi , chief say',
#  'the volum invest two phase project estim usd 300mn ( eur 215.03 mn ) .',
#  "russia account 9 % lagarder magazin divis 's revenu , eur 114.40 mn ( usd 148.11 mn ) 2009 , usa - 18 % .",
#  'the compani also estim alreadi carri invest lead increas net sale 2010 2009 reach eur 141.7 million .',
#  'profit account period eur 0.3 mn .',
#  'the six breweri record 5.2 percent growth domest beer sale last year 270.21 million liter , 256.88 million liter sold 2005 .',
#  "in august-octob 2010 , compani 's result tax total eur 9.6 mn , eur 0.5 mn correspond period 2009 .",
#  "systeemitiimi 's sale project resourc also strengthen , director paul skogberg said .",
#  'tesco share price jump q3 sale top estim',
#  'the fine print .',
#  'the price log clearli improv 2009 also price pulpwood gone .',
#  'thu , sysopen digia , accord chapter 14 section 21 finnish compani act 29.9.1978 - 734 , obtain titl share sentera redeem .',
#  'dilut earn per share ( ep ) fell eur 0.63 eur 1.71 .',
#  'at 3:37 p.m. eastern time , block 2,400 contract chang hand bid price $ 0.45 .',
#  'some recent technolog deliveri includ refineri technolog anrak aluminium , iron ore pellet plant tata steel iron ore sinter plant bhushan steel .',
#  '$ vip similar pattern like begin may . did u sell ? same .. go much higher drop .',
#  'the firm gener sale 187 mln eur 2005 .',
#  'stora enso also meet labor author , employ econom develop centr repres govern order find solut .',
#  'astrazeneca profit sale stalwart fade',
#  'rt @ andrewnyquist chartolog : yahoo : http : //stks.co/1itr $ yhoo crazi look chart , near breakout resist line ...',
#  'most bullish stock twitter dip . $ yhoo $ gdx $ googl $ stz $ gold $ ew $ vz $ celg $ sbux $ scti : http : //t.co/iuzjelfwt3',
#  "finnish geosentr 's net sale decreas eur 939,000 january-march 2009 .",
#  'cohen & steer , inc. : 5 534 626 share repres 4.985 % share capit vote right .',
#  'more staff recruit japan complement network close 50 servic locat 20 countri worldwid .',
#  'paper compani neg territori , stora enso r shed 1.62 pct 12.73 eur , upm-kymmen 0.80 pct 18.64 eur m-real b 0.18 pct lower 5.57 eur .',
#  "kauko-telko 's central administr dissolv appropri part transfer oper activ group administr end year .",
#  'oper profit quarter april-jun 2006 amount eur182 .2 sale eur3 .62 bn .',
#  'atria chose delight attract consum 25-45 age group atria fresh rang microwav meal .',
#  'finnish it solut provid affecto oyj hel : afe1v said today slip net loss eur 115,000 usd 152,000 second quarter 2010 profit eur 845,000 correspond period year earlier .',
#  'us sanction put gazprom-shel allianc plan jeopardi',
#  'profit period eur 10.9 mn , eur 14.3 mn 2009 .',
#  'profit period eur 5.9 mn , eur 1.3 mn .',
#  'oper profit fell eur 20.3 mn eur 74.2 mn second quarter 2008 .',
#  'howev , sale return growth april-jun 2010 , ceo pekka eloholma said .',
#  'oper profit total eur 18.6 mn 8.3 % net sale .',
#  'chang market situat tougher price competit substanti reduc demand bread packag manufactur kauhava plant , accord compani .',
#  'in connect deal , digia employ 19 person nokia oslo silicon valley usa .',
#  "the brazilian unit finnish secur solut provid f-secur sign 1,500 new client last year , onlin news sourc resel web quot divis 's commerci director , vladimir brand+úo , say .",
#  "the fair valu compani 's invest properti went eur 2.768 billion end 2009 eur 2.916 billion year earlier .",
#  'dealer said share larg hit investor disappoint refin margin 9.48 usd per barrel quarter perform ship unit , saw ebit drop 5 mln eur 20 mln eur year amid fall volum tanker rate .',
#  "` it testament qualiti lte solut commit japanes market ' , ad .",
#  "the compani ' aim final negoti sign contract start octob 2008 .",
#  'metso foundri jyvaskyla oy discontinu product line 30 septemb 2008 , compani said .',
#  'a total six poll analyst rate m-real -- two gave `` buy `` - `` accumul `` , three gave `` hold `` one gave `` sell `` .',
#  'in septemb 2010 , finnish group agre buy danish compani rose poultri a- eur23 .9 combin cash stock .',
#  '$ yang doubl bottom 5.2',
#  'tesco share price grocer face sfo investig outcom',
#  '$ aapl news becom bullish http : //stks.co/tmu',
#  'gs engin instal valv liquefi natur ga lng plant built uae lng extract ga plant oper gasco ruwai , uae .',
#  'the percentag share vote right calcul proport total number share regist trade regist total number vote right relat .',
#  "m-real said ` ground ' rumor , ` circul market month . '",
#  'lember said matter topic also estonia , bill draft social affair ministri would scrap old-ag pension favor condit .',
#  "- moodi 's said gave p a1 long-term senior unsecur p p-1 short-term debt rate finnish lender aktia bank 's eur1bn usd1 .4 bn euro medium-term note emtn program 25 march 2011 .",
#  '$ tsla recal',
#  "the liquid provid interrupt may 11 , 2007 aspocomp group oyj 's share trade 0.50 cent ( aspocomp 's stock exchang releas 11.5.2007 ) .",
#  'hargreav lansdown buck weak market see asset rise 2.6 percent',
#  'at 12.59 pm , omx helsinki 25 index 0.32 pct lower 2,694.81 .',
#  "the decis mean temporari lay-off fix durat compani 's nastola jyvaskyla unit , southern central finland , respect .",
#  'the valu order eur 10mn .',
#  "ms laakso respons hkscan 's hr function develop group ` smarket area .",
#  'fiskar also engag global suppli marin energi equip solut servic associ compani , wartsila corpor .',
#  'aberdeen asset manag gain foothold in china',
#  "finland 's domin rail compani vr plan set infect passeng long-dist trip separ carriag .",
#  'in novemb , finnish govern decreas ownership compani 31.1 percent 38 percent .',
#  'finnish exel composit , technolog compani design , manufactur , market composit profil tube variou industri applic , report net sale decreas 0.6 % second quarter 2010 eur 19.2 mn eur 19.3 mn correspond period 2009 .',
#  "of bavelloni 's nst 's joint ventur , bavelloni tool , complet semiproduct produc itali high-qual tool sold diapol brand .",
#  'the tool patent pend design allow consum lay entir project remov plate use multipl clear stamp kind .',
#  '$ googl short 740 upper bb overbought',
#  'light out befor curfew , curl latest bestsel treat eye perfect read light luceplan .',
#  "upm-kymmen corp. , world 's largest maker magazin paper , tuesday report 19-percent profit drop lower paper price , higher cost strong euro hurt revenu .",
#  'the total valu contract eur 8 million .',
#  'the prerequisit inclus program receipt gain key employe acquir aspo share amount determin board advanc , maximum .',
#  "mr. dore eaton sinc 1989 act busi unit manag eaton 's power control busi unit sinc januari 2007 .",
#  "the 250 sq 2,691 sq ft store copenhagen 's premier shop district inaugur today , strengthen compani 's presenc nordic capit .",
#  'in financi statement first quarter 2010 , tikkurila report discontinu oper .',
#  "the world 's second largest stainless steel maker said net profit three-month period dec. 31 surg euro603 million us $ 781 million , euro3 .33 us $ 4.31 per share , euro172 million , euro0 .94 per share , previou year .",
#  'name applic : jot autom oynam inventor : mammila tuomo , piirainen mika kellokoski mikaappl no . : 2424-kolnp-2008 adat file applic : 16-06-2008public date : 30/01/2009',
#  'netflix grow effort to creat loyal custom $ nflx http : //t.co/5qxbkobph',
#  'the omx nordic 40 omxn40 index , compris 40 trade nordic stock nasdaq omx exchang , close 0.87 % 1,064.14 point thursday .',
#  '$ aapl nibbl small long via 525 .. buy 13min chart ..',
#  'the oper margin aker yard cruis & ferri divis went 8.3 % 6.4 % first quarter 2007 .',
#  '$ tyc break new high , lot technic look great right .',
#  'eero katajavuori , current group vice presid , human resourc , take year-long sabbat start octob 1 , 2010 .',
#  'what $ lulu ? number look good , great , good . i think confer call instil confid .',
#  'the adjust measur carri phase secur deliveri capabl .',
#  'alma media corpor press releas 15 march 2010 tyrvaan sanomat and paikallissanomat be bought by suomen paikallissanomat two local paper , tyrvaan sanomat paikallissanomat , appear sastamala neighbour municip , bought suomen paikallissanomat oy .',
#  'temporari lay-off , affect entir workforc , also implement .',
#  "a meet media analyst held day 10:30 a.m. stonesoft headquart helsinki , italahdenkatu 22 a . the interim report present stonesoft 's ceo ilkka hiidenheimo .",
#  'finnish sampo-rosenlew manufactur approxim seven forest machin monthli , half machin export .',
#  'facebook , near buy point last week , face differ technic test today http : //t.co/c72llmpinm $ fb $ aapl $ nflx http : //t.co/fpfbytypuy',
#  '4 februari 2011 - finnish broadband data commun system provid telest oyj hel : tlt1v said wednesday net profit rocket eur4 .8 2010 eur416 ,000 2009 lift dividend propos .',
#  '$ free ha heeeeeer come pump ! so glad i pick 9k end day ! get readi bull ride !',
#  'finnish technolog group aspocomp group oyj ( omx helsinki : acg1v ) issu third quarter report thursday ( 13 novemb ) , post oper profit eur0 .4 , compar loss eur0 .5 third quarter 2007 .',
#  'the build complex consist high-qual offic retail space total 49,200 squar metr , compani said .',
#  'finnish insur compani fennia kesko group end loyal custom cooper .',
#  'the unit plan oper second half 2007 full stream 2008 .',
#  "itg 's share deal estim 500,000 euro $ 627,000 .",
#  'the plant expect enter commerci oper mid-2009 .',
#  "aspo also investig sale opportun kaukomarkkinat 's electron busi .",
#  'bg group appoint new ceo one month earli',
#  "the acquisit immedi posit impact aspocomp 's financi result .",
#  "finnair 's passeng load factor , measur number sold seat share avail seat , drop 1.3 percentag point 76.7 % septemb .",
#  'rt @ bman1 $ lng look prime also $ eght pois run ...',
#  'it also 7.7 pct 12-month volum weight averag price stock .',
#  'coke dividend - 3 % . googl dividend - 0 % . for passiv incom coke take . $ goog $ ko http : //t.co/qbsowjxost',
#  'profit tax eur 5.4 mn , eur 3.6 mn year earlier .',
#  "the subsidiari set facil manufactur high-dens interconnect print circuit board pcb nokia 's special econom zone sriperumbudur near chennai .",
#  '$ crm sep 40 call +35 % sinc entri # bang http : //stks.co/dedm',
#  'in january-jun 2010 , dilut loss per share stood eur0 .3 versu eur0 .1 first half 2009 .',
#  'rapala said estim make save 1-2 mln eur year centralis french oper one site .',
#  '$ vmw got nice push today follow small sweeper may c morn',
#  'that top consensu forecast earn 0.21 euro share .',
#  'r & d loan ) .',
#  'in futur , compani intend look know-how outsid compani cooper actor sector .',
#  'you need readi window open , rosberg said .',
#  'more 50,000 tonn asphalt mix use contract .',
#  'pa ) , jpmorgan chase co ( nyse : jpm ) pohjoa bank joint lead-manag senior , unsecur deal .',
#  '$ ctrp break good vol parser buy signal .. notic bob lang comment look 48 fast',
#  'sale finland decreas 10.5 % januari , sale outsid finland drop 17 % .',
#  'the pulp product finnish kemij+ñrvi also liquid 1,100 employe loos job .',
#  'nordea cheapest also coupl 30 debt .',
#  'jussi pesonen , member sampo board sinc 2006 , renounc seat sampo board .',
#  'tesla recal 2,700 model x car : http : //t.co/8z7bkvstl9 $ tsla',
#  "adjust chang group structur , divis 's net sale increas 1.7 % .",
#  'make matter difficult , compani said grappl higher oil ga price , push cost energi , raw materi transport .',
#  'the amend propos simplifi propos plan increas incent key employe stay compani .',
#  'the solut expand includ ground staff task .',
#  'oper loss total eur 3.2 mn , compar profit eur 7.2 mn third quarter 2008 .',
#  'on # fedday look sharp move equiti $ aapl $ hd $ low $ fb see $ uvxi $ tvix get hammer , even though market .',
#  'net sale total eur 93.6 mn , eur 93.2 mn correspond period 2005 .',
#  'as consequ work council withdrawn petit suspend reorganis .',
#  "ceo erkki j+ñrvinen happi compani 's perform 2010 .",
#  'compar net sale expect increas 10 % 2008 , line group target .',
#  'follow transact , lundbeck worldwid right nalmefen , exclud north america , mexico , turkey south-korea .',
#  'the govern start sell-off last month , put 8 percent stake teliasonera auction bloc .',
#  'the report goe provid detail profil ten lead european specialti chemic compani , brief profil major player .',
#  'both oper profit net sale three-month period increas , respect eur16 .0 eur139m , compar correspond quarter 2006 .',
#  'the compani expect net sale whole 2009 previou year level .',
#  'the compani headquart sievi , finland , list nordic exchang helsinki .',
#  'commiss incom increas 22 % eur 4.4 mn , lend volum rose 13.5 % .',
#  'the finnish compani sold uk oper - consist 50 staff offic london , birmingham manchest - part deal hampden juli 2001 european-wid properti casualti arm sampo industri .',
#  'in build home improv trade , sale decreas 22.5 % eur 201.4 mn .',
#  'the innova 2 build locat close downtown , immedi vicin paviljonki travel center , within walk distanc heart citi thank trade fair bridg .',
#  'finnish textil cloth group marimekko oyj post net profit 7.99 mln euro $ 10.4 mln 2006 , compar 8.4 mln euro $ 10.9 mln 2005 .',
#  'the main strength cooper project lie merg know-how two larg compani .',
#  'sharehold right put agenda agm item within compet gener meet .',
#  'kazgiprotsvetmet outotec finland sign agreement strateg cooper market provid miner process metallurg plant relat servic kazakhstan surround countri .',
#  'due rapid decreas net sale , personnel reduct carri wider scale initi expect .',
#  "the govern instead propos exchang state 's stake lmt teliasonera 's stake lattelecom .",
#  'stora due releas fourth-quart 2009 full-year earn feb. 4 .',
#  'full-year oper result 2008 3.6 million neg .',
#  '$ nq got hit hard lower am -- > look like found support 18.89 http : //stks.co/s052z',
#  'in 2008 , avc systemhau net sale eur 10 million usd 7.1 .',
#  'the compani establish 3g base station 17,000 feet foot mount everest enabl mountain climber 29,035-foot summit surf internet even send video exploit .',
#  'we offer custom solut base renew raw materi .',
#  'a survey conduct taloustutkimu sampo life show compani badli prepar lose key staff member .',
#  "antti orkola , presid kemira growhow 's industri solut unit , told thomson financi new compani put open mine price phosphat ` quit depress long time ' . '",
#  "the pretax profit group 's life insur busi increas eur36m eur27m .",
#  'we make avail follow brand-new market analys cement - pakistan cement - malaysia cement - taiwan cement - philippin these analys give clear overview actual situat futur outlook cement industri asian countri .',
#  'the compani serv approxim 3,000 custom 100 countri .',
#  'rt @ alphatrend vmarket are still act weak http : //stks.co/1agn $ spi $ qqq $ xlf $ smh $ iwm',
#  'oper profit total eur 30.2 mn , eur 43.8 mn year earlier .',
#  "one instal elev double-deck elev , enabl effici use build 's core space .",
#  'helsinki ( afx ) - outokumpu said agre sell hitura nickel mine finland canadian group belveder resourc ltd 10 mln eur worth belveder share .',
#  'just went long $ ilmn',
#  '`` social network location-bas servic trend compris signific share internet traffic today appeal mid user .',
#  'a total 30 % order valu book fourth quarter 2009 remaind book second quarter 2010 .',
#  'johnson matthey share price slump compani post full-year result',
#  'there previou share subscript 2004 stock option .',
#  'affectogenimap build highli customis it solut custom finland baltic countri .',
#  'the close transact schedul take place januari 10 , 2008 .',
#  'howev , offer probabl made current valuat , partli deriv deal compani merg stock market shell .',
#  'oper result 12-month period decreas profit eur0 .4 turnov decreas eur5 .6 , compar 2004 .',
#  'the administr indic need 900 job cut irish insur next 15 month .',
#  'net sale 2008 expect level 2007 .',
#  'technic indic stock bullish s & p give nok posit 4 star 5 buy rank .',
#  'revenu quarter total 27.4 billion , 2 percent 28.1 billion fourth quarter 2008 .',
#  'n-viro oper process facil independ well partnership municip .',
#  'the number bodili injuri case quadrupl 2000-2006 .',
#  'accord ringman , finnish paper compani acquir know-how capac paper recycl , turn success strategi .',
#  'the compani also said poland profit program launch oborniki steel frame sandwich panel plant .',
#  'and u.s. energi execut say high steel price threaten energi explor .',
#  'tesco sale rise show tent recoveri continu',
#  'in finland , launch tie-in sale 3g mobil phone caus dramat rush mobil retail outlet first day .',
#  "$ nuan held well big gain ! mayb 're final move ! ! still undervalu major upsid",
#  'the compani split two part come month , essent own oper product suppli , enexi own oper grid .',
#  'offici disclos contract valu .',
#  "london 's lead share today jump almost 100 point , 1.7 % , market open .",
#  'in third quarter fiscal 2008 efor swung net loss eur 400,000 versu net profit eur 200,000 correspond period fiscal 2007 .',
#  "the group 's oper loss eur 0.8 mn , profit eur 2.5 mn 2004 .",
#  'the move trigger weak demand forestri equip uncertain market situat .',
#  'the combin compani pro-forma net sale 140 mln euro $ 188.9 mln oper profit 13 mln euro $ 17.5 mln 2006 .',
#  "manag director kari inkinen say sponda 's leas oper develop highli favour .",
#  "17 march 2011 - goldman sach estim neg prospect norwegian mobil oper norway 's telenor asa osl : tel sweden 's teliasonera ab sto : tlsn short term .",
#  '$ tsla steam , stock relentless moment',
#  'marathon estim valu remain stake protalix $ 27 million .',
#  'whitbread share price climb q4 sale growth',
#  'incap contract manufactur subsidiari incap corpor finland .',
#  'oper profit total eur 37,7 mn , slightli eur 37.2 mn correspond period 2006 .',
#  'we went market yield guidanc 7.25 % area , gave us flexibl go 1-8th .',
#  'rt @ stockdemon think short close might play , $ spi - high beta revers .. look worth shot',
#  'vdw combin lxe devic enhanc product , enabl worker use singl devic perform voic , scan keyboard function .',
#  'thu method cut work cost , fasten plan build process .',
#  "talentum 's net sale septemb smaller expect .",
#  'copyright afx new afx financi new logo regist trademark afx new limit',
#  '$ lnkd daili phase 2 retest - price experienc earli reject . can retest ? http : //stks.co/t04xx',
#  'rb reportedli appoint howard davi next chairman',
#  'tesco , asda sale fall march discount continues-kantar',
#  '`` with new version import us introduc bim process base detail build inform model .',
#  'sampo plc jarmo salonen head investor relat group commun tel . +358 10 516 0030 distribut : nasdaq omx helsinki the princip media financi supervisori author www.sampo.com thi announc distribut thomson reuter behalf thomson reuter client .',
#  '. @ barronsonlin see # appl $ 150/share year ( +36 % today ) grow servic busi . $ aapl http : //t.co/3bdnekn7l1',
#  'pharmaceut market poland global research & data servic publish recent market analysi pharmaceut market poland .',
#  'altogeth finnair cancel 500 flight strike .',
#  'the employ , togeth health personnel , support quit pay part cost nicotin treatment .',
#  'pretax loss total eur 117mn compar loss eur 65mn correspond period .',
#  'the order includ 48 ship crane deliv 12 contain feeder built wenchong shipyard china .',
#  'copper , lead nickel also drop ... hbo ( hbo ) plummet 20 % 70.3 penc say year+ó ? ?',
#  '$ goog test 200 day consolid http : //stks.co/h0cpj',
#  'he join technopoli kone held variou posit within group , recent director servic busi busi develop kone middl eastern oper .',
#  'we succeed increas market share sold apart `` , comment mr kari kauniskanga , head yit intern construct servic .',
#  'profit ( ebit % ) 13.9 % , compar 13.1 % previous-year period .',
#  "finnish geosentr 's net sale decreas eur 939,000 january-march 2009 .",
#  'the plant schedul complet late februari 2007 hand area januari two supplier nokia - aspocomp group oyj perlo - announc plan establish plant within nokia complex togeth , invest rs 365 crore .',
#  "- upm-kymmen upgrad ` in-lin ' ` underperform ' goldman sach .",
#  'slump weir lead ftse record high',
#  'jan. 6 -- ford struggl face slow truck suv sale surfeit up-to-d , got ta -have car .',
#  "royal mail 'breach competit law ' deliveri servic chang , ofcom claim",
#  "the cooper involv arena partner buy 35 % share new joint ventur compani , oper alma media 's home sale , vehicl consum advertis marketplac busi .",
#  'the efor plant saarijarvi central finland one largest employ region .',
#  'howev short-term rental becom popular .',
#  'emsa deputi chairman board juri lember told bn wednesday first time heard strike swedish side inform estonian union yet .',
#  "tesco close new chairman dixon carphon 's john allan frame",
#  'the devic offer multimedia perform along host product applic , includ live stock price .',
#  'sale climb 19.2 pct 1.002 bln eur , surpass 953 mln eur consensu figur .',
#  '$ fb turn back earli trade .... http : //t.co/reuf5pzhbm',
#  "utah 's capit want next u.s. headquart amer sport corp. , ski-equip compani .",
#  'old mutual first-quart sale up 18 % buoy emerg market',
#  'the dividend payabl februari 1 , 2010 sharehold record januari 19 , 2010 .',
#  'sale finland decreas 10.5 % januari , sale outsid finland drop 17 % .',
#  'furthermor , bung also sign licens agreement sunnuntai carlshamn mejeri brand .',
#  'kesko corpor stock exchang releas 28.02.2008 at 09.30 1 ( 1 ) kesko corpor aspo plc today sign agreement aspo acquir share capit kauko-telko ltd , subsidiari wholli own kesko .',
#  '$ lulu # outlook # q1 2013 # lost revenu rang $ 12 million $ 17 million -not good',
#  'mobil commun wireless broadband provid nokia inc nyse : nok today set new financi target forecast nokia mobil devic industri also nokia siemen network mobil fix infrastructur relat servic market .',
#  'poyri plc addit inform : heikki malinen , presid ceo , poyri plc tel . +358 10 33 21307 poyri global expert consult engin .',
#  'danish compani flsmidth acknowledg violat patent held finnish metso .',
#  'amanda capit invest 22 privat equiti fund 200 unquot compani mainli europ .',
#  'net interest incom eur 39.3 mn , eur 32.7 mn .',
#  'jeder beta-test erh+ñlt kostenlo sech monat lang updat und hat laut eigen aussag die m+âglichkeit , die final version zu beeinflussen .',
#  "jp morgan expect scala lower nobel biocar 's growth forecast 2007 current guidanc 23-25 pct , well oper margin target current 34-35 pct .",
#  'aviva promis higher dividend boost flag share price',
#  'in addit , mid alway onlin enabl full internet brows .',
#  'fiskar strong portfolio intern brand , includ fiskar , iittala , gerber , silva buster .',
#  '# tesla : model x recal add to reliabl issu $ tsla http : //t.co/jvxq4doxnp',
#  'the name buyer disclos .',
#  'net sale veget oil busi rose eur 10.6 mn eur 10.1 mn .',
#  "under agreement benefon 's forthcom rang twig integr gp navig mobil phone devic use jointli develop web-bas track locat technolog , consum commerci applic .",
#  "follow increas huhtamaki 's regist share capit eur360 .62 number share outstand 106,063,320 .",
#  "the three year turn-around program expect ensur salomon 's futur competit , compani said .",
#  'in autumn , plan expand servic st. petersburg moscow launch servic yekaterinburg , russia , fli three time week .',
#  "the compani 's profit total ls 578,100 h1 2007 , 30.9 % year-on-year .",
#  'the feder secretari transport commun mexico award poyri mexican partner sintra consult contract connect buenavista-cuautitlan suburban railway .',
#  'fda approv astrazeneca drug advanc lung cancer',
#  "the order includ metso 's fourth quarter 2007 order backlog .",
#  'lieksaar oy earlier regard control saarelainen oy individu sharehold sharehold agreement .',
#  'raguti , control finnish breweri , report 5.4-per-cent rise beer sale 10.44 million litr held 11.09-per-cent market share .',
#  '$ mcp roll new intraday low . bottom picker continu get destroy',
#  'the compani annual turnov eur32 .8 .',
#  'it has80 branch finland annual revenu finland ?',
#  'the portfolio compris 118,000 m2 leasabl space vacanc rate roughli 5 % , let around 140 tenant two largest swedish govern ericsson .',
#  'wpp boost sale despit cautiou client',
#  'the medium-term oper target compani remain unchang .',
#  'adp new - feb 13 , 2009 - finnish retail kesko oyj hel : kesbv said today total sale , exclud valu ad tax vat , stood eur 661.3 million usd 853.1 januari 2009 , 15.2 % year-on-yea',
#  '`` consum well receiv pack fresh meat .',
#  'the correct chapter entireti .',
#  'the major part deliveri includ differ ac cxe amplifi solut product dinh telecom , compani acquir telest last spring .',
#  "tietoen use nokia 's intellisync mobil suit 's wireless email , calendar , devic manag capabl , compani extend servic custom .",
#  "it provid heat form hot water sawmil 's need .",
#  'howev , net sale declin eur 803.6 million eur 1.2 billion .',
#  "in second quarter 2010 , raut 's net loss narrow eur 123,000 eur 1.5 million period 2009 .",
#  "$ dgi technic alert : gilligan 's island buy setup , stochast buy signal , lizard bullish , hammer candlestick , wid ... http : //stks.co/c29nu",
#  'the record date dividend distribut march 14 , 2008 .',
#  '( i & h ) move enhanc growth .',
#  'the ebrd use fund provid 21.6 million a loan b portion 10 million euro syndic two finnish commerci bank , nordea bank finland plc 7.7 million euro pohjola bank plc 2.3 million euro .',
#  'stockholm , 3 march 2011 about cybercom the cybercom group high-tech consult offer global sourc end-to-end solut .',
#  'he said lose five famili month economi mani make altern arrang save money .',
#  'milan ( afx ) - the italian ship group grimaldi increas stake finnish compani finnlin 35.4 pct 30.5 pct held june , accord news agenc ansa .',
#  'comment deal , shane lennon , svp market & product develop gypsii said : ?',
#  "extern net sale print busi fell 43.7 % , partli due termin print contract ilkka-yhtyma 's print hous i-print oy sector player hss media ab decemb 2009 fall print price .",
#  'the group intend reloc warehous offic space loudeac saint marcel morvillar , east countri , alreadi oper hook manufactur distribut unit .',
#  'the firm headquart vantaa , southern finland 16 employe .',
#  'at 1.33 pm , omx helsinki 25 0.30 pct lower 2,463.67 omx helsinki 0.37 pct 8,537.42 volum 256 mln eur .',
#  'we honor recogn gartner specialist busi process model analysi , compani mani largest softwar vendor world .',
#  'westpac bank corp - is issu benchmark , 3 year frn deal euro .',
#  'includ compani brand share data categori , well distribut channel data .',
#  'for new share subscrib stock option sharehold right commenc date enter trade regist .',
#  '$ aapl price momentum weaken go close .',
#  "through acquisit solteq expand solut offer microsoft 's dynam busi softwar product .",
#  "the compani 's profit total ls 134,700 .",
#  'leed intern recogn green build certif system , develop u.s. green build council .',
#  'howev , market share shrank 47.59 per cent 48 per cent year earlier .',
#  'talktalk hire bae system investig cyber attack',
#  'look like book one way ticket 40 week ma near 50 . lose 10 week $ lulu http : //chart.ly/7xb9h9b',
#  'ftse led lower m & s , glaxosmithklin',
#  "the exercis price option base safran softwar solut ' licens mainten sale well result compani .",
#  'full-year oper result 2008 3.6 million neg .',
#  'the compani said product volum far indic circuit capabl target output rate 60,000 tonn per day , 22 million tonn year .',
#  'jun . 25 , 2008 ( boy geniu report deliv newstex ) -- the nokia ( nyse : nok ) n78 , huh ?',
#  '`` we come decis base preliminari econom , oper environment find , `` karvinen said .',
#  "the new major owner aspocomp thailand co. , ltd certain privat person belong immedi circl aspocomp 's present joint ventur partner , saha pathana inter-hold plc . .",
#  'some 3.8 mln euro ( $ 5.2 mln ) base acquisit price paid cash rest subscript offer total 850,000 new ixono share .',
#  'establish 1987 , srv group privat finnish construct concern oper finland , baltic countri russia .',
#  "the busi section also includ ahlstrom 's sustain report .",
#  '+£lemist citi environ knowledge-bas economi provid work 3,300 peopl total turnov compani amount eek 5.4 bn , `` said +£lo p+ñrnit , chairman supervisori board +£lemist citi mainor .',
#  "jacob support storengi 's invest develop storag site sinc 2006 owner 's engin .",
#  'the compani earlier said consid differ strateg option struggl low-cost mobil oper , includ divest hold .',
#  "sainsburi 's , asda , tesco morrison cut petrol price oil fall ...",
#  'barclay sell benchmark indic unit bloomberg',
#  'oper profit fourth quarter fell eur33m eur39m year earlier .',
#  'finnish forestri compani upm-kymmen wast manag compani lassila & tikanoja said jan. 30 plan produc ethanol energi commerci industri wast .',
#  'ism disclos financi result , daili said .',
#  'the contract cover manufactur , surface-treat instal steel structur .',
#  'finnish metal industri solut supplier outotec oyj net profit rose 50.4 mln euro ( $ 72.5 mln ) first nine month 2007 20.1 mln euro ( $ 28.9 mln ) period 2006 .',
#  'under deal , know it pay sek90m ( usd12 .8 m-eur8 .6 ) cash stock .',
#  "for first nine month 2010 , compani 's net profit rose eur41m eur30m correspond period 2009 .",
#  '$ aapl 50dma turn , macd crossov half-a-hair away weekli . eod break like .',
#  'protalix $ 42 million cash sale .',
#  'that bearish outsid day tuesday signific . 200 day resist still intact . opinion $ sd http : //chart.ly/2bey48t',
#  'all right reserv .',
#  'it oper nokia , support nokia netact network servic manag system .',
#  "mr priit kasak , balti metsamasina 's owner , said rakvere-bas compani wish increas valmet 's market share 27 % third coupl year .",
#  'shire see baxalta deal close expect after new rule',
#  'sainsburi cfo roger replac home retail ceo walden',
#  'marathon 4.6 percent stake plx , said , accord bloomberg .',
#  'simmon elect dcuc chairman portsmouth , n.h.-gordon a. simmon , ceo servic credit union , elect chairman defens credit union council 2007-2008 term .',
#  "sanoma new ' advertis sale decreas 22 % year .",
#  'pharmaceut market czech republ global research & data servic publish recent market analysi pharmaceut market czech republ .',
#  'finnish construct compani yit reduc number start-up market-financ residenti unit 2007 2,300 previous announc 2,700 .',
#  'cash flow oper recent quarter also reach eight year low .',
#  "tietoen 1.13 pct 18.38 , extend recent low last week 's second-quart report , dealer said .",
#  'the maritim administr said ship ignor warn ici condit .',
#  'synergi pharma soar 67 % today on posit phase 3 result $ sgyp http : //stks.co/j2awg',
#  'oper profit rose eur 1.6 mn eur 1.1 mn correspond period 2006 .',
#  'make matter difficult , compani said grappl higher oil ga price , push cost energi , raw materi transport .',
#  '$ vrtx vertex . monthli -lower hi/low lo , long term uptrend intract far',
#  'financi detail disclos .',
#  'these includ softwar develop internet mobil telephon content , commun , value-ad softwar , financi servic , secur applic , system integr electron , `` ebrd inform .',
#  'yit lodg counter claim nest oil total eur25m , primarili base work carri contract addit cost incur due prolong project .',
#  'should you follow berkshir hathaway into appl stock ?',
#  'the total amount subscript price record fund invest non-restrict equiti .',
#  '$ tsla 5th wave 1 hour chart , hammer candl develop , close 200 sma , might good spot call',
#  'strongest growth seen new market russia , czech republ , slovakia .',
#  "the tower 's engin creat 18 degre westward lean - four time inclin lean tower pisa - use diagrid structur align geometr use tekla structur bim ( build inform model ) softwar .",
#  'amer , bought salomon adida octob , said job cut aim boost competit .',
#  'acando ab ( acanb ss ) fell 8.9 percent 13.35 kronor , lowest close sinc dec. 11 .',
#  'with measur , suominen corpor aim ensur competit flexibl packag busi long term .',
#  "@ ifhedieshedi : @ bullhorn334 : $ znga short get nervou '' ''",
#  "the financi statement releas avail publish compani 's internet page www.cargotec.com .",
#  'the world glass come egypt invit visitor around world attend glass world exhibit 2009 , regist now www.glassworldex.com',
#  'compar oper profit total eur 4.7 mn , eur 5.1 mn correspond period 2005 , repres 7.4 % net sale .',
#  'most raw materi come europ us paid euro us dollar , sale take place rubl .',
#  '( adpnew ) - may 4 , 2010 - finnish cutleri hand tool maker fiskar oyj abp ( hel : fisa ) said today net profit declin eur 12.9 million ( usd 17m ) first quarter 2010 eur 17 million correspond',
#  'a maximum 666,104 new share subscrib exercis b option 2004 stock option plan .',
#  'it inspect compani strateg strength weak .',
#  'no plan close date provid .',
#  'the lemminkainen group , headquart helsinki , finland oper sector construct industri : civil engin , build contract , technic build servic build materi industri .',
#  'the implement deal subject approv finnish competit author .',
#  'microsoft also churn courtship , agre use navteq map servic , offer compani nokia bought $ 8.1 billion year ago .',
#  'the geosolut team provid intrigu new technolog combin gp mobile-bas technolog togeth internet-bas social network .',
#  'the 3c expo signatur show dongguan , support dongguan municip govern everi year , featur comput accessori , softwar , commun network product .',
#  'pharmaceut - poland thi brand-new market analysi give clear overview actual situat futur outlook pharmaceut market poland .',
#  'trade new share , right dividend distribut fund , start exchang helsinki tomorrow .',
#  'the dual-fuel engin vessel oper liquefi natur ga lng low emiss .',
#  '- among finnish share trade us , stora enso close 0.33 pct lower 12.11 eur , upm-kymmen 0.28 pct 18.10 eur , metso 0.13 pct 31.06 eur .',
#  "in addit present held presid & ceo kai telann cfo tuoma itkonen , particip opportun discuss member compani 's manag .",
#  'the chang hold accord chapter 2 , section 9 finnish secur market act describ .',
#  "with capman partner , abl develop busi continu focu provid qualiti restaur servic custom , `` say christoph wynn , ceo papa john 's russia .",
#  'the crane would instal onboard two freighter order singaporean ship owner masterbulk .',
#  'the busi divest gener consolid net sale eur 60 million annual current 640 employe .',
#  'adpnew - feb 5 , 2010 - finnish real estat investor sponda oyj hel : sda1v said today slip net loss eur 81.5 million usd 11.8 2009 profit eur 29.3 million 2008 .',
#  'the compani , eur2 .8 bn asset , count among five largest sharehold finnish insur ilmarinen 4.34 % varma 0.70 % , well finnish state pension fund ver 0.61 % .',
#  'in addit , 29 employe laid notic whole workforc laid short period need .',
#  '@ chessnwin : $ iwm 30-minut chart . small cap threaten descend triangl breakdown $ 110.20 . http : //stks.co/r0kkm',
#  'corpor it updat - ( c ) 1995-2009 m2 commun ltd finnish technolog group telest corpor ( omx helsinki : tlt1v ) report wednesday ( 4 februari ) oper profit eur5 .6 net sale eur108 .7 year 2008 .',
#  'stockholm-bas nordea bank ( sto : nda ) said yesterday hire casper von koskul lead corpor merchant bank capit market unit , effect 1 septemb .',
#  'the total need staff cut correspond 300 man-year .',
#  'finnish fiber plastic product maker suominen corpor said net loss narrow 1.6 mln euro $ 2.0 mln first nine month 2006 2.16 mln euro $ 2.7 mln period 2005 .',
#  'companiesfresnillo share jump 8 % silver price break $ 21',
#  'bluewin secur avail monthli subscript .',
#  'oper profit eur 11.4 mn , eur 7.5 mn .',
#  'finnish raisio ( diagnost ) launch new dna-bas quick test ensur safeti food .',
#  "the non-recur cost caus talentum 's premedia busi area restructur amount 2.0 mln euro $ 2.7 mln includ compani 's financi result second quarter 2007 .",
#  'finnish softwar develop baswar oyj said novemb 30 , 2006 u.s. subsidiari baswar , inc. order provid softwar contract lifecycl manag unnam u.s. medic technolog compani .',
#  'the chain unit 45-50 centr end 2008 .',
#  "the import thing keep bank 's exist 15,000 custom .",
#  'the price stainless steel also rose europ .',
#  'in sweden , gallerix accumul sek denomin sale 1 % eur denomin sale 11 % .',
#  '$ isrg - isrg short - http : //stks.co/f1vvu http : //stks.co/c1qrm',
#  '$ dara break',
#  "a total 38,244 new citycon share nomin valu eur 1.35 per share subscrib 19 april exercis a-b-c option base compani 's stock option plan 1999 .",
#  "$ aapl i 'm sure short hold breath hope miracl . lol",
#  '`` manag decid end 2005 increas cathod copper capac .',
#  'imag data produc browser phone server convert bitmap imag sent handset display . ``',
#  'shire say intern synergi goal baxalta deal higher',
#  'one largest project magazin divis sanomawsoy - sanoma magazin intern 2006 becam launch russian magazin gloriya .',
#  'finnish airlin finnair start temporari layoff cabin crew februari 2010 .',
#  'the seller founder compani .',
#  'foodservic consum good market serv approxim 13,000 peopl 54 manufactur unit sever sale offic 33 countri .',
#  "the acquisit frozen food fish sector , long synergi l+ñnnen tehtaat 's busi .",
#  '$ gnrc find support 10-day line far .',
#  "under transact agreement , metsaliitto purchas 24.7 % metsa-botnia 's share upm 3 % m-real .",
#  "britain 's ftse fall back ashtead , commod pressur",
#  'sale seppala diminish 6 per cent .',
#  "$ bbri bye bye sammi . hello bb . sound like 'll see green tomorrow .",
#  'as capac cut 1.4 % , passeng load factor 7.8 percentag point .',
#  'rockwel collin provid flight deck , cabin inform manag solut busi aircraft oper .',
#  "the floor area yliopistonrinn project 7,900 sq build 's gross area total 12,800 sq m. a total 25.1 % facil let .",
#  '$ nflx vision : short term consolid movement higher http : //stks.co/j05uu',
#  'theodosopoulo said tellab could valu nokia siemen nortel given `` lead suppli statu `` verizon , along high-growth product .',
#  'in current posit , manti work sinc 1996 .',
#  'with new product plant compani would increas capac meet expect increas demand would improv use raw materi therefor increas product profit .',
#  'analyst view : astrazeneca share seen recent volatil ; 2015 ...',
#  'earn per share ( ep ) drop eur 0.21 eur 0.31 .',
#  '`` after transact , tikkurila powder coatings-rel oper , `` compani said .',
#  "are arm hold plc , domino 's pizza group plc aso plc 3 must-hav growth stock ?",
#  'pearl plaza llc , joint ventur srv shanghai industri invest hold co ltd , conclud invest decis construct first phase shop center saint petersburg , russia .',
#  'the measur result decreas demand technic design product inform .',
#  'finnish financi group aktia report oper profit eur 44.4 mn january-septemb 2009 , eur 37.3 mn correspond period 2008 .',
#  'key price watch $ nflx , previou doubl top reject , 218.23 http : //stks.co/siyn',
#  'finnish glass technolog compani glaston oyj abp net profit decreas 2.6 mln euro ( $ 3.8 mln ) first nine month 2007 7.8 mln euro ( $ 11.4 mln ) period 2006 .',
#  'citi spirit sink diageo come short sale slide',
#  'oper loss increas eur 17mn loss eur 10.8 mn 2005 .',
#  'alexandria , va. , june 7 -- michael g. william newburi park , calif. , develop network devic .',
#  'olvi post strong set figur first six month year .',
#  'stanchart rb struggl bank england stress test',
#  'in begin year , wartsila secur order deliv four gas-fuel main engin propuls machineri vessel .',
#  "in january-novemb 2009 , group 's sale total eur 7,801.7 mn , drop 12.6 % period 2008 .",
#  'glaxosmithklin target growth across unit , scrap viiv ipo',
#  'bhp billiton share price : brazil sue samarco â£3.5bn',
#  'it come complet lcd touch screen system select chosen function price start around pound 4,805 mark .',
#  'revenu quarter fell 8 percent ( euro ) 2.4 billion compar year earlier .',
#  'after split , compani would 26,885,540 seri a share 9,540,000 seri k share .',
#  'a . le coq special develop bicentenari compani trade mark , brewer said .',
#  'arcelormitt chief execut offic lakshmi mittal alreadi cut output furnac .',
#  'oper profit fell eur 15.1 mn eur 24.6 mn 2006 .',
#  'the bridg part highway 14 develop project .',
#  'kesko agro lietuva , agricultur machineri grain trader anoth member kesko group , boost sale 42.9 percent 13.4 million euro , vat inclus .',
#  '( adpnew ) - dec 1 , 2009 - finnish cutleri hand tool maker fiskar oyj abp ( hel : fisa ) said today make redund total 18 offic manag staff member subsidiari iittala group ltd. .',
#  'metso foundri jyvaskyla oy discontinu product line 30 septemb 2008 .',
#  'the sale price disclos .',
#  'helsinki ( afx ) - retail wholesal group kesko report net sale 659.4 mln eur februari , increas 10.8 pct year-on-year .',
#  'in februari 2011 , new word ident document act make mobil id state-approv electron document februari 1st 2011 enter forc .',
#  "antti orkola , presid kemira growhow 's industri solut unit , told thomson financi new compani put open mine price phosphat ` quit depress long time ' . '",
#  "you 're alon .",
#  '2009 3 februari 2010 - finland-bas steel maker rautaruukki oyj ( hel : rtrk ) , ruukki , said today slip larger-than-expect pretax loss eur46m fourth quarter 2009 year-earli profit eur45m .',
#  'the sale savcor face cencorp result profit loss yet determin , owe factor includ valuat consider share receiv prevail exchang rate .',
#  'the acquisit +àlandsbanken sverig 2009 burden perform eur 3.0 mn .',
#  'it first applic market invoic purchas requisit approv mobil devic .',
#  'a helsinki : eliiv today report ep eur1 .13 2009 , increas ep eur1 .12 2008 .',
#  'easyjet dismiss lufthansa low-cost plan contest germani',
#  'order receiv grew 55 % year-on-year eur732m .',
#  'in january-august 2009 , import sea contain , lorri , trailer unit fell 27.7 % export 28.6 % correspond period 2008 .',
#  'finnish broadband data commun system provid telest oyj hel : tlt1v said yesterday return net profit eur 2.7 million usd 3.8 first nine month 2010 versu net loss eur 579,000 period 2009 .',
#  'adpnew - dec 23 , 2009 - norwegian financi servic group sparebank 1 gruppen as osl : sbgrp said board director appoint today jarl haug manag director claim collect subsidiari sparebank 1 gruppen finan',
#  'finnish-own contract manufactur electron elcoteq hungari kft announc plan recruit 650 new staffer fulfil new order p+®c , compani two plant .',
#  'at 12.59 pm , omx helsinki 25 index 0.32 pct lower 2,694.81 .',
#  "nyrstar also agre suppli talvivaara 150,000 tonn sulphur acid per annum use talvivaara 's leach process period suppli zinc concentr .",
#  '23 april 2010 - finnish construct engin compani outotec oyj hel : ote1v said today slip net loss eur7 .3 first quarter 2010 net profit eur12 .5 correspond period last year .',
#  'revenu slightli , x20ac 495 million $ 634 million , compar x20ac 497 million year earlier .',
#  "rt @ dasan @ tmtanalyst ... sinc $ aapl master suppli chain // corner nand , appl master everyon 's suppli chain !",
#  "poyri 's net sale 2007 amount eur 720 million employ 7400 expert .",
#  'the adjust concern staff specialti paper fiber composit segment .',
#  'accord notif , hold ameripric inc. group compani total 808,973 share , repres 3.582 % tekla -¦ share vote right .',
#  '# appl break major support , level watch - http : //stks.co/jrmw $ aapl $ qqq',
#  'royal mail chairman donald brydon set step',
#  'it also confirm earn guidanc whole 2009 issu report whole 2008 .',
#  "their offer also cover localis servic relat product transfer finnish compani 's custom alreadi product asian market made decis transfer product .",
#  'db , juliu baer emerg potenti bidder barclay asia wealth unit ...',
#  'the fair valu invest properti eur 2 251.0 ( 1 281.4 ) million .',
#  'companiestravi perkin lift dividend , earn rise 15 %',
# ...
#  'consolid net sale increas 16 % reach eur74 .8 , oper profit amount eur0 .9 compar loss eur0 .7 prior year period .',
#  'finnish forest machineri manufactur ponss issu profit warn .',
#  '`` the enterpris valu fray bento pulp mill forest orient total approxim euro1 .6 billion , `` upm said .',
#  'rental build equip account 88 percent oper incom .',
#  'the measur result weak demand shipbuild industri .',
#  'may 29 , 2010 ( companiesandmarkets.com deliv newstex ) -- thi report provid key data inform meat , fish poultri market finland .',
#  'in addit demand finland , export line stone product also increas .',
#  'the current refer grade instrument challeng oper due high price complex routin use .',
#  "`` they 've alreadi alloc money inventori .",
#  "a total 131000 talvivaara mine compani plc 's new share subscrib period may 1 , 2010 june 30 , 2010 compani 's stock option right 2007a .",
#  'eur/usd find support near 1.10 level $ ero $ uup $ udn $ fxe http : //stks.co/b29eu',
#  'the annual valu contract estim usd 2mn next three year .',
#  'in addit , launch versatil onlin servic complet tradit print newspap , mr. valkama say .',
#  'the compani said oper sold newli establish compani , cp gmbh , present manag plastic busi co-own .',
#  'finnish metal product compani componenta oyj net profit went slightli 25.1 mln euro ( $ 40.2 mln ) first half 2008 25.4 mln euro ( $ 40.7 mln ) period 2007 .',
#  'marketsbp promot upstream boss deputi ceo',
#  "britain 's ftse bounc back , mondi barratt lead",
#  'loudey corp. , $ 2.56 $ 4.33 nokia corp. , 10 cent $ 19.46 nokia agre buy digit music distributor $ 60 million .',
#  'raguti , control finnish breweri olvi , achiev 5.7 percent rise beer sale 22.6 million liter held 10.75 percent market share .',
#  'finnair said cancel flight would caus daili loss x20ac 2.5 million us $ 3 million .',
#  'the energi sector account approxim 33 % steel industri 57 % transport volum .',
#  "the 5,000 megawatt wind farm plan raah would built offshor front ruukki 's raah work .",
#  'the australian compani mirabela nickel award outokumpu technolog contract grind technolog nickel sulfid project bahia state , brazil .',
#  'standard charter , rb escap capit rais stress test',
#  'oper profit half 0.8 , 0.9 glisten invest brand manag team .',
#  'the expans final autumn 2009 .',
#  'finnish konecran tri acquir italian fantuzzi , manufactur gantri crane reach stacker .',
#  '1 p.m. central offic nordea bank 19 3-ya ulitsa yamskogo polya , build 1 telephon : 495 777-34-77 ext . 3932 , 3931 03.02.2011 unimilk - egm 03-04 .02.2011 xvi intern business-summit food busi russia 2011 take place .',
#  '( adpnew ) - feb 3 , 2010 - finland-bas steel maker rautaruukki oyj ( hel : rtrk ) , ruukki , said today slip larger-than-expect pretax loss eur 46 million ( usd 64.5 ) fourth quarter 2009',
#  'the compani expect net sale 2008 increas 5-10 % 2007 .',
#  'about 72 % evraz group share own lanebrook , whose beneficiari , one hand , millhous , hold compani asset billionair roman abramovich busi partner 50 % ; evraz execut alexand abramov alexand frolov 50 % , .',
#  '`` the margarin busi put good shape last two year , make natur addit bung , look leverag posit central northern european market , `` raisio ceo matti rihko said statement .',
#  'the loyal custom found bank +àland , index 8.0 .',
#  'tesco break downward slide cut sale declin half',
#  'eriikka s+âderstr+âm previous held sever posit financ control nokia network includ act busi group control corpor control posit nokia siemen network .',
#  'no price detail disclos .',
#  'long $ aapl',
#  "salonen ad data show produc ' pulp inventori north america declin . '",
#  'finnish it consult satama interact oyj post net profit 1.4 mln euro $ 2.0 mln first nine month 2007 , compar net loss 462,000 euro $ 664,000 period 2006 .',
#  "consist seven interconnect unit , mega imag 's logist center 347 metr length 12 metr height .",
#  "tesco plc 's recoveri continu with a â£250m cash infus",
#  'kesko 2,000 store engag chain oper nordic baltic countri , russia , belaru .',
#  'is troubl brew at legal & gener group plc and aviva plc ?',
#  'helsinki-bas componenta bought turkish list compani dokta octob 2006 89 million euro , make largest finnish invest turkey date .',
#  'the ecb mainli target inflat .',
#  'oper profit total eur 3.8 mn , eur 4.5 mn correspond period 2005 .',
#  'the group said intend initi within year process buyout minor sharehold raguti aim becom sole owner compani .',
#  'initi , compani said maximum 15 peopl would made redund parent compani 15 subsidiari .',
#  'the contract incorpor converg charg rate solut voic data , includ internet , gpr , sm , mm wap .',
#  "astrazeneca 's lung cancer drug tagrisso get fda approv",
#  'our custom includ compani energi process industri sector , particular .',
#  'europ howev remain import strong market us .',
#  'morrison debenham surpris citi christma bounc back',
#  'the ongo project tekla structur use vashi exhibit centr develop insteel engin pvt ltd-iivrcl infrastructur & project ltd & cidco .',
#  'talentum expect net sale core busi increas 2008 , compar 2007 .',
#  'oper profit half 0.8 , 0.9 glisten invest brand manag team .',
#  'it total annual revenu come 160 mln zloti ( $ 56.9 mln-42 .3 mln euro ) .',
#  'the correspond increas share capit , eur422 ,754 , enter trade regist today .',
#  'group ebit first half eur13 .6 us $ 17.8 , fall short eur22 .5 post period 2009 .',
#  'relat citi damag comment mr ashley criticis citi investor analyst `` cri babi `` .',
#  'the engin electr output 18,321 kw , make largest ga power gener set world .',
#  'pretax profit total eur 4.9 mn compar eur 5.2 mn first quarter 2005 .',
#  "most recent , found virent energi system , inc. , 80 person catalyt biofuel compani , , presid ceo , led compani multipl financ , defin compani 's market strategi , secur compani 's first custom .",
#  "addu ' servic includ person care assist activ daili live , skill nurs rehabilit therapi , adult day care .",
#  'tripadvisor jump m & a rumor http : //t.co/o4lwcdxmbr $ trip',
#  "finnish civil aviat administr decid temporarili reopen finnish capit 's helsinki airport sinc 3 p.m. 11 p.m. monday local time .",
#  'report accord merg busi oper start januari 1 , 2011 .',
#  'earn per share ( ep ) first quarter 2007 amount eur0 .07 , eur0 .04 .',
#  'finnlin estim annual gener meet 2008 financi tough year due larg invest .',
#  'meanwhil , minor sharehold , expect teliasonera retain bid , sell share .',
#  "extern net sale print busi fell 43.7 % , partli due termin print contract ilkka-yhtyma 's print hous i-print oy sector player hss media ab decemb 2009 fall print price .",
#  'oper profit eur 9.8 mn , compar loss eur 12.7 mn correspond period 2009 .',
#  'word street allergen look endo intern fail pfizer merger . may-20 $ 35 call activ . $ endp',
#  "fbr capit reiter `` outperform '' rate $ brcm price target $ 45.00 friday .",
#  'metals-zinc surg 12 pct glencor cut output , fuell metal ralli',
#  'profit period fell eur 1.6 mn eur 7.5 mn january-septemb 2008 .',
#  'is it worth invest in tesco plc and prudenti plc now ?',
#  'finland finnish pharmaceut compani orion corpor omx helsinki : ornav said wednesday 7 januari conclud personnel negoti finland reduc number personnel 205 .',
#  "finnish retail stockmann approv board swedish rival lindex public tender offer aim expand compani ' presenc russia cee countri , stockmann said monday .",
#  'in releas , compani said vocollect t2 custom north america take advantag voic direct wareh solut increas warehous effici product gain discount price .',
#  'nikla skogster employ abb group variou posit concern develop oper .',
#  'oper profit , exclud non-recur item , total eur 0.2 mn , eur 0.8 mn correspond period 2006 .',
#  "finnish metso paper award contract rebuild sabah forest industri ' ( sfi ) pulp mill sabah , malaysia .",
#  'ruukki forecast 15-20 % annual sale growth posit pretax result 2010 .',
#  'the price gmo soy 5 % -7 % lower non-gmo .',
#  "finland 's nokian tyre kazakhstan 's ordabasi corpor sign agreement build plant astana produc car tire , ordabasi chairman dinmukhamet idrisov said press confer .",
#  "with sale $ 12.7 billion last twelv month end octob , 2010 9,200 store 35 state , dollar gener nation 's largest small box discount retail .",
#  'get midnighttrad in realtim : thi report delay .',
#  'danish compani flsmidth acknowledg violat patent held finnish metso .',
#  'the share issu , derog pre-empt right sharehold compris six million new share market price , offer subscript sharehold , holder capit note profession client .',
#  'tielinja gener net sale 7.5 mln euro $ 9.6 mln 2005 .',
#  'karachi , sept. 14 -- ixono , world leader develop integr solut handheld devic , announc implement touch screen mobil user interfac solut intel atom processor z6xx base smartphon .',
#  '`` nest oil work 20 research commun europ , america , africa , asia , australia develop introduc new raw materi .',
#  'the new agreement , expand long-establish cooper compani , involv transfer certain engin document function larox etteplan .',
#  "it 's .",
#  'took $ endp long , use vwap guid',
#  "despit sale growth , uk 's tesco caution recoveri bumpi",
#  'in finland , metal sector compani componenta lay temporarili staff pori mill christma 2008 till 6 januari 2009 .',
#  'in middl east & north africa , tecnotre grown consider recent year .',
#  'both oper profit net sale six-month period increas , respect eur18 .1 eur127 .6 , compar correspond period 2006 .',
#  'insur axa ( par : cs ) slid 5.35 % eur 14.15 , citigroup ing slash target stock .',
#  'the order valu eur 6.9 mn , consist design servic hardwar softwar licenc .',
#  'scanfil also issu profit warn .',
#  'a spokesman said : `` the food store center , subject council local support , could compris supermarket smaller store nich outlet , firm follow consult council local commun regard appropri use occupi . ``',
#  'the bond valu eur150m matur 4 year .',
#  'millercoor board name gavin hattersley interim ceo',
#  'airbu attempt evacu 873 peopl within 90 second .',
#  'first quarter underli oper profit rose 41 mln eur 33 mln year earlier .',
#  'ep quarter eur0 .00 , compar eur0 .01 third quarter 2008 , repres group net sale third quarter eur15 .3 , 2.8 % compar eur14 .9 third quarter 2008 .',
#  'royal dutch shell profit rise ; dividend 4 %',
#  'meanwhil , electrowatt-ekono philippin , inc. also award three-year oper mainten ( o & m ) contract fr cement corpor .',
#  'the agreement includ applic mainten support servic .',
#  '`` nokia interest bring nokia market . ``',
#  'affecto expect net sale whole 2010 increas 2009 level reach eur 103 million .',
#  'the report profil 158 compani includ mani key nich player includ major nonwoven manufactur ahlstrom corpor , asahi kasei corpor , buckey technolog , inc. , ei .',
#  'the lay-off affect 240 peopl total 320 okmet employe finland .',
#  "`` the acquisit elektro pavara complet kone 's market expans strategi baltic countri .",
#  "18 may 2010 - finnish electron produc elcoteq se hel : elqav said today sign extens cooper agreement industrialis , manufactur , distribut after-market servic mobil phone japan 's sharp tyo : 6753 .",
#  'morrison book second consecut quarter sale growth',
#  'marimekko today ( 20 novemb ) sign licens agreement swedish chain , wherebi marimekko licens popular pattern 1950 , 1960 1970 h & m .',
#  'quick , $ fio 21.35 , market tank , scale long',
#  'the announc push freenet share 6.3 % , eur0 .71 , frankfurt trade eur10 .65 investor gave hope unit internet ag drillisch would pursu takeov breakup freenet .',
#  'finnish telecom softwar develop tecnomen oyj said decemb 5 , 2006 $ 3.3 mln ( 2.5 mln euro ) order suppli expans charg messag system mobil fix network brasil telecom .',
#  'companiesunilev sale lift ice cream soft economi',
#  'ep drop eur0 .2 eur0 .3 .',
#  '@ saltwaternurs $ ino test 10 next day . time take profit . hedg put .',
#  'no financi inform provid .',
#  'easyjet attract passeng june still lag ryanair',
#  "morn agenda : shire 's deal np",
#  "metso suppli equip two process line northland resourc ' new kaunisvaara iron ore project sweden exploit tapuli sahavaara iron ore deposit .",
#  'under agreement biohit becom focu supplier pipettor dispos pipettor tip vwr custom throughout europ .',
#  "the compani 's previou estim lower revenu year-ago eur 93.9 million .",
#  'earn per share ( ep ) drop eur 0.21 eur 0.31 .',
#  'bid offer includ least 1,000 share valu share must correspond least eur4 ,000 .',
#  'earn per share ( ep ) amount loss eur0 .06 .',
#  'netapp downgrad macquari underperform . $ 22.00 pt . http : //t.co/xcngws0t4q $ ntap # ntap via @ ratingsnetwork',
#  "`` russia readi particip open tender lattelecom 's privat .",
#  'technopoli st. petersburg govern sign cooper memorandum octob 2005 set techno-park neudorf product zone villag strelni , st. petersburg suburb .',
#  "the owner particip busi oper compani continu poyri 's employ transact .",
#  "the goal secur compani 's profit competit .",
#  'howev , compani saw net profit third quarter eur 1.4 million eur 1.5 million correspond period 2009 .',
#  "nest oil 's board propos 1.00 eur dividend full-year 2007 , compar 0.90 eur year ago .",
#  'baswar einvoic oy merg parent compani present fiscal period .',
#  '# fintech provid $ cafn cachet financi solut surg forward today post earn up +13.26 % http : //t.co/9bj3csk2i9 $ jkhi $ fisv # momo',
#  "befor kemira 's instal nordalu produc 3,500 ton liquid solid aluminum wast per year .",
#  'he charter account british columbia alberta well certifi public account washington state .',
#  "` veri recommend ' nokian z g2 accord ` adac judgement ' latest summer tyre test german automobil associ adac .",
#  '- the group -¦ result tax loss eur 0.6 ( +0.6 ) million .',
#  '- cash flow oper activ invest eur 0.8 -1.2 million .',
#  'vike line cancel servic .',
#  'exel headquart mantyharju finland .',
#  'stora chief execut jouko karvinen describ russian tariff hike threat futur forest product industri finland .',
#  'after barclay bank america , citigroup blockchain sight',
#  'googl , inc. complet acquisit icoa , inc. http : //stks.co/nfei $ icoa $ goog',
#  "$ tsla look good .. 'd love see base action , let rsi take breather . http : //stks.co/g1t7c",
#  "finnish plumb heat system supplier uponor 's net sale continu oper decreas 9.4 % 2008 eur 949.2 mn eur 1,047.4 mn 2007 .",
#  'thi locat make mall conveni place shop consum three larg residenti area nearbi : jaroszowka , wysockiego zgodi .',
#  'finnish insur compani fennia kesko group end loyal custom cooper .',
#  'the case compris first side case member provid first side vat segment second side case member provid second side vat segment , least first side case member pivot rotat axi .',
#  'finland-bas elcoteq se , privat held provid electron manufactur servic commun compani , said thursday sign long-term manufactur suppli deal commun equip compani andrew corp. .',
#  "in q1 2009 , bank +àland 's net interest incom weaken 10 % eur 9.1 mn .",
#  "rb pay $ 1.7 billion scrap u.k. treasuri 's dividend right",
#  'increas trust client yit seen apart sale acceler .',
#  'talvivaara mine compani plc talvivaara mine compani intern signific base metal produc primari focu nickel zinc use technolog known bioheapleach extract metal ore .',
#  'oper profit 2009 lower outlook publish earlier .',
#  'less ten peopl face pension agreement .',
#  "the compani 's consolid oper profit amount eur 15.86 mn , eur 4.14 mn year-on-year .",
#  'astrazeneca buy zs pharma $ 2.7 billion',
#  'finnish wast manag clean group lassila & tikanoja oyj ( l & t ) net profit went 32.2 mln euro ( $ 47.7 mln ) 2007 35.3 mln euro ( $ 52.3 mln ) 2006 .',
#  'the oper margin aker yard cruis & ferri divis went 8.3 % 6.4 % first quarter 2007 .',
#  'helsinki thomson financi - share cargotec fell sharpli earli afternoon trade cargo handl group post surpris drop april-jun profit , overshadow larg number new order receiv three month .',
#  "the program 's target structur cost reduct eur 30mn 2009 .",
#  'our tool specif design need busi user ict expert mind .',
#  ...]

# %%
#applying count vectorization
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
x=cv.fit(stem_vec)

# %%
import pickle
with open("vectorizer.pickle","wb") as mdl_file:
    pickle.dump(x,mdl_file)

# %%
import pickle
with open("vectorizer.pickle","wb") as mdl_file:
    pickle.dump(x,mdl_file)

# %%
x
# Out:
# CountVectorizer()

# %%
y = df['Sentiment']

# %%
#importing multinomialnb from sklearn(naive_bayes)
from sklearn.naive_bayes import MultinomialNB

# %%
mb=MultinomialNB()

# %%
mb.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\1701910291.py in <module>
# ----> 1 mb.fit(x,y)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     661             Returns the instance itself.
#     662         """
# --> 663         X, y = self._check_X_y(X, y)
#     664         _, n_features = X.shape
#     665
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\naive_bayes.py in _check_X_y(self, X, y, reset)
#     521     def _check_X_y(self, X, y, reset=True):
#     522         """Validate X and y in fit methods."""
# --> 523         return self._validate_data(X, y, accept_sparse="csr", reset=reset)
#     524
#     525     def _update_class_log_prior(self, class_prior=None):
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     759             # If input is scalar raise error
#     760             if array.ndim == 0:
# --> 761                 raise ValueError(
#     762                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#     763                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=CountVectorizer().
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
import pickle
with open("model.pickle","wb") as mdl_file:
    pickle.dump(mb,mdl_file)

# %%
df['Sentence'][3]
# Out:
# 'According to the Finnish-Russian Chamber of Commerce , all the major construction companies of Finland are operating in Russia .'

# %%
x[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\2145826956.py in <module>
# ----> 1 x[3]
#
# TypeError: 'CountVectorizer' object is not subscriptable

# %%
mb.predict([x[2]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\368203094.py in <module>
# ----> 1 mb.predict([x[2]])
#
# TypeError: 'CountVectorizer' object is not subscriptable

# %%
[mb.predict([x[i]]) for i in range(len(x))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\3907060721.py in <module>
# ----> 1 [mb.predict([x[i]]) for i in range(len(x))]
#
# TypeError: object of type 'CountVectorizer' has no len()

# %%
label_map = {1: 'positive', -1: 'negative', 0: 'neutral'}

# %%
X_test = cv.transform(df)  # Convert text to numerical features
predicted_nums = mb.predict(X_test)  # Make predictions
predicted_labels = [label_map[num] for num in predicted_nums]  # Convert to labels

print(predicted_labels)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\2421023725.py in <module>
#       1 X_test = cv.transform(df)  # Convert text to numerical features
# ----> 2 predicted_nums = mb.predict(X_test)  # Make predictions
#       3 predicted_labels = [label_map[num] for num in predicted_nums]  # Convert to labels
#       4
#       5 print(predicted_labels)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      79             Predicted target values for X.
#      80         """
# ---> 81         check_is_fitted(self)
#      82         X = self._check_X(X)
#      83         jll = self._joint_log_likelihood(X)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
predicted_num = mb.predict([x[3]])[0]  # Extract the scalar value

# Convert to text label
predicted_label = label_map[predicted_num]

print(predicted_label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\3151650996.py in <module>
# ----> 1 predicted_num = mb.predict([x[3]])[0]  # Extract the scalar value
#       2
#       3 # Convert to text label
#       4 predicted_label = label_map[predicted_num]
#       5
#
# TypeError: 'CountVectorizer' object is not subscriptable

# %%
for row in x:
    predicted_num = mb.predict([row])[0]  # Predict using the entire row
    predicted_label = label_map[predicted_num]
    print(predicted_label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\526524899.py in <module>
# ----> 1 for row in x:
#       2     predicted_num = mb.predict([row])[0]  # Predict using the entire row
#       3     predicted_label = label_map[predicted_num]
#       4     print(predicted_label)
#
# TypeError: 'CountVectorizer' object is not iterable

# %%
mb.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\2542223458.py in <module>
# ----> 1 mb.score(x,y)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      79             Predicted target values for X.
#      80         """
# ---> 81         check_is_fitted(self)
#      82         X = self._check_X(X)
#      83         jll = self._joint_log_likelihood(X)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
 
z=mb.predict(x)
pd.Series(z).value_counts()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20396\1550410885.py in <module>
# ----> 1 z=mb.predict(x)
#       2 pd.Series(z).value_counts()
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      79             Predicted target values for X.
#      80         """
# ---> 81         check_is_fitted(self)
#      82         X = self._check_X(X)
#      83         jll = self._joint_log_likelihood(X)
#
# c:\Users\varun\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
